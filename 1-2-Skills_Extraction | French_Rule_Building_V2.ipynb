# %%
#spacy
import spacy
from spacy.pipeline import EntityRuler
from spacy.lang.en import English
from spacy.tokens import Doc

#gensim
import gensim
from gensim import corpora

#Visualization
from spacy import displacy
import pyLDAvis.gensim_models
from wordcloud import WordCloud
import plotly.express as px
import matplotlib.pyplot as plt

#Data loading/ Data manipulation
import pandas as pd
import numpy as np
import json
import jsonlines
from collections import Counter
from tqdm.notebook import tqdm

#nltk
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download(['stopwords','wordnet', 'omw-1.4'])

#warning
import warnings 
#from PyPDF2 import PdfFileReader
from os.path import join
from tqdm.notebook import tqdm
tqdm.pandas()

warnings.filterwarnings('ignore')
DATA_FILES = 'data/rules'
PRO_FILES = 'data/source_data/SkillDB'
SKILL_OUT = 'data/transformed_data/extracted_skills'
JO_OUT = 'data/transformed_data/job_offers_out'
# Out:
# 2023-02-09 13:34:23.911708: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-09 13:34:24.454248: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pc/anaconda3/envs/testenv1/lib
# 2023-02-09 13:34:24.454290: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pc/anaconda3/envs/testenv1/lib
# 2023-02-09 13:34:24.454295: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-09 13:34:25.175956: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 13:34:25.176205: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pc/anaconda3/envs/testenv1/lib
# 2023-02-09 13:34:25.176266: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pc/anaconda3/envs/testenv1/lib
# 2023-02-09 13:34:25.176318: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pc/anaconda3/envs/testenv1/lib
# 2023-02-09 13:34:25.176369: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pc/anaconda3/envs/testenv1/lib
# 2023-02-09 13:34:25.176398: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/pc/.local/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/pc/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/pc/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def write_json_lines(file_name,dict_data):
    json_string = json.dumps(dict_data)
    with open(file_name, 'a') as f:
        f.write(json_string+"\n")
        
def read_json_lines(file_name):
    lines = []
    with open(file_name) as file_in:
        for line in file_in:
            lines.append(json.loads(line))
    return lines

# %%
fr_nlp = spacy.load('fr_core_news_sm')  # download model first
en_nlp = spacy.load('en_core_web_sm')
# fr_core_news_sm

# %% [markdown]
# ## Rule Creation for French Skills

# %%
def continued_sequence(tst):
    not_all = True
    prev_len = len(tst)
    new_len = len(tst)
    while not_all:
      for i in range(len(tst)):
          if i < len(tst)-1:
              if (i>1) & (tst[i+1]-tst[i]==1):
                  # print(tst[i])
                  # tst[i] = tst[i+1]
                  del tst[i]
                  not_all = True
                  break
      new_len = len(tst)
      if new_len == prev_len:
          break
      else:
          prev_len = new_len
    return tst

# %%
def get_sent_meta(sent):
    all_sents = []
    old_sent = ''
    for idx, token in enumerate(sent):
        old_sent += ' '+ token.text
        sent_meta = {}
        sent_meta['pos'] = token.pos_
        sent_meta['text'] = token.text
        sent_meta['lemma'] = token.lemma_
        sent_meta['i'] = token.i
        all_sents.append(sent_meta)
    return pd.DataFrame(all_sents)

def get_sub_phrases(sent):
    sent_df = get_sent_meta(sent)
    df_meta_ = sent_df[sent_df['pos'].isin(['NOUN','ADJ'])]
    df_meta_i = continued_sequence(list(df_meta_['i']))
    res = []
    for i in range(len(df_meta_i)):
        if i < len(df_meta_i)-1:
          phrase = ' '.join(list(sent_df[(sent_df['i']>=df_meta_i[i])&(sent_df['i']<=df_meta_i[i+1])]['text']))
          # print(phrase)
          res.append(phrase)
          phrase = ' '.join(list(sent_df[(sent_df['i']>=df_meta_i[i])&(sent_df['i']<=df_meta_i[i+1])]['lemma']))
          # print(phrase)
          res.append(phrase)
    return res

# %%
def segment_skill(sent):
    all_sents = []
    all_sents_rep = []
    old_sent = ''
    old_phrase_sent = ''
    first_noun = False
    first_noun_ = True
    for idx, token in enumerate(sent):
        old_sent += ' '+ token.text
        if first_noun:
            old_phrase_sent += ' '+ token.text
        if (idx == 0) & (token.pos_ == 'VERB'):
            all_sents.append(old_sent.strip())
        elif (token.pos_ == 'NOUN') | (token.pos_ == 'ADJ'):
            first_noun  = True
            if len(old_sent.strip().split())>1:
                all_sents.append(old_sent.strip())
            if first_noun & first_noun_:
                old_phrase_sent += ' '+ token.text
                first_noun_ = False
            if len(old_phrase_sent.strip().split())>1:
                all_sents_rep.append(old_phrase_sent.strip())
    return list(set(all_sents + all_sents_rep))

def segment_skill_rules(sent):
    all_sents = {}
    all_sents_rep = {}
    all_sents_text = []
    all_sents_rep_text = []
    old_sent = ''
    old_phrase_sent = ''
    first_noun = False
    first_noun_ = True
    prev_pos = []
    all_pos = [token.pos_ for token in sent]
    
    for idx, token in enumerate(sent):
        old_sent += ' '+ token.text
        prev_pos.append(token.pos_)
        if first_noun:
            old_phrase_sent += ' '+ token.text
        if (idx == 0) & (token.pos_ == 'VERB'):
            rule_form = {}
            skill = old_sent.strip()
#             rule_form['label'] = 'SKILL'
#             rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
#             all_sents.append(rule_form)
            rule_form = {}
            rule_form['label'] = 'SKILL'
            rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
            first_ = True
            for idx_, token_ in enumerate(sent):
                if idx_> idx:
#                     if first_:
#                         first_ = False
#                         rule_form['pattern'][0].update({'POS':token_.pos_})
#                     else:
                    rule_form['pattern'].append({'POS':token_.pos_})
            all_sents[skill] = rule_form
            all_sents_text.append(skill)
#             all_sents.append(old_sent.strip())
        elif (token.pos_ == 'NOUN') | (token.pos_ == 'ADJ'):
            first_noun  = True
            if len(old_sent.strip().split())>1:
                skill = old_sent.strip()
                rule_form = {}
                rule_form['label'] = 'SKILL'
                rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
                all_sents[skill] = rule_form
                all_sents_text.append(skill)
#                 all_sents.append(rule_form)
            if first_noun & first_noun_:
                old_phrase_sent += ' '+ token.text
                first_noun_ = False
            if len(old_phrase_sent.strip().split())>1:
                skill = old_phrase_sent.strip()
                rule_form = {}
                rule_form['label'] = 'SKILL'
                rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
                all_sents_rep[skill] = rule_form
#                 all_sents_rep.append(rule_form)
                all_sents_rep_text.append(skill)
    all_sents.update(all_sents_rep)
    return all_sents, list(set(all_sents_text + all_sents_rep_text))

def get_rules(skills_file, file_name):
  for ind, row in skills_file.iterrows():
      skill = row['name']
      rule_form = {}
      rule_form['label'] = 'SKILL'
      rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
      write_json_lines(file_name,rule_form)

def get_skill_patterns(skill_name):
    all_skills = []
    skills = fr_nlp(skill_name)
    skills = list(skills.sents)[0]
    print('-'*12)
    rules_, text_ = segment_skill_rules(sent = skills)
    print(rules_)
    print('/'*12)
    print(text_)
    all_skill_pat = get_sub_phrases(skills)
    all_skills += all_skill_pat
    print('-'*12)
    print(all_skill_pat)
    all_skill_pat = segment_skill(skills)
    all_skills += all_skill_pat
    print('-'*12)
    print(all_skill_pat)
    all_skills = list(set(all_skills))
    return all_skills

def get_skill_patterns_v2(skill_name):
    all_rules = {}
    skills = fr_nlp(skill_name)
    skills = list(skills.sents)[0]
    rules_, text_ = segment_skill_rules(sent = skills)
#     print(rules_)
    all_rules.update(rules_)
    all_skill_pat = get_sub_phrases(skills)
    for skill in all_skill_pat:
        rule_form = {}
        rule_form['label'] = 'SKILL'
        rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
        all_rules[skill] = rule_form
    return all_rules

def get_rules_v2(skills_file, file_name):
  pbar = tqdm(total = skills_file.shape[0])
  for ind, row in skills_file.iterrows():
      skills = row['preferredLabel']
      all_skills = get_skill_patterns(skill_name = skills)
      for skill in all_skills:
          rule_form = {}
          rule_form['label'] = 'SKILL'
          rule_form['pattern'] = [{'LOWER':word.lower()} for word in skill.split(' ')]
          # print(rule_form)
          write_json_lines(file_name,rule_form)
      pbar.update()

def get_rules_v3(skills_file, file_name):
  pbar = tqdm(total = skills_file.shape[0])
  for ind, row in skills_file.iterrows():
      skills = row['preferredLabel']
      all_rules = list(get_skill_patterns_v2(skill_name = skills).values())
      for rule_form in all_rules:
          write_json_lines(file_name,rule_form)
      pbar.update()

def get_rules_v4(skills_list, file_name):
  pbar = tqdm(total = len(skills_list))
  for skill in skills_list:
      all_rules = list(get_skill_patterns_v2(skill_name = skill).values())
      for rule_form in all_rules:
          write_json_lines(file_name,rule_form)
      pbar.update()

def unique_skills(x):
    return list(set(x))

# %%
df = pd.read_csv(join(PRO_FILES, 'ESCO_FR', 'skills_fr.csv'))

# %%
get_rules_v3(df, join(DATA_FILES, 'fr_skill_patterns_final.jsonl'))
# Out:
#   0%|          | 0/13896 [00:00<?, ?it/s]

# %%
df

# %%
get_skill_patterns(skill_name = list(df['preferredLabel'])[0])
# Out:
# ------------
# {'gérer': {'label': 'SKILL', 'pattern': [{'LOWER': 'gérer'}, {'POS': 'DET'}, {'POS': 'NOUN'}, {'POS': 'NOUN'}]}, 'gérer le personnel': {'label': 'SKILL', 'pattern': [{'LOWER': 'gérer'}, {'LOWER': 'le'}, {'LOWER': 'personnel'}]}, 'gérer le personnel musical': {'label': 'SKILL', 'pattern': [{'LOWER': 'gérer'}, {'LOWER': 'le'}, {'LOWER': 'personnel'}, {'LOWER': 'musical'}]}, 'personnel musical': {'label': 'SKILL', 'pattern': [{'LOWER': 'personnel'}, {'LOWER': 'musical'}]}}
# ////////////
# ['gérer le personnel', 'gérer le personnel musical', 'gérer', 'personnel musical']
# ------------
# ['personnel musical', 'personnel musical']
# ------------
# ['gérer le personnel', 'gérer le personnel musical', 'gérer', 'personnel musical']
# ['personnel musical',
#  'gérer le personnel musical',
#  'gérer le personnel',
#  'gérer']

# %%
list(get_skill_patterns_v2(skill_name = list(df['preferredLabel'])[0]).values())
# Out:
# {'gérer': {'label': 'SKILL', 'pattern': [{'LOWER': 'gérer'}, {'POS': 'DET'}, {'POS': 'NOUN'}, {'POS': 'NOUN'}]}, 'gérer le personnel': {'label': 'SKILL', 'pattern': [{'LOWER': 'gérer'}, {'LOWER': 'le'}, {'LOWER': 'personnel'}]}, 'gérer le personnel musical': {'label': 'SKILL', 'pattern': [{'LOWER': 'gérer'}, {'LOWER': 'le'}, {'LOWER': 'personnel'}, {'LOWER': 'musical'}]}, 'personnel musical': {'label': 'SKILL', 'pattern': [{'LOWER': 'personnel'}, {'LOWER': 'musical'}]}}
# [{'label': 'SKILL',
#   'pattern': [{'LOWER': 'gérer'},
#    {'POS': 'DET'},
#    {'POS': 'NOUN'},
#    {'POS': 'NOUN'}]},
#  {'label': 'SKILL',
#   'pattern': [{'LOWER': 'gérer'}, {'LOWER': 'le'}, {'LOWER': 'personnel'}]},
#  {'label': 'SKILL',
#   'pattern': [{'LOWER': 'gérer'},
#    {'LOWER': 'le'},
#    {'LOWER': 'personnel'},
#    {'LOWER': 'musical'}]},
#  {'label': 'SKILL', 'pattern': [{'LOWER': 'personnel'}, {'LOWER': 'musical'}]}]

# %%
list(df['preferredLabel'])[0]
# Out:
# 'gérer le personnel musical'

# %%
df
# Out:
#                     conceptType  \
# 0      KnowledgeSkillCompetence
# 1      KnowledgeSkillCompetence
# 2      KnowledgeSkillCompetence
# 3      KnowledgeSkillCompetence
# 4      KnowledgeSkillCompetence
# ...                         ...
# 13891  KnowledgeSkillCompetence
# 13892  KnowledgeSkillCompetence
# 13893  KnowledgeSkillCompetence
# 13894  KnowledgeSkillCompetence
# 13895  KnowledgeSkillCompetence
#
#                                               conceptUri         skillType  \
# 0      http://data.europa.eu/esco/skill/0005c151-5b5a...  skill/competence
# 1      http://data.europa.eu/esco/skill/00064735-8fad...  skill/competence
# 2      http://data.europa.eu/esco/skill/000709ed-2be5...  skill/competence
# 3      http://data.europa.eu/esco/skill/0007bdc2-dd15...  skill/competence
# 4      http://data.europa.eu/esco/skill/00090cc1-1f27...  skill/competence
# ...                                                  ...               ...
# 13891  http://data.europa.eu/esco/skill/ffef5eb3-a15e...  skill/competence
# 13892  http://data.europa.eu/esco/skill/fff0b074-5a76...  skill/competence
# 13893  http://data.europa.eu/esco/skill/fff0e2cd-d0bd...         knowledge
# 13894  http://data.europa.eu/esco/skill/fff5bc45-b506...  skill/competence
# 13895  http://data.europa.eu/esco/skill/fff74a70-4f82...  skill/competence
#
#                 reuseLevel                                     preferredLabel  \
# 0          sector-specific                         gérer le personnel musical
# 1      occupation-specific         superviser des procédures correctionnelles
# 2          sector-specific  appliquer des pratiques de travail social anti...
# 3          sector-specific  contrôler la conformité à la réglementation su...
# 4             cross-sector                  recenser les services disponibles
# ...                    ...                                                ...
# 13891      sector-specific  restaurer les capacités professionnelles d’un ...
# 13892      sector-specific  installer l’éclairage dans des engins de trans...
# 13893      sector-specific          traitement automatique du langage naturel
# 13894         cross-sector             coordonner des travaux de construction
# 13895         cross-sector            placer des garde-corps et des bastaings
#
#                                                altLabels hiddenLabels  \
# 0                                                    NaN          NaN
# 1                                                    NaN          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN          NaN
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 13891                                                NaN          NaN
# 13892                                                NaN          NaN
# 13893  traitement automatique des langages naturels\n...          NaN
# 13894                                                NaN          NaN
# 13895             placer des garde-corps et des bastings          NaN
#
#          status              modifiedDate  scopeNote  definition  \
# 0      released      2016-12-20T17:43:43Z        NaN         NaN
# 1      released      2016-12-20T20:17:49Z        NaN         NaN
# 2      released      2016-12-20T19:18:19Z        NaN         NaN
# 3      released      2016-12-20T20:02:19Z        NaN         NaN
# 4      released      2016-12-20T20:15:17Z        NaN         NaN
# ...         ...                       ...        ...         ...
# 13891  released      2016-12-20T19:25:53Z        NaN         NaN
# 13892  released      2016-12-20T20:03:21Z        NaN         NaN
# 13893  released  2022-07-05T14:34:09.904Z        NaN         NaN
# 13894  released      2016-12-20T18:22:35Z        NaN         NaN
# 13895  released      2016-12-20T18:24:23Z        NaN         NaN
#
#                                                 inScheme  \
# 0      http://data.europa.eu/esco/concept-scheme/skil...
# 1      http://data.europa.eu/esco/concept-scheme/memb...
# 2      http://data.europa.eu/esco/concept-scheme/skil...
# 3      http://data.europa.eu/esco/concept-scheme/skil...
# 4      http://data.europa.eu/esco/concept-scheme/memb...
# ...                                                  ...
# 13891  http://data.europa.eu/esco/concept-scheme/memb...
# 13892  http://data.europa.eu/esco/concept-scheme/skil...
# 13893  http://data.europa.eu/esco/concept-scheme/skil...
# 13894  http://data.europa.eu/esco/concept-scheme/skil...
# 13895  http://data.europa.eu/esco/concept-scheme/skil...
#
#                                              description
# 0      Attribuer et gérer les tâches du personnel dan...
# 1      Superviser les opérations d’un établissement c...
# 2      Identifier l’oppression dans les sociétés, les...
# 3      Inspecter le matériel roulant, les composants ...
# 4      Identifier les différents services disponibles...
# ...                                                  ...
# 13891  Restaurer ou améliorer les composantes cogniti...
# 13892  Installer des éléments d’éclairage dans des éq...
# 13893  Les technologies qui permettent aux dispositif...
# 13894  Coordonner les travaux de plusieurs ouvriers o...
# 13895  Fixer des garde-corps et des bastaings aux éch...
#
# [13896 rows x 13 columns]

# %%
gg = read_json_lines(join(DATA_FILES, 'fr_skill_patterns_final.jsonl'))

# %%
len(gg)
# Out:
# 77862

# %% [markdown]
# ### New Rules

# %%
def split_skills(skill_concat):
    if isinstance(skill_concat, str):
        skill_list = re.split("(?=,[A-Z])", skill_concat)
        skill_list = [i for i in skill_list if len(i)>0]
#         skill_list = [(i[:-1] if (i[-1]==',') else i).lower() for i in skill_list]
        skill_list = [(i[1:] if (i[0]==',') else i).lower() for i in skill_list]
        return skill_list
    else:
        return ['']
def get_all_pole_emploi_skills():
#     savoir_faire_base 	savoirs_base 	savoir_faire_specifiques 	savoirs_specifiques
    all_skills = []
    df = pd.read_csv(join(PRO_FILES, 'pole_emploi_complete.csv'))
    all_skills += sum([split_skills(i) for i in list(df['savoir_faire_base'])],[])
    all_skills += sum([split_skills(i) for i in list(df['savoirs_base'])],[])
    all_skills += sum([split_skills(i)  for i in list(df['savoir_faire_specifiques'])],[])
    all_skills += sum([split_skills(i)  for i in list(df['savoirs_specifiques'])],[])
    
    all_skills = [i.strip().lower() for i in all_skills if len(i)>0]
    return list(set(all_skills))

# %%
df = pd.read_csv(join(PRO_FILES, 'pole_emploi_complete.csv'))

# %%
list(df['savoir_faire_base'])
# Out:
# ["Préparer le matériel, les matériaux et les outillages,Identifier le type d'intervention,Sécuriser un équipement,Atteler un équipement,Conduire les engins agricoles vers le lieu de production (champs, forêt), de stockage, de livraison (fermes, coopératives),Matérialiser une implantation de parcelle ou de passage,Approvisionner des engins d'exploitation,Réaliser une opération de maintenance",
#  "Recenser les arbres à couper ou élaguer,Déterminer l'abattage ou l'élagage selon la trajectoire de chute des arbres en prenant en compte l'environnement et les conditions climatiques,Organiser l'abattage d'un arbre ou d'une branche,Réaliser l'abattage des arbres désignés (positionnement des coins, tronçonnage de la base, ...) selon la trajectoire de chute voulue,Elaguer les branches d'un arbre,Tailler les arbres selon l'orientation de croissance ou la forme recherchée et supprimer les branches indésirables,Débiter un arbre selon son usage,Entretenir des équipements,Assurer une maintenance de premier niveau,Réaliser un suivi d'activité",
#  "Préparer le matériel, les matériaux et les outillages,Identifier le type d'intervention,Entretenir un espace extérieur,Collecter des déchets,Assurer une maintenance de premier niveau,Entretenir des équipements,Installer un élément de protection d'espace naturel,Préparer les sols et les plantations (épandage, semis, récolte, ...)",
#  "Sécuriser le chantier et son environnement (signalisation, ...),Préparer les sols et les plantations (épandage, semis, récolte, ...),Entretenir un élément de décoration,Entretenir un espace extérieur,Tailler les arbres selon l'orientation de croissance ou la forme recherchée et supprimer les branches indésirables,Assurer une maintenance de premier niveau,Entretenir des équipements",
#  "Etudier les évolutions de la faune et de la flore dans les milieux naturels,Surveiller un espace naturel pour la prévention des risques d'accidents, de pollution, d'incendie,Diagnostiquer l'état d'un site et définir les priorités d'action au sein des milieux inventoriés,Déployer les directives du ministère et des collectivités pour la protection et la valorisation des milieux naturels par réintroduction d'espèces, restauration de plages ...,Établir un rapport d'intervention,Etablir un rapport d'étude,Sensibiliser tous les publics à la protection et la sauvegarde du patrimoine naturel,Apporter une assistance technique",
#  "Préparer le matériel, les matériaux et les outillages,Identifier le type d'intervention,Planter un arbre ou un cep (arrachage, greffe, palissage, ...),Installer un élément de protection sur une plantation,Installer un tuteur de croissance,Contrôler l'état d'une plantation,Débroussailler une plantation et ses chemins d'accès,Tailler les arbres selon l'orientation de croissance ou la forme recherchée et supprimer les branches indésirables,Identifier la cause d'une anomalie,Surveiller l'état sanitaire d'un arbre,Classer les arbres d'un site d'exploitation,Recenser les arbres d'un site d'exploitation,Assurer une maintenance de premier niveau,Entretenir des équipements",
#  "Déterminer des besoins en financement,Analyser les résultats d'une expérimentation,Mettre en place des actions correctives et préventives,Identifier une anomalie de réaction ou développement d'une exploitation agricole,Concevoir un plan d'action de projet,Planifier les étapes d'un projet,Concevoir les solutions technico-économiques (reprise d'exploitation, reconversion, ...) adaptées aux problématiques d'un site de production (environnement, pollution, rendements, ...),Etablir un compte rendu d'analyse,Concevoir des procédures de tests",
#  "Identifier les priorités d'intervention (contrôles, relevés, ...) en fonction de la planification annuelle et déterminer le matériel approprié,Repérer et signaler des anomalies,Contrôler l'état des stocks,Repérer une irrégularité dans un registre,Vérifier le contenu d'un registre de suivi de production ou d'élevage,Relever les données de performance individuelle des animaux (quantité et qualité du lait, prise de poids, ...),Prélever des échantillons de matières ou de produits, les référencer et les enregistrer pour analyse,Accompagner la mise en oeuvre d'actions préventives et curatives,Préconiser des actions préventives ou curatives,Transmettre un rapport d'inspection et de contrôle aux services concernés,Etablir un rapport d'inspection et de contrôle,Assister techniquement un professionnel",
#  "Identifier les thèmes de projets de recherche en fonction des évolutions du secteur,Définir un avant-projet,Définir la faisabilité et la rentabilité d'un projet,Planifier les étapes d'un projet,Déterminer des protocoles d'expérimentation,Assister techniquement une collectivité, un industriel,Mener des études et expérimentations à des fins d'innovation,Communiquer un diagnostic sur des risques environnementaux ou sanitaires aux élus, institutionnels, organismes et leur apporter un appui technique,Suivre la mise en oeuvre d'actions de prévention des risques,Préconiser des mesures environnementales,Etablir un rapport d'étude,Etablir un rapport de recherche",
#  "Conditionner un produit selon les caractéristiques et les modes de transport,Identifier un lieu d'intervention,Identifier le type d'intervention,Entretenir une plantation,Récolter un produit agricole,Entretenir un outil ou matériel,Réaliser l'entretien du matériel",
#  "Identifier un lieu d'intervention,Identifier le type d'intervention,Entretenir une plantation,Récolter un produit agricole,Conditionner un produit,Entretenir un outil ou matériel,Réaliser l'entretien du matériel",
#  "Déterminer les rations alimentaires selon les besoins physiques et physiologiques des animaux,Regrouper des animaux,Récolter le produit d'un élevage,Entretenir des locaux,Désinfecter et décontaminer un équipement,Entretenir les éléments de structure d'un bâtiment (clôtures, zone de stockage, /...)",
#  "Identifier un lieu d'intervention,Préparer le matériel adapté,Identifier un animal malade et informer les acteurs concernés (vétérinaire, /...),Proposer un traitement adapté,Installer des dispositifs de prévention,Repérer la présence de nuisibles et constater la nature et l'étendue des dégâts,Récolter le produit d'un élevage,Préparer un produit au conditionnement,Conditionner un produit,Entretenir des équipements,Assurer une maintenance de premier niveau",
#  "Identifier le type d'intervention,Préparer le matériel, les matériaux et les outillages,Planter un arbre ou un cep (arrachage, greffe, palissage, ...),Installer un dispositif d'irrigation sur une plantation,Installer un élément de protection sur une plantation,Réaliser l'entretien et les soins d'un arbre ou d'un cep,Appliquer des produits phytosanitaires,Surveiller le développement d'un fruit ou un légume,Récolter un produit à maturité selon les consignes de calibrage,Entretenir des équipements,Assurer une maintenance de premier niveau",
#  "Planifier les pêches selon la saison et les conditions météorologiques,Définir la route du navire et les paramètres sur les instruments de pilotage et de contrôle,Coordonner l'activité d'un équipage de pêche,Surveiller la route du bateau, identifier les écarts et ajuster les paramètres de navigation,Réaliser ou contrôler les manoeuvres du navire et les opérations de pêche,Sécuriser l'embarcation (contrôle des équipements, identification des risques d'avarie) et mettre en oeuvre des moyens palliatifs,Contrôler un équipement ou matériel,Planifier des interventions de maintenance,Réceptionner un produit",
#  "Identifier un animal par marquage,Vérifier les origines géographiques ou génétiques d'un animal,Surveiller l'état de gestation d'un animal,Identifier un animal malade et informer les acteurs concernés (vétérinaire, /...),Dispenser les soins préventifs ou curatifs aux animaux,Déterminer les rations alimentaires selon les besoins physiques et physiologiques des animaux,Renseigner un registre d'élevage,Désinfecter et décontaminer un équipement,Entretenir des locaux,Entretenir des équipements,Assurer une maintenance de premier niveau",
#  "Vérifier les origines géographiques ou génétiques d'un animal,Consigner des données dans un registre,Identifier un animal par marquage,Proposer un traitement adapté,Identifier un animal malade et informer les acteurs concernés (vétérinaire, /...),Déterminer les rations alimentaires selon les besoins physiques et physiologiques des animaux,Réaliser les opérations de reproduction des animaux d'un élevage,Aménager un lieu pour des animaux d'élevage,Entretenir des locaux,Désinfecter et décontaminer un équipement,Vérifier l'état de fonctionnement des équipements (chaudière, système d'extraction d'air, ...) et réaliser la maintenance de premier niveau des installations,Réaliser un suivi d'activité,Construire une caisse de mise bas",
#  "Vérifier les origines géographiques ou génétiques d'un animal,Administrer des produits vétérinaires,Identifier les animaux par bague,Contrôler le fonctionnement d'un outil ou équipement,Répartir les animaux dans des locaux d'élevage ou en plein air,Effectuer ou planifier des vaccinations, castrations sur des lapins/volailles,Evaluer l'état de santé d'un animal et informer les acteurs concernés (vétérinaire, /...),Préparer les aliments et les distribuer aux animaux,Renseigner un registre d'élevage,Entretenir des locaux,Désinfecter et décontaminer un équipement,Assurer une maintenance de premier niveau,Entretenir des équipements,Construire une caisse de mise bas",
#  "Identifier un animal par marquage,Vérifier les origines géographiques ou génétiques d'un animal,Identifier un animal malade et informer les acteurs concernés (vétérinaire, /...),Proposer un traitement adapté,Dispenser les soins préventifs ou curatifs aux animaux,Déterminer les rations alimentaires selon les besoins physiques et physiologiques des animaux,Répartir les animaux dans des locaux d'élevage ou en plein air,Désinfecter et décontaminer un équipement,Entretenir des locaux,Entretenir des équipements,Assurer une maintenance de premier niveau,Renseigner un registre d'élevage,Construire une caisse de mise bas",
#  "Vérifier les origines géographiques ou génétiques d'un animal,Identifier un animal par marquage,Prélever les semences des verrats et les analyser en laboratoire,Conditionner des doses de semence en fonction du planning de reproduction,Réaliser la reproduction artificielle d'une espèce animale,Dispenser les soins préventifs ou curatifs aux animaux,Etablir un diagnostic de gestation et de santé,Assister les animaux lors des mises bas et prodiguer les premiers soins aux nouveau-nés,Préparer un porcelet à l'élevage,Déterminer les rations alimentaires selon les besoins physiques et physiologiques des animaux,Renseigner un registre d'élevage",
#  "Procéder au caillage du lait après sa mise en cuve,Confectionner et affiner un fromage,Réaliser le moulage d'un fromage,Contrôler l'affinage d'un fromage,Entreposer des produits,Conditionner un produit,Entretenir des locaux,Entretenir une machine ou un équipement",
#  "Conditionner des produits avant une opération de fermentation,Effectuer et suivre les étapes d'élaboration d'un alcool,Ajuster le dosage des ingrédients d'un alcool,Soutirer un produit après fermentation,Réaliser la mise en fûts ou en bouteilles, le bouchage, l'étiquetage du vin, du cidre, de la bière, ...,Entretenir une machine ou un équipement,Entretenir des locaux",
#  "Identifier le type d'intervention,Préparer le matériel, les matériaux et les outillages,Surveiller l'état d'une plantation,Entretenir une plantation,Récolter un produit agricole,Entretenir des équipements,Assurer une maintenance de premier niveau,Préparer les sols et les plantations (épandage, semis, récolte, ...)",
#  "Préparer le poisson pour la conservation,Déployer un outil de pêche,Trier des produits de la pêche,Remonter un filet de pêche,Conditionner un produit alimentaire,Vérifier l'état du matériel de pêche,Réparer du matériel de pêche,Réaliser une opération de maintenance,Surveiller l'état de l'embarcation pendant la navigation, détecter les anomalies (avaries, ...) et en informer le maître d'équipage ou l'officier de quart,Effectuer les manoeuvres d'accostage ou d'appareillage du bateau,Réaliser le remaillage d'un filet",
#  "Sécuriser un équipement,Atteler un équipement,Suivre l'approvisionnement,Régler les paramètres des machines et des équipements,Récolter un produit à maturité selon les consignes de calibrage,Réaliser une opération de maintenance,Préparer les sols et les plantations (épandage, semis, récolte, ...),Appliquer des produits phytosanitaires",
#  "Contrôler le niveau d'eau de salines,Ajuster le niveau d'un plan d'eau,Immerger des salines,Réaliser un prélèvement,Réaliser un test de contrôle de salinité,Réparer des dégâts d'origine naturelle,Réaliser une opération de maintenance,Récolter la fleur de sel ou le sel,Réaliser un suivi d'activité,Entretenir des équipements,Assurer une maintenance de premier niveau",
#  "Identifier le motif de consultation et son degré d'urgence et informer le client sur les modalités de prise en charge de l'animal,Préparer et installer l'animal (désinfection, rasage, mise en cage, ...),Préparer le matériel et apporter une aide technique au vétérinaire, à l'éleveur, ...,Conseiller sur l'alimentation, les soins, la médication de l'animal ou procéder à la vente de médicaments, d'apports nutritionnels,Entretenir un poste de travail,Désinfecter et décontaminer un équipement,Détruire des déchets",
#  "Identifier avec le client le type d'intervention (ferrage traditionnel, orthopédique, ...) et en définir les modalités (coût, date de rendez-vous, ...),Repérer les affections du pied de l'animal (boiterie, douleur, abcès, ...) et procéder à son immobilisation pour l'intervention,Parer le pied d'un animal,Sélectionner le fer en fonction de la mobilité, de l'effort et de la morphologie de l'animal et le former d'après l'empreinte,Ferrer un animal,Informer et conseiller sur le type de ferrure, les produits de soin, le besoin de consultation vétérinaire (prescription de médicaments, ...)",
#  "Identifier la demande (toilettage saisonnier, traitement anti-parasitaire, ...) du propriétaire de l'animal et planifier l'intervention,Vérifier l'aspect de l'animal et orienter si nécessaire le propriétaire vers un vétérinaire, un éducateur canin, ...,Sélectionner le matériel et les produits et préparer l'animal au toilettage par désinfection, douche, ...,Procéder aux soins de toilettage des animaux,Conseiller le client sur les articles destinés aux animaux et procéder à la vente,Renseigner le dossier de suivi de l'animal et proposer des soins ultérieurs,Détruire des déchets,Désinfecter et décontaminer un équipement,Entretenir un poste de travail",
#  "Identifier la demande de l'interlocuteur (propriétaire de l'animal, éleveur, soigneur, ...) et déterminer les modalités d'intervention (soin sur place, transfert, ...),Recueillir les informations sur l'animal (troubles, comportement, antécédents, traitements en cours, ...) auprès de son accompagnant ou dans le dossier médical,Procéder à l'examen clinique de l'animal et déterminer les besoins thérapeutiques (médication, intervention chirurgicale, ...),Informer le responsable de l'animal sur la prise en charge thérapeutique (traitement, risques, coût, durée, ...) ou l'orienter vers un service spécialisé (centre hospitalier vétérinaire, ...),Réaliser les soins sur l'animal ou procéder à des examens complémentaires (radiographie, prélèvements biologiques, ...),Réaliser l'intervention chirurgicale de l'animal et effectuer la surveillance post-opératoire,Conseiller sur l'alimentation, les soins, la médication de l'animal ou procéder à la vente de médicaments, d'apports nutritionnels,Réaliser une déclaration réglementaire,Réaliser le suivi des règlements clients,Renseigner des documents médico-administratifs,Evaluer le degré de la douleur de l'animal",
#  "Imaginer une oeuvre artistique/plastique avec ou sans cadre imposé,Recueillir les informations préalables à la création d'une oeuvre artistique,Déterminer les contraintes techniques de l'oeuvre liées aux caractéristiques des matériaux, aux conditions d'exposition, aux normes de sécurité,Sélectionner des matières et matériaux,Définir les étapes d'exécution d'une oeuvre,Réaliser l'esquisse ou le croquis d'une oeuvre, d'un ouvrage,Créer une oeuvre artistique,Réaliser les finitions d'un ouvrage,Réaliser une structure de présentation de l'ouvrage,Commercialiser une oeuvre,Réaliser des actions de promotion",
#  "Définir les étapes d'intervention pour le façonnage ou la décoration d'un objet,Sélectionner des matières et matériaux,Composer des poudres, des pâtes plastiques ou liquides,Façonner une pâte céramique,Façonner une pâte en matériaux de synthèse,Assembler les parties constitutives d'un ouvrage,Appliquer des motifs, des revêtements de surface sur des objets d'art et artisanaux,Contrôler la conformité d'un produit,Enregistrer la vente d'un article,Conditionner un produit",
#  "Repérer les tendances et les ambiances de décoration,Concevoir un projet d'aménagement d'espace de vente,Concevoir des vitrines,Disposer des produits sur le lieu de vente,Mettre en place la signalétique d'un espace de vente,Agencer un espace de vente,Etablir une commande,Définir des besoins en approvisionnement,Suivre l'état des stocks",
#  "Définir les étapes d'intervention pour le façonnage ou la décoration d'un objet,Nettoyer une surface à décorer ou à recouvrir,Démonter un objet,Tracer des décors,Reproduire à la main un motif sur un article,Appliquer manuellement un produit, un traitement,Réaliser une opération de polissage de surface,Procéder à une opération de ponçage,Procéder à une opération de cirage,Monter des pièces de décorations, ornementations,Conditionner un produit,Enregistrer la vente d'un article",
#  "Définir les besoins d'un client,Déterminer les conditions de réalisation d'un projet,Reproduire à la main un motif sur un article,Affûter des outils,Sélectionner des matériels, matériaux et outillages,Procéder à des opérations d'estampage, d'incision ou d'enlèvement de matière sur un article,Réaliser les finitions d'un ouvrage",
#  "Préparer la matière première en vue d'une production,Assouplir des matériaux d'origine végétale,Couper à dimension une toile ou un tissu,Contrôler la conformité d'aspect d'un produit,Monter des articles de vannerie,Terminer l'ouvrage par rabattage des tiges d'osier, le serrage des lignes torsadées, insérer les éléments de renforts et effectuer les opérations de ponçage, vernis,Conditionner un produit,Enregistrer la vente d'un article,Définir un avant-projet,Déterminer les conditions de réalisation d'un projet",
#  "Restaurer des documents,Maintenir en état la couverture et les pages d'un ouvrage,Mettre en place des pages de gardes et de couvertures,Réparer des fonds de cahiers,Réaliser une plaçure par démontage d'un ouvrage,Constituer le corps d'ouvrage,Habiller des cartons de couverture,Fixer des cartons de couverture,Mettre en place une coiffe et des nerfs d'une couverture,Couvrir par découpe de gabarit",
#  "Etudier une demande client,Conseiller un client,Définir les étapes d'intervention pour le façonnage ou la décoration d'un objet,Sélectionner les matériaux et accessoires,Constituer un stock de matières et fournitures,Assembler les parties constitutives d'un intrument de musique,Façonner les parties d'un instrument de musique,Régler la sonorité d'un instrument de musique,Réparer un instrument de musique,Entretenir un instrument de musique",
#  "Conseiller une clientèle ou un public,Réaliser un croquis, un dessin de pièce,Relever les mesures de pièces ou de leur implantation,Constituer le stock de matières premières et de consommables,Reporter des cotes,Tracer des développés,Débiter de la matière métallique,Dimensionner du métal,Assembler les différentes pièces d'un ouvrage,Réaliser les finitions d'un ouvrage,Poser des ouvrages de métallerie sur un chantier",
#  "Vérifier la faisabilité de la commande (dimensions de la pièce en verre, aspect esthétique, ...), définir et arrêter avec le client les conditions de réalisation (délais, coût, ...),Définir les étapes d'intervention pour le façonnage ou la décoration d'un objet,Préparer le matériel, les matériaux et les outillages,Souffler le verre pour le mettre en forme (soufflage, étirement, torsion, ...) et veiller au maintien de sa température (arche de recuisson, fours de réchauffe, ...),Contrôler la conformité d'aspect d'un produit,Enregistrer la vente d'un article,Consigner des données d'activité",
#  "Etudier une demande client,Conseiller un client,Détecter les défauts, nuances, alliage des matériaux et déterminer les contraintes de la pièce,Définir l'éxécution d'un ouvrage,Sélectionner les métaux, accessoires, produits, outils,Mettre en forme un sous-ensemble,Monter une plaque de métal, une pierre taillée sur une article de bijouterie,Réaliser les finitions d'un ouvrage,Décorer des pièces ou des articles,Contrôler la conformité d'une réalisation,Authentifier un produit de joaillerie,Consigner des données d'activité,Conclure une vente",
#  "Réaliser un diagnostic à partir de dysfonctionnements constatés,Evaluer les coûts d'une prestation,Contrôler l'état et la qualité d'une pièce ou d'une série,Constituer un stock de matières et fournitures,Remplacer les pièces défectueuses par échange standard (mouvement quartz, aiguilles, cadrans, ...) et assembler les éléments,Régler la précision d'un mouvement horloger,Contrôler la qualité d'un système mécanique,Consigner des données d'activité",
#  "Réceptionner des pièces animales,Vérifier la faisabilité de la naturalisation,Conseiller un client,Déplacer des produits vers la zone de stockage,Etiqueter un produit,Dépouiller un animal,Entretenir des animaux naturalisés,Réaliser un mannequin pour la restauration d'un animal,Habiller le mannequin (positionnement et tension de la peau, couture, ...),Réaliser les finitions d'un ouvrage,Réaliser une structure de présentation de l'ouvrage,Réaliser une sculpture",
#  "Définir avec le client les caractéristiques de l'article à réaliser selon ses souhaits, ses besoins et l'informer sur les conditions de réalisation,Concevoir un patron selon l'article (mensurations, proportions),Couper les matières du chapeau,Monter les différentes pièces d'un chapeau,Monter des éléments de garniture,Lustrer un chapeau,Conditionner un produit,Enregistrer la vente d'un article",
#  "Définir avec le client les caractéristiques de l'article à réaliser selon ses souhaits, ses besoins et l'informer sur les conditions de réalisation,Réaliser manuellement un gabarit, patron,Sélectionner les matériaux, produits et accessoires de l'article,Réaliser les opérations de coupe de matériaux (positionnement de gabarit, ...) manuellement ou à l'aide d'une machine,Assembler (collage, couture) les pièces de l'article (tige, soufflet) manuellement ou à l'aide d'une machine,Réaliser les opérations de finition sur les pièces et articles montés (coupe de fil, teinte de tranche, nourriture du cuir, ...),Vérifier la conformité des pièces/articles façonnés (aspect de teinte, régularité des coutures, ...) et procéder aux actions correctives",
#  "Définir avec le client les caractéristiques de l'article à réaliser selon ses souhaits, ses besoins et l'informer sur les conditions de réalisation,Prendre les mensurations du client et les consigner (fiche client),Concevoir un patron de base,Modifier un patron existant,Marquer un repère sur une toile ou un tissu,Couper à dimension une toile ou un tissu,Ajuster les pièces du vêtement (manches, col) par essayage,Assembler les différentes parties d'un vêtement,Ajuster un vêtement,Vérifier le montage d'une pièce vestimentaire,Conditionner un produit,Conseiller une clientèle ou un public",
#  "Définir un avant-projet,Déterminer les conditions de réalisation d'un projet,Sélectionner les matériaux (tissus, fils, ornements, ...), coloris et outils appropriés à l'ouvrage,Façonner un ouvrage,Monter un métier à tisser ou à rentrayer,Réaliser des ornementations sur un tissu,Reporter des dessins, motifs sur un tissu,Terminer l'ouvrage du métier, réaliser les opérations de finition (tonte, apprêt, repassage) et d'emballage",
#  "Repérer des tendances de mode,Collecter des échantillons de produit, photos etc.,Concevoir un plan de collection selon le style de la marque et les thèmes définis,Définir les couleurs d'une nouvelle collection,Réaliser l'esquisse ou le croquis d'une oeuvre, d'un ouvrage,Définir la composition d'un vêtement,Evaluer la conformité artistique et technique de modèles, prototypes,Sélectionner les matières et fournitures (fil, tissu, fermoirs, ...) de la gamme de produits,Evaluer le coût d'un produit,Réaliser un catalogue de modèle,Expliciter une collection à divers intervenants,Enrichir une base de données",
#  "Déterminer les conditions de réfection ou de réalisation de l'article (siège, tenture, ...) ou d'un ensemble d'ameublement selon l'état, le style de mobilier, le délai, le coût des matériaux,Présenter les caractéristiques de matériaux de revêtement, de garnissage et de décoration,Mesurer les murs, fenêtres, carcasses et déterminer les quantités de matériaux et accessoires nécessaires,Dégarnir un siège, matelas ou support mural,Positionner une toile sur l'assise,Marquer un repère sur une toile ou un tissu,Couper à dimension une toile ou un tissu,Positionner un patron/gabarit sur le tissu,Réaliser l'enveloppe ou le support d'une assise,Réaliser des opérations de mise en volume et garnissage d'article,Orner des revêtements muraux, paravents etc.,Recouvrir un article ou un support mural d'un revêtement de décoration,Poser les éléments d'ornement ou de fixation",
#  "Analyser les données du secteur de l'assurance,Identifier les besoins d'un client,Proposer des axes de développement de produits,Définir la cible, les tarifs et garanties de nouveaux produits et organiser le plan de lancement,Elaborer le plan média de mise sur le marché d'un produit,Concevoir des campagnes publicitaires,Analyser les résultats des ventes,Déterminer des mesures correctives,Assister techniquement des collaborateurs",
#  "Définir les besoins en assurance d'un client,Proposer un service, produit adapté à la demande client,Développer un portefeuille clients et prospects,Rassembler les justificatifs et transmettre la proposition d'assurance pour décision,Rédiger un contrat d'assurance,Traiter l'information (collecter, classer et mettre à jour)",
#  "Mettre en place des actions commerciales,Expertiser des biens,Evaluer les biens mobiliers et immobiliers d'un client,Evaluer des risques de sinistre,Concevoir une proposition de contrat,Présenter les clauses d'un contrat,Vérifier la conformité d'une déclaration de sinistre,Evaluer les responsabilités des parties prenantes,Mettre en oeuvre une procédure d'expertise de sinistre,Réaliser le suivi des dossiers clients et prospects,Actualiser un contrat,Assister techniquement des collaborateurs",
#  "Définir une stratégie commerciale,Suivre des indicateurs,Déterminer des mesures correctives,Contrôler les procédures de traitement des contrats, des sinistres,Proposer des axes d'amélioration,Assurer la qualité des souscriptions en assurance,Mettre en place des actions correctives et préventives,Développer un réseau de partenaires,Réaliser une gestion administrative,Réaliser une gestion comptable",
#  "Développer des modèles mathématiques pour la création de produits d'assurance ou d'épargne,Définir des tarifs et garanties de produits d'assurance ou d'épargne,Réaliser des calculs de rentabilité de produits d'assurance ou d'épargne,Réaliser l'inventaire d'un portefeuille de contrats,Contrôler l'engagement monétaire d'une entreprise par contrat d'assurance,Calculer l'engagement monétaire d'une entreprise par contrat d'assurance,Elaborer un compte de résultat,Evaluer l'impact financier d'une opération sur les résultats d'une entreprise,Proposer des axes d'amélioration de gestion d'une entreprise",
#  "Prospecter des entreprises, des institutionnels ou des collectivités territoriales,Définir les besoins en assurance d'un client,Répertorier des biens physiques, des installations,Recenser les moyens de protection/prévention des risques sur site,Élaborer une cartographie des risques,Estimer le montant des pertes en cas de sinistre sur un site,Diagnostiquer la nature des risques sur un site,Apporter une assistance à la maîtrise d'oeuvre,Assister la mise en place d'actions de prévention des risques,Elaborer un scénario de sinistre (Sinistre maximum possible)",
#  "Vérifier les garanties souscrites dans le cas d'un sinistre,Constater les dommages, dégâts, pertes sur les lieux du sinistre et auprès des assurés,Recueillir les preuves, témoignages et rapports de police auprès des parties impliquées dans le sinistre (victimes, témoins, services de secours, ...),Analyser l'origine, la cause et les circonstances d'un sinistre,Définir les responsabilités respectives des parties dans le cadre d'un sinistre,Evaluer le montant des préjudices (corporels, moraux, économiques, ...,Etablir un rapport de suivi de sinistre,Déployer les procédures d'indemnisation des assurés, victimes,Expertiser des dommages corporels, matériels et moraux",
#  "Piloter un département ou un service en assurances,Mettre en place une procédure de traitement des dossiers (délais, réglementation, ...),Concevoir des outils de suivi qualitatif et quantitatif de l'activité,Déterminer des mesures correctives,Evaluer des risques pour une souscription,Constater des sinistres sur le terrain,Réaliser une gestion administrative,Recueillir et traiter les réclamations d'usagers, clients, résidents, ...,Apporter une assistance technique",
#  "Etudier une demande client,Proposer un service, produit adapté à la demande client,Rédiger un contrat d'assurance,Conseiller un client en matière de gestion d'assurance,Transmettre des documents contractuels à des clients,Mettre à jour les fichier des assurés et tiers,Recueillir les informations et documents des clients,Expertiser des dommages corporels, matériels et moraux",
#  "Vérifier les garanties souscrites dans le cas d'un sinistre,Evaluer des risques de sinistre,Evaluer un sinistre,Définir des modalités de souscription,Assister techniquement des collaborateurs,Négocier un contrat,Actualiser un contrat,Concevoir des supports d'information et de communication,Définir les besoins en assurance d'un client,Elaborer un scénario de sinistre (Sinistre maximum possible)",
#  "Accueillir une clientèle,Sensibiliser les clients à l'utilisation des automates et des services à distance,Etudier une demande client,Enregistrer des opérations comptables,Enregistrer les mouvements d'un portefeuille boursier,Conseiller un client en matière de gestion d'assurance,Actualiser les informations mises à la disposition d'un public,Classer des documents professionnels",
#  "Analyser la recevabilité d'une demande de crédit,Collecter des données clients,Analyser la situation financière d'un client,Evaluer la solvabilité d'un créditeur et les risques,Vérifier la rentabilité d'un crédit pour une banque,Emettre un avis / une décision argumentés en fonction de la délégation en charge et élaborer la note de synthèse,Déterminer des mesures correctives,Réaliser le suivi de comptes clients,Apporter une expertise technique,Animer une formation",
#  "Réaliser un entretien commercial,Identifier les besoins d'un client,Proposer une offre commerciale adaptée,Proposer des services de gestion comptable,Arrêter une décision de demande de crédit,Rendre une décision sur une demande de crédit,Analyser les causes des difficultés de trésorerie,Déterminer des mesures correctives,Développer un portefeuille clients et prospects,Rédiger des documents de synthèse,Rédiger un rapport de performance",
#  "Identifier les besoins d'un client,Suivre l'évolution d'un produit financier en fonction du marché bancaire,Définir les caractéristiques d'un produit,Etudier la faisabilité économique et technique d'un produit sur le marché bancaire,Concevoir un planning de lancement d'un produit financier,Organiser des visites, prospections ou phoning,Concevoir des supports d'information et de communication,Proposer des ajustements suite aux résultats des ventes,Analyser les résultats des ventes,Assister techniquement des collaborateurs",
#  "Consulter des fichiers clients en préparation d'entretiens programmés,Analyser la situation financière d'un client,Etablir le bilan patrimonial d'un client,Définir les besoins d'un client,Réaliser une étude patrimoniale,Renseigner les usagers et les conseiller dans leurs démarches juridiques et fiscales,Déterminer une stratégie financière,Orienter un client vers un avocat, un notaire ou un gérant de portefeuille,Etablir des justificatifs de placement et rapports de rentabilité de produits financiers,Vérifier les justificatifs de placement et rapports de rentabilité de produits financiers,Réaliser un suivi des dossiers clients, fournisseurs",
#  "Consulter des fichiers clients en préparation d'entretiens programmés,Elaborer des propositions commerciales,Réaliser le bilan de la situation financière d'un client,Promouvoir un produit financier auprès d'une clientèle,Arrêter les termes d'un contrat,Collecter l'ensemble des justificatifs clients,Renseigner un formulaire de contractualisation,Développer un portefeuille clients et prospects,Surveiller des comptes débiteurs,Déterminer des mesures correctives,Monter un dossier de crédit",
#  "Contrôler l'opérationnalité d'une structure,Suivre les états d'alertes financières d'une structure,Arrêter une décision de demande de crédit,Rendre une décision sur une demande de crédit,Réaliser un contrôle interne des actes bancaires,Suivre la comptabilité d'une structure,Vérifier l'enregistrement d'opérations bancaires et de justificatifs comptables réglementaires,Représenter une structure lors d'évènements (salons professionnels, ...),Représenter une structure auprès d'instances de décision,Evaluer l'activité financière d'une structure,Déterminer des mesures correctives",
#  "Réaliser une étude de marché,Analyser les marchés financiers,Suivre des évolutions boursières et indices de référence,Établir une courbe d'évolution de produits financiers,Evaluer des risques financiers,Proposer une stratégie d'investissement,Emettre des ordres d'achat ou de vente,Transmettre un ordre d'achat ou de vente au service middle ou back-office,Mettre à jour un tableau de suivi client",
#  "Paramétrer des outils de gestion des opérations de marché,Déterminer les résultats quotidiens par produit, ligne de produits,Etablir les courbes d'évolution de produits financiers,Vérifier des enregistrements comptables d'opérations de marché,Corriger les écarts par rapport aux états des opérateurs/négociateurs,Gérer des portefeuilles d'actifs financiers,Effectuer le règlement et la livraison de titres financiers,Contrôler les sommes engagées par les opérateurs financiers,Déterminer des mesures correctives,Etablir un rapport périodique d'activité",
#  "Réaliser une étude de marché,Identifier les priorités du client,Evaluer des actifs financiers,Identifier les besoins en renouvellement de titres/actifs financiers,Surveiller l'équilibre de répartition d'un portefeuille suivant des critères de rentabilité,Réguler la vente d'actifs financiers sur le marché boursier,Établir un rapport de gestion,Établir un rapport de performance",
#  "Assurer un accueil téléphonique,Accueillir les personnes,Renseigner un client,Traiter les pièces constitutives d'un dossier administratif,Réaliser le suivi des dossiers clients et prospects,Mettre à jour un tableau de suivi client,Codifier des données clients,Réaliser un échéancier de cotisation,Réaliser une attestation fiscale,Réaliser un relevé boursier,Réaliser un relevé de situation de client,Procéder à l'enregistrement, au tri, à l'affranchissement du courrier",
#  "Définir une stratégie de gestion du patrimoine immobilier,Planifier des travaux de rénovation, de réhabilitation de patrimoine immobilier,Définir les besoins en rénovation du patrimoine immobilier,Étudier la faisabilité technique, juridique et financière d'un projet,Sélectionner des fournisseurs, sous-traitants, prestataires,Piloter la préparation de travaux,Contrôler la conformité des travaux jusqu'à réception,Suivre l'état d'avancement des travaux jusqu'à réception,Réaliser un suivi d'activité,Traiter des dossiers de contentieux (litiges, réclamations ...),Mettre en place des actions correctives et préventives,Renseigner des documents comptables, juridiques et fiscaux,Suivre un budget,Réaliser un appel d'offre",
#  "Analyser une demande de location,Gérer un planning de vacances de logements,Proposer l'attribution de logements,Etablir un bail immobilier,Réaliser un suivi administratif du recouvrement des loyers et charges,Recueillir et traiter les réclamations d'usagers, clients, résidents, ...,Actualiser les informations mises à la disposition d'un public,Planifier des travaux de rénovation, de réhabilitation de patrimoine immobilier,Réaliser des travaux de rénovation, de réhabilitation de patrimoine immobilier,Evaluer des réparations,Evaluer des travaux d'entretien,Réaliser un suivi d'activité,Renseigner les supports de suivi d'intervention et transmettre les informations au service concerné,Contrôler la conformité de réalisation de fournisseurs, sous-traitants, prestataires,Analyser l'évolution des loyers",
#  "Suivre l'évolution du marché immobilier,Définir la faisabilité et la rentabilité d'un projet,Prospecter un marché,Elaborer un budget prévisionnel,Etablir un montage financier,Etablir un montage juridique,Réaliser une procédure d'acquisition de terrain, de bien immobilier,Sélectionner des fournisseurs, sous-traitants, prestataires,Déterminer des besoins en travaux,Coordonner une équipe d'intervenants,Contrôler la réalisation d'un projet,Proposer des axes d'amélioration,Réaliser un appel d'offre",
#  "Prospecter des biens immobiliers, des terrains,Prospecter de nouveaux clients,Formaliser une demande de transaction,Définir les besoins d'un client,Conseiller un client sur les améliorations et obligations réglementaires liées à un bien immobilier,Evaluer la valeur d'un bien immobilier,Réaliser le descriptif d'un bien immobilier,Définir des actions de promotion commerciale,Valoriser un bien immobilier,Présenter un bien immobilier à un client,Présenter les modalités d'acquisition d'un bien,Réaliser une transaction immobilière,Conseiller un client",
#  "Réceptionner des carcasses de viande,Contrôler la qualité d'un produit,Préparer une carcasse aux opérations de découpe,Découper de la viande,Trier des pièces de viande,Détailler des pièces de viande,Conditionner des pièces de viande, des spécialités bouchères,Disposer des produits sur le lieu de vente,Renseigner un client,Prendre la commande des clients,Entretenir un espace de vente,Nettoyer du matériel ou un équipement,Entretenir un poste de travail",
#  "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse,Conduire une fermentation,Diviser la masse de pâte en pâtons,Bouler et effectuer la tourne ou le façonnage des pâtons,Confectionner des viennoiseries,Cuire des pièces de viennoiserie,Cuire des pâtons,Défourner des pains et viennoiseries,Décorer des produits culinaires,Entretenir un espace de vente,Entretenir un poste de travail,Nettoyer du matériel ou un équipement",
#  "Planifier la production selon les commandes de clients, les produits en stocks et la saisonnalité,Éplucher des légumes et des fruits,Réaliser la salaison d'une viande,Réaliser le fumage d'une viande,Conditionner un produit alimentaire,Disposer des produits sur le lieu de vente,Renseigner un client,Prendre la commande des clients,Entretenir un poste de travail,Nettoyer du matériel ou un équipement,Entretenir un espace de vente",
#  'Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des produits,Mélanger des produits et ingrédients culinaires,Cuire des produits de pâtisserie, confiseries ou pièces de chocolat,Effectuer le montage et la décoration des produits pâtissiers,Entretenir un poste de travail,Entretenir un espace de vente,Nettoyer du matériel ou un équipement',
#  "Réceptionner un produit,Stocker un produit,Contrôler la réception des commandes,Trier les poissons et effectuer leur préparation,Ouvrir des coquillages et crustacés,Mettre en place/rafraîchir l'étal (glace, décoration), disposer les poissons, crustacés et coquillages et afficher les prix,Renseigner un client,Conditionner un produit,Entretenir un espace de vente,Entretenir un poste de travail,Nettoyer du matériel ou un équipement",
#  "Disposer des produits sur le lieu de vente,Ranger des produits ou marchandises selon leurs dates de validité et les conditions de conservation,Accueillir une clientèle,Proposer un service, produit adapté à la demande client,Contrôler l'état de conservation d'un produit périssable,Retirer un produit impropre à la vente,Renseigner le support de suivi de traçabilité des marchandises (dates de livraison, relevés des températures, numéros de lot, ...),Suivre l'état des stocks,Définir des besoins en approvisionnement,Préparer les commandes,Entretenir un espace de vente,Entretenir un poste de travail,Nettoyer du matériel ou un équipement",
#  "Accueillir une clientèle,Proposer un service, produit adapté à la demande client,Négocier des prix,Définir des modalités de paiement adaptées,Etablir une commande,Suivre l'état des stocks,Présenter les coûts et délais de livraison à un client,Organiser le transport des marchandises,Développer un portefeuille clients et prospects",
#  "Préparer les objets pour la vente,Etiqueter un produit,Disposer des produits sur le lieu de vente,Etudier une demande client,Conseiller un client,Enregistrer la vente d'un article,Editer une facture,Proposer un service complémentaire à la vente,Rechercher des objets d'art, anciens ou d'occasion auprès de professionnels ou de particuliers",
#  "Accueillir le client et l'installer,Identifier la coiffure attendue (coupe, coloration, traitement, ...) et conseiller le client (morphologie, implantation des cheveux, ...),Réaliser le diagnostic capillaire, les préparations du lavage et le shampoing,Couper les cheveux (dégradés, effilés, piquetés),Procéder à la mise en forme ou en volume des cheveux (enroulement, bouclage, brushing, ...), au coiffage, à la fixation ou brillance (laque, gel, ...),Présenter au client sa coiffure sous différents angles pour recueillir son avis,Entretenir un outil ou matériel,Entretenir des locaux,Entretenir un poste de travail,Disposer des produits sur le lieu de vente",
#  "Accueillir la personne, identifier les soins appropriés et lui en présenter les modalités (résultats attendus, durée de traitement),Installer la personne sur le lieu de soins (appareil, baignoire, douche, cabine, ...),Appliquer les soins corporels (hydrothérapie, fangothérapie) ou surveiller le déroulement des soins selon le protocole,Assister les masseurs-kinésithérapeutes, médecins pour l'application de soins lors de cure médicalisée,Informer les personnels de santé des réactions de la personne (rougeur, essoufflement, ...),Entretenir un outil ou matériel,Entretenir un poste de travail",
#  "Accueillir une clientèle,Renseigner un client,Etudier une demande client,Proposer un service, produit adapté à la demande client,Etablir un contrat,Informer le client sur les modalités de location,Vérifier l'état général, le fonctionnement du matériel de location, identifier des anomalies et effectuer l'entretien de premier niveau,Enregistrer une réclamation client,Proposer des solutions techniques à un client,Réaliser le suivi administratif d'un contrat de location,Réaliser un suivi d'activité",
#  "Renseigner un client,Identifier une tache ou une salissure,Trier les articles et déterminer les modes de nettoyage (à l'eau, à sec, avec détachage, ...),Appliquer un produit au pistolet,Détacher des tissus et peaux,Charger le linge dans les machines et enclencher le programme,Préparer un article en vue du repassage,Repasser du textile (vêtements, linge),Classer les articles nettoyés sur un portant,Restituer les articles au client après contrôle du nettoyage, repassage",
#  "Renseigner un client,Déterminer les réparations ou modifications de l'article,Regrouper des articles par type de réparation,Etiqueter un produit,Changer une pièce défectueuse,Démonter une pièce de son support,Positionner des éléments de renfort,Assembler des fournitures standardisées,Vérifier la stabilité, l'aplomb, ... et procéder aux ajustements nécessaires,Réaliser le bichonnage d'un article de maroquinerie,Fixer des éléments de garniture,Remettre à la teinte des parties d'articles de maroquinerie,Entretenir une machine ou un équipement,Conseiller un client,Encaisser le montant d'une vente",
#  "Identifier les retouches, réparations à réaliser sur le vêtement et renseigner le client sur les conditions,Marquer les retouches et réparations lors de l'essayage,Vérifier les dimensions et la symétrie du vêtement,Sélectionner les matériaux, produits et accessoires de l'article,Retoucher un vêtement,Insérer les éléments de serrage (élastique, ...), renfort et protection (coudière, ...) sur l'article,Assembler préalablement et fixer les différents éléments (doublure, col, manche, ...) par couture,Vérifier la symétrie et le bien-aller du vêtement sur mannequin ou lors de l'essayage,Repasser du textile (vêtements, linge),Enregistrer la vente d'un article,Encaisser le montant d'une vente",
#  "Accueillir une clientèle,Proposer un service, produit adapté à la demande client,Déterminer le traitement adapté à la personne et présenter les produits, l'application des soins,Nettoyer et préparer le corps, le visage, les mains, les pieds aux soins (démaquillage, désinfection, ...),Appliquer les produits (masque, sérum, crème) et réaliser les soins du visage, du corps, de manucure ou de maquillage,Entretenir un outil ou matériel,Entretenir un poste de travail,Disposer des produits sur le lieu de vente,Définir des besoins en approvisionnement",
#  "Accueillir une clientèle,Proposer un service, produit adapté à la demande client,Encaisser le montant d'une vente,Proposer un service complémentaire à la vente,Réceptionner un produit,Vérifier la conformité de la livraison,Disposer des produits sur le lieu de vente,Trier des végétaux,Contrôler l'état de végétaux,Effectuer l'entretien de végétaux,Entretenir des locaux,Entretenir un espace de vente",
#  "Accueillir une clientèle,Renseigner le client sur les races, modes de vie des animaux,Conseiller le client sur les articles destinés aux animaux et procéder à la vente,Encaisser le montant d'une vente,Editer une facture,Proposer un service complémentaire à la vente,Réceptionner les animaux, vérifier leur état, carnet de santé et les répartir dans les cages, les aquariums,Vérifier la conformité de la livraison,Réaliser la mise en rayon,Identifier les troubles et symptômes des animaux et définir l'intervention appropriée,Entretenir l'espace de vie d'un animal",
#  "Accueillir une clientèle,Proposer un service, produit adapté à la demande client,Encaisser le montant d'une vente,Proposer un service complémentaire à la vente,Réaliser la mise en rayon,Réaliser le balisage et l'étiquetage des produits en rayon,Ranger des produits ou marchandises selon leurs dates de validité et les conditions de conservation,Suivre l'état des stocks,Définir des besoins en approvisionnement,Préparer les commandes,Réceptionner un produit,Vérifier la conformité de la livraison",
# ...
#  "Concevoir le schéma d'organisation d'une activité logistique,Concevoir des outils de pilotage,Synchroniser les activités logistiques avec le cahier des charges,Suivre la mise en place et la réalisation des plans d'action logistiques et contrôler la conformité d'application,Déterminer des actions correctives,Superviser l'acheminement de produits,Analyser les coûts de la chaîne logistique (supply chain),Organiser et coordonner le circuit des informations sur le fonctionnement d'une structure",
#  "Superviser la planification de l'exploitation du ou des sites logistiques en fonction de l'activité (flux internes/externes, commandes spécifiques, ...),Superviser l'activité des équipes logistiques,Analyser les données d'activité de la structure, du service et identifier des axes d'évolution,Analyser les coûts de la chaîne logistique (supply chain),Organiser et coordonner le circuit des informations sur le fonctionnement d'une structure,Suivre un budget,Concevoir des procédures de gestion,Contrôler l'application d'une réglementation,Superviser la gestion administrative du personnel,Mettre en place des actions de gestion de ressources humaines",
#  "Planifier le traitement des commandes,Contrôler la réception des commandes,Planifier l'activité du personnel,Suivre la gestion des zones de stockage,Contrôler la gestion des stocks,Coordonner des opérations,Contrôler une opération logistique,Suivre les besoins en équipements, matériels et consommables,Informer le client sur les conditions de réalisation d'une commande,Réaliser un suivi d'activité",
#  "Contrôler la conformité du matériel technique de bord,Accueillir, renseigner les passagers et les assister si besoin,Effectuer les vérifications techniques de la cellule avant décollage (portes, chargement de coffres à bagages, ...) en lien avec le poste de pilotage,Dispenser les consignes de sécurité aérienne aux passagers,Contrôler l'application d'une réglementation,Préparer, servir et débarrasser les plateaux-repas, collations ou éléments de confort à bord,Intervenir auprès des passagers en cas de besoin ou difficulté et mettre en place les procédures adaptées (premiers secours, rappel des mesures de sécurité, ...)",
#  "Contrôler le dossier de vol, le plan de vol, les données techniques de l'appareil et vérifier le niveau de carburant et les conditions météorologiques,Procéder aux contrôles et à la préparation du poste de pilotage, des équipements et matériels de la cellule avec le personnel navigant commercial -PNC-,Transmettre et échanger les informations de vol avec le personnel de bord et le personnel technique au sol,Organiser ou superviser les opérations à bord (chargement, accueil passagers, ...) et mettre en place des mesures d'urgence en cas d'aléas,Réaliser les opérations de mise en vol, de pilotage et d'atterrissage de l'appareil et procéder aux vérifications techniques à chaque étape,Contrôler les paramètres de navigation et de fonctionnement de l'appareil en vol et adapter le plan de vol en liaison avec les centres de contrôle aérien,Réaliser les différents comptes rendus de fin de vol et les transmettre au service concerné",
#  "Accueillir les passagers et les informer sur les conditions d'enregistrement, d'embarquement/débarquement et de vol,Collecter les informations concernant les vols et effectuer les opérations d'ouverture d'enregistrement, d'embarquement,Vérifier et enregistrer les documents des passagers et les bagages (référencement, surpoids, ...),Réaliser les opérations d'embarquement/débarquement (réservation de bus sur piste, accompagnement des passagers, remise des coupons de vol, ...),Vérifier les cartes d'embarquement avec la liste des passagers présents à bord, renseigner et transmettre les documents de suivi de vol,Accueillir les personnes",
#  "Recueillir les données techniques de l'espace aérien et évaluer les écarts avec les paramètres transmis par les pilotes,Contrôler les indicateurs techniques et communiquer aux pilotes les instructions de positionnement et le guidage aux différentes phases de vol,Repérer le positionnement des aéronefs sur les appareils de contrôle et surveiller la conformité de leur trajectoire dans l'espace aérien,Réguler le trafic aérien et élaborer des modifications de plan de vol en fonction des urgences,Identifier les besoins d'intervention en fonction des anomalies/accidents et mettre en place les procédures d'alerte,Consigner les éléments d'activité (dysfonctionnement, infraction, incident) sur les supports techniques",
#  "Vérifier la sécurisation des aires de roulement ou de stationnement des aéronefs,Préparer le matériel (balises, cales) et les équipements (rampe passagers, ...) en fonction du type de l'appareil et du chargement,Contrôler un dispositif de sécurité,Contrôler la sécurisation d'un engin à l'arrêt,Décharger des marchandises, des produits,Charger des marchandises, des produits,Réaliser le tri des bagages, du fret et des sacs postaux en soute, sur piste ou en galerie, selon leur destination,Vérifier l'application des règles de circulation sur les zones de stationnement et de roulement par les intervenants de la piste et signaler tout dysfonctionnement,Interpréter des données techniques",
#  "Collecter les données techniques de vol ou d'escale et organiser la répartition du chargement de l'appareil,Constituer le dossier de vol (plan de vol, de chargement, devis de masse) et le présenter au service de l'Aviation Civile, au commandant de bord,Planifier les interventions des équipes de piste et la mise à disposition du matériel et des équipements pour la touchée (temps d'immobilisation au sol),Transmettre aux personnels de piste, d'équipage, d'escale, ... les informations techniques de déroulement de la touchée (chargement, embarquement/débarquement, parkings, horaires, ...),Coordonner et contrôler les opérations d'escale et mettre en oeuvre des mesures correctives en cas de retard ou d'avarie technique,Contrôler l'application de procédures Qualité, Hygiène, Sécurité et Environnement (QHSE),Renseigner les supports de suivi de vol et identifier les dysfonctionnements",
#  "Planifier l'activité des équipes selon le programme de vol, les escales et mettre en place les mesures correctives en cas de retard, de surréservation, d'annulation, ...,Coordonner ou superviser les interventions aux différentes étapes des vols (escale, filtrage, piste, maintenance) et contrôler l'application des consignes de sécurité,Etablir un contrat,Gérer des contrats de fournisseurs, sous-traitants, prestataires,Coordonner les échanges d'information entre les intervenants de l'escale (sous-traitants, personnel d'exploitation),Gérer le budget global d'une structure,Analyser les données d'activité de la structure, du service et identifier des axes d'évolution,Mettre en place des actions de gestion de ressources humaines",
#  "Recueillir les données techniques de la traversée (horaires, distances, météo, ...) et élaborer la feuille de route,Coordonner la conduite du navire durant la traversée et mettre en place les mesures correctives,Coordonner l'activité d'une équipe,Planifier l'activité d'une structure,Contrôler le fonctionnement d'un équipement de sécurité,Charger des marchandises, des produits,Décharger des marchandises, des produits,Planifier une opération de maintenance,Superviser une opération de maintenance,Consigner les éléments d'activité (dysfonctionnement, infraction, incident) sur les supports techniques",
#  "Préparer et actionner les équipements du navire (ancres, câbles, cordages et gréement...) lors des manoeuvres d'appareillage ou d'accostage,Manoeuvrer des équipements embarqués (grue de navire, ...), des équipements de transbordement des passagers ou de sauvetage,Surveiller la route maritime et identifier les obstacles éventuels sur le trajet,Réaliser des opérations de chargement/déchargement de navires et effectuer le rangement et la sécurisation de la cargaison,Entretenir un bateau,Entretenir l'équipement nautique,Vérifier la conformité des équipements de sécurité (matériel de manutention, de sauvetage) et effectuer leur maintenance",
#  "Constituer le convoi de navigation fluviale (nombre et type de barges, branchements électriques, hydrauliques et ventilation),Procéder aux manoeuvres d'amarrage/largage d'amarres, de mise en fonctionnement et de conduite du bateau en lien avec l'équipage,Réaliser ou surveiller les opérations de chargement/déchargement des marchandises,Contrôler l'embarquement/débarquement des passagers,Réaliser une opération de maintenance,Déclencher les mesures d'urgence en cas d'incident",
#  "Sélectionner et positionner le matériel et les élingues, treuils, ... selon la nature de la cargaison,Procéder à l'ouverture ou la fermeture des panneaux de cale,Installer et vérifier les équipements d'accès aux bateaux (rampes, échelle de coupée et passerelle),Déposer une charge,Enlever une charge,Entretenir un poste de travail,Entretenir des locaux,Assurer une maintenance de premier niveau,Entretenir des équipements",
#  "Contrôler l'état de fonctionnement du véhicule,Réaliser les opérations d'attelage,Définir un itinéraire en fonction des consignes de livraison,Organiser ou contrôler le chargement des marchandises dans le véhicule,Vérifier la présence et la conformité des documents de bord et de transport,Vérifier la conformité de la livraison,Organiser le transfert et la livraison des produits aux clients,Réaliser un suivi d'activité,Déclencher les mesures d'urgence en cas d'incident",
#  "Accueillir la clientèle à bord du véhicule et préciser la destination et les impératifs avec le client,Déterminer un itinéraire en fonction des délais et des particularités du trafic,Conduire et déposer le client à son lieu de destination,Renseigner les documents de bord d'un véhicule,Assurer une maintenance de premier niveau,Réaliser l'entretien du matériel",
#  "Préparer le véhicule, repérer le parcours et prévoir les aléas,Accueillir, renseigner les passagers et les assister si besoin,Encaisser le montant d'une vente,Contrôler les titres de transport,Conduire des passagers selon un parcours/circuit prédéfini,Renseigner les documents de bord d'un véhicule,Contrôler l'état de fonctionnement du véhicule et effectuer le nettoyage,Déclencher les mesures d'urgence en cas d'incident",
#  "Vérifier des documents de livraison,Définir un itinéraire en fonction des consignes de livraison,Charger les colis, plis, plats cuisinés sur ou dans le véhicule,Livrer une commande,Enlever un colis chez un client,Établir un rapport d'intervention,Réaliser l'entretien du matériel,Assurer une maintenance de premier niveau",
#  "Vérifier des documents de livraison,Définir un itinéraire en fonction des consignes de livraison,Charger des marchandises, des produits,Livrer une commande,Actualiser les données de suivi de la livraison ou de l'enlèvement,Assurer une maintenance de premier niveau,Réaliser l'entretien du matériel",
#  "Superviser les plannings du service ou de l'exploitation à partir des carnets de commande,Coordonner l'activité d'une équipe,Concevoir les modalités de prestation et les conditions de réalisation de transport avec la clientèle ou les prestataires,Organiser et coordonner le circuit des informations sur le fonctionnement d'une structure,Analyser les données d'activité de la structure, du service et identifier des axes d'évolution,Suivre un budget,Superviser la gestion administrative du personnel,Mettre en place des actions de gestion de ressources humaines",
#  "Organiser un planning du personnel,Coordonner les plannings d'un site d'exploitation de transports routiers,Réguler le traffic d'un site d'exploitation de transports routiers,Déterminer les modifications d'itinéraires en cas d'aléas, l'information des voyageurs et en contrôler la mise en oeuvre,Organiser et coordonner le circuit des informations sur le fonctionnement d'une structure,Analyser les données d'activité de la structure, du service et identifier des axes d'évolution,Suivre un budget,Superviser la gestion administrative du personnel,Mettre en place des actions de gestion de ressources humaines",
#  "Organiser le traitement des commandes,Constituer le dossier de transport routier et transmettre les documents aux clients ou aux conducteurs,Organiser et planifier les plans de tournées des conducteurs,Suivre et contrôler la réalisation du transport, identifier les anomalies et mettre en place les mesures correctives,Assister techniquement les conducteurs (modifications d'itinéraires, de délais) en cas de panne, accident,Réaliser un suivi d'activité,Vérifier les éléments d'activité et de gestion administrative du personnel",
#  "Organiser et planifier les mouvements du matériel roulant selon la densité du trafic, les véhicules disponibles, ...,Concevoir le planning d'affectation des conducteurs sur le réseau ou la zone d'intervention,Suivre et contrôler la réalisation du transport, identifier les anomalies et mettre en place les mesures correctives,Contrôler un réseau ou un équipement d'exploitation,Vérifier les éléments d'activité du personnel,Réaliser un suivi d'activité",
#  "Collecter les informations du transport sur rail et contrôler la présence de la documentation technique à bord,Procéder aux vérifications de sécurité d'un véhicule,Conduire le véhicule sur rails en fonction de la signalisation, des horaires, des arrêts définis,Déclencher les mesures d'urgence en cas d'incident,Renseigner des supports de suivi d'activité",
#  "Verbaliser une infraction ou un délit,Contrôler les titres de transport,Informer les voyageurs et apporter assistance aux personnes à mobilité réduite,Réguler la vie à bord et autour du véhicule, et intervenir en cas d'incivilité ou de conflit,Déclencher les mesures d'urgence en cas d'incident,Vérifier la présence des matériels et équipements de bord (sécurité, alerte), contrôler leur état et signaler toute anomalie ou dégradation,Renseigner les supports de suivi d'intervention et transmettre les informations au service concerné",
#  "Vérifier la sécurisation des voies et des quais à l'arrivée/départ des trains (signalisation, montée/descente des voyageurs, ...) et lancer les ordres de départ en fonction de la planification,Ajuster la signalisation et actionner les systèmes de manoeuvre d'aiguillage selon la destination des trains,Contrôler le fonctionnement d'un dispositif de sécurité,Intervenir sur une zone sensible,Déployer et mettre en place les mesures palliatives en cas de situation perturbée (information voyageurs, transport de remplacement, ...),Adapter les tracés de parcours des trains en cas de dysfonctionnements,Renseigner les supports de suivi d'intervention et transmettre les informations au service concerné",
#  "Maintenir en état des zones d'embarquement/débarquement,Contrôler la mise en sécurité des accès aux équipements,Contrôler la sécurité d'une installation,Contrôler le fonctionnement d'un outil ou équipement,Manoeuvrer les systèmes des remontées mécaniques, surveiller le passage des cabines, perches et le flux des passagers,Informer les clients sur les horaires, le plan, l'état des pistes et les assister en cas de besoin lors de l'embarquement/débarquement,Organiser les mesures appropriées en cas de panne, incident, chute ou de changement météorologique,Renseigner les supports d'exploitation (registre d'exploitation, d'incident, de réclamation, ...)",
#  "Constituer une rame de wagons et la mettre à quai ou sur desserte,Vérifier et corriger le fonctionnement des équipements de sécurité (freinage, signalisation, transmetteur, ...) et de confort (climatisation/chauffage, étiquetage, ...),Contrôler les mouvements de trains sur périmètre restreint (autorisation de départ, contrôle du «défilé», aiguillage) à partir des signaux,Identifier les dysfonctionnements sur la zone d'intervention lors d'avarie, de retard, signaler les anomalies et mettre en oeuvre les mesures d'urgence,Assurer une maintenance de premier niveau"]

# %%
df.shape
# Out:
# (521, 18)

# %%
pe_skills = get_all_pole_emploi_skills()

# %%
len(pe_skills)
# Out:
# 11186

# %%
pe_skills
# Out:
# ["techniques de réglage d'outillage",
#  'surveiller ou réguler une installation de conditionnement, palettisation, étiquetage',
#  "superviser un projet d'étude et développement",
#  "surveiller l'état d'une plantation",
#  'techniques de terrassement',
#  'réaliser la préparation de pièces par refente',
#  'produits frais',
#  "délivrer des autorisations d'accès",
#  'piloter la réalisation des entretiens annuels du personnel,établir un reporting social',
#  'mettre en place des pages de gardes et de couvertures',
#  'techniques de marouflage',
#  'techniques de formation',
#  'réaliser des relevés de sondage, forage, pollution des sols et sous-sols',
#  "rédiger un conducteur d'émission tv",
#  'poser des couvertures en pierre',
#  "déterminer les évolutions des systèmes informatiques de gestion et de suivi d'une chaîne logistique",
#  "ajuster la signalisation et actionner les systèmes de manoeuvre d'aiguillage selon la destination des trains",
#  'chimie',
#  'intervenir en établissement scolaire',
#  'entraîneur de vol synthétique hélicoptère (sfih)',
#  'hydrogéologie',
#  'techniques de calorifugeage',
#  "sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#  'contrôler la surface (dépôt, aspect, épaisseur), identifier les non-conformités et réaliser les retouches, reprises de finition',
#  'organiser le traitement des commandes',
#  'réaliser des gabarits de fabrication',
#  'contrôler des fichiers du personnel',
#  'réaliser des relevés dimensionnels sur site',
#  'broder des étoffes, des articles sur une machine à broder multi-têtes industrielle',
#  "superviser et organiser les travaux d'exploitation/production informatique",
#  'découper, désosser, parer des volailles',
#  'restaurer du mobilier ancien',
#  'caractéristiques des véhicules de tourisme',
#  'réglementation du transport',
#  "corriger l'épreuve avant l'impression de l'oeuvre",
#  'foreuse jumbo',
#  'ostéopathie du sport',
#  "ecrire des chansons, livrets d'opéra, comédies musicales",
#  "assembler les pièces d'un prototype par piquage ou collage",
#  'réaliser des opérations de grainage sur des peaux, des cuirs',
#  'identifier les opérations de montage/assemblage à partir des instructions (plans, nomenclatures, ordres de fabrication)',
#  "coordonner la réalisation et la fabrication d'un ouvrage",
#  'intervenir en génie civil',
#  'procédés de tissage',
#  "effectuer, en ligne et/ou en escale, des opérations d'avitaillement (énergie, air, eau)",
#  'logiciel de montage photo',
#  'procédures et plan de stockage',
#  'détecter des défauts sur des tissus maille',
#  'contrôler des actes fonciers',
#  'identifier des moyens techniques, matériels et financiers pour un chantier',
#  "identifier la demande (visite de contrôle, soins dentaires, actes d'orthodontie, ...) et recueillir les informations (antécédents, traitements en cours, ...) auprès du patient ou dans le dossier de soins",
#  'assembler des pièces de métal par collage',
#  'répandre les granulats, les gravillons ou les déblayer',
#  'réaliser une opération de laminage à chaud (laminoir, train de laminage)',
#  "système d'exploitation windows",
#  'fixer des contreventements définitifs',
#  'réaliser les modifications de la coque ou des supports (ouvertures, pose de cale, ...) et installer les équipements et accessoires (moteurs, apparaux, compas, ...)',
#  "utilisation d'instruments de mesure tridimensionnelle",
#  'appliquer de la résine de synthèse',
#  'préparer des pâtes fraîches',
#  "définir les besoins en système d'information",
#  'détacher des tissus et peaux',
#  'techniques de formation en présentiel',
#  'approvisionnement de fonds numéraires',
#  'superviser la gestion des carrières',
#  "réaliser des plans d'outillages non métalliques",
#  'réaliser des opérations de gravure sur pierre',
#  'surveiller des comptes débiteurs',
#  'accidentologie',
#  'rédiger un discours',
#  'règles de tenue de quart',
#  "tenir informés ses équipes et ses partenaires sur l'insertion des personnes",
#  'réaliser des préparations culinaires à partir de viandes',
#  'monter des fermettes',
#  'produits jouets et loisirs',
#  'techniques de sculpture ornementale',
#  'recueillir et analyser les informations sur les prestations des partenaires (hôteliers, autocaristes, compagnies aériennes, ...)',
#  "renseigner le dossier de suivi de l'animal et proposer des soins ultérieurs",
#  'points de contrôle des peaux',
#  "utilisation d'appareils et outils de contrôle et/ou de mesure (loupe binoculaire, balance, règle...)",
#  "concevoir le programme de la séance d'orthoptie et adapter les exercices selon les réactions du patient",
#  'déterminer les décors, costumes, coiffures et maquillages pour un tournage',
#  'réaliser des opérations de céruse',
#  'epicerie salée',
#  "contrôler le trafic aérien d'un site aéroportuaire de catégorie c - services à courte distance et services moyenne et longue distance ne comportant que des étapes courtes au départ de ces aérodromes",
#  'appliquer les consignes de sécurité',
#  'mener des enquêtes sociales sur requête judiciaire',
#  'histoire des coiffures',
#  'réaliser des dessins, des gabarits et des cotations (dimension, géométrie, tolérance) de pièces, outils, outillages',
#  'monter des sièges',
#  'procédures de cuisson de la céramique',
#  'réaliser manuellement un gabarit, patron',
#  'caractéristiques des vêtements homme',
#  'réaliser des opérations de montage à joints secs',
#  'réparer des instruments à vent',
#  "réaliser un contrôle aérien au sol / contrôle d'aérodrome",
#  'conduire un petit train touristique',
#  'réaliser la mise en place du mobilier, du matériel audio-visuel et informatique des salles de réunions, de conférences',
#  'piloter des opérations liées à la gestion des emplois et des compétences',
#  "proposer et animer des activités d'éveil et intervenir en cas de chute, dispute, ...",
#  'nomenclature de la chaussure',
#  "réglementation de l'équitation",
#  "effectuer une navigation nécessitant le certificat d'initiation nautique (cin)",
#  'pratique du ski nautique',
#  'chariots automoteurs de manutention à conducteur porté (caces r 389)',
#  'réaliser un dossier technico- économique pour un projet',
#  'accueillir, renseigner les passagers et les assister si besoin',
#  'coulage en sable',
#  'réaliser des articles de sellerie',
#  "réaliser le bilan d'activité d'un service et informer les acteurs concernés",
#  'réaliser des tests et essais',
#  'réaliser des décors de peinture',
#  'poser une surface en béton',
#  'eco-conception',
#  'vérifier le montage et le câblage (valeur des composants, continuité électrique, ...)',
#  'proposer des activités de divertissement selon les participants et le contexte',
#  'peser des wagons',
#  "apporter un appui technique lors du lancement d'une campagne promotionnelle",
#  'dorure à la feuille',
#  'gestalt thérapie',
#  'réglementation du marché du médicament',
#  "définir des méthodes de fabrication, d'assemblage, de réglage ou de démontage d'équipements, systèmes mécaniques",
#  'ecologie',
#  'vendre des articles de sports et de loisirs',
#  'paramétrage de machine à découper automatisée',
#  'réaliser un état des lieux',
#  'réaliser des effets décoratifs et des ornementations',
#  "evaluer la valeur d'un bien immobilier",
#  'techniques de versification',
#  "réaliser manuellement, pour l'expédition, le tri par destination (par produit, client, ...)",
#  'réaliser des opérations de traitement de surface par bain de gaz réactif',
#  "contrôler la conformité des opérations de prospection ou d'exploitation des sols ou sous-sols",
#  'réaliser des calculs',
#  'référencement naturel (seo)',
#  'certificat de formation à la sécurité (cfs)',
#  "conditions de stockage d'effluents",
#  'organiser un rétro-planning',
#  'mécanique marine',
#  'coacher des particuliers',
#  'parachever le filetage',
#  "intervenir dans l'étape d'électrométallurgie pour la transformation du métal",
#  'restituer les éléments non distribués au service concerné',
#  "réaliser et faire évoluer les schémas, les plans de détails, de sous-ensembles ou d'ensembles",
#  'régler un fond de forme,élinguer une charge',
#  'réaliser des purges de tuyauterie',
#  "evaluer la performance d'une structure",
#  "contrôler le fonctionnement des équipements, des systèmes et vecteurs d'information",
#  'sciences médicosociales',
#  'photo filmage',
#  'tracer des décors',
#  "définir les modalités d'industrialisation des productions",
#  'cuisiner des produits de rôtisserie',
#  'conduire et déposer le client à son lieu de destination',
#  'réaliser des travaux de raccordement aux appareils de chauffage et éléments sanitaires',
#  'marketing mobile',
#  "contrôler des données d'instrumentation",
#  "contrôler un système d'imposition numérique",
#  'chimie minérale',
#  'elaboration de tableaux de bord',
#  'concevoir un numéro visuel dans ses aspects techniques, artistiques, esthétiques',
#  'contrôler les cellules des détenus',
#  "déterminer les équipements nécessaires aux mouvements d'une caméra",
#  'vérifier la présence et la conformité des documents de bord et de transport',
#  'dessin de détail',
#  'superviser un parc de véhicules légers',
#  'contractualiser une affaire avec un client',
#  "coordonner les différentes phases d'intervention des corps de métiers du chantier",
#  'instruire des affaires civiles, pénales et administratives',
#  'outils manuels de maçonnerie',
#  'poser des sols',
#  'effectuer une navigation fluviale sur un bateau-promenade',
#  "intervenir sur sites/clients dans le cadre d'une organisation",
#  'réparer du matériel forestier',
#  'réaliser le routage sur machine à filmer',
#  'réaliser des postiches',
#  'définir une stratégie de collecte de fonds',
#  'utilisation de machine à coudre à bras',
#  'défiler lors de manifestations publiques selon les indications du styliste et les répétitions',
#  'intervenir sur des attractions à sensation',
#  'transmettre des documents contractuels',
#  "planifier les étapes d'un projet",
#  'cuisiner des sauces',
#  'réaliser des agencements de chambres froides',
#  'organiser et planifier les plans de tournées des conducteurs',
#  'intervenir dans un milieu nocif, nucléaire et radiologique',
#  'biologie végétale',
#  'réglementation sur la production vinicole',
#  'techniques de mixage',
#  'bombage du verre',
#  "contrôler la conformité d'une réalisation",
#  'pratique de discipline sportive',
#  'communication digitale',
#  "réaliser une mission d'ordre public",
#  'réaliser le patron modèle de produits à manches (tailleur, manteau, ...)',
#  'surveiller le déroulement de la production et ajuster le réglage des paramètres des équipements en fonction des écarts',
#  'monter une plaque de métal, une pierre taillée sur une article de bijouterie',
#  'equipements de chauffage',
#  'intervenir en arts industriels, sciences et techniques industrielles, ...',
#  'anglais financier',
#  'réaliser des éléments de nautisme',
#  'types de déchets',
#  'approvisionner une ligne de production',
#  "participer au réglage d'une grue de chantier",
#  'développer une application en lien avec une base de données',
#  'installer une structure de forage',
#  'intervenir en efficacité énergétique',
#  "constituer un dossier de demande d'aide à la formation",
#  'biérologie',
#  'gynécologie',
#  'découper et fixer les plinthes et les barres de seuil',
#  'répéter une oeuvre musicale pour une représentation ou un enregistrement',
#  'intervenir auprès de sportifs',
#  "définir des thèmes d'exposition",
#  'réaliser des travaux de maquette, prototypes',
#  "contrôler la conformité d'un équipement ou matériel de sécurité",
#  'logiciel character studio',
#  'défibrage chimique',
#  'utilisation de machines à dorer/à brunir',
#  "surveiller les réactions, la tolérance de la personne lors de la réalisation de l'examen radiologique et intervenir selon nécessité",
#  'knowledge management',
#  "décliner les tailles d'un modèle de base sur un logiciel de gradation",
#  "contrôler l'état de fonctionnement d'un appareil",
#  "rédiger un compte rendu d'activité",
#  'micromécanique',
#  'langage informatique prolog',
#  'conditionner un produit',
#  'rechercher des auteurs et sélectionner des ouvrages, textes, manuscrits',
#  'piloter le déploiement de nouveaux outils informatiques',
#  'déterminer une stratégie financière',
#  'réaliser des opérations de change de devises',
#  'droit du commerce international',
#  "administrer un site web,évaluer l'e-reputation d'un site web",
#  'intervenir lors de la phase de séchage en industrie du bois',
#  'fonctionnement et caractéristiques des aéroports (nationaux et internationaux)',
#  'pratique de la boxe française, savate',
#  'surveiller des équipements ou phases de texturation',
#  "former de l'acier, acier inox",
#  "coordonner un dispositif de certification validation des acquis de l'expérience (vae)",
#  'découper, désosser, parer du veau',
#  "commercialiser des produits d'extraction",
#  "rédiger des correspondances pour le compte de particuliers ou d'entreprises",
#  'identifier des affaires potentielles',
#  'caractéristiques anatomiques du pied',
#  'sensibiliser un public à une réglementation',
#  "evaluer l'impact financier d'une opération sur les résultats d'une entreprise",
#  "réaliser le bilan de fin de rééducation avec la personne et échanger des informations avec le médecin, l'enseignant, ...",
#  'mettre sous tension une installation électrique',
#  "pratiquer des actions de rééducation d'ergothérapie en psychiatrie",
#  "réaliser manuellement l'affranchissement pour l'expédition",
#  'techniques de triangulation',
#  'réparer la carrosserie de véhicules de collection',
#  'installer des équipements complémentaires (dispositifs de confort, protection, films teintés, attelage, ...) sur un véhicule automobile particulier ou industriel',
#  'hygrométrie',
#  'contrôler la conformité des peaux/cuirs et rectifier les anomalies',
#  'ficelage des viandes',
#  'utilisation de scie à chantourner',
#  'conduite de chariot cavalier',
#  "techniques de l'expertise à distance en assurances",
#  'régler les paramètres des machines et des équipements',
#  "dégager l'empreinte, en contrôler les dimensions, l'état de surface et procéder aux retouches et finitions",
#  "façonner et mettre en place des châssis supports d'éléments (groupe, condenseurs, échangeurs, ...)",
#  'retirer un produit impropre à la vente',
#  'réaliser des opérations de traitement de surface par bain électrolytique',
#  'examinateur de vol (fe)',
#  'chariots tracteurs et à plateau porteur de capacité inférieure à 6 000 kg (caces r 389-2)',
#  'elaborer une fiche de nomenclature',
#  'indicateurs de suivi de production',
#  'caractéristiques des plâtres de moulage',
#  "intervenir dans le cadre d'une curatelle",
#  'relever les mesures et détecter les atteintes ou dépassement de seuil de contamination, de toxicité ou de pollution',
#  "réaliser des décors d'incrustation d'éléments (nacre, ivoire, ...)",
#  "pratiquer des actions de rééducation d'ergothérapie en traumatologie",
#  "réaliser des tests de produit auprès d'un panel de consommateurs",
#  'améliorer une procédure qualité',
#  "maintenir en état des zones d'embarquement/débarquement",
#  'portage de cercueil',
#  "définir l'implantation de succursales bancaires",
#  'sélectionner le bois',
#  'pratiquer des exercices instrumentaux',
#  'concevoir des supports de suivi de fabrication',
#  "organiser la présentation d'une collection",
#  'visionner les rushes du tournage et sélectionner les prises pour le montage selon les indications et les intentions artistiques du réalisateur, du journaliste, ...',
#  'imprimer des motifs par impression par dévorage, rongeage',
#  'réglementation sur la production cidricole',
#  'cuisiner des poissons, produits de la mer',
#  "superviser des opérations de conduite de machines et coordonner le service technique d'un navire (système de propulsion, production d'énergie, auxiliaires, ...)",
#  'nourrir des animaux domestiques',
#  'intervenir auprès de nourrissons',
#  "chaîne de distribution d'un film",
#  'réaliser des opérations de traitement par tropicalisation',
#  'intervenir sur un procédé de fabrication en moyennes séries',
#  'film publicitaire',
#  'monter des porte-bagages',
#  'techniques de soudure en aéronautique',
#  'techniques de peinture à la brosse',
#  "logiciel de conception et analyse d'enquête",
#  'intervenir sur des hélicoptères',
#  'procédures de réservation touristique',
#  "evaluer l'activité financière d'une structure",
#  "modalités d'essai sur équipements pilotes",
#  'langage informatique sql',
#  "tracer, reporter les repères de coupe et d'assemblage sur les pièces",
#  'epicerie sucrée',
#  'evaluer le montant des préjudices (corporels, moraux, économiques, ...',
#  'caractéristiques des produits financiers',
#  'constituer le convoi de navigation fluviale (nombre et type de barges, branchements électriques, hydrauliques et ventilation)',
#  'organiser le planning des activités',
#  'effectuer une navigation nécessitant la mention de capitaine de yacht',
#  'certificat de formation adr - spécialisation classe 7 (matières radioactives)',
#  "définir les thèmes, l'objet et la finalité d'études ou de recherches",
#  'définir un style de supports textiles',
#  'réaliser une opération de coupage/cisaillage (cisaille, ...)',
#  'vérifier le tracé et la tension de piqûre, procéder aux réparations nécessaires et évacuer les articles non-conformes',
#  'réaliser une technique de marquage à chaud ou dorure sur un produit imprimé',
#  'réaliser des opérations de pressage relatives au placage',
#  "intervenir auprès d'un public d'enfants en difficultés importantes du langage ou du comportement",
#  'conseiller une clientèle ou un public',
#  'surveiller un site de déchetterie et contrôler la nature des déchets, encombrants, composts déposés',
#  "procédures de déploiement d'installation",
#  'concevoir un programme de formation,évaluer des actions de formation',
#  'intelligence économique',
#  'attestation de capacité de déménagement',
#  'réaliser la mise en conformité de fonctionnement (état de référence, sécurité, environnement, ...)',
#  'composer des poudres, des pâtes plastiques ou liquides',
#  'façonner des objets usuels',
#  "vérifier la disponibilité de l'équipement de secours",
#  'règles de branchement/débranchement des équipements',
#  'réseaux de télécommunication',
#  'préparations culinaires de base',
#  'réaliser des opérations de finition sur des articles chaussants (bas, collants, ...)',
#  'mener des actions de suivi social spécifiques à une structure et à un public',
#  'techniques de métré',
#  'réaliser des opérations de perçage sur des ouvrages en bois',
#  "transporter des passagers au moyen d'un télé corde",
#  'architecture',
#  'définir des procédures de traitement et de sécurisation',
#  'spectrographie',
#  'définir des axes prioritaires de développement commercial',
#  "réaliser la mise à jour du site à l'aide d'une interface d'administration",
#  "méthodes d'analyse en parasitologie",
#  'yoga',
#  "définir ou participer à la définition de la stratégie de développement d'un territoire",
#  'tailler un arbre ou un cep',
#  'techniques de surfaçage de surfaces/sols',
#  "lancer une projection manuellement ou au moyen d'un pupitre de commande",
#  'repérer les anomalies, les défauts de fabrication',
#  'utilisation de pointeuse',
#  "règles de mesure de vitesse et d'altitude",
#  "réaliser des ouvrages ou revêtements d'ouvrages",
#  'proposer des évolutions et des modifications (techniques, économiques) de système, sous-ensemble ou composant',
#  'psychopathologie',
#  'techniques de pose des revêtements souples',
#  'conseiller des clients en matière de gestion comptable',
#  'réaliser un soudage nécessitant la qualification soudage à la flamme oxyacétylénique - 311',
#  'logiciels de gestion du temps de travail',
#  'assembler les éléments du produit électrique ou électronique (composants, câblage)',
#  'définir des profils de stagiaires',
#  'suivre des prestations de transport à caractère international',
#  "ecrire des légendes d'iconographies, livrets d'exposition (peintures, photographies, ...)",
#  'gestion du risque vol',
#  'réaliser des traitements thermiques de revenu',
#  "s'informer des circonstances de la panne et dresser un premier diagnostic",
#  "réaliser les opérations de mise en vol, de pilotage et d'atterrissage de l'appareil et procéder aux vérifications techniques à chaque étape",
#  "réaliser des forages d'extraction maritime (off-shore) à partir de plate-forme semi-submersible",
#  'ergonomie',
#  'filage du verre',
#  'paysage audiovisuel français',
#  'réaliser des escaliers, rambardes, mezzanines, pergola, vitrines',
#  'techniques de maquillage télévision',
#  'prélever, peser et doser les matières/produits (ingrédients, colorants, grains, ...) sur les balances, trémies peseuses, ...',
#  'navire gazier',
#  'attestation de capacité de transport marchandises moins de 3,5t',
#  'marinage des matériaux',
#  "utilisation d'outil de supervision",
#  'enregistrer des actes fonciers',
#  "gestion d'un parc de véhicules",
#  'histoire du cinéma',
#  'trier des produits',
#  'réaliser des opérations de délignage sur des ouvrages en bois',
#  'outil de contrôle',
#  "suivre et contrôler la conformité réglementaire d'utilisation de véhicules (contrôle technique, assurance, permis, temps de repos, ...)",
#  'réaliser des prototypes en cuir',
#  'intervenir sur des matériaux en plastiques et composites',
#  'adapter le déroulement des apprentissages selon les difficultés des élèves',
#  'médecine du travail',
#  'stratégie internationale',
#  "contrôler l'accès et la circulation des personnes",
#  'géomatique',
#  "consigner les éléments d'activité (dysfonctionnement, infraction, incident) sur les supports techniques",
#  'intervenir sur une voiturette (sans permis)',
#  'tailler, calibrer la pierre de couverture (lauze, gneiss, ...) et la poser en toiture sur voûte par calage avec du remblai',
#  'entretien de vente',
#  'préparer la phase de réveil du patient et procéder au transfert en salle de surveillance post-interventionnelle -sspi -',
#  'planifier et suivre la réalisation des mesures et analyses et interpréter les résultats',
#  'rédiger un compte rendu de réunion',
#  "technologie des mécanismes d'engins de motoculture",
#  "réaliser des opérations de micromécanique sur des pièces d'horlogerie par usinage",
#  'réparer la carrosserie de véhicules légers',
#  'caractéristiques des débroussailleuses',
#  'intervenir sur des matériaux en forme de fils',
#  "cerner l'environnement familial, social de la personne et identifier la nature des difficultés (troubles fonctionnels, de la personnalité, de l'apprentissage)",
#  'techniques de pressage',
#  "réaliser les rapports de contrôles et de diagnostics d'anomalie ou de risque et les transmettre aux services production, maintenance, sécurité,,,",
#  'réaliser des études et des essais en électronique',
#  'logiciel 3ds max',
#  'analyser des ventes',
#  'techniques de modelage',
#  'réaliser des gravures ou des ciselures sur linoléum',
#  'terminer la pièce textile obtenue et la ranger dans des bacs ou des zones de stockage',
#  "contrôler l'application d'un plan d'implantation",
#  "entretenir les mécanismes d'un engin motorisé",
#  'techniques de séchage',
#  'intervenir sur des architectures, ingénieries de réseaux',
#  'exploration fonctionnelle',
#  "concevoir l'aménagement de sites industriels",
#  "techniques d'accrochage",
#  'réparer la carrosserie de véhicules de transport routier de marchandises (isothermes, frigorifiques, produits en vrac, ...)',
#  "concevoir une procédure d'intervention de maintenance",
#  'techniques de réanimation',
#  'renseigner des documents médico-administratifs',
#  'typologie de la clientèle de voyageurs',
#  'caractéristiques des dossiers de maintenance',
#  "identifier des tendances et déterminer les spécificités d'un article ou d'une collection",
#  'caractéristiques des vins',
#  'intervenir dans un milieu nucléaire, radiologique, bactériologique et chimique - nrbc',
#  'danse classique',
#  'couture',
#  'logiciels de gestion de base de données',
#  'intervenir sur un moteur à gaz naturel',
#  'réaliser une navigation maritime en zone portuaire',
#  "négocier des conditions d'achat",
#  "sélectionner un traitement pour des fibres d'origine naturelle végétale (coton, lin)",
#  'fiscalité',
#  'surveiller des équipements ou phases de moulinage, retordage',
#  "mettre à disposition d'un public des fonds documentaires",
#  'intervenir dans le domaine des plastiques, caoutchouc et composites',
#  "façonner au moyen d'une brocheuse",
#  'réaliser des opérations de « travail aérien » nécessitant une qualification largage de charges toute nature',
#  "démouler la pièce, la protéger et l'entreposer avant usinage",
#  'remonter les équipements, structures et circuits, effectuer leurs réglages et contrôler leur fonctionnement',
#  'techniques de fauchage',
#  "mettre en place un projet d'accueil individualisé (pai)",
#  'positionner une armoire électrique industrielle',
#  'réaliser des maquillages',
#  'procédés de photographie moyen format',
#  'rédiger un écrit professionnel',
#  "réaliser le soudage (à l'arc, brasage, ...) de pièces, organes mécaniques, ...",
#  "concevoir des protocoles d'analyses",
#  "service de sécurité incendie et d'assistance à personnes (ssiap3)",
#  'techniques de soudure en chimie',
#  'traitement du poisson à bord',
#  'pratique de la guitare, basse',
#  "règles d'hygiène et d'asepsie",
#  "etablir des accords, des conventions, des relations contractuelles au nom de l'etat avec des collectivités locales, des associations et des partenaires locaux",
#  'réaliser le montage vidéo',
#  'broder des étoffes, des articles sur un métier à broder classique',
#  'système à temps partagé ou transactionnel',
#  'intervenir sur des matériaux en titane, magnésium',
#  "techniques de mesure de l'audition",
#  "vérifier la faisabilité technique d'un produit",
#  'définir les données de programmation de machines à partir de fiches techniques',
#  "réaliser une enquête, un sondage d'opinion",
#  "utilisation d'olfactomètre",
#  'réaliser le suivi logistique de la structure, du projet',
#  "réparer des dégâts d'origine naturelle",
#  'répéter un rôle',
#  'marquer des prises choisies par un réalisateur',
#  'spécificités des moteurs à pistons',
#  'architectures de réseaux de téléphonie fixe',
#  "sélectionner une bête auprès d'un producteur",
#  'réaliser des menuiseries extérieures',
#  'acheter des espaces publicitaires pour la radio',
#  'traiter des informations recueillies (vérification, recoupement, analyse)',
#  'déposer des toitures amiantées',
#  'remettre en état des produits par des opérations de nettoyage',
#  "informer et conseiller la personne sur des aménagements (rampe d'accès, domotique, ...) ou des équipements, des appareillages",
#  'techniques de cintrage',
#  'comptabilité bancaire',
#  'réglementation des marchés financiers',
#  "réaliser les opérations d'ouverture et d'aménagement de sentiers pour le public",
#  'réaliser les opérations de prétraitement ou de teinte de matières',
#  'trier les produits défectueux et les diriger vers les zones ou services concernés (réparation, recyclage, évacuation, ...)',
#  'surveiller ou conduire des phases de granulation',
#  "informer et conseiller des femmes en situation d'interruption thérapeutique de grossesse",
#  'pratique de la dactylographie',
#  'achevage et réglage',
#  'utilisation de micro',
#  'eléments de base en psychologie',
#  'tailler des diamants',
#  'logiciel autocad',
#  'organiser le suivi (pédagogique, logistique, administratif, ...) des stagiaires en formation professionnelle',
#  'procéder à la mise en service de nouveaux équipements',
#  'immunologie',
#  'réaliser un modèle de prévision',
#  'pratique de la clarinette',
#  'comptabilité tiers',
#  "contrôler la conformité d'aspect d'un produit",
#  'terminologie juridique',
#  'réaliser la préparation de pièces par gaufrage',
#  "organisation d'évènements",
#  "définir les besoins en rénovation du patrimoine immobilier,étudier la faisabilité technique, juridique et financière d'un projet",
#  'déménager des objets volumineux (pianos, billards, ...)',
#  "procéder à des actions correctives ou des réparations de remise à teinte (tranches d'articles de maroquinerie, ...)",
#  'conseiller les clients sur un choix de vin selon les plats choisis et effectuer le service',
#  "techniques d'arasage",
#  'rédiger un communiqué de presse',
#  "intervenir dans le domaine d'édition technique, technologique",
#  'définir les conditions et le coût du transport avec le client et en organiser les différentes étapes (enlèvement, livraison, ...)',
#  'réaliser des opérations de parage',
#  'livrer une commande',
#  "utilisation d'un chariot équipé de porte-charges",
#  'utilisation de fer/table aspirante',
#  "concevoir les orientations et les objectifs stratégiques des programmes d'action des pouvoirs publics",
#  "coordonner l'intervention des secours sur zone",
#  'bonnes pratiques de fabrication -bpf-',
#  "réaliser des opérations de fabrication/d'usinage sur des machines-outils à commandes numériques",
#  "concevoir le planning d'affectation des conducteurs sur le réseau ou la zone d'intervention",
#  'procédés de validation de réseaux',
#  'contrôle chimique',
#  "contrôler l'aspect d'un matériau",
#  "reporter les repères de coupe et d'assemblage sur des pièces de construction",
#  'pratique du squash',
#  'utilisation de porteuse, de perche motorisée',
#  'réglementation des niveaux sonores',
#  "réaliser des soins d'hygiène corporelle, de confort et de prévention",
#  'foreuse mobile',
#  'installer des dispositifs de prévention',
#  'appréciation sensorielle',
#  'définir une thématique pour un évènement professionnel',
#  'lecture de plan de salle',
#  'navire remorqueur portuaire',
#  "réaliser l'intervention chirurgicale de l'animal et effectuer la surveillance post-opératoire",
#  'constituer des rapports caméra',
#  'réseaux voies-données-images (vdi)',
#  'procédures de nettoyage/décapage',
#  'réaliser le fardelage',
#  'traitement des opérations sur titres',
#  'organiser les conditions de réinsertion de détenus',
#  'compléter les formulaires, les questionnaires et les compte rendus',
#  'utilisation de soudeuse haute fréquence',
#  'appareils électroniques de navigation',
#  "déterminer les modifications d'itinéraires en cas d'aléas, l'information des voyageurs et en contrôler la mise en oeuvre",
#  "collecter des informations dans le cadre d'une émission",
#  'techniques de restauration de document',
#  "normes d'adressage",
#  'reproduire des articles de bijouterie',
#  'détecter des dysfonctionnements sur un poste de travail',
#  'caractéristiques des pigments et colorants',
#  'pratique du parachutisme',
#  "types d'ambiances",
#  "intervenir sur une opération automatisée d'usinage, meulage",
#  'préparer, servir et débarrasser les plateaux-repas, collations ou éléments de confort à bord',
#  'montage, démontage et utilisation des échafaudages roulants (caces r 457)',
#  'nomenclature des actes médicaux',
#  "modalités d'approvisionnement de machines à sous",
#  'recueillir les preuves, témoignages et rapports de police auprès des parties impliquées dans le sinistre (victimes, témoins, services de secours, ...)',
#  'utilisation de machine à cercler',
#  "concevoir des mesures de régulation, de sécurisation ou d'alerte",
#  'technologies informatiques',
#  'procédés de traitement de surface',
#  'informer le client sur les modalités de location',
#  'procéder à un diagnostic de performance énergétique',
#  'installer un avitailleur carburant nécessitant une habilitation',
#  'identifier les composants et les pièces défectueuses',
#  'photogrammétrie',
#  "réglementation de l'assurance construction dommages-ouvrage",
#  'procédures de décontamination',
#  'intervenir en support avant-vente',
#  'réaliser le cerclage',
#  'implanter une zone de chantier',
#  "renseigner les supports de suivi d'intervention et rédiger les procès-verbaux (essais, contrôles, ...)",
#  "analyser la recevabilité d'une demande de crédit",
#  "caractéristiques des logiciels d'interface (middleware)",
#  'réaliser des contrôles ou des tests',
#  'concevoir des modèles pour une collection hiver/été enfant',
#  "réaliser le dessin artistique d'un produit",
#  'analyser des échantillons de front de taille sous-terrain',
#  'caractéristiques de la saurisserie (produits fumés, salés ou séchés)',
#  'formalisation de processus de gestion',
#  'utilisation de conformateur',
#  'réglementation des diplômes et certifications',
#  'types de consoles (analogique, numérique)',
#  'techniques de réglage de perceuses',
#  "préparer et organiser des actions d'information sur le marché du travail",
#  'produits exotiques',
#  'lustrer un chapeau',
#  'suivre un marché sur une zone nationale',
#  'législation funéraire',
#  'renseigner un public, des usagers',
#  'utilisation de matériel de signalisation et de sécurité (balise, panneaux, ...)',
#  'techniques de parage des viandes',
#  "surveiller le fonctionnement d'espaces disques",
#  "sensibiliser les clients à l'utilisation des automates et des services à distance",
#  "analyser les potentialités d'un marché d'entreprises clientes",
#  'analyser les processus métier',
#  'caractéristiques des tunneliers',
#  "identifier des caractéristiques de prises de vues en fonction d'un scénario",
#  'utilisation de machine à coudre pilier',
#  'contrôle par ressuage',
#  'techniques de rééducation abdominale (urologie, gynécologie, proctologie, /...)',
#  'déterminer les conditions de réalisation (temps, lieu, logistique, compétences) des coiffures ou des maquillages, les moyens (matériel, budget) et effectuer les commandes',
#  "etudier l'impact d'une oeuvre sur un public et ses retombées médiatiques",
#  'participer à des instances représentatives',
#  'orner des cadres',
#  "surveiller un espace naturel pour la prévention des risques d'accidents, de pollution, d'incendie",
#  'assembler des structures spéciales',
#  'intervenir sur des matériaux en cire',
#  'isoler une tuyauterie',
#  'contrôler une installation',
#  'identification des symptomatologies (fonctionnelles, mécaniques, tissulaires, circulatoires, ...)',
#  "utilisation d'appareils de mesure électrique (multimètre, ...)",
#  "licence jar 66 c - visite d'entretien en base principale",
#  "intervenir dans l'étape de préparation et de frittage du processus de transformation de verre (à chaud, à froid)",
#  'réaliser des dessins techniques pour un réseau sous-terrain',
#  "isoler ou mettre à l'écart du troupeau",
#  'vérifier et assembler les éléments de cycles, motocycles, ... ou du matériel (motoculteur, tondeuse, ...) avant livraison',
#  "adapter des menus selon les besoins d'une structure, les impératifs budgétaires et des spécificités du public",
#  "techniques d'affûtage",
#  'concevoir le programme des activités selon les spécificités du public',
#  "utilisation d'équipements de conditionnement d'air",
#  'mettre à disposition du public des jeux et des jouets',
#  'polissage, dépolissage de verre',
#  'soutirer un produit après fermentation',
#  "réaliser les prestations de bilan ou d'orientation professionnelle (investigation, évaluation, passation de tests, ...) et restituer les résultats",
#  "parachever la pose d'oeillets, boucles, décoration",
#  'nettoyer une salle de réception',
#  'réaliser un dépannage sur installations thermiques industrielles',
#  "réguler les échanges entre les participants d'un débat",
#  'transposition de partition',
#  "procédures d'entretien d'outillages et d'équipements de transformation du verre",
#  'logiciel alias studio tools',
#  'electromagnétisme',
#  'animer des groupes de paroles',
#  'accompagner des familles fragilisées',
#  "réaliser un projet d'aménagement d'espaces paysagers",
#  'proposer des services de gestion comptable',
#  "participer aux phases créatives d'un projet marketing",
#  "positionner les inserts (bois, plastique, métal, nid d'abeille, ...) entre les plis",
#  'démarrer une nouvelle gamme de produits et tester les réglages des équipements',
#  "utilisation d'outils de découpe",
#  'concevoir les nomenclatures des schémas et plans',
#  'intervenir auprès de sportifs de haut niveau (shn)',
#  "analyser les données d'activité d'une production",
#  'réaliser des ornementations ou des décorations spécifiques avec des adjonctions de métal',
#  'commande en gros',
#  'elaborer et mettre en oeuvre les conventions de délégation de services publics et contrôler leur mise en oeuvre (publicité, candidats, marchés, prestations, ...)',
#  'confectionner des viennoiseries',
#  'contrôler la mise en sécurité des accès aux équipements',
#  'comptabilité des opérations de marché',
#  'film long métrage',
#  'analyse des risques professionnels',
#  'réaliser une opération de tournage',
#  'abattre un bovin',
#  'types de câbles',
#  "médecine d'urgence",
#  'lever des charges',
#  'réaliser des pâtisseries',
#  'décliner les décisions du gouvernement, des élus en fonction du contexte et des enjeux locaux et définir des projets à mettre en oeuvre',
#  'techniques de scratching',
#  'utilisation de machine à claquer',
#  'risques de circulation sur voie publique',
#  'développer un partenariat de recherche avec des acteur locaux',
#  'génétique animale',
#  'stratégie financière',
#  'remonter un filet de pêche',
#  'etablir un document de fabrication',
#  "utilisation d'appareil d'otoscope, d'audiophone, d'audiomètre, ...",
#  'réaliser un échauffement corporel et vocal avant une répétition ou une représentation',
#  'logiciel page maker',
#  'transférer le film cinématographique sur vidéo à partir du télécinéma et numériser les rushes pour un montage virtuel',
#  'intervenir en mécanique de précision',
#  'concevoir une gamme, une collection de matières premières, des motifs en fils, tissus',
#  'lecture de chronotachygraphe',
#  'interprétation par signes',
#  "améliorer le positionnement d'un site web",
#  "réaliser un soudage nécessitant la qualification soudage avec fil fourré sans gaz innershield (soudage à l'arc avec fil fourré autoprotecteur - 114)",
#  'pose de vitrages',
#  'concevoir un projet éducatif selon les spécificités de la structure et des publics',
#  'définir la cible, les tarifs et garanties de nouveaux produits et organiser le plan de lancement',
#  'utilisation de matériel de pulvérisation (jet de sable)',
#  'equipements de vol',
#  "techniques d'embossage de viande",
#  "proposer un traitement selon une orientation thérapeutique d'ostéopathie",
#  'réaliser des traitements thermiques de céramisation',
#  'habiller le mannequin (positionnement et tension de la peau, couture, ...)',
#  'procédures de réglage des outils (tension des lames, ...)',
#  "concevoir un projet d'aménagement d'espace de vente",
#  "techniques d'élingage",
#  'cibler une gamme de produits',
#  'concevoir un voyage à la carte pour un client ou un groupe',
#  'intervenir dans le domaine du béton armé',
#  'réaliser une opération de ponçage, polissage',
#  "définir et superviser les conditions d'accueil des élèves dans l'établissement",
#  "principes d'implantation du matériel son",
#  'elimination des levures',
#  'techniques de taille de pierre précieuse',
#  'définir une surveillance médicale selon la situation de la personne et proposer un suivi médical, aménagement de poste, ...',
#  "réaliser un patron à partir d'une toile",
#  "surveiller la performance, la capacité, la qualité du réseau et adapter les équipements, systèmes et vecteurs d'informations",
#  'poser un plafond tendu',
#  'identifier une tache ou une salissure',
#  'pratique du clavecin',
#  "remettre des documents de référence à l'arrivée des clients",
#  'procédés de fabrication du verre',
#  'pratique du golf',
#  'présélectionner des candidats lors des recrutements',
#  'recenser le patrimoine, les collections et contrôler le mouvement des oeuvres (inventaire, entrées, sorties, ...)',
#  'réaliser un entretien commercial',
#  'normes de sécurité liées au gaz',
#  'règles de sécurité et de plongée',
#  "entretenir l'équipement nautique",
#  "transformer un produit de l'élevage",
#  "procédures d'entretien de premier niveau des équipements et matériels",
#  'suivre des procédures de contentieux',
#  'démonter un équipement',
#  'caractéristiques des matériaux de carrosserie',
#  'rééducation auditive',
#  'analyse de la performance',
#  'réaliser le curage mécanisé, hydrodynamique, hydrocurage',
#  'interpréter des données de contrôle',
#  "réaliser l'ossature en bois d'une coque de bateaux",
#  "assembler les parties constitutives d'un ouvrage",
#  'concevoir des référentiels de compétences',
#  'identifier un litige client',
#  'veiller au respect des procédures de travail',
#  'surveiller le déroulement des phases de production de métaux',
#  'assister les animaux lors des mises bas et prodiguer les premiers soins aux nouveau-nés',
#  'réaliser des opérations de disposition des différents plis composant le panneau (kraft, papier mélaminé, placage, ...)',
#  'réécrire du contenu ou du style de textes',
#  'définir des procédés de fabrication',
#  'concevoir des outils spécifiques de fabrication',
#  "renseigner des documents de suivi et d'évaluation d'un élève",
#  'caractéristiques des chaussures',
#  'caractéristiques des pâtes à papier recyclé',
#  'rééducation uro gynécologique',
#  'calculer des développés en fonction de paramètres (matière, épaisseur, outils, rayons)',
#  "préparer les verres (centrage, axage, montage, ...), procéder à l'essayage sur le client et effectuer les ajustements",
#  'installer du mobilier sanitaire',
#  'coordonner des opérations',
#  'réaliser des opérations de rabotage sur des ouvrages en bois',
#  'réaliser des déplacements internationaux',
#  "cours des marchés de l'art",
#  "effectuer le service de plats à table selon les techniques spécifiques (à l'assiette, à la française, à l'anglaise, ...)",
#  'logiciel quark express',
#  'assembler des matières premières et des notes simples',
#  'assembler des fournitures standardisées',
#  'diriger et coordonner des actions de sécurité publique',
#  'génie thermique',
#  "recouvrir un article ou un support mural d'un revêtement de décoration",
#  'concevoir une chorégraphie dans ses aspects artistiques, esthétiques et techniques',
#  "régler les paramètres d'un appareil photographique",
#  'rechercher des financements, des partenariats',
#  "monter la forme imprimante sur la machine, régler les paramètres d'impression (calage, encrage, pression des cylindres, ...) et charger les supports d'impression et les consommables",
#  'procédés de brasage',
#  "modalités d'approvisionnement de machines de textiles nontissés",
#  "réaliser le compte rendu d'une animation commerciale",
#  "commercialiser un produit de l'élevage",
#  'distinction de couleurs (régularité, ...)',
#  'utilisation de machine à coudre',
#  'concevoir des documents techniques',
#  'equipements audiovisuels',
#  'etablir une gamme de fabrication',
#  "intervenir dans l'étape du four de fusion (à induction, ...) pour la transformation du métal",
#  'réaliser la collecte ou des prélèvements de faune ou de flore du milieu marin (coraux, plants, ...)',
#  "produits d'assurance collective multirisques",
#  "etablir une reccommandation de cession d'actifs financiers",
#  'fixer des structures et des éléments de structure en bois',
#  'monter des pièces de décorations, ornementations',
#  'gravure au pointillé',
#  'contrôler la conformité des réalisations, procéder aux rectifications et évacuer les non-conformes',
#  "collecter les matériaux d'extraction et les déblais",
#  "stratégie d'entreprise",
#  'evaluer le résultat de ses actions',
#  "réaliser une opération d'alésage",
#  'vérifier les caractéristiques organoleptiques (successions de sensations, pyramide olfactive, équilibre, stabilité, ...) du produit final',
#  'préparer des équipements de production',
#  'pratiquer un prélèvement multi organes (pmo)',
#  'procédés de découpage',
#  'stérilisation',
#  'techniques de coupe des revêtements',
#  'mettre en place des inventaires de personnalité',
#  "réaliser la protection (masquage, emballage, ...) et l'expédition de pièces",
#  'techniques de moissonnage',
#  "evacuer les personnes, les mettre en sécurité en cas d'accident, d'incendie et guider les secours",
#  'techniques de conservation de documents',
#  'génie énergétique',
#  "techniques d'application d'enrobés",
#  "evaluer les besoins sanitaires d'une structure",
#  'participer à une action ou mission de sauvegarde maritime',
#  'réaliser des prototypes en fourrure, peausserie',
#  "enregistrer les réservations et actualiser le plan d'occupation des tables, des salles du restaurant",
#  "assister techniquement les agents de l'équipe (explication de schéma de montage, difficultés techniques)",
#  'e-procurement',
#  'configurer et paramétrer un équipement ou un système électronique',
#  'terminologie du costume',
#  'etiqueter un produit',
#  'concevoir des interfaces ux/ui',
#  "mettre en place un système d'information de gestion",
#  'ecrire des critiques, essais',
#  'propriétés du plâtre',
#  "réaliser la démonstration d'un produit",
#  'pathologies fonctionnelles',
#  "etablir le bilan patrimonial d'un client",
#  'electricité moyenne tension',
#  'intervenir sur des chaudières de cogénération, régénération',
#  'réaliser des opérations de « travail aérien » nécessitant une qualification vérification de lignes électriques',
#  'intervenir dans le domaine de projets immobiliers',
#  'sciences paramédicales',
#  "réaliser une opération d'usinage d'empreintes",
#  'intervenir sur une ligne aérienne court courrier',
#  'analyser une demande de location',
#  'identifier les attentes des consommateurs',
#  'fonte à la cire perdue',
#  'produits de boulangerie',
#  'tracer, couper des plaques et panneaux de verre',
#  "modalités d'approvisionnement d'une ligne de production de première transformation de bois d'oeuvre",
#  'etablir une commande',
#  'poser des couches de revêtement de sols sportifs',
#  "réaliser le bilan des actions, proposer des axes d'amélioration à la personne et transmettre les informations aux interlocuteurs concernés",
#  'réaliser les différents comptes rendus de fin de vol et les transmettre au service concerné',
#  'caractéristiques des linges de maison',
#  "vérifier la disponibilité d'un produit",
#  'réaliser des pièces de charpente',
#  'réaliser des opérations de détourage (détoureuse, ...)',
#  'aquaculture',
#  'réaliser des opérations de « travail aérien » nécessitant une qualification lutte incendie',
#  "contrôler la conformité de réalisation d'un projet",
#  "surveiller et réguler le fonctionnement en mer d'installations auxiliaires",
#  "réaliser des forages d'extraction maritime (off-shore) à partir de navire à positionnement dynamique",
#  'monter un numéro visuel dans ses aspects techniques, artistiques, esthétiques',
#  "négocier les conditions d'achat d'un espace publicitaire",
#  'techniques de rééducation des troubles veino-lymphatiques',
#  'réceptionner et préparer des commandes à livrer (prélèvement, emballage, ...)',
#  'marquer un repère sur une toile ou un tissu',
#  'travail des métaux',
#  'réglementation du transport de marchandises',
#  'assister et apporter un appui technique sur les lieux de troubles à la tranquillité et à la sécurité publiques',
#  'traiter des métaux non ferreux',
#  'préparer des boissons chaudes ou froides',
#  'utilisation de mannequin de repassage',
#  'caractéristiques des fibres, résines, colles',
#  'utilisation de dégauchisseuse',
#  'régler des couches de revêtement de sols sportifs',
#  'transporter des matériaux de construction, btp',
#  'coordonner des opérations de transport de produits dangereux',
#  'trouver une solution amiable pour régler un litige entre propriétaires et locataires, faire respecter une servitude de passage, ...',
#  'réaliser un chapeau à plat',
#  'marketing relationnel',
#  'poser des ardoises',
#  "contrôler la fusion d'un métal",
#  'histoire des arts décoratifs',
#  "enregistrer les recettes d'une entreprise",
#  'appliquer de la laque à la main',
#  "sélectionner le fer en fonction de la mobilité, de l'effort et de la morphologie de l'animal et le former d'après l'empreinte",
#  "déterminer l'implantation des postes de travail",
#  'réaliser un montage/assemblage manuel de précision (petite chaudronnerie, micro-mécanique, optique, ...)',
#  'sélectionner les métaux, accessoires, produits, outils',
#  "réaliser la pose de film de protection pour l'entretien",
#  'réaliser des opérations de fret par transport aérien',
#  'façonner des sièges et des équipements de locaux publics',
#  'appareils de test aéronautique',
#  "rédiger un contrat d'assurance",
#  'caractéristiques des alliages de métaux',
#  "superviser et contrôler l'exécution d'études, de documents et de plans de détails confiés aux bureaux d'études",
#  'sélectionner une gamme de données géoréferencées sur requêtes selon la demande du client',
#  'connecter une boîte de raccordements',
#  "système d'exploitation hp-ux",
#  "contrôler la conformité d'un produit",
#  'réparer des fonds de cahiers',
#  'transpalettes à conducteur porté et préparateurs de commandes au sol (caces r 389-1)',
#  "vérifier et maintenir l'état de propreté des équipements (machines de remplissage, ensachage, étiquetage, ...) et du matériel",
#  "assister un client lors de la prise en main d'un outil/ équipement",
#  'utilisation de chantourneuse',
#  "réaliser des vêtements de cérémonie à partir d'un patron, d'un modèle",
#  'réaliser un relevé boursier',
#  'activités physiques pour tous',
#  'identifier les matières/produits (colorant, ingrédients, silice, terre, ...) nécessaires à la préparation (bains de teinture, composition du verre, ...)',
#  'mettre une grue de chantier en état de fonctionnement',
#  "réaliser la pose/dépose d'échafaudage ou de calorifuge",
#  "réaliser un gabarit (bois, métal), une épure de forme d'élément de structure",
#  "planifier les travaux d'entretien d'un site",
#  'langage informatique cobol',
#  'préparer des fils électriques',
#  'intervenir sur un camping-cars',
#  'caractéristiques des minerais',
#  "proposer des axes d'amélioration",
#  "critères de contrôle de l'équipement piloté (check list)",
#  'conception et dessin assistés par ordinateur (cao/dao)',
#  'techniques de diction',
#  "former des enseignants, des directeurs d'école",
#  'conseiller le client sur les différents produits (transports, prestations), effectuer la réservation et établir les documents contractuels',
#  "collecter des informations et préparer la leçon en séance (fiche de préparation, méthode d'apprentissage)",
#  'procédés de fabrication des produits à base de viandes',
#  "etablir un compte rendu d'analyse",
#  "règles d'installation informatiques",
#  "conduite d'un chariot-élévateur latéral",
#  'système temps réel',
#  'détecter les dysfonctionnements du véhicule et des équipements',
#  'audit environnemental',
#  "elaguer les branches d'un arbre",
#  'déployer un système de gestion des flux logistiques',
#  'intervenir sur des blocs nucléaires',
#  'réaliser une opération de tournage, fraisage',
#  "réaliser les dessins d'une pièce ou d'un ensemble",
#  'principes mécaniques du vol et de la navigation aérienne',
#  "coordonner des opérations d'entreposage",
#  'convoyer sur les pistes ou installer aux abords des aéronefs une passerelle télescopique',
#  'solliciter un appui logistique auprès des services concernés',
#  'installer du matériel de plantation',
#  'injecter un matériau (mousse, isolant, résine, colle, ...) lors du montage/assemblage',
#  'langue étrangère - espagnol des affaires',
#  'equipement de redressage de carrosserie',
#  'analyser le marché immobilier',
#  "réaliser des opérations de transformation sur des peaux d'animaux à fourrure (renard, astrakans, ...)",
#  'réaliser un test de contrôle de salinité',
#  'analyse des risques',
#  'découper, désosser, parer du mouton',
#  'réaliser une pose de charpentes, structures métalliques, tuyauteries, vitrages',
#  'procédures de maintenance de distributeurs automatiques',
#  'réaliser des démarches médico administratives',
#  'techniques de faucardage',
#  "démolir un site à l'explosif",
#  'poser des vitrages sur des ouvrages en bois',
#  "restaurer un élément du patrimoine ou d'une collection",
#  'techniques de garnissage',
#  "répertoire de musique d'opéra",
#  'réaliser des ornementations sur un tissu',
#  "procéder à des visites d'inspection et de contrôle des entreprises, des institutions sanitaires et sociales et vérifier l'application de la législation",
#  'conseiller un client sur les améliorations et obligations réglementaires liées à un bien immobilier',
#  'coordonner les prestations des praticiens, chercheurs',
#  'transmettre les techniques du métier ou mener des actions de sensibilisation au métier',
#  'protocoles de soins pré et post-opératoires',
#  'assembler des pièces synthétiques par soudure selon des repères ou indications',
#  'réaliser un soudage nécessitant la qualification soudage par point',
#  'déployer une prestation de transport dans le domaine routier national et communautaire',
#  'modalités de stockage',
#  'permis carte mer',
#  'ligaturer des têtes de bobines pour maintien de câbles (frettage)',
#  'parachever le brossage',
#  'formaliser une demande de transaction',
#  "identifier les conditions de réalisation d'une commande",
#  "réaliser la maintenance de premier niveau d'équipements de laboratoire",
#  "utilisation de centre d'usinage / prototypage rapide",
#  'caractéristiques des métaux non ferreux',
#  "usiner des éléments (barres de cuivre, ...) nécessaires au câblage d'armoires de puissance élevée",
#  'poser des verreries sur un chantier',
#  'effectuer une navigation fluviale sur un bateau bac',
#  'fabriquer un accessoire de musique (clé, anche, archet)',
#  'caractéristiques des textiles extensibles',
#  'intervenir sur des matériaux en métaux ferreux (fonte, acier, ...)',
#  'préparer le poisson pour la conservation',
#  "assister techniquement les conducteurs (modifications d'itinéraires, de délais) en cas de panne, accident",
#  'lancer des effets de lumières pendant un spectacle',
#  'adapter des articles de maroquinerie',
#  'représenter des clients devant la justice',
#  'réaliser un croquis, un dessin de pièce',
#  "système d'exploitation informatique open bsd",
#  'techniques de restauration traditionnelle',
#  'réaliser une opération de tirage de câbles',
#  'réaliser le bilan des animations touristiques',
#  'procédés de fabrication fibres courtes',
#  'cuire des pièces de viennoiserie',
#  'réaliser des mesures topométriques',
#  'annexes convention de washington (cites)',
#  "restaurer des bijoux et des pièces d'orfèvrerie",
#  'intervenir en méthodes process',
#  "repérer la présence de nuisibles et constater la nature et l'étendue des dégâts",
#  'montage de cordes',
#  'concevoir la composition de trains (types et nombre de wagons) en fonction du flux de passagers et/ou du fret',
#  'utilisation de gabarit',
#  "analyseur de gaz d'échappement",
#  'diagnostiquer une maladie ou une carence sur un arbre',
#  'réaliser la pose de visuels (adhésifs prédécoupés, impressions numériques, ...)',
#  'réaliser les essais de fonctionnement',
#  'réparer du matériel blanc (lavage, four, table de cuisson, réfrigérateur, congélateur, petit électroménager, ...)',
#  'procédures de prise en charge des enfants mineurs',
#  "effectuer le transit international d'un convoi de déménagement routier",
#  'réaliser des ciselures en repoussé direct',
#  "organiser et coordonner le circuit des informations sur le fonctionnement d'une structure",
#  'accrocher des éléments de décors sur des porteuses',
#  'caractéristiques des toitures en chaume',
#  'superviser une production',
#  'découper, désosser, parer du gibier, des viandes exotiques',
#  'langue des signes',
#  "suivre et animer un réseau d'assistants maternels (demandes d'agrément, formation, conseils, ...)",
#  "déterminer des solutions de constructions, d'installations et d'aménagements",
#  "soumettre des projets à l'appréciation d'un artiste,mannequin ou sportif",
#  'modalités de stockage des produits pharmaceutiques',
#  'caractéristiques du béton armé',
#  "assister le personnel médical habilité pour l'examen du corps ou la préparation de l'autopsie (manipulation, transfert)",
#  "etablir un rapport d'inspection et de contrôle",
#  'connecter des bobines (entre elles, sur plaque à bornes) avec des fils ou des barres',
#  'oganiser la diffusion de suports de communication',
#  'techniques de montage de sellerie',
#  'produits traiteurs et rôtisserie',
#  'appliquer la résine',
#  'pétrographie',
#  "réaliser des documents d'explorations, d'exploitations de sols, sous-sols (cartes, coupes, sections sismiques, ...)",
#  "réaliser des bordereaux d'expédition",
#  "repérer et positionner les éléments électriques, composants électroniques dans l'ordre d'assemblage ou alimenter la machine",
#  ...]

# %%
[i for i in pe_skills if len(i)==10]
# Out:
# ['biérologie',
#  'géomatique',
#  'optométrie',
#  'histologie',
#  'géographie',
#  'orthogénie',
#  'géothermie',
#  'optronique',
#  'régulation',
#  'cosmétique',
#  'management',
#  'radiologie',
#  'neurologie',
#  'aéraulique',
#  'diagraphie',
#  'généalogie',
#  'argenterie',
#  'handisport',
#  'sociologie',
#  'caséologie',
#  'gnomonique',
#  'mentalisme',
#  'orthopédie',
#  'métallerie',
#  'tapisserie',
#  'repoussage',
#  'zootechnie',
#  'endoscopie',
#  'sismologie',
#  'diététique',
#  'hydrologie',
#  'sportswear',
#  'leadership',
#  'métrologie',
#  'sémiotique',
#  'gemmologie',
#  'e-business',
#  'serrurerie',
#  'ethnologie',
#  'topométrie',
#  'dosimétrie',
#  'sténotypie',
#  'e-commerce',
#  'muséologie',
#  'sémiologie']

# %%
# list(df['savoir_faire_base'])

# %%
# df

# %%
# get_rules_v3(df, join(DATA_FILES, 'fr_skill_patterns_pole_emploi_v3.jsonl'))
get_rules_v4(pe_skills, join(DATA_FILES, 'fr_skill_patterns_pole_emploi_v2.jsonl'))
# Out:
#   0%|          | 0/11186 [00:00<?, ?it/s]

# %% [markdown]
# ## Rule Extraction

# %%
jo_df = pd.read_csv(join(DATA_REK, 'all_job_offers.csv'))

# %%
jo_df.head()
# Out:
#                                       job_title        city  \
# 0  Chargés de Clientèle en Assistance Technique  Casablanca
# 1                                   1  42 PHP 3      zerzer
# 2                                          JAVA  PARIS (75)
# 3                              110   Negotiator      Berlin
# 4         Responsable logistique et prodruction   Mohamédia
#
#                                         function  \
# 0                      Call Centers (métiers de)
# 1                       Journalisme / Traduction
# 2                 Communication / Publicité / RP
# 3                                Audit / Conseil
# 4  Production / Qualité / Sécurité / Maintenance
#
#                             sector Expérience requise  \
# 0      Informatique / Electronique       De 1 à 3 ans
# 1  Administration des ventes / SAV           Débutant
# 2                  Audit / Conseil      De 5 à 10 ans
# 3             Assurance / Courtage           Débutant
# 4           Aéronautique / Spatial       De 3 à 5 ans
#
#                                          Région Niveau d'étude et formation  \
# 0  10 poste(s) sur Casablanca et région - Maroc                      Bac +2
# 1                Agadir et région - Afghanistan     Qualification avant Bac
# 2                      Meknès et région - Maroc                         NaN
# 3                      Autres régions - Albanie                 Autodidacte
# 4   3 poste(s) sur Casablanca et région - Maroc                         NaN
#
#   Type de contrat Télétravail  \
# 0             CDI     no info
# 1             CDD     no info
# 2             CDI     no info
# 3             NaN     no info
# 4             CDI     no info
#
#                                          soft_skills  ...  \
# 0                                                NaN  ...
# 1  Rationalisme|Besoin d'autonomie|Recherche de n...  ...
# 2  Flexibilité|Extraversion|Ambition|Recherche de...  ...
# 3  Flexibilité|Organisation|Rationalisme|Besoin d...  ...
# 4  Besoin d'objectivité|Ténacité|Organisation|Rat...  ...
#
#   Qualités requises pour réussir dans ce rôle  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Ce que vous pouvez attendre de nous    pub_date    exp_date pub_date_day  \
# 0                                 NaN  05/06/2017  05/08/2017            5
# 1                                 NaN  12/12/2005  12/12/2006           12
# 2                                 NaN  28/01/2010  04/02/2010           28
# 3                                 NaN  09/11/2005  29/12/2005            9
# 4                                 NaN  02/02/2006  02/03/2006            2
#
#    pub_date_month pub_date_year exp_date_day exp_date_month exp_date_year
# 0               6          2017            5              8          2017
# 1              12          2005           12             12          2006
# 2               1          2010            4              2          2010
# 3              11          2005           29             12          2005
# 4               2          2006            2              3          2006
#
# [5 rows x 27 columns]

# %%
jo_df['Poste'] = jo_df['Poste'].replace(np.nan, '')
jo_df['Profil recherché'] = jo_df['Profil recherché'].replace(np.nan, '')
jo_df['Qualités requises pour réussir dans ce rôle'] = jo_df['Qualités requises pour réussir dans ce rôle'].replace(np.nan, '')

# %%
jo_df['post_data'] = jo_df['Poste']+jo_df['Profil recherché']+jo_df['Qualités requises pour réussir dans ce rôle']

# %%
jo_df.iloc[0,:]
# Out:
# job_title                                           Chargés de Clientèle en Assistance Technique
# city                                                                                  Casablanca
# function                                                               Call Centers (métiers de)
# sector                                                               Informatique / Electronique
# Expérience requise                                                                  De 1 à 3 ans
# Région                                              10 poste(s) sur Casablanca et région - Maroc
# Niveau d'étude et formation                                                               Bac +2
# Type de contrat                                                                              CDI
# Télétravail                                                                              no info
# soft_skills                                                                                  NaN
# Entreprise                                     Acteur global de l’outsourcing, Intelcia conju...
# Poste                                          Le chargé de clientèle en assistance technique...
# Profil recherché                               Compétences: Parfaite maîtrise de la langue fr...
# Adresse                                                   nearshore Park 1100, Boulevard Al Qods
# recruiter_id                                                                              127912
# job_offer_id                                                                                   0
# Poste avec Management                                                                        NaN
# Qualités requises pour réussir dans ce rôle
# Ce que vous pouvez attendre de nous                                                          NaN
# pub_date                                                                              05/06/2017
# exp_date                                                                              05/08/2017
# pub_date_day                                                                                   5
# pub_date_month                                                                                 6
# pub_date_year                                                                               2017
# exp_date_day                                                                                   5
# exp_date_month                                                                                 8
# exp_date_year                                                                               2017
# post_data                                      Le chargé de clientèle en assistance technique...
# Name: 0, dtype: object

# %%
jo_df['post_data'] = jo_df['post_data'].str.lower()

# %%
def get_skills(nlp,text):
    doc = fr_nlp(text)
    myset = []
    subset = []
    for ent in doc.ents:
        if ent.label_ == "SKILL":
            subset.append(ent.text)
    myset.append(subset)
    return subset

def get_all_skills(nlp,df, file_name):
    pbar = tqdm(total = df.shape[0])
    for i, rec in df.iterrows():
        added_data = {}
        post_data = rec['post_data']
        job_offer_id = rec['job_offer_id']
        post_data = post_data.lower()
        skills = get_skills(nlp, post_data)
        added_data['job_offer_id'] = job_offer_id
        added_data['skills'] = '|'.join(list(set(skills)))
        write_json_lines(file_name,added_data)
        pbar.update()

# %% [markdown]
# ### French Rule Extraction

# %%
skill_pattern_path = join(DATA_FILES,"fr_skill_patterns_v2.jsonl")
ruler = fr_nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_pattern_path)

# %%
get_all_skills(fr_nlp, jo_df, join(SKILL_OUT, 'fr_extracted_skills_v3.jsonl'))
# Out:
#   0%|          | 0/123991 [00:00<?, ?it/s]

# %%
jo_df.loc[0, "post_data"]
# Out:
# "Le chargé de clientèle en assistance technique a la principale mission de Recueillir puis traiter à distance les requêtes d'utilisateurs en difficulté au regard d'une utilisation de matériel informatique. Rattaché au responsable d'équipe, la mission consiste à : Gérer des demandes des utilisateurs par téléphone de manière optimale Diagnostiquer des problèmes système et réseau Prendre en compte et résoudre des incidents Traiter les demandes de changement en provenance des utilisateurs Avant de prendre en charge votre mission, une formation complète est assurée afin de vous préparer aux responsabilités qui vous seront confiées.Compétences: Parfaite maîtrise de la langue française, avec une bonne aisance à l’oral. Sens de l’écoute et de l’orientation. Bonne capacité de diagnostic et d'analyse. Connaissance générale des concepts de base et des techniques d’architecture des systèmes et des réseaux. Connaissance générale des différents systèmes d’exploitation usuels, des architectures matérielles, logicielles et de télécommunications. Expérience requise: Vous disposez idéalement d’une expérience réussie en assistance technique. Le + Intelcia Chez Intelcia, Vous êtes un talent qui va s’épanouir, grâce à notre management de proximité et à notre politique de formation et de développement. Nous vous offrons des opportunités de carrière au sein d’une entreprise en croissance continue, en plus d’une rémunération motivante et autres avantages (mutuelle..), vous aurez accès à un environnement de travail conçu autour de votre bien être (espaces de confort et restauration, transport, animations de la vie de l’entreprise). Chez Intelcia, vous faites partie d’une équipe qui partage des valeurs fortes : Transparence, Engagement, Excellence, Innovation . Votre réussite nous passionne."

# %%
read_json_lines(join(SKILL_OUT, 'fr_extracted_skills_v3.jsonl'))
# Out:
# [{'job_offer_id': 0,
#   'skills': 'utilisation de matériel|s’|résoudre des incidents|architectures matérielles|environnement de travail|gérer des demandes des utilisateurs par téléphone de manière|traiter à distance|diagnostiquer des problèmes système|traiter les demandes de changement en provenance|systèmes d’exploitation|prendre en charge|prendre en compte'},
#  {'job_offer_id': 1, 'skills': ''},
#  {'job_offer_id': 2, 'skills': ''},
#  {'job_offer_id': 110, 'skills': ''},
#  {'job_offer_id': 1015, 'skills': 'mécanique'},
#  {'job_offer_id': 1016, 'skills': ''},
#  {'job_offer_id': 1017, 'skills': 'gérer différentes tâches en même temps'},
#  {'job_offer_id': 1019, 'skills': ''},
#  {'job_offer_id': 1020,
#   'skills': 'aspects financiers|connaissance des normes'},
#  {'job_offer_id': 1021,
#   'skills': "résolution des problèmes|veiller à l'atteinte du chiffre d'affaire|satisfaction des clients|avoir une vision globale|optimiser la logistique|autres services|assurer la responsabilité du chiffre|envoyer votre dossier"},
#  {'job_offer_id': 1022,
#   'skills': "résolution des problèmes|veiller à l'atteinte du chiffre d'affaire|satisfaction des clients|avoir une vision globale|optimiser la logistique|autres services|assurer la responsabilité du chiffre|envoyer votre dossier"},
#  {'job_offer_id': 1023,
#   'skills': "traiter les problèmes|gérer l'escalade des problèmes avec l'appui du service|amélioration de la qualité|distribuer toute information relative|équipes techniques|service client|envoyer votre dossier|fournir un support technique de qualité|jouer un rôle de veille"},
#  {'job_offer_id': 1024,
#   'skills': 'assurer la responsabilité|optimiser le pilotage|cahier des charges|évaluation des risques|service client|envoyer votre dossier|changement rapide|mise en place'},
#  {'job_offer_id': 1025,
#   'skills': 'prise en compte|comprendre les causes initiales|mettre en place les process qualité|envoyer votre dossier|mise en place|plan d’action|prendre en charge les escalades techniques'},
#  {'job_offer_id': 1026,
#   'skills': 'répondre à leurs attentes en matière|courant indispensable|comprendre leurs besoins|envoyer votre dossier|recruter des managers'},
#  {'job_offer_id': 1027, 'skills': 'participer au montage des arrêtés'},
#  {'job_offer_id': 1028, 'skills': 'participer au montage des arrêtés'},
#  {'job_offer_id': 1029,
#   'skills': "bons de commande|gérer l'administratif du montage des arrêtés comptables|envoyer votre dossier"},
#  {'job_offer_id': 1030,
#   'skills': 'préparer les états intermédiaires pour les reportings|participer au montage des arrêtés|envoyer votre dossier'},
#  {'job_offer_id': 1044,
#   'skills': "interfaces graphiques|faire état de l’avancement|sein d'une équipe|nouvelles technologies|remonter les problèmes|envoyer votre dossier|code source|faire preuve|information technique|environnement de développement intégré"},
#  {'job_offer_id': 1045,
#   'skills': 'gérer les planning|suivi de défauts|veiller à la qualité|outils de gestion de configuration|nouvelles technologies|travail d’équipe|développement de projet|envoyer votre dossier|gestion de projet|améliorer la fiabilité des développements|gestion de projets'},
#  {'job_offer_id': 1046,
#   'skills': "interfaces graphiques|faire état de l’avancement|développement de projets|sein d'une équipe|nouvelles technologies|remonter les problèmes|envoyer votre dossier|code source|faire preuve"},
#  {'job_offer_id': 1047,
#   'skills': 'avoir un bon relationnel|coordonner le développement|mener vos missions|mettre en place|envoyer votre dossier|mise en place'},
#  {'job_offer_id': 1048,
#   'skills': 'conception technique|développement de projets|c#|travail en équipe|envoyer votre dossier'},
#  {'job_offer_id': 1049,
#   'skills': 'nouveaux clients|mise en œuvre|gestion de la relation'},
#  {'job_offer_id': 1050,
#   'skills': 'presse écrite|animer les réunions|accompagner les entreprises|communication interne|mener des entretiens de diagnostic en communication'},
#  {'job_offer_id': 1051,
#   'skills': 'envoyer votre dossier|maintenance du matériel informatique|l’environnement|systèmes d’information'},
#  {'job_offer_id': 1052,
#   'skills': 'développer vos résultats de manière mesurable'},
#  {'job_offer_id': 1053,
#   'skills': 'points de vente|remise en forme|l’intérieur|envoyer votre dossier|mettre en place'},
#  {'job_offer_id': 1054,
#   'skills': 'analyser le contenu des documents|effectuer les recherches nécessaires|créer un fond documentaire|assurer la qualité|outil informatique|recenser les besoins documentaires|envoyer votre dossier|droit d’auteur'},
#  {'job_offer_id': 1058,
#   'skills': 'génie mécanique|hygiène et de sécurité|suivre les commandes internes|assurer le suivi et les commande des consommables des produit|contrôler les activités du responsable du stock|respecter le planning de livraison du service commercial|préparer les véhicules neufs avant la livraison|veiller au respect du procédures|envoyer votre dossier|superviser l’équipe de la préparation vn|assurer la livraison des voitures neuves|assurer la réception|assurer les travaux de la préparation des voitures neuves|veiller au respect des normes|assurer la garde'},
#  {'job_offer_id': 1059,
#   'skills': "avancement des travaux|hygiène et de sécurité|assurer le contrôle des travaux réalisés par vos collaborateurs|superviser l’équipe de l'atelier mécanique|suivre les commandes internes|assurer la coordination de l'activité de l'équipe|répartir le volume de travail|veiller au respect du procédures|établir les devis de réparation|envoyer votre dossier|assurer la bonne exécution des travaux de réparation|contrôler la main d'œuvre|mécanique de préférence mécanique|contrôler les activités de ses collaborateurs|veiller au respect des normes|maintenir en bon état"},
#  {'job_offer_id': 1066,
#   'skills': 'motiver son équipe|milieu industriel|qualité au sein|qualité des produits'},
#  {'job_offer_id': 1068,
#   'skills': 'demandes de renseignements|gérer les besoins du cabinet|gérer le planning des patients|suivre le processus de sélection des dossiers|l’utilisation|envoyer votre dossier|outils informatiques'},
#  {'job_offer_id': 1070, 'skills': 'aspects financiers'},
#  {'job_offer_id': 1071,
#   'skills': 'bonne connaissance|envoyer votre dossier|développer le business infrastructure|systèmes d’information'},
#  {'job_offer_id': 1072,
#   'skills': 'bonne connaissance|développer le business|envoyer votre dossier'},
#  {'job_offer_id': 1073, 'skills': 'piloter des projets|envoyer votre dossier'},
#  {'job_offer_id': 1074,
#   'skills': 'conduire des projets applicatifs|analyse des besoins|bonne connaissance|envoyer votre dossier'},
#  {'job_offer_id': 1075,
#   'skills': 'conception technique|bonne connaissance|envoyer votre dossier'},
#  {'job_offer_id': 1076,
#   'skills': 'assurer le support technique des systèmes installés|gérer une relation|sein d’une équipe|installer nos solutions edi|analyser leurs besoins'},
#  {'job_offer_id': 1077, 'skills': 'directeur artistique'},
#  {'job_offer_id': 1078, 'skills': 'réaliser le budget.profil souhaité'},
#  {'job_offer_id': 1079,
#   'skills': 'bonne connaissance|faire preuve|développer notre portefeuille|envoyer votre dossier'},
#  {'job_offer_id': 1080,
#   'skills': 'droit commercial|toutes les activités|fournir les conseils légaux|droit de la consommation|protection des données|droit du travail'},
#  {'job_offer_id': 1081,
#   'skills': 'monde entier|suivre un parcours|normes internationales|intégrer une structure professionnelle|national et international'},
#  {'job_offer_id': 1082, 'skills': 'envoyer votre dossier'},
#  {'job_offer_id': 1083, 'skills': ''},
#  {'job_offer_id': 1084, 'skills': ''},
#  {'job_offer_id': 1086, 'skills': ''},
#  {'job_offer_id': 1087, 'skills': ''},
#  {'job_offer_id': 1088,
#   'skills': 'vérifier la cohérence|s’|vérifier certains points|faire des vérifications|modifier le texte|envoyer votre dossier'},
#  {'job_offer_id': 1089, 'skills': ''},
#  {'job_offer_id': 1091,
#   'skills': "faire preuve de qualités|ressources humaines|gestion du personnel|promouvoir la gestion des carrières|culture d’entreprise|plans de formation|élaborer la stratégie de l'entreprise en matière"},
#  {'job_offer_id': 1092,
#   'skills': 'fixer|faire preuve de grandes|animer les équipes'},
#  {'job_offer_id': 1093,
#   'skills': "surveiller ses applications opérationnelles|soutenir l'équipe commerciale|fixer des objectifs|gérer des budgets marketing|mettre en œuvre|déterminer des stratégies marketing"},
#  {'job_offer_id': 1094,
#   'skills': 'fournir des données fiables pour la structure commerciale|assurer la marge|s’|satisfaction des clients|assurer la résolution des problèmes commerciaux|développer la performance des membres de l’équipe|optimiser la logistique|gérer les ventes des produits|autres services'},
#  {'job_offer_id': 1096, 'skills': 'entrer en contact|pièces métalliques'},
#  {'job_offer_id': 1097, 'skills': "aide d'outils|toutes les activités"},
#  {'job_offer_id': 1098,
#   'skills': 'définir les objectifs|participer à la gestion|génie mécanique|assurer l’application des règles|gérer le suivi individuel des opérateurs|optimiser la productivité|veiller à la sécurité|évaluer la performance des opérateurs|promouvoir le présentiéisme de son équipe'},
#  {'job_offer_id': 1099, 'skills': ''},
#  {'job_offer_id': 1100, 'skills': ''},
#  {'job_offer_id': 1101, 'skills': 'formation technique'},
#  {'job_offer_id': 1102,
#   'skills': 'objectifs commerciaux|étroite collaboration|nouveaux produits|grande qualité'},
#  {'job_offer_id': 1103,
#   'skills': 'nouveaux produits|grande qualité|politiques commerciales|aspects techniques|objectifs commerciaux|l’administration'},
#  {'job_offer_id': 1104, 'skills': 'vente de produits'},
#  {'job_offer_id': 1105, 'skills': ''},
#  {'job_offer_id': 1106, 'skills': ''},
#  {'job_offer_id': 1109, 'skills': 'mise en place|mise en œuvre'},
#  {'job_offer_id': 1110,
#   'skills': 'gestion financière|contrôler les états financiers'},
#  {'job_offer_id': 1111,
#   'skills': 'esprit critique|réaliser les études quantitatives'},
#  {'job_offer_id': 1112,
#   'skills': 'respect de la réglementation|l’analyse|service de comptabilité'},
#  {'job_offer_id': 1113,
#   'skills': 'respect des procédures|conformité réglementaire'},
#  {'job_offer_id': 1115,
#   'skills': "veiller au perfectionnement du potentiel|amélioration de la qualité|atteindre les objectifs de productivité|garantir la sécurité des personnels de son secteur|assurer l'obtention|animer la fonction|respecter la politique environnementale du siteexpérience"},
#  {'job_offer_id': 1116,
#   'skills': 'autres personnes|résolution des problèmes|satisfaction des clients|gérer une équipe de 80|haut niveau|service client|gérer les appels entrants|autres services|assurer le développement|mettre en place des procédures|rédiger des rapports au directeur'},
#  {'job_offer_id': 1117,
#   'skills': 'c#|expertise sur sharepoint|spécifications techniques'},
#  {'job_offer_id': 1128,
#   'skills': 'l’environnement|gestion administrative|ressources humaines|gestion du personnel|femmes enceintes|professionnelle dans le domaine'},
#  {'job_offer_id': 1129,
#   'skills': 'génie mécanique|respecter le standard|respecter les besoins clients|mise à jour|respect des règles'},
#  {'job_offer_id': 1136,
#   'skills': 'optimiser le déroulement|informations relatives|optimiser notre intervention'},
#  {'job_offer_id': 1137,
#   'skills': 'collaborer avec le service informatique|optimiser notre système de contrôle|comptabilité analytique'},
#  {'job_offer_id': 1138,
#   'skills': 'développer nos parts de marchés nationaux|garantir un suivi|base de données'},
#  {'job_offer_id': 1139, 'skills': 'bonne connaissance'},
#  {'job_offer_id': 1140,
#   'skills': 'journalisme|gestion efficace|traitement des données|lignes directrices|assurer la confidentialité'},
#  {'job_offer_id': 1141,
#   'skills': 'bonne connaissance|journalisme|outils informatiques|collecter les informations|mener des enquêtes|animer des rubriques'},
#  {'job_offer_id': 1142,
#   'skills': 'bonne connaissance|journalisme|outils informatiques|collecter les informations|mener des enquêtes|animer des rubriques'},
#  {'job_offer_id': 1143,
#   'skills': 'esprit créatif|suivre le budget|autres services|organiser le service|gérer le planning'},
#  {'job_offer_id': 1144,
#   'skills': 'assurer un rôle de support sur les problématiques fortes|assurer la production|s’|gestion de projets'},
#  {'job_offer_id': 1145,
#   'skills': "veiller à la cohérence de l'information|prendre en charge les tâches suivantes|coordonner le travail du support administratif|analyser les demandes des clients"},
#  {'job_offer_id': 1146,
#   'skills': 'plans d’action|définir la stratégie marketing|assurer la cohérence des actions menées par votre équipe|campagnes publicitaires|assurer la veille concurrentielle|gérer le budget|définir le plan de communication externe|travailler en groupe|contribuer au développement|contrôler les études|mettre en place la politique de partenariat|diriger la politique marketing'},
#  {'job_offer_id': 1147,
#   'skills': 'réaliser les objectifs commerciaux fixés par la direction'},
#  {'job_offer_id': 1148, 'skills': 'changer les pièces|effectuer le dépannage'},
#  {'job_offer_id': 1149,
#   'skills': 'analyser le contenu des documents|créer un fond documentaire|assurer la qualité|gestion électronique|outil informatique|recenser les besoins documentaires|effectuer les recherches nécessaires ·'},
#  {'job_offer_id': 1150,
#   'skills': 'appels entrants|faire le suivi|suivi des demandes|traiter les demandes'},
#  {'job_offer_id': 1151, 'skills': 'bon déroulement'},
#  {'job_offer_id': 1152,
#   'skills': 'bonne connaissance|journalisme|bonne diction|collecter les informations|mener des enquêtes|animer des rubriques'},
#  {'job_offer_id': 1153,
#   'skills': 'appels entrants|faire le suivi|suivi des demandes|traiter les demandes'},
#  {'job_offer_id': 1154,
#   'skills': 'bonne connaissance|journalisme|bonne diction|collecter les informations|mener des enquêtes|animer des rubriques'},
#  {'job_offer_id': 1155,
#   'skills': 'appels entrants|faire le suivi|suivi des demandes|traiter les demandes'},
#  {'job_offer_id': 1156,
#   'skills': 'bonne connaissance|journalisme|bonne diction|collecter les informations|mener des enquêtes|animer des rubriques'},
#  {'job_offer_id': 1157,
#   'skills': 'bonne connaissance|appels entrants|faire le suivi|traiter les demandes|suivi des demandes'},
#  {'job_offer_id': 1158,
#   'skills': 'participer au développement|documentation technique|spécifications techniques|participer à la recette|assurer les développements|suivre des consignes de développement'},
#  {'job_offer_id': 1159, 'skills': 'bonne connaissance|l’analyse|journalisme'},
#  {'job_offer_id': 1160, 'skills': 'formation aux techniques|mise en œuvre'},
#  {'job_offer_id': 1161,
#   'skills': "animer des émissions|participer à l'élaboration"},
#  {'job_offer_id': 1162, 'skills': 'formation aux techniques|mise en œuvre'},
#  {'job_offer_id': 1163,
#   'skills': 'formation aux techniques|l’analyse|bonne connaissance'},
#  {'job_offer_id': 1164, 'skills': 'formation aux techniques|mise en œuvre'},
#  {'job_offer_id': 1165,
#   'skills': 'formation aux techniques|l’analyse|bonne connaissance'},
#  {'job_offer_id': 1166, 'skills': 'formation aux techniques|mise en œuvre'},
#  {'job_offer_id': 1167, 'skills': 'formation aux techniques|mise en œuvre'},
#  {'job_offer_id': 1168,
#   'skills': 'formation aux techniques|l’analyse|bonne connaissance'},
#  {'job_offer_id': 1170,
#   'skills': "anticiper les problèmes|gestion des dossiers|répondre à leurs attentes en matière|comprendre leurs besoins|gérer l'ensemble des aspects|assurer le suivi administratif|veiller au respect des valeurs|méthodes de gestion|recruter des managers"},
#  {'job_offer_id': 1172, 'skills': ''},
#  {'job_offer_id': 1173,
#   'skills': 'génie mécanique|hygiène et de sécurité|suivre les commandes internes|assurer le suivi et les commande des consommables des produit|contrôler les activités du responsable du stock|respecter le planning de livraison du service commercial|préparer les véhicules neufs avant la livraison|veiller au respect du procédures|envoyer votre dossier|superviser l’équipe de la préparation vn|assurer la livraison des voitures neuves|assurer la réception|assurer les travaux de la préparation des voitures neuves|veiller au respect des normes|assurer la garde'},
#  {'job_offer_id': 1174, 'skills': ''},
#  {'job_offer_id': 1175, 'skills': ''},
#  {'job_offer_id': 1176, 'skills': ''},
#  {'job_offer_id': 1177, 'skills': ''},
#  {'job_offer_id': 1178, 'skills': ''},
#  {'job_offer_id': 1179, 'skills': ''},
#  {'job_offer_id': 1180, 'skills': 'self-'},
#  {'job_offer_id': 1181, 'skills': ''},
#  {'job_offer_id': 1182, 'skills': ''},
#  {'job_offer_id': 1183, 'skills': ''},
#  {'job_offer_id': 1189,
#   'skills': "fixer|analyser le portefeuille produits de la société|gérer les budgets fonctionnels et opérationnels|mener les études|définir une stratégie pour l'ensemble des produits|analyser les opportunités des produits|coacher l'ensemble|évaluer les équipes|marketing stratégique|assurer le développement optimal des axes stratégiques|planifier les opérations de promotion"},
#  {'job_offer_id': 1190,
#   'skills': 'étroite collaboration|travailler en équipe|mise en service|nouvelles technologies|l’apprentissage|l’internet'},
#  {'job_offer_id': 1192, 'skills': ''},
#  {'job_offer_id': 1194, 'skills': 'conseil technique'},
#  {'job_offer_id': 1198,
#   'skills': 'documents nécessaires|commerce international|assurer la gestion des comptes en admission|assurer le volet export|travail de terrain|sein d’une équipe|outil informatique|assurer la gestion des commandes export|assurer le bon|apporter un support à la performance du service'},
#  {'job_offer_id': 1199,
#   'skills': 'domaine du génie civil|faire preuve d’esprit|outil informatique|travail en équipe|génie civil'},
#  {'job_offer_id': 1200,
#   'skills': 'technique d’évaluation|mécanique|aspects techniques|compétences techniques'},
#  {'job_offer_id': 1201,
#   'skills': 'optimiser les résultats|marché marketing|développer un portefeuille de clients existants|prospecter de nouveaux clients|marché commercial'},
#  {'job_offer_id': 1202,
#   'skills': 'assurer le suivit des devis|fixer|bonne connaissance|conduire la stratégie commerciale|évaluer un dossier avec méthode|proposer des axes de développement commerciaux|preuve de qualités|assurer le développement de la clientèle|définir une stratégie commerciale'},
#  {'job_offer_id': 1203,
#   'skills': 'élaborer une cuisine rentable|respecter les normes'},
#  {'job_offer_id': 1204,
#   'skills': 'outil informatique|marché des technologies|journalisme'},
#  {'job_offer_id': 1205,
#   'skills': 'animer les forums|outil informatique|veiller à la qualité'},
#  {'job_offer_id': 1206,
#   'skills': 'c#|organiser l’équipe de développement.de formation|expertise sur sharepoint|spécifications techniques'},
#  {'job_offer_id': 1207, 'skills': ''},
#  {'job_offer_id': 1208,
#   'skills': 'mise en place|outil de gestion|développer des outils de communication web|gérer des opérations journalières'},
#  {'job_offer_id': 1211, 'skills': 'outil informatique|gérer son équipe'},
#  {'job_offer_id': 1212, 'skills': ''},
#  {'job_offer_id': 1213,
#   'skills': 'assurer la pérennité de leur image de marque|analyse des besoins'},
#  {'job_offer_id': 1215,
#   'skills': 'étroite collaboration|commerce international|bonne connaissance|travailler en équipe|valeur ajoutée|équipes techniques|analyse des besoins|haut niveau|assurer le développement|systèmes d’information'},
#  {'job_offer_id': 1216,
#   'skills': "prendre des rdv commerciaux|assurer la partie administrative de notre représentation|assurer l'accueil|prendre les appels|assurer les missions suivantes"},
#  {'job_offer_id': 1218, 'skills': ''},
#  {'job_offer_id': 1220,
#   'skills': 'assurer le développement|prendre des risques|qualité de service|travailler en équipe'},
#  {'job_offer_id': 1221,
#   'skills': 'gérer les éditions|assurer le filtrage téléphonique|organiser les réunions de travail|gérer le secrétariat courant du directoire|comptes rendus|gérer des tâches|gérer les différentes tâches|assurer l’accueil des visiteurs|outils informatiques'},
#  {'job_offer_id': 1222,
#   'skills': 'assurer la relation entre son service|utiliser|développer le portefeuille de clients existants|analyser les besoins et la qualité des prospects|animer le réseau|analyse financière|outils informatiques|vendre le produit|veiller au respect des procédures|préserver les intérêts|veiller à la qualité|respecter les procédures internes|vendre aux meilleures|autres services|traiter les anomalies|gérer les tâches suivantes|suivre l’état du parc client|gérer les relances téléphoniques'},
#  {'job_offer_id': 1223,
#   'skills': 'bonne connaissance|communiquer toute information nécessaire|suivre les délais d’immobilisation|donner des accords|contrôler des accords|communiquer les informations techniques|gérer la base de données véhicules|veiller à la qualité|gérer des tâches|mécanique|outils informatiques|gérer les tâches suivantes|contrôler les factures par rapports aux accords'},
#  {'job_offer_id': 1226,
#   'skills': "optimiser les moyens humains|assurer la responsabilité de l'organisation|ressources techniques|conduire des projets informatiques|outils de gestion|avoir les capacités d'analyse|avoir le sens"},
#  {'job_offer_id': 1227,
#   'skills': "avoir le sens critique|suivre la mise en force des crédits|bonne connaissance|avoir une bonne maîtrise|respect de la réglementation|effectuer des analyses financières|avoir l'esprit d'équipe|suivre les tendances du marché"},
#  {'job_offer_id': 1228,
#   'skills': 'travailler en équipe|respecter les normes|cahier des charges|écrire les composanrs|tenir compte|accompagner le déploiement'},
#  {'job_offer_id': 1229,
#   'skills': 'améliorer son niveau technique|entretenir des relations avec la clientèle|travail en équipe|posséder le sens commercial|assurer le suivi|avoir une volonté permanente|avoir une capacité réelle'},
#  {'job_offer_id': 1230,
#   'skills': 'gérer des relations avec une clientèle exigeante|assurer un remplissage maximum en permanence.jeune|site internet|outil informatique|gérer les difficultés de planning en cas|déterminer les disponibilités en temps|optimiser le remplissage|demandes de réservation'},
#  {'job_offer_id': 1232,
#   'skills': 'gérer les missions suivantes|bonne connaissance|systèmes d’information|assurer le support de 1er niveau|communiquer avec nos structures|compétences techniques'},
#  {'job_offer_id': 1233,
#   'skills': 'gérer les missions suivantes|bonne connaissance|systèmes d’information|assurer le support de 1er niveau|communiquer avec nos structures|compétences techniques'},
#  {'job_offer_id': 1234,
#   'skills': 'développer votre portefeuille|esprit d’équipe|outil informatique|animer les points'},
#  {'job_offer_id': 1236, 'skills': 'transférer via le système'},
#  {'job_offer_id': 1237,
#   'skills': 'prendre des initiatives|définir la stratégie relative|définir le plan|outil informatique|stratégie marketing'},
#  {'job_offer_id': 1238,
#   'skills': 'constituer une base de donnée|manière efficace|renforcer la capacité des entreprises|assurer une veille informationnelle sur le secteur|organiser les événements de promotion du secteur|effectuer des déplacements|marché américain|mise en place|maintenir la relation avec les associations'},
#  {'job_offer_id': 1239,
#   'skills': 'management de la qualité|gérer les tâches suivantes|gestion de la qualité|directeur de production'},
#  {'job_offer_id': 1240,
#   'skills': 'développement personnel|conditions de travail|mise en œuvre'},
#  {'job_offer_id': 1241,
#   'skills': 'proposer des orientations stratégiques|développement personnel|conditions de travail|réaliser les études quantitatives'},
#  {'job_offer_id': 1249, 'skills': 'service client|ingénierie financière'},
#  {'job_offer_id': 1252, 'skills': 'étude de faisabilité'},
#  {'job_offer_id': 1253,
#   'skills': 'autres services|rédiger les schémas comptables de la bmci'},
#  {'job_offer_id': 1254,
#   'skills': 'appel d’offres|réaliser les activités suivantes|analyse des besoins|autres services|garantir la qualité du processus'},
#  {'job_offer_id': 1255,
#   'skills': 'apporter un service de qualité|concrétiser des opportunités commerciales.de'},
#  {'job_offer_id': 1256,
#   'skills': "optimiser l'utilisation des ressources|formuler toute proposition susceptible|maîtriser les outils de pilotage|travailler en équipe|évaluer les performances financières|conduire des actions d'information|maîtriser les mécanismes de construction|développer de nouveaux outils|performances financières|conduire les études|construire un compte d'exploitation|juger les données|analyser les composantes des résultats|participer à l'élaboration|concevoir des outils locaux"},
#  {'job_offer_id': 1258,
#   'skills': 'outils informatiques|tenir une discussion|gérer un portefeuille d’une soixantaine de clients|rédiger des synthèses et notes en anglais'},
#  {'job_offer_id': 1259,
#   'skills': 'gestion de stock|face à la pression|aspects techniques|gestion de transport|planification stratégique|superviser les activités d’|mécanique|définir les objectifs pour votre département|compétences techniques|livrer le produit'},
#  {'job_offer_id': 1261,
#   'skills': 'déposer votre candidature|l’environnement|transférer votre dossier de candidature'},
#  {'job_offer_id': 1262,
#   'skills': 'développement personnel|accompagner les actions|sein d’une équipe|mise en œuvre|travail en équipe'},
#  {'job_offer_id': 1265,
#   'skills': 'gérer les tâches suivantes|gérer les missions de reporting et de gestion'},
#  {'job_offer_id': 1266,
#   'skills': 'vendre les produits|gérer la négociation commerciale|suivre les processus de facturation|effectuer vos reportings à la direction commerciale|gérer les tâches suivantes'},
#  {'job_offer_id': 1272,
#   'skills': 'contribuer à l’|mettre en œuvre le plan de formation|superviser la gestion des contrats spéciaux|ressources humaines|préparer le cahier des charges|superviser la mise en œuvre du plan|système d’information|plan de formation|l’exploitation|gérer les réponses aux appels'},
#  {'job_offer_id': 1273,
#   'skills': 'intégrer une équipe jeune|concevoir des accroches publicitaires|créer des chartes graphiques|travailler sur différents projets transversaux|contrôler la qualité des livraisons de prestataires|concevoir des animations en flash'},
#  {'job_offer_id': 1274,
#   'skills': 'techniques de gestion|superviser le traitement|suivre la mise en œuvre des plans|techniques de contrôle|déposer votre candidature|assurer la disponibilité|animer le processus de contrôle de gestion|service clients|milieu industriel'},
#  {'job_offer_id': 1276,
#   'skills': 'travailler en étroite collaboration|systèmes de gestion|nouvelles méthodes|assurer la communication|suivre les évaluations à froid|ressources humaines|accompagner la mise en place|travail en équipe|mise en place|bonnes pratiques|gestion de projets'},
#  {'job_offer_id': 1277, 'skills': ''},
#  {'job_offer_id': 1278, 'skills': 'documents nécessaires|outil informatique'},
#  {'job_offer_id': 1282,
#   'skills': 'mise en place|valeur ajoutée|accès aux services'},
#  {'job_offer_id': 1286,
#   'skills': 'assurer le recouvrement amiable des créances|mesurer les risques financiers|prendre les décisions nécessaires'},
#  {'job_offer_id': 1287,
#   'skills': "résolution des problèmes|veiller à l'atteinte du chiffre d'affaire|satisfaction des clients|avoir une vision globale|équipe de vente|optimiser la logistique|autres services|assurer la responsabilité du chiffre"},
#  {'job_offer_id': 1288,
#   'skills': 'revoir les process|répondre à leurs attentes en matière|améliorer la productivité|comprendre leurs besoins|mettre en place|avoir une bonne expérience|recruter des managers|communication interne'},
#  {'job_offer_id': 1289,
#   'skills': "coordination avec le service|évolution de la demande|actualiser la stratégie|comprendre l'environnement|coordonner la réalisation des actions|assurer la communication interne sur les produits|définir les objectifs qualitatifs|optimiser l'implication du terrain|participer à l'effort de relation publique|proposer les objectifs quantitatifs|contribuer à l'étude de projet stratégique"},
#  {'job_offer_id': 1290, 'skills': 'service client|ingénierie financière'},
#  {'job_offer_id': 1297, 'skills': ''},
#  {'job_offer_id': 1300,
#   'skills': "procédés de fabrication|ligne de production|gérer efficacement l'implantation|optimiser le temps de fabrication|lancement de nouveaux|mécanique|milieu industriel"},
#  {'job_offer_id': 1301,
#   'skills': 'assurer une relation commerciale entre notre société|étroite collaboration|gérer ses missions en travaillant|s’|respecter la politique qualité|proposer des solutions|marché local|différents services'},
#  {'job_offer_id': 1303,
#   'skills': 'appliquer les dispositions du système de management|l’environnement|gérer en parallèle|veiller au respect des délais|coordonner la sous-traitance|systèmes d’information'},
#  {'job_offer_id': 1304,
#   'skills': 'réaliser les travaux dans le respect des engagements en terme|participer à la mise en œuvre|nouvelles technologies|mise en place|gestion de projets'},
#  {'job_offer_id': 1305,
#   'skills': 'sélectionner des opportunités d’investissements|piloter la mise en place de fonds immobiliers'},
#  {'job_offer_id': 1306,
#   'skills': 'assurer le développement des missions de conseil'},
#  {'job_offer_id': 1307, 'skills': 'étude de faisabilité|cadre de projets'},
#  {'job_offer_id': 1308,
#   'skills': 'ingénierie financière|contribuer à la réalisation de missions de conseil'},
#  {'job_offer_id': 1309, 'skills': 'ingénierie financière'},
#  {'job_offer_id': 1310,
#   'skills': 'mettre en œuvre les meilleures pratiques de gestion|étroite collaboration|l’administration'},
#  {'job_offer_id': 1311,
#   'skills': 'étroite collaboration|bases de données|travailler en équipe avec les gestionnaires des systèmes|l’administration|prendre en charge'},
#  {'job_offer_id': 1312, 'skills': 'techniques de conduite|utiliser'},
#  {'job_offer_id': 1313, 'skills': 'analyse financière|conseil en stratégie'},
#  {'job_offer_id': 1314, 'skills': "mener à bien l'ensemble des tâches"},
#  {'job_offer_id': 1315, 'skills': ''},
#  {'job_offer_id': 1316, 'skills': 'nouvelles technologies|travail en équipe'},
#  {'job_offer_id': 1317,
#   'skills': 'solutions innovantes|développer de nouvelles offres|nouveaux clients|développer des partenariats|nouvelles technologies|mettre en œuvre la stratégie commerciale|optimiser la performance des ingénieurs'},
#  {'job_offer_id': 1318,
#   'skills': "systèmes d'information|présentation des résultats|bases de données|programmes de fidélisation|mise en place|outils informatiques"},
#  {'job_offer_id': 1319, 'skills': ''},
#  {'job_offer_id': 1320, 'skills': ''},
#  {'job_offer_id': 1322,
#   'skills': 'faire vivre la politique qualité de la société|motiver des équipes|superviser une équipe composée de responsables qualité|mettre en place|compétences techniques'},
#  {'job_offer_id': 1323, 'skills': ''},
#  {'job_offer_id': 1324,
#   'skills': "équipes techniques|domaine de l’|travail d'équipe"},
#  {'job_offer_id': 1327,
#   'skills': 'gérer les indicateurs rh du centre|s’|veiller au maintien du climat|l’environnement|gestion administrative|veiller au respect|gestion des ressources humaines|communication interne'},
#  {'job_offer_id': 1328, 'skills': ''},
#  {'job_offer_id': 1329,
#   'skills': 'gestion des ressources humaines|ressources humaines'},
#  {'job_offer_id': 1330,
#   'skills': "formation technique|état de fonctionnement|garantir la pertinence du choix des constructeurs|gestion d'un parc"},
#  {'job_offer_id': 1331,
#   'skills': "systèmes d'information|piloter la mise en oeuvre des projets|outil informatique|assurer la consolidation du reporting périodique pour la direction"},
#  {'job_offer_id': 1332, 'skills': 'outil informatique'},
#  {'job_offer_id': 1333,
#   'skills': 'activités commerciales|visiter des clients à l’|apprendre des langues étrangères|faciliter la communication entre le client|exercer les fonctions suivantes'},
#  {'job_offer_id': 1334,
#   'skills': "définir la stratégie commerciale|fixer|bonne connaissance|définir les moyens adéquats|canaux de distribution|mettre en œuvre la politique|développer l'offre|superviser la stratégie commerciale|contribuer à la définition de la politique tarifaire|identifier des canaux de distribution|prendre des décisions"},
#  {'job_offer_id': 1335,
#   'skills': 'gérer les missions suivantes|s’|entretien du matériel|maintenance préventif|respect de l’environnement|mise en place|règles de sécurité|prévention des risques'},
#  {'job_offer_id': 1336,
#   'skills': 'mettre en place la gestion du laboratoire|sécurité du personnel|assurer l’organisation de nos agréages|réaliser les agréages|veiller au respect des procédures|mettre en pratique les procédures hygiènes|participer à la réalisation des objectifs qualité|participer à la mise en place des procédures agréages|outil informatique|mettre en place la démarche|gérer les équipes de travail'},
#  {'job_offer_id': 1337,
#   'skills': 'respect des procédures|prendre des initiatives|contrôler la fiabilité des comptes|travailler en équipe|préparer les reportings et tableaux|remettre toute information|outil informatique|gérer les tâches suivantes|préparer les états financiers périodiques'},
#  {'job_offer_id': 1338,
#   'skills': "prendre des initiatives|travailler en équipe|logiciels de bureautique|présenter des projets d'investissements|suivre les participations en portefeuille|outil informatique|réaliser les opérations de cession|gérer les tâches suivantes|sein d'une société"},
#  {'job_offer_id': 1339,
#   'skills': "génie civil|assurer la production|assurer l'interface avec le client"},
#  {'job_offer_id': 1340,
#   'skills': 'animer une équipe|gérer les ventes.nous recherchons|développer les porte-feuilles'},
#  {'job_offer_id': 1341,
#   'skills': 'sécurité et le respect|gérer le budget d’entretien mécanique|superviser les travaux d’entretien curatif|améliorer les coûts d’entretien|animer les réunions|planifier les différentes opérations de maintenance|améliorer les performances des équipements|mécanique'},
#  {'job_offer_id': 1342,
#   'skills': 'bonne connaissance|participer à des projets de développement java|respect des normes|envoyer votre dossier|participer à des projets de tierce'},
#  {'job_offer_id': 1343,
#   'skills': 'bonne connaissance|piloter des projets|envoyer votre dossier'},
#  {'job_offer_id': 1344,
#   'skills': 'bonne connaissance|déploiement des modules|base de données|différents environnements|outils de développement|l’installation|envoyer votre dossier|environnement de développement'},
#  {'job_offer_id': 1345,
#   'skills': "fibre optique|assurer le déploiement du réseau d'accès|répondre aux besoins de transmission|sélectionner les offres|garantir la capacité de transmission suffisante|optimiser le réseau d'accès|valeur ajoutée|mise en service"},
#  {'job_offer_id': 1346,
#   'skills': 'valeur ajoutée|droit commercial|assurer la veille|assurer le conseil juridique'},
#  {'job_offer_id': 1347,
#   'skills': "systèmes d'information|base de données|valeur ajoutée|assurer la disponibilité du réseau informatique|effectuer la maintenance corrective|administrer le réseau"},
#  {'job_offer_id': 1348,
#   'skills': "systèmes d'information|assurer la sécurité des données|administrer la plate forme|fournir aux prestataires|valeur ajoutée|gérer les sauvegardes de toutes|assurer la sécurité du réseau informatique"},
#  {'job_offer_id': 1349,
#   'skills': "systèmes d'information|assurer l’administration du système|valeur ajoutée|assurer la gestion|effectuer les opérations de gestion de profils|effectuer les opérations d’administration"},
#  {'job_offer_id': 1350,
#   'skills': 'valeur ajoutée|mettre à disposition des business units|analyser les bases de données|bases de données|orienter la réalisation'},
#  {'job_offer_id': 1351,
#   'skills': 'valeur ajoutée|l’installation|suivre les projets'},
#  {'job_offer_id': 1352,
#   'skills': "suivre son évolution.diplômé|proposer les scénarios d'évolution|garantir la cohérence|valeur ajoutée|définir les standards|superviser les opérations de construction"},
#  {'job_offer_id': 1353,
#   'skills': 'valeur ajoutée|mettre en place les actions de rétention|retenir les clients|suivre la qualité de prestation|réduire le churn'},
#  {'job_offer_id': 1354,
#   'skills': 'définir les projets|analyser les profils des clients|fournir des recommandations|valeur ajoutée|analyser les réclamations|suivre les actions de fidélisation|suivre une stratégie de fidélisation pour les clients|mesurer la satisfaction|mettre en place|mise en place|répondre aux besoins des clients'},
#  {'job_offer_id': 1355,
#   'skills': 'coordonner les études de définitions|garantir la disponibilité du réseau|réseau informatique|superviser les opérations de maintenance|cahier de charge|coordonner les projets de déploiement|valeur ajoutée'},
#  {'job_offer_id': 1356,
#   'skills': "réaliser des analyses|systèmes d'information|vérifier la fiabilité des données par la suite.diplômé|base de données|avoir un outil fiable|valeur ajoutée|satisfaire les besoins|modéliser les outils|optimiser les outils|mettre en place"},
#  {'job_offer_id': 1357,
#   'skills': "contrôler l'intégration de nouvelles|planifier|assurer la couverture|valeur ajoutée"},
#  {'job_offer_id': 1358,
#   'skills': "assurer le déploiement du réseau d'accès|répondre aux besoins de transmission|sélectionner les offres|garantir la capacité de transmission suffisante|valeur ajoutée|planifier|mise en service|gérer l'ingénierie"},
#  {'job_offer_id': 1359,
#   'skills': 'ressources humaines|milieu industriel|l’organisation|suivi des actions|participer au développement des ressources|plan de formation'},
#  {'job_offer_id': 1360,
#   'skills': 'réaliser cette mission|l’organisation|travail en équipe|développer une équipe|gérer les aspects financiers de la société|systèmes d’information'},
#  {'job_offer_id': 1361,
#   'skills': 'assurer les objectifs de rentabilité|développer les résultats|optimiser sa rentabilité|garantir l’évolution des compétences|assurer l’application de la promesse|former vos équipes|assurer la satisfaction des clients|organiser une activité|développer vos qualités|prendre des décisions'},
#  {'job_offer_id': 1362,
#   'skills': 'développer vos qualités|assurer l’application de la promesse|assurer la satisfaction des clients'},
#  {'job_offer_id': 1363,
#   'skills': 'bonne connaissance|gérer les réponses aux mails techniques'},
#  {'job_offer_id': 1364,
#   'skills': 'produits chimiques|compétences techniques|nouvelles opportunités|nouveaux contrats'},
#  {'job_offer_id': 1365,
#   'skills': "qualité de service|présenter l'offre technique|valeur ajoutée|planifier|mettre en place une offre sur mesure|maintenir un portefeuille de clients"},
#  {'job_offer_id': 1366,
#   'skills': 'anticiper les problèmes|bonne connaissance|s’|coordonner les équipes|l’environnement|veiller au respect|gérer les indicateurs rh du site'},
#  {'job_offer_id': 1367, 'skills': 'assister dans les tâches suivantes'},
#  {'job_offer_id': 1368,
#   'skills': 'service client|former des débutants|dispenser une formation|membres du personnel'},
#  {'job_offer_id': 1369,
#   'skills': 'gamme de produits|développer les portefeuilles clients|gérer les ventes|participer au développement de produits|produits dans l’industrie|développer un réseau de distribution|suivi des clients'},
#  {'job_offer_id': 1371,
#   'skills': 'bonne connaissance|base de données|ressources humaines|suivi des actions|développement professionnel'},
#  {'job_offer_id': 1372,
#   'skills': 'garantir le respect du cahier des charges|l’exploitation|suivre les plantations'},
#  {'job_offer_id': 1376,
#   'skills': "résolution des problèmes|service client|traiter les problèmes + questions|coordonner le travail d'équipes|gérer l'escalade des problèmes"},
#  {'job_offer_id': 1377, 'skills': 'outil informatique|directeur artistique'},
#  {'job_offer_id': 1378,
#   'skills': 'modes opératoires|garantir le bon état|proposer des améliorations terrain|analyser les rebuts|réaliser les contrôles en production|esprit d’équipe|réaliser les audits de poste|créer les documents d’acceptation des produits|mécanique|assurer la polyvalence'},
#  {'job_offer_id': 1379,
#   'skills': 'réaliser les devis liés|peindre les pompes|assurer l’assistance téléphonique|esprit d’équipe|outils informatiques|mécanique|demandes des clients'},
#  {'job_offer_id': 1380,
#   'skills': 'service après-vente|prise de commande|équipe dans un environnement|connaissances en informatique'},
#  {'job_offer_id': 1381,
#   'skills': 'service de comptabilité|fournir une assitance téléphonique fonctionnelle'},
#  {'job_offer_id': 1382,
#   'skills': "plans de formation|animer l'activité|mise en place|contribuer au développement des compétences|gestion de projets"},
#  {'job_offer_id': 1383, 'skills': 'outils informatiques|différents services'},
#  {'job_offer_id': 1385,
#   'skills': 'suivre les adaptations|faire les recherches de tissu et accessoires|collaborer avec l’équipe de modélistes|préparer des rapports sur l’orientation de mode|faire partie d’une équipe dynamique|contribuer à la réalisation des patronages|exercer les fonctions suivantes|suivre les tendances de mode avec une actualisation'},
#  {'job_offer_id': 1387,
#   'skills': 'gestion administrative|législation sociale|environnement international|mettre en place|développer votre fonction|respect des règles'},
#  {'job_offer_id': 1388,
#   'skills': 'unité de production|ressources humaines|respect des normes|évaluation des risques|l’élaboration|sein d’un groupe|garantir l’adhésion de l’|l’organisation|mise en œuvre|mettre en œuvre|hygiène et sécurité|compétences techniques'},
#  {'job_offer_id': 1389,
#   'skills': 'nouveaux produits|renforcement du positionnement|améliorer les résultats|marché marocain|moyen terme'},
#  {'job_offer_id': 1390,
#   'skills': 'environnement international|superviser les équipes de production|participer à la planification'},
#  {'job_offer_id': 1391,
#   'skills': 'créer les contacts nécessaires|mise en œuvre'},
#  {'job_offer_id': 1392,
#   'skills': 'ressources nécessaires|ressources humaines|développer votre fonction|identifier les ressources optimales|environnement international|nouvelles technologies|suivi des actions|garantir le respect des méthodologies|mise en place|processus de développement|compétences techniques|gérer les hommes et les situations'},
#  {'job_offer_id': 1393,
#   'skills': 'ressources humaines|travailler dans un cadre de travail|milieu industriel|l’organisation|suivi des actions|participer au développement des ressources|plan de formation'},
#  {'job_offer_id': 1394,
#   'skills': 'gérer le support aux utilisateurs ainsi|bonne connaissance'},
#  {'job_offer_id': 1395,
#   'skills': 'mise en place|audit interne|l’analyse|outils informatiques'},
#  {'job_offer_id': 1396,
#   'skills': 'sécurité des réseaux|résoudre une problématique|qualité de services|besoins des clients|mise en œuvre|mise en place|systèmes d’information'},
#  {'job_offer_id': 1397,
#   'skills': 'gérer des projets dans leur globalité|aspects techniques'},
#  {'job_offer_id': 1398,
#   'skills': 'expert technique|ressources nécessaires|gérer en parallèle|assurer le montage|gestion de projet'},
#  {'job_offer_id': 1399, 'skills': 'outil informatique'},
#  {'job_offer_id': 1400,
#   'skills': "veiller à la cohérence de l'information|prendre en charge les tâches suivantes|coordonner le travail du support administratif|analyser les demandes des clients"},
#  {'job_offer_id': 1401, 'skills': 'gérer les tâches suivantes'},
#  {'job_offer_id': 1403,
#   'skills': "veiller au perfectionnement du potentiel|unité de production|bonne connaissance|gérer la production d'une unité autonome|amélioration de la qualité|atteindre les objectifs de productivité|garantir la sécurité des personnels de son secteur|assurer l'obtention|respecter la politique environnementale du sitediplômé|animer la fonction"},
#  {'job_offer_id': 1404,
#   'skills': 'assurer la responsabilité|optimiser le pilotage|cahier des charges|évaluation des risques|service client|changement rapide|mise en place'},
#  {'job_offer_id': 1405,
#   'skills': 'réduire les dépenses|garantir le respect|assurer le reporting|gérer le budget'},
#  {'job_offer_id': 1406,
#   'skills': 'bonne connaissance|étroite collaboration|marché du textile|développer des relations commerciales durables|travail en équipe'},
#  {'job_offer_id': 1407, 'skills': ''},
#  {'job_offer_id': 1408, 'skills': ''},
#  {'job_offer_id': 1409,
#   'skills': 'améliorer les performances|analyser les circuits de fonctionnement|animer les équipes|mise en place|participer à la définition|assurer le suivi|rédiger les règles de fonctionnement|l’analyse|systèmes d’information'},
#  {'job_offer_id': 1410,
#   'skills': 'sélectionner le produit adéquat par rapport aux attentes|bonne connaissance|suivre la procédure d’un sinistre'},
#  {'job_offer_id': 1412,
#   'skills': 'traduire les textes de lois relatifs|assurer cette responsabilité'},
#  {'job_offer_id': 1414,
#   'skills': 'préparer les dossiers de remboursements à l’|actualiser les dossiers|suivre les émissions de bons de commande|ressources humaines|suivre les dossiers pour paiement|suivre les demandes d’achats|mettre à jour les données|système d’information|préparer le matériel didactique|gérer les inscriptions|piloter la coordination avec les organismes de formations|gérer les facturations|suivre les présences|gérer le classement|envoyer les informations'},
#  {'job_offer_id': 1415,
#   'skills': 'former des groupes|travailler en équipe|mettre à jour les données sur système|résolution des problèmes|recueillir les besoins|gérer les formation en mode|réaliser le reporting mensuel|analyse des besoins|systèmes d’information|gérer les formations en langues|réaliser les projets de formations transversales'},
#  {'job_offer_id': 1416,
#   'skills': 'travailler en toute autonomie|effectuer des recherches sur l’évaluation des technologies|entretenir des relations|professions de santé'},
#  {'job_offer_id': 1417,
#   'skills': 'développer notre réseau de communication afin|faciliter les relations de notre entreprise|journalisme|mettre en œuvre|techniques de communication|communication interne'},
#  {'job_offer_id': 1418, 'skills': ''},
#  {'job_offer_id': 1419, 'skills': 'l’organisation'},
#  {'job_offer_id': 1420,
#   'skills': 'gestion des dossiers|service juridique|l’organisation|outil informatique'},
#  {'job_offer_id': 1421,
#   'skills': "suivre l'organisation commerciale|mettre en œuvre la politique commerciale du groupe.profil|domaine de l’|l’organisation|développer le portefeuille"},
#  {'job_offer_id': 1422, 'skills': 'outil informatique'},
#  {'job_offer_id': 1423, 'skills': 'plan d’action|agence de publicité'},
#  {'job_offer_id': 1424,
#   'skills': 'pièces de rechange|génie mécanique|déroulement des opérations|esprit d’équipe|interventions de maintenance|l’organisation|réaliser des interventions spécifiques permettant'},
#  {'job_offer_id': 1425,
#   'skills': 'gestion administrative|haut niveau|différents services'},
#  {'job_offer_id': 1426, 'skills': 'l’organisation'},
#  {'job_offer_id': 1427, 'skills': 'premiers soins'},
#  {'job_offer_id': 1434,
#   'skills': 'respect des procédures|promouvoir des services de qualité|ressources humaines|qualité de service'},
#  {'job_offer_id': 1435,
#   'skills': 'modèles de données|l’élaboration|analyse des besoins|esprit d’équipe|mise en œuvre|matière de conception'},
#  {'job_offer_id': 1436,
#   'skills': 'esprit créatif|définition des besoins|l’analyse|gestion des ressources humaines|conseil dans le cadre|tenir des responsabilités motivantes|gestion de projets'},
#  {'job_offer_id': 1437,
#   'skills': 'assurer la réponse aux appels|établir les offres|organiser la prospection|faire le suivi|motiver vos équipes|atteindre des objectifs|développer le portefeuille|génie civil'},
#  {'job_offer_id': 1438, 'skills': 'self-'},
#  {'job_offer_id': 1439, 'skills': ''},
#  {'job_offer_id': 1440, 'skills': ''},
#  {'job_offer_id': 1443, 'skills': 'manière autonome|outil informatique'},
#  {'job_offer_id': 1444,
# ...
#  {'job_offer_id': 2256,
#   'skills': 'acquérir des qualités de travail|l’élaboration'},
#  {'job_offer_id': 2257,
#   'skills': 'garantir la réussite et la pérennisation des approvisionnements'},
#  {'job_offer_id': 2258,
#   'skills': 'bonne gestion|animer les activités|mécanique|compétences techniques|reconnaître vos valeurs'},
#  {'job_offer_id': 2259,
#   'skills': "formation du personnel|diriger l'intervention des secours|participer à la conception du plan de formation sécurité|réaliser des exercices|conditions de travail|contrôler le respect des consignes de sécurité|diffuser la documentation réglementaire|organiser les actions de sensibilisation|collaborer à l'animation du comité|compétences techniques|assurer sa mise en oeuvre"},
#  {'job_offer_id': 2263,
#   'skills': "aider la direction dans l'orientation|évaluer l'activité de l'entreprise"},
#  {'job_offer_id': 2264,
#   'skills': 'respect des procédures|optimiser la pertinence|participer à la définition des procédures de gestion|s’'},
#  {'job_offer_id': 2265,
#   'skills': 'coacher les équipes|assurer l’interface avec les partenaires|s’|apporter des améliorations|mettre en place des tableaux de bords de suivi|négocier avec les transporteurs|hygiène et sécurité|optimiser les coûts|veiller au respect des délais|assurer la circulation de la marchandise|respect des règles'},
#  {'job_offer_id': 2266,
#   'skills': 'bonne connaissance|s’|gestion de la relation'},
#  {'job_offer_id': 2267,
#   'skills': 'assurer la maintenance|accompagner les techniciens|contrat de maintenance|superviser le réseau d’access transmission|gérer le lot de rechange|assurer un support technique aux techniciens|assurer des interventions|supporter le supérieur hiérarchique|contrôler l’état|gérer l’interface avec les fournisseurs|assister dans la collecte|analyser les alarmes générées par les systèmes|assurer un bon fonctionnement des systèmes de supervision'},
#  {'job_offer_id': 2268,
#   'skills': 'fibre optique|intervenir dans la collecte des indicateurs|sélectionner les offres|planifier|supporter le supérieur hiérarchique|analyser son fonctionnement opérationnel|assurer le suivi de son déploiement|mise en service'},
#  {'job_offer_id': 2269,
#   'skills': 'étroite collaboration|travailler en équipe|réaliser les éléments de communication autour|mise à jour|compétences techniques'},
#  {'job_offer_id': 2273,
#   'skills': "élaborer les documents comptables|entrer en contact|procédures comptables|expert-|faire preuve d'organisation|différents services|outils informatiques"},
#  {'job_offer_id': 2274,
#   'skills': 'bonne connaissance|faire preuve|développer notre portefeuille|envoyer votre dossier'},
#  {'job_offer_id': 2275,
#   'skills': 'utiliser|envoyer votre dossier|outil informatique|appels téléphoniques'},
#  {'job_offer_id': 2276, 'skills': ''},
#  {'job_offer_id': 2277, 'skills': ''},
#  {'job_offer_id': 2278, 'skills': ''},
#  {'job_offer_id': 2279, 'skills': ''},
#  {'job_offer_id': 2280, 'skills': ''},
#  {'job_offer_id': 2281, 'skills': ''},
#  {'job_offer_id': 2282, 'skills': ''},
#  {'job_offer_id': 2283, 'skills': 'marché espagnol|centre d’appel'},
#  {'job_offer_id': 2284, 'skills': ''},
#  {'job_offer_id': 2285, 'skills': ''},
#  {'job_offer_id': 2286,
#   'skills': 'veiller au respect des normes|conditions de travail|satisfaire les besoins|centrales électriques|gérer votre service|analyser les coûts et les ratios de consommation|assurer le suivi quotidien nécessaire|optimiser les coûts|production d’énergie|traitement des eaux|mécanique|milieu industriel|assurer le développement des ressources humaines sous votre responsabilité|établir les plans d’action'},
#  {'job_offer_id': 2287, 'skills': ''},
#  {'job_offer_id': 2288,
#   'skills': 'fournir le support juridique nécessaire aux acheteurs pour les demandes|droit des affaires|superviser les travaux de modifications|coordonner les validations avec les directions financière|traiter les dossiers administratifs|fournir le support juridique à la direction|travail en équipe'},
#  {'job_offer_id': 2289, 'skills': ''},
#  {'job_offer_id': 2290, 'skills': 'respecter le planning'},
#  {'job_offer_id': 2291, 'skills': 'gérer une équipe de chargés de clientèle'},
#  {'job_offer_id': 2292,
#   'skills': 'projet de développement|outils de gestion|outil informatique|travail en équipe|acquérir des connaissances|gestion de projets'},
#  {'job_offer_id': 2293, 'skills': 'travailler en équipe'},
#  {'job_offer_id': 2294,
#   'skills': 'proposer des améliorations fonctionnelles|méthodes de gestion|bases de données'},
#  {'job_offer_id': 2296,
#   'skills': 'diriger une équipe|assurer la gestion du département tant au niveau|service client|superviser toutes les opérations de production'},
#  {'job_offer_id': 2297,
#   'skills': 'présenter les détails techniques|suivre l’activité|mener la vente à terme|garantir l’atteinte des objectifs|développer le chiffres d’affaires'},
#  {'job_offer_id': 2299,
#   'skills': 'gérer une relation avec des responsables techniques|gamme de produits|garantir la mise à disposition|bon déroulement|collaborer avec les équipes techniques|assurer la satisfaction finale de vos clients|contrats de vente|assurer le suivi prévisionnel'},
#  {'job_offer_id': 2301,
#   'skills': "assurer le suivi des stratégies des concurrents sur le segment produit|proposer des plans d'attaque|activités promotionnelles|self-|marché résidentiels|réagir aux stratégies|maintenir les parts de marché sur sa ligne|mettre en œuvre|contrôler la réalisation du plan marketing pour la ligne|prendre en charge"},
#  {'job_offer_id': 2302, 'skills': 'appels téléphoniques'},
#  {'job_offer_id': 2303,
#   'skills': 'mise en place|esprit d’équipe|bases de données|mise à jour'},
#  {'job_offer_id': 2304,
#   'skills': 'travail en équipe|mettre en place des actions de rétention prépayé|bases de données|outil informatique'},
#  {'job_offer_id': 2308,
#   'skills': 'assurer la qualité des services.diplômé(e|créer des opportunités|valeur ajoutée|planifier|améliorer le portefeuille de services à valeur|outil informatique|développer les processus nécessaires|l’analyse'},
#  {'job_offer_id': 2309,
#   'skills': "appels téléphoniques|assurer l'interface entre les directeurs|mise en place|méthodes de gestion|travail quotidien"},
#  {'job_offer_id': 2310,
#   'skills': 'développer leur expertise|mise en œuvre|compétences techniques'},
#  {'job_offer_id': 2311,
#   'skills': "assurer les opérations de caisse|bonne connaissance|préparer les documents d'inventaire dans les délais.vous maîtrisez le système|contrôler l'exactitude de toutes|réaliser les activités suivantes|préparer le bilan dans les délais fixés|contrôler l'exactitude"},
#  {'job_offer_id': 2312,
#   'skills': 'prendre les commandes|organiser la logistique|formation technique|prospecter de nouveaux clients'},
#  {'job_offer_id': 2313, 'skills': 'marché francophone|centre d’appel'},
#  {'job_offer_id': 2314, 'skills': 'plan d’action'},
#  {'job_offer_id': 2315,
#   'skills': "préparer les dossiers d’importation en vue|participer à la gestion des réclamations|contrôler les règlements avant leur signature par la direction générale|participer à la mise en oeuvre des objectifs qualité|gestion de la qualité|coordonner les travaux des arrêtés comptables|valider les déclarations mensuelles|l’analyse|assurer la répartition des centres de coût|respect des procédures|participer à la collecte|améliorer les procédures comptables|optimiser l'efficacité|enregistrer les documents relatifs|traiter les heures productives|participer à l’évaluation des formations.de|informations relatives|assurer la clôture de fin de mois et de fin|comptabilité analytique|assurer sa diffusion|revoir les comptes|participer à la collecte des besoins en formation|développer les rapports utilitaires|vérifier la fiabilité|respecter le planning|analyse financière|respect de la législation|tenir à jour le fichier des immobilisations|gérer les relations avec les banques|tenir la situation financière|participer à la mise en œuvre des actions correctives|préparer les dossiers d’import pour comptabilisation"},
#  {'job_offer_id': 2316,
#   'skills': 'écritures comptables|principes comptables|assurer le respect de la déontologie comptable|participer à la mise en oeuvre des objectifs qualité|assurer le respect des dates|gestion de la qualité|l’analyse|participer à la collecte|enregistrer les documents relatifs|traitement des données|participer à l’évaluation des formations.de|informations relatives|comptabilité analytique|participer à la collecte des besoins en formation|mise à jour|assurer la coordination|analyse financière|participer à la mise en œuvre des actions correctives|données financières'},
#  {'job_offer_id': 2317, 'skills': 'audit scores'},
#  {'job_offer_id': 2319,
#   'skills': 'droit des obligations|droit commercial|droit des contrats|droit des sociétés|droit des affaires'},
#  {'job_offer_id': 2320,
#   'skills': 'risque opérationnel|gestion des risques|esprit d’équipe|mesurer les risques de marché|outils informatiques|l’analyse|compétences techniques'},
#  {'job_offer_id': 2322, 'skills': ''},
#  {'job_offer_id': 2323,
#   'skills': 'bonne connaissance|traduire les textes de lois relatifs|droit public'},
#  {'job_offer_id': 2324,
#   'skills': "surveiller la gestion du contentieux|supporter le supérieur hiérarchique|exécuter les demandes de consultations juridiques|assister l'avocat|superviser le recouvrement des impayés|participer activement à des projets transversaux|effectuer la gestion et le suivi|assister dans la collecte|conseil juridique"},
#  {'job_offer_id': 2325,
#   'skills': 'affaires juridiques|assurer la gestion|assurer l’interface avec les cabinets|gérer les arrêts et les suspensions de poursuites|gérer les factures des honoraires des avocats'},
#  {'job_offer_id': 2327,
#   'skills': 'garantir le renouvellement des abonnements|étroite collaboration|optimiser la qualité des titres en fonction|assurer le routage des magazines.diplômé(e'},
#  {'job_offer_id': 2328,
#   'skills': 'respect des procédures|gérer les missions suivantes|contrôler la fiabilité des comptes|gestion administrative|préparer les reportings et tableaux|outil informatique|assurer les activités liées au cycle|assurer le suivi|tenir les états financiers|assurer les travaux de comptabilité en collaboration|participer à la mise à jour des procédures|préparer les états financiers périodiques'},
#  {'job_offer_id': 2329,
#   'skills': 'bonne connaissance|conduire les audits|planifier|systèmes de management|coordonner la qualification des auditeurs selon la procédure|systèmes de management de la qualité|outil informatique|formuler les actions correctives|milieu industriel'},
#  {'job_offer_id': 2330,
#   'skills': 'audit interne|génie mécanique|s’|gestion de la relation|mécanique|gestion de projets'},
#  {'job_offer_id': 2335,
#   'skills': 'prendre des initiatives|envoyer votre candidature|espaces publicitaires|plan de communication|prendre de réelles|négocier des volumes'},
#  {'job_offer_id': 2336,
#   'skills': 'l’aspect|console de mixage|compétences techniques|finaliser vos projets'},
#  {'job_offer_id': 2337,
#   'skills': 'équipements techniques|mise en œuvre|nouveaux équipements|travailler dans un environnement jeune|maintenance préventive'},
#  {'job_offer_id': 2338,
#   'skills': 'finaliser vos projets|préparer le découpage technique du travail|analyser les émissions|maîtriser le système de diffusion|l’aspect|console de mixage|compétences techniques'},
#  {'job_offer_id': 2339, 'skills': ''},
#  {'job_offer_id': 2340,
#   'skills': 'bonne connaissance|grand public|bon déroulement|nouveaux concepts|nouvelles idées'},
#  {'job_offer_id': 2343,
#   'skills': 'conseiller les clients|assurer la réalisation des achats nationaux|procédures en matière|matière de procédures|respect de la réglementation|satisfaire les besoins|motiver vos équipes|l’organisation|définir les normes|mettre en œuvre des actions|assurer la réalisation des achats en réponse aux besoins'},
#  {'job_offer_id': 2344,
#   'skills': 'environnement international|projets de développement|mener à bien des missions de conseil'},
#  {'job_offer_id': 2345,
#   'skills': 'négocier le droit de passage|résolution des problèmes|représenter la société|résoudre les problèmes de blocage d’accès|assurer la disponibilité permanente du réseau gsm|négocier les contrats cadre'},
#  {'job_offer_id': 2346,
#   'skills': 'gérer un portefeuille de clients sur le marché français|marché des télécoms|vente de produits'},
#  {'job_offer_id': 2347,
#   'skills': 'gestion administrative|environnement de travail'},
#  {'job_offer_id': 2348,
#   'skills': 'maintenance des machines|outil informatique|problèmes techniques'},
#  {'job_offer_id': 2349,
#   'skills': 'fonction logistique|formation complémentaire|effectuer le reporting|directeur de production|fournir à la production|gestion de projet|l’organisation|animer le plan|participer activement|génie industriel|effectuer le suivi des performances|garantir la disponibilité des composants|garantir le niveau de qualité des composants'},
#  {'job_offer_id': 2350,
#   'skills': 'équipe de production|développer une bonne connaissance|l’organisation|normes de qualité|faire progresser de façon'},
#  {'job_offer_id': 2352,
#   'skills': 'participer à la mise en oeuvre des projets|réaliser les procédures de travail|supporter les collaborateurs|participer à la mise en œuvre|pratiques en matière|assister dans la collecte|gestion de la qualité|travail en équipe|systèmes d’information'},
#  {'job_offer_id': 2353,
#   'skills': "audit réglementaire|travailler en équipe|assurer le suivi de l'audit réglementaire de la comptabilité analytique|maintenir un modèle de coût pour les tarifs|l’analyse|conformité à la réglementation|assurer l'analyse des tarifs de détail|maintenir un modèle de squeeze"},
#  {'job_offer_id': 2354,
#   'skills': 'fiche technique|mettre en place des procédures de travail|contrôler le suivi d’utilisation du tissu|s’|communiquer aux achats|garantir la fluidité|effectuer des inventaires tournants|conformité des produits|outil informatique|garantir le support|prendre en charge la gestion du stock|produire les rapports|plan de production|bonne gestion'},
#  {'job_offer_id': 2355,
#   'skills': "aider les approvisionnements à suivre|préparer les plans d'actions|suivre les plans d'actions|évaluer les fournisseurs.de formation|management de la qualité|assurer la liaison avec les services qualité|traiter les réclamations|participer aux actions préventives pour les produits|superviser les équipes de fabrication|communiquer les résultats|mettre en place l'autocontrôle|coordonner les actions préventives|outil informatique|participer à l'amélioration du niveau de qualité|gérer les audits internes|mise en place|faire le reporting des performances|assurer la mise à jour"},
#  {'job_offer_id': 2356,
#   'skills': 'opérations de traitement|exigences des clients|produits chimiques|directeur de production|besoins des clients|outil informatique|l’organisation|compétences techniques'},
#  {'job_offer_id': 2357,
#   'skills': 'l’autre|évaluer les quantités de tissu nécessaires'},
#  {'job_offer_id': 2358, 'skills': ''},
#  {'job_offer_id': 2359,
#   'skills': 'prendre des initiatives|développer les tâches définies|canaux de distribution|assurer le lancement des nouveaux produits|réaliser les objectifs prévus|esprit d’équipe|développer les opportunités commerciales'},
#  {'job_offer_id': 2360,
#   'skills': 'assurer le suivi commercial des projets|gérer le lancement commercial|nouveaux produits|proposer des actions de promotion|mener les négociations avec les clients|assurer une remontée régulière|s’|prendre en charge|faire le suivi de la veille|accompagner les revendeurs|développer une relation durable|garantir l’atteinte des objectifs|développer la revente|analyser le potentiel du marché|organiser leur formation|définir les objectifs collectifs|analyser les risques'},
#  {'job_offer_id': 2361,
#   'skills': 'ressources financières|procédures comptables|performances financières|décisions stratégiques|moyen terme|plan financier|prendre en charge'},
#  ...]

# %% [markdown]
# ### New french rule extraction:

# %%
skill_pattern_path = join(DATA_FILES,"fr_skill_patterns_pole_emploi_v2.jsonl")
ruler = fr_nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_pattern_path)

# %%
get_all_skills(fr_nlp, jo_df, join(SKILL_OUT, 'extracted_skills_pole_emploi_v2.jsonl'))

# %%
read_json_lines(join(SKILL_OUT, 'extracted_skills_pole_emploi_v2.jsonl'))
# Out:
# [{'job_offer_id': 0,
#   'skills': 'chargé de clientèle|utilisation de matériel|assistance technique|gérer des demandes des utilisateurs par téléphone|prendre en charge|traiter les demandes de changement|matérielles, logicielles|architecture des systèmes'},
#  {'job_offer_id': 1, 'skills': ''},
#  {'job_offer_id': 2, 'skills': 'encadrer une équipe'},
#  {'job_offer_id': 110, 'skills': ''},
#  {'job_offer_id': 1015, 'skills': 'gestion de production|mécanique'},
#  {'job_offer_id': 1016, 'skills': "conduite d'opérations"},
#  {'job_offer_id': 1017,
#   'skills': 'informatique de gestion|gérer différentes tâches'},
#  {'job_offer_id': 1019, 'skills': ''},
#  {'job_offer_id': 1020,
#   'skills': 'contrôle de gestion|normes comptables|gestion du stress'},
#  {'job_offer_id': 1021,
#   'skills': 'entretien annuel|gestion du stress|assurer la responsabilité du chiffre|business|différents éléments'},
#  {'job_offer_id': 1022,
#   'skills': 'entretien annuel|gestion du stress|assurer la responsabilité du chiffre|business|différents éléments'},
#  {'job_offer_id': 1023,
#   'skills': "support technique|gestion du stress|équipes techniques|gérer l'escalade des problèmes|traiter les problèmes|distribuer toute information"},
#  {'job_offer_id': 1024,
#   'skills': 'cahier des charges|support technique|mise en place|business'},
#  {'job_offer_id': 1025,
#   'skills': 'support technique|mise en place|démarche qualité|prendre en charge|actions de prévention|mettre en place les process qualité|anglais indispensable'},
#  {'job_offer_id': 1026, 'skills': 'répondre à leurs attentes en matière'},
#  {'job_offer_id': 1027,
#   'skills': 'participer au montage|comptabilité générale'},
#  {'job_offer_id': 1028, 'skills': 'participer au montage'},
#  {'job_offer_id': 1029,
#   'skills': "gérer l'administratif du montage des arrêtés|commande"},
#  {'job_offer_id': 1030,
#   'skills': 'participer au montage|préparer les états intermédiaires pour les reportings'},
#  {'job_offer_id': 1044,
#   'skills': 'nouvelles technologies|information technique'},
#  {'job_offer_id': 1045,
#   'skills': 'encadrer une équipe|outils de gestion|mise en production|conduite de projet|gérer les planning|nouvelles technologies|améliorer la fiabilité des développements|développement de projet|gestion de projet'},
#  {'job_offer_id': 1046, 'skills': 'nouvelles technologies'},
#  {'job_offer_id': 1047,
#   'skills': 'mettre en place|mise en place|spécifications fonctionnelles|coordonner le développement'},
#  {'job_offer_id': 1048, 'skills': ''},
#  {'job_offer_id': 1049,
#   'skills': 'nouveaux clients|veille concurrentielle|politique commerciale|gestion de la relation'},
#  {'job_offer_id': 1050,
#   'skills': 'accompagner les entreprises|communication interne|outils de communication|mener des entretiens de diagnostic en communication|animer les réunions'},
#  {'job_offer_id': 1051,
#   'skills': 'sécurité des systèmes|maintenance du matériel'},
#  {'job_offer_id': 1052,
#   'skills': 'portefeuille clients|développer vos résultats de manière|conclure vos ventes'},
#  {'job_offer_id': 1053,
#   'skills': 'points de vente|mettre en place|remise en forme'},
#  {'job_offer_id': 1054,
#   'skills': 'outil informatique|créer un fond documentaire|exploiter des documents|assurer la qualité|analyser le contenu des documents|recenser les besoins documentaires|effectuer les recherches nécessaires'},
#  {'job_offer_id': 1058,
#   'skills': 'suivi du stock physique|réceptionner les véhicules neufs|hygiène et de sécurité|mécanique|assurer le suivi|veiller au respect|voitures neuves|veiller au respect du procédures de travail|contrôler les activités du responsable du stock|assurer la livraison des voitures|commande|service après vente|préparer les véhicules neufs avant la livraison|assurer les travaux de la préparation des voitures|etablir les rapports|suivre les commandes internes|valider les fiches de travail'},
#  {'job_offer_id': 1059,
#   'skills': "mécanique, électrique|veiller au respect des normes du constructeur|hygiène et de sécurité|exécution des travaux|contrôler les activités de ses collaborateurs|veiller au respect|assurer la coordination de l'activité|état de fonctionnement|avancement des travaux|service rapide|veiller au respect du procédures de travail|mécanique automobile|service après vente|contrôler la main d'œuvre|établir les devis de réparation|assurer le contrôle des travaux|suivre les commandes internes|mécanique de préférence"},
#  {'job_offer_id': 1066, 'skills': 'milieu industriel'},
#  {'job_offer_id': 1068,
#   'skills': 'gérer les besoins du cabinet|suivre le processus de sélection des dossiers|dossiers clients|outils informatiques|gérer le planning des patients'},
#  {'job_offer_id': 1070,
#   'skills': "humains, matériels|contrôle de gestion|définition de la stratégie|chiffre d'affaires"},
#  {'job_offer_id': 1071, 'skills': 'développer le business infrastructure'},
#  {'job_offer_id': 1072, 'skills': 'business'},
#  {'job_offer_id': 1073, 'skills': 'piloter des projets'},
#  {'job_offer_id': 1074, 'skills': 'conduire des projets applicatifs'},
#  {'job_offer_id': 1075, 'skills': 'spécifications fonctionnelles'},
#  {'job_offer_id': 1076,
#   'skills': 'analyser leurs besoins|installer nos solutions|gérer une relation client|assurer le support technique'},
#  {'job_offer_id': 1077,
#   'skills': 'grande consommation|définition de la stratégie'},
#  {'job_offer_id': 1078,
#   'skills': 'place les actions|grande consommation|réaliser le budget.profil souhaité|définition de la stratégie de développement'},
#  {'job_offer_id': 1079, 'skills': 'portefeuille clients'},
#  {'job_offer_id': 1080,
#   'skills': 'protection des données|droit du travail|droit de la consommation|droit commercial'},
#  {'job_offer_id': 1081,
#   'skills': 'intégrer une structure|suivre un parcours|national et international'},
#  {'job_offer_id': 1082, 'skills': ''},
#  {'job_offer_id': 1083, 'skills': 'besoins du client'},
#  {'job_offer_id': 1084, 'skills': ''},
#  {'job_offer_id': 1086, 'skills': 'gestion du stress'},
#  {'job_offer_id': 1087, 'skills': ''},
#  {'job_offer_id': 1088,
#   'skills': 'corriger les fautes|orthographe, de grammaire'},
#  {'job_offer_id': 1089, 'skills': 'anglais courant'},
#  {'job_offer_id': 1091,
#   'skills': 'ressources humaines|promouvoir la gestion des carrières|entreprise en matière de gestion|valoriser le potentiel'},
#  {'job_offer_id': 1092,
#   'skills': "fixer|animer les équipes commerciales|commerciale de l'entreprise|actions commerciales|axes prioritaires"},
#  {'job_offer_id': 1093,
#   'skills': 'déterminer des stratégies marketing|fixer|diriger et manager une équipe marketing|surveiller ses applications opérationnelles|gérer des budgets marketing'},
#  {'job_offer_id': 1094,
#   'skills': 'entretien annuel|outils bureautiques|activité commerciale|clients et prospects|gérer les ventes des produits|développer la performance des membres|business|assurer la résolution des problèmes|différents éléments'},
#  {'job_offer_id': 1096, 'skills': ''},
#  {'job_offer_id': 1097, 'skills': 'outils spécifiques'},
#  {'job_offer_id': 1098,
#   'skills': 'postes de travail|mécanique|veiller à la sécurité|plan de fabrication|fabrication des produits|promouvoir le présentiéisme de son équipe|définir les objectifs|corriger les écarts|participer à la gestion de la polyvalence|application des règles|gérer le suivi individuel|délai, coût'},
#  {'job_offer_id': 1099, 'skills': ''},
#  {'job_offer_id': 1100, 'skills': ''},
#  {'job_offer_id': 1101, 'skills': ''},
#  {'job_offer_id': 1102,
#   'skills': 'nouveaux produits|politique commerciale|objectifs commerciaux'},
#  {'job_offer_id': 1103,
#   'skills': 'nouveaux produits|commerciale et marketing|administration des ventes|objectifs commerciaux'},
#  {'job_offer_id': 1104,
#   'skills': 'grande distribution|produits de grande consommation'},
#  {'job_offer_id': 1105, 'skills': ''},
#  {'job_offer_id': 1106, 'skills': 'domaine de la gestion'},
#  {'job_offer_id': 1109, 'skills': 'mise en place|commerciale et marketing'},
#  {'job_offer_id': 1110,
#   'skills': 'contrôler les états financiers|positionner|gestion financière|administratif et financier'},
#  {'job_offer_id': 1111,
#   'skills': 'réaliser les études quantitatives et qualitatives'},
#  {'job_offer_id': 1112,
#   'skills': 'respect de la réglementation|techniques et outils|administrative et financière'},
#  {'job_offer_id': 1113,
#   'skills': 'respect des procédures|conformité réglementaire|administratif et financier|comptabilité générale'},
#  {'job_offer_id': 1115,
#   'skills': 'animer la fonction fabrication|piloter les démarrages|veiller au perfectionnement du potentiel humain'},
#  {'job_offer_id': 1116,
#   'skills': 'gérer les appels entrants|mettre en place des procédures|gérer une équipe|service après vente|rédiger des rapports au directeur|haut niveau'},
#  {'job_offer_id': 1117, 'skills': 'spécifications fonctionnelles'},
#  {'job_offer_id': 1128,
#   'skills': 'femmes enceintes|ressources humaines|gestion administrative|tableaux de bord|règles de sûreté|sciences économiques|gestion du personnel|actions de formation'},
#  {'job_offer_id': 1129,
#   'skills': 'actions correctives|mise à jour|règles de sûreté|mécanique'},
#  {'job_offer_id': 1136, 'skills': ''},
#  {'job_offer_id': 1137,
#   'skills': 'comptabilité analytique|optimiser notre système de contrôle'},
#  {'job_offer_id': 1138,
#   'skills': 'développer nos parts de marchés|base de données|propositions commerciales|réseaux de distribution|évolution du marché|second oeuvre'},
#  {'job_offer_id': 1139, 'skills': ''},
#  {'job_offer_id': 1140, 'skills': ''},
#  {'job_offer_id': 1141,
#   'skills': 'mener des enquêtes|animer des rubriques|collecter les informations|outils informatiques|acteurs locaux'},
#  {'job_offer_id': 1142,
#   'skills': 'mener des enquêtes|animer des rubriques|collecter les informations|outils informatiques|acteurs locaux'},
#  {'job_offer_id': 1143,
#   'skills': 'organiser le service|suivre le budget|gérer le planning'},
#  {'job_offer_id': 1144, 'skills': 'assurer un rôle de support|leadership'},
#  {'job_offer_id': 1145,
#   'skills': "analyser les demandes des clients|prendre en charge|coordonner le travail du support administratif|veiller à la cohérence de l'information"},
#  {'job_offer_id': 1146,
#   'skills': 'assurer la veille concurrentielle|assurer la cohérence des actions|mettre en place la politique de partenariat|définir la stratégie marketing|définir le plan de communication externe|développement économique|gérer le budget|contrôler les études et la recherche marketing|diriger la politique marketing|campagnes publicitaires'},
#  {'job_offer_id': 1147,
#   'skills': 'réaliser les objectifs commerciaux fixés par la direction'},
#  {'job_offer_id': 1148,
#   'skills': 'effectuer le dépannage|changer les pièces défectueuses'},
#  {'job_offer_id': 1149,
#   'skills': 'outil informatique|créer un fond documentaire|exploiter des documents|assurer la qualité|analyser le contenu des documents|recenser les besoins documentaires|effectuer les recherches nécessaires'},
#  {'job_offer_id': 1150,
#   'skills': 'appels entrants|suivi administratif|traiter les demandes clients'},
#  {'job_offer_id': 1151, 'skills': ''},
#  {'job_offer_id': 1152,
#   'skills': 'animer des rubriques|mener des enquêtes|collecter les informations|acteurs locaux'},
#  {'job_offer_id': 1153,
#   'skills': 'appels entrants|suivi administratif|traiter les demandes clients'},
#  {'job_offer_id': 1154,
#   'skills': 'animer des rubriques|mener des enquêtes|collecter les informations|acteurs locaux'},
#  {'job_offer_id': 1155,
#   'skills': 'appels entrants|suivi administratif|traiter les demandes clients'},
#  {'job_offer_id': 1156,
#   'skills': 'animer des rubriques|mener des enquêtes|collecter les informations|acteurs locaux'},
#  {'job_offer_id': 1157,
#   'skills': 'appels entrants|suivi administratif|traiter les demandes clients'},
#  {'job_offer_id': 1158,
#   'skills': 'participer au développement de notre structure en pleine|documentation technique|suivre des consignes de développement'},
#  {'job_offer_id': 1159, 'skills': ''},
#  {'job_offer_id': 1160, 'skills': 'aide de matériels de prise'},
#  {'job_offer_id': 1161,
#   'skills': "présenter ou animer des émissions|participer à l'élaboration"},
#  {'job_offer_id': 1162, 'skills': 'aide de matériels de prise'},
#  {'job_offer_id': 1163, 'skills': ''},
#  {'job_offer_id': 1164, 'skills': 'aide de matériels de prise'},
#  {'job_offer_id': 1165, 'skills': ''},
#  {'job_offer_id': 1166, 'skills': 'aide de matériels de prise'},
#  {'job_offer_id': 1167, 'skills': 'aide de matériels de prise'},
#  {'job_offer_id': 1168, 'skills': ''},
#  {'job_offer_id': 1170,
#   'skills': "méthodes de gestion|gérer l'ensemble des aspects|veiller au respect|répondre à leurs attentes en matière|assurer le suivi administratif|méthodes et outils"},
#  {'job_offer_id': 1172, 'skills': ''},
#  {'job_offer_id': 1173,
#   'skills': 'suivi du stock physique|réceptionner les véhicules neufs|hygiène et de sécurité|mécanique|assurer le suivi|veiller au respect|voitures neuves|veiller au respect du procédures de travail|contrôler les activités du responsable du stock|assurer la livraison des voitures|commande|service après vente|préparer les véhicules neufs avant la livraison|assurer les travaux de la préparation des voitures|etablir les rapports|suivre les commandes internes|valider les fiches de travail'},
#  {'job_offer_id': 1174, 'skills': ''},
#  {'job_offer_id': 1175, 'skills': ''},
#  {'job_offer_id': 1176, 'skills': 'business'},
#  {'job_offer_id': 1177, 'skills': ''},
#  {'job_offer_id': 1178, 'skills': 'business'},
#  {'job_offer_id': 1179, 'skills': 'business'},
#  {'job_offer_id': 1180, 'skills': 'business'},
#  {'job_offer_id': 1181, 'skills': 'business'},
#  {'job_offer_id': 1182, 'skills': ''},
#  {'job_offer_id': 1183, 'skills': ''},
#  {'job_offer_id': 1189,
#   'skills': "analyser le portefeuille|marketing de l'entreprise|assurer le développement optimal|gérer les budgets fonctionnels|définir une stratégie pour l'ensemble des produits|coacher l'ensemble|business|leadership|évolution du marché|fonction des évolutions|planifier les opérations de promotion et de commercialisation|fixer les priorités de développement|analyser les opportunités des produits|elaborer des plans marketing"},
#  {'job_offer_id': 1190,
#   'skills': 'nouvelles technologies|mise en service|équipe de développement|outils de suivi'},
#  {'job_offer_id': 1192, 'skills': ''},
#  {'job_offer_id': 1194,
#   'skills': 'grande distribution|technique et fonctionnel'},
#  {'job_offer_id': 1198,
#   'skills': 'apporter un support à la performance du service|commerce international|outil informatique|assurer la gestion des comptes en admission|assurer le volet export|assurer la gestion des commandes'},
#  {'job_offer_id': 1199, 'skills': 'génie civil|outil informatique'},
#  {'job_offer_id': 1200,
#   'skills': 'techniques de négociation|électrique, mécanique|matières et fournitures|bon fonctionnement'},
#  {'job_offer_id': 1201,
#   'skills': 'développer un portefeuille de clients|leadership|veille concurrentielle|politique commerciale|prospecter de nouveaux clients|commerciale et marketing'},
#  {'job_offer_id': 1202,
#   'skills': 'fixer|assurer le suivit des devis|portefeuille clients|conduire la stratégie commerciale|proposer des axes de développement commerciaux|définir une stratégie commerciale pour assurer|collectivités territoriales|actions commerciales|axes prioritaires'},
#  {'job_offer_id': 1203, 'skills': 'réaliser des plats|cuisine espagnole'},
#  {'job_offer_id': 1204,
#   'skills': "technologies de l'information|outil informatique"},
#  {'job_offer_id': 1205,
#   'skills': 'animer les forums de discussion|corriger les articles des journalistes|outil informatique'},
#  {'job_offer_id': 1206,
#   'skills': 'équipe de développement|spécifications fonctionnelles|fonctionnelle et technique'},
#  {'job_offer_id': 1207, 'skills': 'business'},
#  {'job_offer_id': 1208,
#   'skills': 'mise en place|outil de gestion|réaliser entre mai|développer des outils de communication|gérer des opérations journalières'},
#  {'job_offer_id': 1211, 'skills': 'outil informatique|gérer son équipe'},
#  {'job_offer_id': 1212, 'skills': ''},
#  {'job_offer_id': 1213,
#   'skills': 'chaîne graphique|gestion du stress|assurer la pérennité de leur image de marque|charte graphique'},
#  {'job_offer_id': 1215,
#   'skills': 'produits et services|commerce international|portefeuille clients|équipes techniques|propositions commerciales|suivi commercial|haut niveau'},
#  {'job_offer_id': 1216,
#   'skills': 'appels entrants|assurer la partie administrative|assurer les missions suivantes|outils bureautiques'},
#  {'job_offer_id': 1218, 'skills': ''},
#  {'job_offer_id': 1220, 'skills': ''},
#  {'job_offer_id': 1221,
#   'skills': 'organiser les réunions de travail|documents administratifs|gérer les éditions|gérer des tâches|comptes rendus|assurer le filtrage téléphonique|gérer le secrétariat courant|outils informatiques'},
#  {'job_offer_id': 1222,
#   'skills': 'activité commerciale|gérer les relances téléphoniques|portefeuille client|marketing direct|techniques de vente|gestion du risque|analyser les besoins et la qualité|analyse financière|veiller au respect des procédures|commande|animer le réseau des agences|traiter les anomalies|assurer la relation entre son service|outils informatiques|gérer les tâches suivantes|développer le portefeuille de clients'},
#  {'job_offer_id': 1223,
#   'skills': 'information nécessaire|gérer et suivre les délais|mécanique|gérer des tâches|gérer la base de données véhicules|contrôler les factures par rapports aux accords donnés|contrôler des accords|elaborer des reportings de suivi des coûts|outils informatiques|service après vente|système de messagerie|gérer les tâches suivantes'},
#  {'job_offer_id': 1226,
#   'skills': "humains, matériels|conduire des projets informatiques.|outils de gestion|domaine d'intervention|organisation, de gestion|assurer la responsabilité de l'organisation|gérer et optimiser les moyens"},
#  {'job_offer_id': 1227,
#   'skills': 'effectuer des analyses financières|suivre la mise en force des crédits|suivre les tendances du marché|respect de la réglementation'},
#  {'job_offer_id': 1228,
#   'skills': "cahier des charges|maître d'ouvrage|accompagner le déploiement|mise en oeuvre|spécifications fonctionnelles"},
#  {'job_offer_id': 1229,
#   'skills': 'assurer le suivi|améliorer son niveau technique|entretenir des relations|fonds de commerce'},
#  {'job_offer_id': 1230,
#   'skills': 'gérer des relations avec une clientèle exigeante|outil informatique|déterminer les disponibilités en temps réel|gérer les difficultés|assurer un remplissage maximum|site internet'},
#  {'job_offer_id': 1232,
#   'skills': 'gérer les missions suivantes|réseaux informatiques|suivi des projets réseaux|assurer le support de 1er niveau aux utilisateurs'},
#  {'job_offer_id': 1233,
#   'skills': 'gérer les missions suivantes|réseaux informatiques|suivi des projets réseaux|assurer le support de 1er niveau aux utilisateurs'},
#  {'job_offer_id': 1234,
#   'skills': 'outil informatique|portefeuille clients|animer les points de ventes|techniques de vente|encadrer les vendeurs'},
#  {'job_offer_id': 1236, 'skills': ''},
#  {'job_offer_id': 1237,
#   'skills': 'définir le plan d’|outil informatique|stratégie marketing|leadership|business|définir la stratégie relative à la marque'},
#  {'job_offer_id': 1238,
#   'skills': 'information sur le marché|mise en place|opérations de sourcing|assurer une veille informationnelle|conception et la réalisation|constituer une base de donnée|organiser les événements de promotion du secteur|effectuer des déplacements'},
#  {'job_offer_id': 1239,
#   'skills': 'gérer les tâches suivantes|management de la qualité'},
#  {'job_offer_id': 1240,
#   'skills': 'stratégie de développement|conditions de travail|développement personnel'},
#  {'job_offer_id': 1241,
#   'skills': 'réaliser les études quantitatives et qualitatives|proposer des orientations stratégiques|conditions de travail|développement personnel'},
#  {'job_offer_id': 1249, 'skills': ''},
#  {'job_offer_id': 1252,
#   'skills': 'business|technique et financier|étude de faisabilité|projets immobiliers'},
#  {'job_offer_id': 1253, 'skills': 'rédiger les schémas comptables de la bmci'},
#  {'job_offer_id': 1254,
#   'skills': 'réaliser les activités suivantes|techniques du produit'},
#  {'job_offer_id': 1255,
#   'skills': 'relation commerciale|traitement des demandes'},
#  {'job_offer_id': 1256,
#   'skills': "construire un compte d'exploitation prévisionnel|analyser les composantes des résultats|plans d'actions|participer à l'élaboration de la gestion prévisionnelle|sensibiliser l'encadrement à la maîtrise|conduire les études|gestion prévisionnelle|conduire des actions d'information|concevoir des outils locaux de gestion|outils de pilotage|optimiser l'utilisation des ressources"},
#  {'job_offer_id': 1258,
#   'skills': 'gérer un portefeuille d’une soixantaine|normes comptables|outils informatiques|encadrer votre équipe|rédiger des synthèses'},
#  {'job_offer_id': 1259,
#   'skills': 'gestion de transport|superviser les activités|livrer le produit|électrique, mécanique|gestion de stock|définir les objectifs pour votre département|gestion de production'},
#  {'job_offer_id': 1261,
#   'skills': 'portefeuille clients|techniques de vente|déposer votre candidature|nouvelle gamme|prospection commerciale'},
#  {'job_offer_id': 1262,
#   'skills': 'relever des défis|développement personnel|grande consommation|évolution du marché|accompagner les actions marketing|actions marketing'},
#  {'job_offer_id': 1265,
#   'skills': "piloter l'animation|gérer les tâches suivantes|gérer les missions de reporting et de gestion"},
#  {'job_offer_id': 1266,
#   'skills': 'gérer la négociation commerciale|suivre les processus de facturation - effectuer vos reportings|gérer les tâches suivantes|prospecter les clients'},
#  {'job_offer_id': 1272,
#   'skills': 'superviser la gestion des contrats spéciaux de formation|mettre en œuvre le plan de formation|besoins en formation|superviser la mise en œuvre du plan|préparer le cahier des charges|elaborer le plan de formation|elaborer le plan de formation en adéquation|ressources humaines|gérer les réponses aux appels'},
#  {'job_offer_id': 1273,
#   'skills': 'intégrer une équipe|créer des chartes graphiques|concevoir des animations|animation commerciale|outils spécifiques|contrôler la qualité des livraisons de prestataires avant mise'},
#  {'job_offer_id': 1274,
#   'skills': 'milieu industriel|techniques de gestion|tableaux de bord|gestion industriel|suivre la mise en œuvre des plans|contrôle de gestion|déposer votre candidature|superviser le traitement|elaborer les rapports d’activité|animer le processus de contrôle'},
#  {'job_offer_id': 1276,
#   'skills': 'méthodes pédagogiques|mise en place|accompagner la mise en place des systèmes de gestion|bonnes pratiques|suivre les évaluations à froid|ressources humaines'},
#  {'job_offer_id': 1277,
#   'skills': 'techniques de vente|fidéliser une clientèle|clientèle de particuliers'},
#  {'job_offer_id': 1278, 'skills': 'outil informatique|méthodes de classement'},
#  {'job_offer_id': 1282, 'skills': 'formation de base|mise en place|business'},
#  {'job_offer_id': 1286,
#   'skills': 'risques financiers|négocier par téléphone|assurer le recouvrement amiable'},
#  {'job_offer_id': 1287,
#   'skills': 'entretien annuel|gestion du stress|équipe de vente|assurer la responsabilité du chiffre|business|différents éléments'},
#  {'job_offer_id': 1288,
#   'skills': 'gestion du stress|mettre en place|communication interne|répondre à leurs attentes en matière'},
#  {'job_offer_id': 1289,
#   'skills': "elaborer le plan marketing|elaborer les plans de campagne|proposer les objectifs quantitatifs|assurer la communication interne|plan marketing|actualiser la stratégie au global|participer à l'effort de relation publique|optimiser l'implication du terrain|veille concurrentielle|résultats commerciaux|coordonner la réalisation des actions|définir les objectifs qualitatifs|risque de rupture"},
#  {'job_offer_id': 1290, 'skills': ''},
#  {'job_offer_id': 1297, 'skills': 'business'},
#  {'job_offer_id': 1300,
#   'skills': "ligne de production|mécanique|milieu industriel|optimiser le temps de fabrication|procédés de fabrication. acteur|maîtrise d'ouvrage|formation initiale"},
#  {'job_offer_id': 1301,
#   'skills': 'proposer des solutions adaptées|portefeuille client|relation commerciale|assurer une relation commerciale|gérer ses missions|suivi des relations commerciales|politique commerciale'},
#  {'job_offer_id': 1303,
#   'skills': 'coordonner la sous-traitance|veiller au respect|cahiers des charges|appliquer les dispositions du système de management'},
#  {'job_offer_id': 1304,
#   'skills': 'mise en place|nouvelles technologies|schéma directeur|participer à la mise en œuvre|réaliser les travaux dans le respect des engagements'},
#  {'job_offer_id': 1305,
#   'skills': 'piloter la mise en place de fonds|sélectionner des opportunités'},
#  {'job_offer_id': 1306,
#   'skills': 'professionnelle au sein|assurer le développement des missions de conseil'},
#  {'job_offer_id': 1307,
#   'skills': 'suivi des opérations immobilières|étude de faisabilité technique'},
#  {'job_offer_id': 1308, 'skills': ''},
#  {'job_offer_id': 1309, 'skills': ''},
#  {'job_offer_id': 1310,
#   'skills': 'mettre en œuvre les meilleures pratiques de gestion technique'},
#  {'job_offer_id': 1311, 'skills': 'prendre en charge|bases de données'},
#  {'job_offer_id': 1312, 'skills': 'techniques de conduite'},
#  {'job_offer_id': 1313, 'skills': 'analyse financière'},
#  {'job_offer_id': 1314,
#   'skills': "business|spécifications fonctionnelles|leadership|maîtrise d'ouvrage"},
#  {'job_offer_id': 1315, 'skills': ''},
#  {'job_offer_id': 1316, 'skills': 'nouvelles technologies'},
#  {'job_offer_id': 1317,
#   'skills': 'mettre en œuvre la stratégie commerciale de la société|parts de marché|nouveaux clients|nouvelles technologies|développer des partenariats|business|optimiser la performance des ingénieurs'},
#  {'job_offer_id': 1318,
#   'skills': "mise en place|programmes de fidélisation|systèmes d'information|définition d'une stratégie|bases de données|outils informatiques|mise en oeuvre"},
#  {'job_offer_id': 1319,
#   'skills': 'fidéliser une clientèle|clientèle de particuliers'},
#  {'job_offer_id': 1320, 'skills': 'administration des ventes'},
#  {'job_offer_id': 1322,
#   'skills': 'sensibiliser tous|mettre en place|superviser une équipe'},
#  {'job_offer_id': 1323, 'skills': 'droit privé'},
#  {'job_offer_id': 1324,
#   'skills': 'progiciels de gestion|informatique de gestion|équipes techniques|assurance santé'},
#  {'job_offer_id': 1327,
#   'skills': 'veiller au maintien du climat de travail|sciences humaines|gestion administrative|gestion des ressources humaines|gérer les indicateurs|veiller au respect|communication interne'},
#  {'job_offer_id': 1328,
#   'skills': 'mettre en oeuvre|définition de la politique|axes de développement|caractéristiques techniques|résultats commerciaux|réaliser dans un secteur géographique|politique commerciale'},
#  {'job_offer_id': 1329,
#   'skills': 'gestion des ressources humaines|ressources humaines'},
#  {'job_offer_id': 1330,
#   'skills': "prix de revient|état de fonctionnement|gestion d'un parc"},
#  {'job_offer_id': 1331,
#   'skills': "outil informatique|piloter la définition et la collecte des indicateurs|systèmes d'information|assurer la consolidation du reporting|processus de gestion|piloter la mise en oeuvre des projets"},
#  {'job_offer_id': 1332,
#   'skills': 'gestion du stress|outil informatique|business'},
#  {'job_offer_id': 1333,
#   'skills': 'planning des activités|plan marketing|suivi des activités commerciales|activité commerciale'},
#  {'job_offer_id': 1334,
#   'skills': "fixer|mettre en œuvre la politique|définition de la politique|administration des ventes|définir les moyens|superviser la stratégie commerciale|outils d'aide à la vente|identifier des canaux de distribution|définir la stratégie commerciale|réseau de distribution"},
#  {'job_offer_id': 1335,
#   'skills': 'prévention des risques|maintenance préventif|mise en place|gérer les missions suivantes|entretien du matériel|application des règles|suivi comptable'},
#  {'job_offer_id': 1336,
#   'skills': 'outil informatique|gérer les équipes de travail|mettre en pratique les procédures hygiènes|participer à la réalisation des objectifs qualité|analyses biologiques|réaliser les agréages réception / expédition|veiller au respect des procédures de qualité|mettre en place la gestion du laboratoire interne|participer à la mise en place des procédures agréages|piloter la réalisation|mettre en place la démarche'},
#  {'job_offer_id': 1337,
#   'skills': 'outil informatique|préparer les états financiers périodiques|tableaux de bord|respect des procédures|préparer les reportings|logiciels comptables|relever des défis|contrôler la fiabilité des comptes|gérer les tâches suivantes|etablir des déclarations fiscales et sociales'},
#  {'job_offer_id': 1338,
#   'skills': "outil informatique|réaliser les opérations de cession|suivre les participations en portefeuille|relever des défis|présenter des projets d'investissements|gérer les tâches suivantes"},
#  {'job_offer_id': 1339,
#   'skills': "matière de qualité|assurer l'interface avec le client|génie civil"},
#  {'job_offer_id': 1340,
#   'skills': 'gérer les ventes.nous recherchons|animer une équipe de commerciaux'},
#  {'job_offer_id': 1341,
#   'skills': 'encadrer une équipe|animer les réunions quotidiennes|mécanique|améliorer les coûts d’entretien|superviser les travaux|opérations de maintenance|améliorer les performances des équipements|gérer le budget d’'},
#  {'job_offer_id': 1342,
#   'skills': 'participer à des projets de développement java|participer à des projets de tierce'},
#  {'job_offer_id': 1343,
#   'skills': 'suivi de la qualité|piloter des projets de développement java'},
#  {'job_offer_id': 1344,
#   'skills': 'mise en oeuvre|mise en production|base de données'},
#  {'job_offer_id': 1345,
#   'skills': "sélectionner les offres|mise en service|fibre optique|optimiser le réseau d'accès|assurer le déploiement du réseau d'accès"},
#  {'job_offer_id': 1346,
#   'skills': 'assurer le conseil juridique|droit commercial'},
#  {'job_offer_id': 1347,
#   'skills': "effectuer la maintenance corrective|base de données|systèmes d'information|assurer la disponibilité du réseau|administrer le réseau lan"},
#  {'job_offer_id': 1348,
#   'skills': "assurer la sécurité des données|systèmes d'information|gérer les sauvegardes|assurer la sécurité du réseau"},
#  {'job_offer_id': 1349,
#   'skills': "effectuer les opérations de gestion de profils|systèmes d'information|effectuer les opérations d’|bon fonctionnement"},
#  {'job_offer_id': 1350,
#   'skills': 'réalisation des actions|analyser les bases de données|mettre à disposition des business units|bases de données|business|actions marketing'},
#  {'job_offer_id': 1351,
#   'skills': 'gérer et suivre les projets|coût de réalisation'},
#  {'job_offer_id': 1352,
#   'skills': "définir les standards|superviser les opérations de construction et évolution|suivre son évolution.diplômé|proposer les scénarios d'évolution"},
#  {'job_offer_id': 1353,
#   'skills': 'suivre la qualité de prestation|mettre en place les actions de rétention|traitement des demandes'},
#  {'job_offer_id': 1354,
#   'skills': 'suivre une stratégie de fidélisation pour les clients|mise en place|définir les projets|mettre en place|analyser les profils des clients|suivre les actions de fidélisation|analyser les réclamations'},
#  {'job_offer_id': 1355,
#   'skills': 'réseau informatique|cahier de charge|coordonner les projets de déploiement|superviser les opérations de maintenance|coordonner les études de définitions'},
#  {'job_offer_id': 1356,
#   'skills': "réaliser des analyses|vérifier la fiabilité des données par la suite.diplômé|mettre en place|base de données|systèmes d'information"},
#  {'job_offer_id': 1357,
#   'skills': "contrôler l'intégration de nouvelles stations"},
#  {'job_offer_id': 1358,
#   'skills': "gérer l'ingénierie|mise en service|sélectionner les offres|assurer le déploiement du réseau d'accès"},
#  {'job_offer_id': 1359,
#   'skills': 'ressources humaines|plan de formation|participer au développement|milieu industriel'},
#  {'job_offer_id': 1360,
#   'skills': 'gérer les aspects financiers de la société|réaliser cette mission|administratif et financier'},
#  {'job_offer_id': 1361,
#   'skills': 'permis de développer vos|gérer et organiser une activité|assurer les objectifs de rentabilité|fidéliser chaque collaborateur|former vos équipes|assurer la satisfaction des clients'},
#  {'job_offer_id': 1362,
#   'skills': 'permis de développer vos|assurer la satisfaction des clients'},
#  {'job_offer_id': 1363,
#   'skills': 'support technique|gérer les réponses aux mails techniques'},
#  {'job_offer_id': 1364, 'skills': 'produits chimiques'},
#  {'job_offer_id': 1365,
#   'skills': "mettre en place une offre sur mesure|commande|présenter l'offre technique au client"},
#  {'job_offer_id': 1366,
#   'skills': 'sciences humaines|gestion du stress|gérer les indicateurs|veiller au respect|coordonner les équipes'},
#  {'job_offer_id': 1367, 'skills': 'assister dans les tâches'},
#  {'job_offer_id': 1368, 'skills': 'former des débutants|membres du personnel'},
#  {'job_offer_id': 1369,
#   'skills': 'participer au développement|développer les portefeuilles clients|gérer les ventes|développer un réseau de distribution|nouvelle gamme de produits'},
#  {'job_offer_id': 1371,
#   'skills': 'psychologie de travail|ressources humaines|positionner|base de données'},
#  {'job_offer_id': 1372,
#   'skills': 'cahier des charges|congélation des produits|suivre les plantations|appliquer dans le cadre de votre mission'},
#  {'job_offer_id': 1376,
#   'skills': "support technique|gestion du stress|traiter les problèmes + questions|coordonner le travail d'équipes|gérer l'escalade des problèmes"},
#  {'job_offer_id': 1377,
#   'skills': 'définition de la stratégie|outil informatique'},
#  {'job_offer_id': 1378,
#   'skills': 'outillages de production|proposer des améliorations terrain|créer les documents|mécanique|réaliser les contrôles en production et en réception|modes opératoires|réaliser les audits de poste (production|outils de contrôle|analyser les rebuts et les non-conformes|audit de poste pour intervention'},
#  {'job_offer_id': 1379,
#   'skills': 'demandes des clients|outils informatiques|mécanique|réaliser les devis liés aux opérations de services'},
#  {'job_offer_id': 1380,
#   'skills': 'qualité des prestations|service après-vente|commande'},
#  {'job_offer_id': 1381, 'skills': 'logiciel de facturation'},
#  {'job_offer_id': 1382,
#   'skills': "mise en place et le suivi|mise en place|gérer et animer l'activité"},
#  {'job_offer_id': 1383, 'skills': 'tableaux de bord|outils informatiques'},
#  {'job_offer_id': 1385,
#   'skills': 'intégrer notre structure|préparer des rapports|fiches techniques|suivre les adaptations|suivre les tendances de mode avec une actualisation'},
#  {'job_offer_id': 1387,
#   'skills': 'politique de développement|législation sociale|gestion administrative|mettre en place'},
#  {'job_offer_id': 1388,
#   'skills': 'hygiène et sécurité|piloter le processus|politique de développement|actions préventives|unité de production|ressources humaines'},
#  {'job_offer_id': 1389,
#   'skills': 'nouveaux produits|fidéliser le portefeuille'},
#  {'job_offer_id': 1390,
#   'skills': 'participer à la planification de la production|superviser les équipes de production'},
#  {'job_offer_id': 1391,
#   'skills': 'clients dans le cadre|client dans le cadre|fidéliser notre portefeuille|place les actions|stratégie commerciale|positionner|business|moyen et long terme|créer les contacts nécessaires'},
#  {'job_offer_id': 1392,
#   'skills': 'ressources nécessaires|mise en place|modalités de développement des ressources humaines|gestion budgétaire|nouvelles technologies|gestion des relations|moyens nécessaires|identifier les ressources optimales|technologies informatiques|gérer les hommes'},
#  {'job_offer_id': 1393,
#   'skills': 'ressources humaines|plan de formation|participer au développement|milieu industriel'},
#  {'job_offer_id': 1394, 'skills': 'gérer le support aux utilisateurs'},
#  {'job_offer_id': 1395,
#   'skills': 'mise en place|audit interne|outils informatiques'},
#  {'job_offer_id': 1396,
#   'skills': 'mise en place|fournisseurs, sous-traitants'},
#  {'job_offer_id': 1397,
#   'skills': 'gérer des projets dans leur globalité|cahiers des charges|eau potable'},
#  {'job_offer_id': 1398, 'skills': 'gestion de projet|ressources nécessaires'},
#  {'job_offer_id': 1399,
#   'skills': 'dessin sur autocad|outil informatique|réalisation des plans'},
#  {'job_offer_id': 1400,
#   'skills': "analyser les demandes des clients|prendre en charge|coordonner le travail du support administratif|veiller à la cohérence de l'information"},
#  {'job_offer_id': 1401,
#   'skills': 'outils bureautiques|gérer les tâches suivantes|éléments de facturation'},
#  {'job_offer_id': 1403,
#   'skills': "gérer la production d'une unité autonome|animer la fonction fabrication|veiller au perfectionnement du potentiel humain|unité de production|piloter les démarrages"},
#  {'job_offer_id': 1404,
#   'skills': 'cahier des charges|support technique|mise en place|business'},
#  {'job_offer_id': 1405, 'skills': 'gérer le budget'},
#  {'job_offer_id': 1406,
#   'skills': 'développer des relations commerciales|objectifs stratégiques|leadership|business|anglais courant(obligatoire|marché du textile'},
#  {'job_offer_id': 1407, 'skills': 'business'},
#  {'job_offer_id': 1408, 'skills': 'anglais envisageable'},
#  {'job_offer_id': 1409,
#   'skills': 'mise en place|applications informatiques|assurer le suivi|analyser les circuits de fonctionnement|animer les équipes|participer à la définition|rédiger les règles de fonctionnement'},
#  {'job_offer_id': 1410,
#   'skills': 'suivre la procédure d’un sinistre|sélectionner le produit adéquat'},
#  {'job_offer_id': 1412,
#   'skills': 'traitement des dossiers|application des règles'},
#  {'job_offer_id': 1414,
#   'skills': 'gérer les inscriptions|mettre à jour les données|suivi des paiements|gérer le classement|actualiser les dossiers|suivre les émissions de bons de commande|gérer les facturations|suivre les présences|préparer et suivre les dossiers|piloter la coordination avec les organismes de formations|ressources humaines|suivre les demandes|préparer les dossiers de remboursements à l’|préparer le matériel didactique'},
#  {'job_offer_id': 1415,
#   'skills': 'former des groupes|leadership|réaliser le reporting mensuel des différentes activités|gérer les formation en mode|problèmes techniques|réaliser les projets de formations transversales (formations|gérer les formations en langues|mettre à jour les données sur système d’'},
#  {'job_offer_id': 1416,
#   'skills': 'médecine générale|effectuer des recherches|entretenir des relations'},
#  {'job_offer_id': 1417,
#   'skills': 'relation publique|communication interne|développer notre réseau de communication|techniques de communication'},
#  {'job_offer_id': 1418, 'skills': ''},
#  {'job_offer_id': 1419, 'skills': 'commercial et marketing'},
#  {'job_offer_id': 1420, 'skills': 'outil informatique'},
#  {'job_offer_id': 1421,
#   'skills': "portefeuille clients|mettre en œuvre la politique commerciale|suivre l'organisation commerciale"},
#  {'job_offer_id': 1422, 'skills': 'outil informatique'},
#  {'job_offer_id': 1423, 'skills': 'portefeuille clients|différents produits'},
#  {'job_offer_id': 1424,
#   'skills': 'interventions de maintenance|mécanique, pneumatique|maintenance corrective|réaliser des interventions spécifiques|déroulement des opérations'},
#  {'job_offer_id': 1425,
#   'skills': 'tableaux de bord|gestion administrative|haut niveau'},
#  {'job_offer_id': 1426, 'skills': ''},
#  {'job_offer_id': 1427, 'skills': 'jour les dossiers'},
#  {'job_offer_id': 1434,
#   'skills': 'ressources humaines|respect des procédures|promouvoir des services de qualité'},
#  {'job_offer_id': 1435,
#   'skills': 'humains et matériels|gestion des relations|procédures de fonctionnement|positionner'},
#  {'job_offer_id': 1436,
#   'skills': 'conduite du changement|gestion des ressources humaines|stratégie de développement|tenir des responsabilités motivantes'},
#  {'job_offer_id': 1437,
#   'skills': 'organiser la prospection|génie civil|créer et développer le portefeuille|assurer la réponse aux appels'},
#  {'job_offer_id': 1438, 'skills': 'business'},
#  {'job_offer_id': 1439, 'skills': 'business'},
#  {'job_offer_id': 1440, 'skills': 'business'},
#  {'job_offer_id': 1443, 'skills': 'portefeuille clients|outil informatique'},
#  {'job_offer_id': 1444,
#   'skills': 'mettre en œuvre les actions|elaborer les procédures de sécurité|contrôler le budget de production|optimiser le rendement des activités|assurer la disponibilité des ressources|gérer les équipes|assurer la coordination des activités de production|positionner|assurer la mise en place du système|superviser les opérations de production'},
#  {'job_offer_id': 1446,
#   'skills': 'prévisionnelle des emplois|ressources humaines|assurer la gestion de projets'},
#  {'job_offer_id': 1447,
#   'skills': 'assurer les opérations courantes|conseiller la clientèle'},
#  {'job_offer_id': 1448, 'skills': ''},
#  {'job_offer_id': 1449,
#   'skills': "gérer les contacts|techniques et fonctionnels|superviser la réalisation des travaux|nouveaux marchés|gérer les aspects communication|génie civil|suivre la maintenance|chiffre d'affaires|identifier les besoins en matériaux|valider le plan d’exécution|établir le planning d’exécution|gérer la facturation|piloter les travaux|gérer les tâches suivantes|moyens humains"},
#  {'job_offer_id': 1450,
#   'skills': 'stratégie de développement|assurer la rentabilité financière|définition de la politique|mécanique|écoute active|orientations stratégiques|atteinte des objectifs|politique commerciale|business|moyen et long terme'},
#  {'job_offer_id': 1451,
#   'skills': "fixer|organiser la mise en application|assurer un rôle de représentation|entreprise dans le cadre|relever des défis|cadre d'une organisation|assurer la gestion du groupe"},
#  {'job_offer_id': 1452,
#   'skills': 'mettre en œuvre les actions|elaborer les procédures de sécurité|contrôler le budget de production|optimiser le rendement des activités|assurer la disponibilité des ressources|gérer les équipes|assurer la coordination des activités de production|positionner|assurer la mise en place du système|superviser les opérations de production'},
#  {'job_offer_id': 1453,
#   'skills': 'coacher son équipe|nouveaux produits|plan marketing|déployer les opportunités de développement|réaliser des analyse macroéconomiques et stratégiques|business|produits de grande consommation'},
#  {'job_offer_id': 1454,
#   'skills': 'définir les plans|opérations commerciales|créer une ambiance agréable|permis de développer vos|contrôler les stocks|gérer le merchandising|créer une ambiance motivante|gérer les recrutements|gérer les tâches suivantes'},
#  {'job_offer_id': 1455,
#   'skills': 'définir les plans|opérations commerciales|créer une ambiance agréable|permis de développer vos|contrôler les stocks|gérer le merchandising|créer une ambiance motivante|gérer les recrutements|gérer les tâches suivantes'},
#  {'job_offer_id': 1456,
#   'skills': 'définir les plans|opérations commerciales|créer une ambiance agréable|contrôler les stocks|gérer le merchandising|créer une ambiance motivante|gérer les recrutements|gérer les tâches suivantes'},
#  {'job_offer_id': 1457,
#   'skills': 'business|contrôle de gestion|mise en forme'},
#  {'job_offer_id': 1458, 'skills': 'droit des affaires|droit privé'},
#  {'job_offer_id': 1459,
#   'skills': 'assurer la conformité des obligations|traiter les demandes de règlement|suivre les audits de la comptabilité analytique|nouveaux produits|suivre les dossiers des litiges|nouvelles technologies|participer dans les groupes de travail relatifs|assurer le traitement des échanges|répondre aux demandes|nouveaux projets|contraintes de la réglementation|intervenir dans la résolution des problèmes'},
#  {'job_offer_id': 1461, 'skills': 'business'},
#  {'job_offer_id': 1463, 'skills': 'gammes de produits'},
#  {'job_offer_id': 1464,
#   'skills': 'client, fournisseur|outils bureautiques|comptabilité fournisseur|relever les challenges|comptabilité générale'},
#  {'job_offer_id': 1465,
#   'skills': 'service après vente|prendre en charge|remonter des tendances du marché|assurer la qualité du service'},
#  {'job_offer_id': 1466,
#   'skills': 'diriger les contrats de prestation de service|contribuer à la mise en œuvre des normes qualité|normes de qualité|gérer des clients grands|gérer le budget|prestations de service|moyens humains'},
#  {'job_offer_id': 1467,
#   'skills': 'réaliser les tâches suivantes|préparer les projets|outil informatique'},
#  {'job_offer_id': 1468,
#   'skills': 'éléments nécessaires|conseil juridique|assister dans la collecte|veille juridique|surveiller la gestion du contentieux|droit privé|superviser le recouvrement des impayés|documents contractuels|préparer et maintenir le reporting|effectuer la gestion et le suivi du contentieux|approvisionner les directions'},
#  {'job_offer_id': 1469,
#   'skills': 'recevoir les demandes des directions|améliorer les modèles de contrats|effectuer les démarches auprès|gérer le portefeuille|assurer le conseil juridique|assurer la veille juridique|actualiser l’information|traiter les demandes de consultations juridiques|veille juridique|suivre le portefeuille de marque|analyser le lancement des produits|actes juridiques|contrôler les contrats|mettre à jour|réaliser les activités suivantes|droit privé|rédiger les courriers externes à caractère'},
#  {'job_offer_id': 1470,
#   'skills': 'encadrer une équipe|elaborer les bilans|assurer le suivi|maîtriser les relations avec les tiers|suivre les dépenses|tenir une comptabilité analytique|effectuer des missions spéciales|leadership|optimiser la politique fiscale|place les mesures correctives|etablir les budgets annuels|administratif et financier|réaliser les reportings comptables et financiers|gérer la trésorerie'},
#  {'job_offer_id': 1475, 'skills': 'technique et commerciale'},
#  {'job_offer_id': 1476, 'skills': 'outil informatique'},
#  {'job_offer_id': 1477,
#   'skills': 'suivi statistique|négocier des volumes|espaces publicitaires|activité commerciale'},
#  {'job_offer_id': 1479, 'skills': 'assurer les site surveys'},
#  {'job_offer_id': 1480, 'skills': 'gérer les commandes|gammes de produits'},
#  {'job_offer_id': 1481,
#   'skills': 'outil de production|assurer le maintien en bon état des équipements|informatiques de gestion|tableaux de bord|concevoir la politique|suivre la maintenance|suivre les démarches de contrôle|gérer le budget de son entitéde|élaboration de la politique|gérer les réclamations|organiser et assurer le management opérationnel|mécaniques et électriques|gérer les tâches suivantes|génie rural'},
#  {'job_offer_id': 1482,
#   'skills': 'suivre la mise en place d’une politique|suivre le système|droit social|hygiène, sécurité|assurer une communication optimale|psychologie du travail|droit du travail|gestion administrative du personnel|administratif et financier|relations avec les partenaires|gestion des carrières|outils informatiques|gérer les tâches suivantes|gestion de la paie'},
#  {'job_offer_id': 1483,
#   'skills': 'suivre la réalisation|exécution des travaux|concevoir la politique|assurer la gestion des interfaces|gérer le budget de son entité.de|gérer les réclamations|cahiers des charges|outils informatiques|organiser et assurer le management opérationnel|assurer la réalisation des travaux|gérer les tâches suivantes'},
#  {'job_offer_id': 1485,
#   'skills': 'gestion commerciale|gérer des relations avec des clients|tableaux de bord|traiter les opérations courantes|accueil téléphonique|haut niveau'},
#  {'job_offer_id': 1486, 'skills': ''},
#  {'job_offer_id': 1487, 'skills': ''},
#  {'job_offer_id': 1488,
#   'skills': 'mise en place|gérer des projets dans un environnement dynamique|contrôle de gestion|gestion financière'},
#  {'job_offer_id': 1490, 'skills': 'définir les besoins en approvisionnements'},
#  {'job_offer_id': 1492, 'skills': 'business'},
#  {'job_offer_id': 1493,
#   'skills': "mise en place|nouvelles technologies|leadership|outils d'aide|business|cahier de charges|groupe de travail"},
#  {'job_offer_id': 1496,
# ...
#  {'job_offer_id': 2240,
#   'skills': 'audit qualité|mettre en œuvre les préconisations nécessaires|programme de fabrication'},
#  {'job_offer_id': 2241,
#   'skills': 'mécanique|qualité des prestations|définition de la politique'},
#  {'job_offer_id': 2242,
#   'skills': 'réaliser de façon|permis de développer des|qualité des prestations|leadership'},
#  {'job_offer_id': 2243,
#   'skills': 'outils spécifiques|mettre en place la comptabilité classique|suivre le financement des stocks|bon fonctionnement'},
#  {'job_offer_id': 2244,
#   'skills': "cahier des charges|techniques, économiques|suivre l'exécution des contrats|etablir les contrats d'achats en prenant|négocier les meilleurs|actualiser un fonds documentaire de fournisseurs|evaluer les fournisseurs"},
#  {'job_offer_id': 2245,
#   'skills': 'proposer des modifications dans les produits|nouveaux projets|évolutions techniques'},
#  {'job_offer_id': 2246,
#   'skills': 'assurer le suivi|procéder à la passation des commandes|recenser les besoins des responsables'},
#  {'job_offer_id': 2247,
#   'skills': 'construction mécanique|équipes de travail|mécanique|milieu industriel|gestion de production'},
#  {'job_offer_id': 2248, 'skills': 'cahiers des charges|piloter des équipes'},
#  {'job_offer_id': 2249, 'skills': 'mécanique|milieu industriel'},
#  {'job_offer_id': 2250, 'skills': 'définir les modalités|schéma directeur'},
#  {'job_offer_id': 2251, 'skills': 'milieu industriel'},
#  {'job_offer_id': 2252, 'skills': 'contrôle de gestion|comptabilité générale'},
#  {'job_offer_id': 2254,
#   'skills': 'déclarations fiscales|tableaux de bord|etablir les études financières relatives|opérations comptables|procéder au contrôle des situations|gestion financière|diffuser la réglementation|assurer les relations avec les banques|tenir les situations budgétaires|assurer le contrôle des factures|risques financiers|établir les états de rapprochement|mettre en oeuvre la communication financière|éléments nécessaires|mettre en œuvre la politique de financement et de gestion|relever les anomalies|définir les règlements|suivre le recouvrement|contrôler les inventaires physiques|respect de la réglementation|états financiers|mettre à jour'},
#  {'job_offer_id': 2255,
#   'skills': 'permis de développer une|contrôle de gestion|unités opérationnelles|outils informatiques|comptabilité analytique'},
#  {'job_offer_id': 2256, 'skills': 'actions de communication'},
#  {'job_offer_id': 2257, 'skills': 'produits et services|mise à disposition'},
#  {'job_offer_id': 2258,
#   'skills': 'diriger et animer les activités|intégrer un groupe|moyens nécessaires|mécanique'},
#  {'job_offer_id': 2259,
#   'skills': "contrôler le respect des consignes de sécurité|organiser et diriger l'intervention des secours|réaliser des exercices et simulations|hygiène, sécurité|assurer sa mise en oeuvre|participer à la conception du plan de formation sécurité|conditions de travail|diffuser la documentation|organiser les actions de sensibilisation et de formation"},
#  {'job_offer_id': 2263,
#   'skills': 'procédures du contrôle|tableaux de bord|indicateurs de gestion'},
#  {'job_offer_id': 2264,
#   'skills': 'actions correctives|respect des procédures|tableaux de bord|contrôle de gestion|participer à la définition des procédures de gestion|évolution des résultats'},
#  {'job_offer_id': 2265,
#   'skills': 'hygiène et sécurité|veiller au respect|coacher les équipes|mettre en place des tableaux de bords|assurer la circulation de la marchandise|apporter des améliorations'},
#  {'job_offer_id': 2266,
#   'skills': 'délais de livraison|gestion commerciale|gestion de la relation|suivi des dossiers'},
#  {'job_offer_id': 2267,
#   'skills': 'contrat de maintenance|outils bureautiques|analyser les alarmes|bon fonctionnement|assister dans la collecte|gérer le lot de rechange|superviser le réseau d’access|assurer un support technique|accompagner les techniciens|correctives et préventives|assurer la maintenance'},
#  {'job_offer_id': 2268,
#   'skills': 'sélectionner les offres|assurer le suivi de son déploiement|mise en service|fibre optique|analyser son fonctionnement opérationnel|intervenir dans la collecte des indicateurs,'},
#  {'job_offer_id': 2269,
#   'skills': 'mise à jour|support technique|développement informatique|réaliser les éléments de communication autour'},
#  {'job_offer_id': 2273,
#   'skills': "bilan annuel|calcul d'impôt|fiscales et sociales|documents comptables|procédures comptables|outils informatiques|suivi des activités connexes|comptabilité générale"},
#  {'job_offer_id': 2274, 'skills': 'portefeuille clients'},
#  {'job_offer_id': 2275,
#   'skills': 'outil informatique|mise en forme|dossiers administratifs|appels téléphoniques|support administratif'},
#  {'job_offer_id': 2276, 'skills': ''},
#  {'job_offer_id': 2277, 'skills': ''},
#  {'job_offer_id': 2278, 'skills': ''},
#  {'job_offer_id': 2279, 'skills': 'business'},
#  {'job_offer_id': 2280, 'skills': ''},
#  {'job_offer_id': 2281, 'skills': 'business'},
#  {'job_offer_id': 2282, 'skills': ''},
#  {'job_offer_id': 2283, 'skills': 'commercialiser divers produits'},
#  {'job_offer_id': 2284, 'skills': 'leadership'},
#  {'job_offer_id': 2285, 'skills': 'leadership'},
#  {'job_offer_id': 2286,
#   'skills': 'mécanique|milieu industriel|assurer le suivi quotidien|assurer le développement des ressources|conditions de travail|fonctionnement des installations|gérer votre service|veiller au respect des normes de qualité|analyser les coûts et les ratios de consommation des installations|moyens de production|traitement des eaux|encadrer votre équipe'},
#  {'job_offer_id': 2287,
#   'skills': 'gestion de la trésorerie|suivi de dossiers administratifs'},
#  {'job_offer_id': 2288,
#   'skills': 'superviser les travaux de modifications ou de résiliation des contrats|droit des affaires|elaborer les clauses administratives|cahiers des charges|traiter les dossiers administratifs|coordonner les validations avec les directions financière|traitement des contrats'},
#  {'job_offer_id': 2289, 'skills': ''},
#  {'job_offer_id': 2290,
#   'skills': 'conduite de réunion|ensemble des intervenants'},
#  {'job_offer_id': 2291, 'skills': 'gérer une équipe de chargés de clientèle'},
#  {'job_offer_id': 2292,
#   'skills': 'méthodes et outils de gestion|outil informatique|tableaux de bord|projet de développement|besoins du client'},
#  {'job_offer_id': 2293, 'skills': ''},
#  {'job_offer_id': 2294,
#   'skills': 'méthodes de gestion|proposer des améliorations fonctionnelles|bases de données'},
#  {'job_offer_id': 2296,
#   'skills': 'opérations de production|participer aux opérations|assurer la gestion du département|diriger une équipe'},
#  {'job_offer_id': 2297,
#   'skills': 'présenter les détails techniques et administratifs|atteinte des objectifs|renseigner les clients potentiels|mener la vente à terme'},
#  {'job_offer_id': 2299,
#   'skills': 'assurer le suivi prévisionnel|commercialiser la gamme de produits|équipes techniques|mise à disposition|fidéliser votre portefeuille|etablir des tableaux de bord|assurer la satisfaction finale|gérer une relation avec des responsables techniques et aimez'},
#  {'job_offer_id': 2301,
#   'skills': "parts de marché|assurer le suivi des stratégies des concurrents|contrôler la réalisation du plan marketing pour la ligne|prendre en charge|proposer des plans d'attaque|ligne de produits"},
#  {'job_offer_id': 2302, 'skills': 'appels téléphoniques'},
#  {'job_offer_id': 2303,
#   'skills': 'mise à jour|mise en place|bases de données'},
#  {'job_offer_id': 2304,
#   'skills': 'concevoir et mettre en place des actions de rétention prépayé|bases de données|outil informatique'},
#  {'job_offer_id': 2308,
#   'skills': 'développer les processus nécessaires|outil informatique|améliorer le portefeuille de services à valeur|objectifs stratégiques|assurer la qualité des services.diplômé(e|créer des opportunités'},
#  {'job_offer_id': 2309,
#   'skills': "compte rendu de réunion|méthodes de gestion|mise en place|outils bureautiques|assurer l'interface entre les directeurs|appels téléphoniques"},
#  {'job_offer_id': 2310, 'skills': 'équipe de développement|leadership'},
#  {'job_offer_id': 2311,
#   'skills': "contrôler l'exactitude|préparer le bilan dans les délais fixés|assurer les opérations de caisse|etablir les situations comptables|préparer les documents d'inventaire|réaliser les activités suivantes"},
#  {'job_offer_id': 2312,
#   'skills': 'portefeuille clients|organiser la logistique|etablir la grille tarifaire sous la responsabilité|prospecter de nouveaux clients'},
#  {'job_offer_id': 2313, 'skills': 'commercialiser divers produits'},
#  {'job_offer_id': 2314, 'skills': 'portefeuille client'},
#  {'job_offer_id': 2315,
#   'skills': 'assurer la clôture de fin de mois|respect des procédures|participer à la mise en œuvre des actions correctives|tenir la situation financière|participer à la gestion des réclamations|editer les factures|développer les rapports utilitaires|gérer les relations avec les banques|améliorer les procédures comptables|vérifier la fiabilité|assurer la répartition des centres de coût|traiter les heures productives|coordonner les travaux des arrêtés comptables|contrôler les règlements avant leur signature par la direction générale|comptable et financière|valider les déclarations|préparer les dossiers|participer à la mise en oeuvre des objectifs qualité|enregistrer les documents relatifs|tenir à jour|veiller au respect|participer à la collecte des besoins en formation|analyse financière|comptabilité analytique'},
#  {'job_offer_id': 2316,
#   'skills': 'participer à la mise en oeuvre des objectifs qualité|enregistrer les documents relatifs|assurer le respect de la déontologie comptable|comptabilité analytique|elaborer les différents tableaux|comptable et financière|tableaux de bord|participer à la mise en œuvre des actions correctives|participer à la collecte des besoins en formation|analyse financière|mise à jour|assurer le respect des dates'},
#  {'job_offer_id': 2317, 'skills': 'audit scores'},
#  {'job_offer_id': 2319,
#   'skills': 'veille juridique|droit des affaires|conformité des opérations|outil de pilotage|droit privé|droit des sociétés|droit commercial'},
#  {'job_offer_id': 2320,
#   'skills': 'opérations de marché|gestion des risques|modélisation mathématique|outils informatiques'},
#  {'job_offer_id': 2322, 'skills': ''},
#  {'job_offer_id': 2323,
#   'skills': 'traitement des dossiers|application des règles|droit public'},
#  {'job_offer_id': 2324,
#   'skills': 'conseil juridique|assister dans la collecte|surveiller la gestion du contentieux|superviser le recouvrement des impayés|documents contractuels|effectuer la gestion et le suivi du contentieux|approvisionner les directions'},
#  {'job_offer_id': 2325,
#   'skills': 'orientations stratégiques|gérer les arrêts|suivi des dossiers contentieux|contrôler et gérer les factures des honoraires'},
#  {'job_offer_id': 2327,
#   'skills': 'assurer le routage des magazines.diplômé(e|optimiser la qualité des titres'},
#  {'job_offer_id': 2328,
#   'skills': 'assurer les travaux de comptabilité en collaboration|etablir les déclarations fiscales et sociales|outil informatique|assurer le suivi|respect des procédures|préparer les états financiers périodiques|tableaux de bord|préparer les reportings|participer à la mise à jour des procédures|administrative et financière|contrôler la fiabilité des comptes|logiciels comptables|gérer les missions suivantes|administratif et financier|tenir les états financiers|contrôle interne'},
#  {'job_offer_id': 2329,
#   'skills': 'formaliser les rapports de mission|outil informatique|milieu industriel|actions correctives|management de la qualité|coordonner la qualification des auditeurs selon la procédure|conduire les audits|audit de certification'},
#  {'job_offer_id': 2330,
#   'skills': 'mécanique|contrôle dimensionnel|bon fonctionnement|gestion de la relation|audit interne'},
#  {'job_offer_id': 2335,
#   'skills': 'suivi statistique|négocier des volumes|espaces publicitaires|activité commerciale'},
#  {'job_offer_id': 2336, 'skills': 'différents éléments'},
#  {'job_offer_id': 2337, 'skills': 'maintenance préventive'},
#  {'job_offer_id': 2338,
#   'skills': 'analyser les émissions|préparer le découpage technique|réalisation technique'},
#  {'job_offer_id': 2339, 'skills': "chiffre d'affaires"},
#  {'job_offer_id': 2340, 'skills': 'éléments constitutifs|animation radio'},
#  {'job_offer_id': 2343,
#   'skills': "respect de la réglementation|définir les normes|conseiller les clients|assurer la réalisation des achats en réponse|mettre en œuvre des actions|atteinte des objectifs|elaborer les programmes d'achat nationaux|assurer la réalisation des achats"},
#  {'job_offer_id': 2344, 'skills': 'projets de développement'},
#  {'job_offer_id': 2345,
#   'skills': 'assurer la disponibilité permanente|etablir les demandes|négocier les contrats|négocier le droit de passage'},
#  {'job_offer_id': 2346,
#   'skills': 'produits et services|gérer un portefeuille de clients|marché des télécoms|suivi des dossiers'},
#  {'job_offer_id': 2347, 'skills': 'gestion administrative'},
#  {'job_offer_id': 2348,
#   'skills': 'problèmes techniques|gestion de parc informatique|outil informatique'},
#  {'job_offer_id': 2349,
#   'skills': 'effectuer le reporting auprès|nécessaires à la réalisation|composants (pièces|bon fonctionnement|effectuer le suivi des performances|leadership|atteinte des objectifs|animer le plan de production|gestion de projet|outils de pilotage'},
#  {'job_offer_id': 2350,
#   'skills': 'permis de développer une|moyens techniques|lignes de conditionnement|normes de qualité'},
#  {'job_offer_id': 2352,
#   'skills': 'réaliser les procédures de travail|assister dans la collecte|participer à la mise en oeuvre des projets d’amélioration des processus|bonnes pratiques|participer à la mise en œuvre'},
#  {'job_offer_id': 2353,
#   'skills': "données économiques|contrôle de gestion|audit réglementaire|analyse des coûts|assurer le suivi de l'audit réglementaire|assurer l'analyse des tarifs de détail|comptabilité analytique"},
#  {'job_offer_id': 2354,
#   'skills': 'outil informatique|humains et matériels|prendre en charge|effectuer des inventaires|état des produits|mettre en place des procédures de travail|quantité et qualité|contrôler le suivi|fiche technique'},
#  {'job_offer_id': 2355,
#   'skills': "piloter les audits|superviser les équipes de fabrication (agents|mise en oeuvre de la politique|assurer la liaison avec les services qualité|mise en place|mettre en place l'autocontrôle|actions préventives|coordonner les actions préventives|assurer la mise à jour|outil informatique|actions correctives|préparer les plans d'actions|gérer les audits internes|suivre les plans d'actions|traiter les réclamations|système de management de la qualité|procédures qualité|participer à l'amélioration du niveau de qualité|normes qualité"},
#  {'job_offer_id': 2356,
#   'skills': 'optimisation des coûts|produits chimiques|outil informatique|opérations de traitement|leadership|schéma directeur|techniques et organisationnelles|suivi des données techniques|gestion des opérations'},
#  {'job_offer_id': 2357,
#   'skills': 'pièces du patron|forme et les dimensions|etablir les tailles d’un vêtement|déterminer le nombre|fiches techniques|différentes parties'},
#  {'job_offer_id': 2358, 'skills': 'leadership|business'},
#  {'job_offer_id': 2359,
#   'skills': 'réaliser les objectifs prévus en matière de volume|assurer le lancement des nouveaux produits|développer les tâches définies|développer les opportunités commerciales'},
#  {'job_offer_id': 2360,
#   'skills': 'analyser les risques|assurer le suivi commercial|définir les objectifs collectifs|nouveaux produits|proposer des actions de promotion des ventes|organiser leur formation|analyser le potentiel du marché|leadership|veille concurrentielle|atteinte des objectifs|piloter les ventes|créer et développer une relation|prendre en charge|gérer le lancement commercial|assurer une remontée régulière|gérer et accompagner les revendeurs'},
#  {'job_offer_id': 2361,
#   'skills': 'comptable et financier|leadership|prendre en charge|procédures comptables|ressources financières|juridiques et fiscaux'},
#  ...]

# %% [markdown]
# ### English Skill Extraction

# %%
skill_pattern_path = join(DATA_FILES,"jz_skill_patterns.jsonl")
ruler = en_nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_pattern_path)

# %%
get_all_skills(en_nlp, jo_df, join(SKILL_OUT, 'jz_extracted_skills_v3.jsonl'))

# %% [markdown]
# ## Coursera Hard Skill extraction

# %%
def get_skills(nlp,text):
    doc = nlp(text)
    myset = []
    subset = []
    for ent in doc.ents:
        if ent.label_ == "SKILL":
            subset.append(ent.text)
    myset.append(subset)
    return subset

def get_all_skills(nlp, df, file_name, id_col, id_text):
    pbar = tqdm(total = df.shape[0])
    for i, rec in df.iterrows():
        added_data = {}
        post_data = rec[id_text]
        job_offer_id = rec[id_col]
        post_data = post_data.lower()
        skills = get_skills(nlp, post_data)
        added_data[id_col] = job_offer_id
        added_data['skills'] = '|'.join(list(set(skills)))
        write_json_lines(file_name,added_data)
        pbar.update()

# %%
cours_df = pd.DataFrame(read_json_lines(file_name=join('coursera', 'coursera_courses.jsonl')))

# %%
cours_df.head()
# Out:
#     courseType                                        description  \
# 0  v2.ondemand  In this two-hour, project-based course, we int...
# 1  v2.ondemand  À la fin de ce projet, vous aurez toutes les c...
# 2  v2.ondemand  ينشئ العديد من الأشخاص حسابات وسائط اجتماعية م...
# 3  v2.ondemand  Gamification is the application of game elemen...
# 4  v2.ondemand  This course will cover the steps used in weigh...
#
#                        id                                               slug  \
# 0  NJSdGN71Eeq4CApSN3OTvQ  make-pick-ups-look-cool-unity-introduction-ani...
# 1  DMkcgX7LEeyRTg6FtAvfBw          integrer-applications-dashboard-hootsuite
# 2  YLO0oGSUEeyIUg4Qv2RsBQ                  getting-started-with-hootsuite-ar
# 3  69Bku0KoEeWZtA4u62x6lQ                                       gamification
# 4  0HiU7Oe4EeWTAQ4yevf_oQ                                       missing-data
#
#   instructorIds specializations partnerIds  \
# 0     [4730641]              []      [565]
# 1    [26958800]              []      [565]
# 2    [76377122]              []      [565]
# 3      [226710]              []        [6]
# 4     [8394050]              []       [32]
#
#                                                 name  page
# 0  Make Your Pick-Ups Look Cool in Unity (Intro t...     0
# 1  Intégrer des applications dans votre Dashboard...     0
# 2                     كيفية استعمال التطبيق هووتسويت     0
# 3                                       Gamification     0
# 4                          Dealing With Missing Data     0

# %%
cours_df['all_text'] = cours_df['description']+' '+cours_df['name']

# %% [markdown]
# ### French Rule Extraction

# %%
skill_pattern_path = join(DATA_FILES,"fr_skill_patterns_final.jsonl")
# ruler = fr_nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_pattern_path)

# %%
get_all_skills(fr_nlp, cours_df, join(SKILL_OUT, 'fr_coursera_extracted_skills_v2.jsonl'), 'id', 'all_text')
# Out:
#   0%|          | 0/10180 [00:00<?, ?it/s]

# %% [markdown]
# ### New French Rule Extraction

# %%
skill_pattern_path = join(DATA_FILES,"fr_skill_patterns_pole_emploi_v2.jsonl")
ruler = fr_nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_pattern_path)

# %%
get_all_skills(fr_nlp, cours_df, join(SKILL_OUT, 'fr_coursera_extracted_skills_pole_emploi_v1.jsonl'), 'id', 'all_text')
# Out:
#   0%|          | 0/10180 [00:00<?, ?it/s]

# %%
read_json_lines(join(SKILL_OUT, 'fr_coursera_extracted_skills_pole_emploi_v1.jsonl'))

# %% [markdown]
# ### English Skill Extraction

# %%
skill_pattern_path = join(DATA_FILES,"jz_skill_patterns.jsonl")
ruler = en_nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_pattern_path)

# %%
get_all_skills(en_nlp, cours_df, join(SKILL_OUT, 'jz_coursera_extracted_skills_v1.jsonl'), 'id', 'all_text')
