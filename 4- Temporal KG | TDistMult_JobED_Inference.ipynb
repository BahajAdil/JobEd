# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torchkge
# Out:
# Collecting torchkge
#   Downloading torchkge-0.17.7-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.6/51.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from torchkge) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.64 in /usr/local/lib/python3.10/dist-packages (from torchkge) (4.66.1)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from torchkge) (1.5.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from torchkge) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->torchkge) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->torchkge) (2023.3.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->torchkge) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->torchkge) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.2.0->torchkge) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.2.0->torchkge) (1.3.0)
# Installing collected packages: torchkge
# Successfully installed torchkge-0.17.7

# %%
from torch import empty, zeros, cat
from tqdm.notebook import tqdm

from torchkge.data_structures import SmallKG
from torchkge.exceptions import NotYetEvaluatedError
from torchkge.sampling import PositionalNegativeSampler
from torchkge.utils import DataLoader
import pandas as pd
import torch
import torch
import os
from os.path import join
# from evaluation import TemporalLinkPredictionEvaluator

from torchkge.utils import datasets
import torch
from pandas import read_csv, concat
import json
from datetime import datetime
import pandas as pd

from torchkge.utils import datasets
import torch
from pandas import read_csv, concat
# from data_utils import TemporalKnowledgeGraph
from numpy.random import RandomState

from torch import tensor, bernoulli, randint, ones, rand, cat
from torchkge.utils import init_embedding
from torch.nn.functional import normalize
import torch.nn.functional as F
import itertools
import seaborn as sns
from datetime import datetime, time, timedelta
# Out:
# /usr/local/lib/python3.10/dist-packages/torchkge/utils/data_redundancy.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import shutil

from os import environ, makedirs
from os.path import exists, expanduser, join
from torch.utils.data import Dataset
from torchkge.exceptions import SizeMismatchError, WrongArgumentsError, SanityError
from torchkge.utils.operations import get_dictionaries
from torch import cat, eq, int64, long, randperm, tensor, Tensor, zeros_like
from collections import defaultdict
from pandas import DataFrame
import torch
# from utils import get_temporal_dictionaries
from pandas import read_csv, concat

# %%
from os.path import join
import torch
from torch import cuda
from torch.optim import Adam
from torchkge.sampling import BernoulliNegativeSampler, UniformNegativeSampler
from tqdm.notebook import tqdm
import pandas as pd
import os

# %%
from torchkge.utils import MarginLoss, BinaryCrossEntropyLoss, LogisticLoss
import torch
import torch.distributed as dist
from abc import ABC, abstractmethod
import torch.distributed as dist
import torch.nn as nn

import numpy as np

# %%
from torch.nn import Module


from torchkge.utils.dissimilarities import l1_dissimilarity, l2_dissimilarity, \
    l1_torus_dissimilarity, l2_torus_dissimilarity, el2_torus_dissimilarity

# %%
from collections import defaultdict

from torch import tensor, bernoulli, randint, ones, rand, cat

from torchkge.exceptions import NotYetImplementedError
from torchkge.utils.data import DataLoader
from torchkge.utils.operations import get_bernoulli_probs

# %%
import torch
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
DATA_PATH = '/content/drive/MyDrive/PhD/TKG/1 TDYCE/data'
MODEL_PATH = '/content/drive/MyDrive/PhD/TKG/1 TDYCE/best_models'
# device = 'cpu'

# %% [markdown]
# ## Utils

# %%
tem_dict = {
    '0y': 0, '1y': 1, '2y': 2, '3y': 3, '4y': 4, '5y': 5, '6y': 6, '7y': 7, '8y': 8, '9y': 9,
    '0m': 10, '1m': 11, '2m': 12, '3m': 13, '4m': 14, '5m': 15, '6m': 16, '7m': 17, '8m': 18, '9m': 19,
    '0d': 20, '1d': 21, '2d': 22, '3d': 23, '4d': 24, '5d': 25, '6d': 26, '7d': 27, '8d': 28, '9d': 29
}

class Params():
    def __init__(self):
        pass


def get_expriment_tests(results):
    res = []
    for exp in results:
        train_params = exp['train_params']
        test_results = exp['test_results']
        train_params.update(test_results)
        res.append(train_params)
    return pd.DataFrame(res)

def read_json_lines(file_name):
    lines = []
    with open(file_name) as file_in:
        for line in file_in:
            lines.append(json.loads(line))
    return lines

def write_json_lines(file_name,dict_data):
    json_string = json.dumps(dict_data)
    with open(file_name, 'a') as f:
        f.write(json_string+"\n")

def experiment_exists(all_exp_data_df, exp_data_dict, important_fields = None):
    if important_fields is None:
        search_keys = exp_data_dict
    else:
        search_keys = important_fields
    for k in search_keys:
        all_exp_data_df = all_exp_data_df[all_exp_data_df[k]==exp_data_dict[k]]
        if all_exp_data_df.shape[0]==0:
            return False
    return True

def check_experiment(exp_file_name):
    res = read_json_lines(exp_file_name)
    res = get_expriment_tests(res)
    return res

def transform_time_V2(years, months, days):
    all_data = []
    for year, month, day in zip(years, months, days):
        tem_id_list = []
        for j in range(len(year)):
            token = year[j:j+1]+'y'
            tem_id_list.append(tem_dict[token])
        # print(tem_id_list)
        # exit()

        for j in range(1):
            # print(month[1])
            # exit()
            token1 = month[0]+'m'
            tem_id_list.append(tem_dict[token1])
            token2 = month[0]+'m'
            tem_id_list.append(tem_dict[token2])


        for j in range(len(day)):
            token = day[j:j+1]+'d'
            tem_id_list.append(tem_dict[token])

        all_data.append(torch.tensor(tem_id_list))
    return all_data

def transform_time(raw_time):
    year, month, day = raw_time.split("-")
    tem_id_list = []
    for j in range(len(year)):
        token = year[j:j+1]+'y'
        tem_id_list.append(tem_dict[token])
    # print(tem_id_list)
    # exit()

    for j in range(1):
        # print(month[1])
        # exit()
        token1 = month[0]+'m'
        tem_id_list.append(tem_dict[token1])
        token2 = month[0]+'m'
        tem_id_list.append(tem_dict[token2])


    for j in range(len(day)):
        token = day[j:j+1]+'d'
        tem_id_list.append(tem_dict[token])
    return tem_id_list

def transform_time_v3(raw_time):
    date = list(map(float, raw_time.split("-")))
    return date

def transform_time_v4(raw_time):
    year, month, day = raw_time.split("-")
    year, month, day = int(year), int(month), int(day)
    return month + day

def transform_time_v5(raw_time):
    year, month, day = raw_time.split("-")
    return [int(year), int(month), int(day)]

def get_temporal_dictionaries(df, mode='simple'):

    tmp = list(set(df['start_time'].unique()).union(set(df['end_time'].unique())))
    if mode == 'simple_time':
        # return {timee: i for i, timee in enumerate(sorted(tmp))}
        idx = {timee: i for i, timee in enumerate(sorted([datetime.strptime(dt, "%Y-%m-%d") for dt in tmp]))}
        time_trans = torch.tensor(list(idx.values()))
        return idx, time_trans
    elif mode == 'simple':
        # return {timee: i for i, timee in enumerate(sorted(tmp))}
        idx = {timee: i for i, timee in enumerate(sorted([dt for dt in tmp]))}
        time_trans = torch.tensor(list(idx.values()))
        return idx, time_trans
    elif mode == 'seq':
        idx = {timee: i for i, timee in enumerate(sorted(tmp))}
        time_trans = torch.vstack([torch.tensor(transform_time(timee)) for timee in sorted(tmp)])
        return idx, time_trans
        # return {timee: torch.tensor(transform_time(timee)) for i, timee in enumerate(sorted([datetime.strptime(dt, "%Y-%m-%d") for dt in tmp]))}
    elif mode == 'ymd':
        idx = {timee: transform_time_v4(timee) for i, timee in enumerate(sorted(tmp))}
        time_trans = torch.vstack([transform_time_v4(timee) for timee in sorted(tmp)])
        return
    elif mode == 'ymd_':
#         idx = {timee: torch.tensor(transform_time_v5(timee)) for i, timee in enumerate(sorted(tmp))}
        idx = {timee: i for i, timee in enumerate(sorted(tmp))}
        time_trans = torch.vstack([torch.tensor(transform_time_v5(timee)) for timee in sorted(tmp)])
        return idx, time_trans

def cconv(a, b):
    return torch.fft.ifft(torch.fft.fft(a) * torch.fft.fft(b)).real


def ccorr(a, b):
    return torch.fft.ifft(torch.conj(torch.fft.fft(a)) * torch.fft.fft(b)).real

# %% [markdown]
# ##  Data Utils

# %%
class TemporalKnowledgeGraph(Dataset):

    def __init__(self, df=None, time_mode = None,kg=None, ent2ix=None, rel2ix=None, time2ix = None,
                 time_trans = None,
                 dict_of_heads=None, dict_of_tails=None, dict_of_rels=None,
                 temp_dict_of_heads=None, temp_dict_of_tails=None, temp_dict_of_rels=None):

        if df is None:
            if kg is None:
                raise WrongArgumentsError("Please provide at least one "
                                          "argument of `df` and kg`")
            else:
                try:
                    assert (type(kg) == dict) & ('heads' in kg.keys()) & \
                           ('tails' in kg.keys()) & \
                           ('relations' in kg.keys())& \
                            ('start_time' in kg.keys())& \
                            ('end_time' in kg.keys())

                except AssertionError:
                    raise WrongArgumentsError("Keys in the `kg` dict should "
                                              "contain `heads`, `tails`, "
                                              "`relations`.")
                try:
                    assert (rel2ix is not None) & (ent2ix is not None)
                except AssertionError:
                    raise WrongArgumentsError("Please provide the two "
                                              "dictionaries ent2ix and rel2ix "
                                              "if building from `kg`.")
        else:
            if kg is not None:
                raise WrongArgumentsError("`df` and kg` arguments should not "
                                          "both be provided.")

        if ent2ix is None:
            self.ent2ix = get_dictionaries(df, ent=True)
        else:
            self.ent2ix = ent2ix

        if rel2ix is None:
            self.rel2ix = get_dictionaries(df, ent=False)
        else:
            self.rel2ix = rel2ix

        if time_mode is not None:
            self.time_mode = time_mode

        if time2ix is None:
            self.time2ix, self.time_trans = get_temporal_dictionaries(df, mode = self.time_mode)
        else:
            self.time2ix, self.time_trans = time2ix, time_trans

        self.n_ent = max(self.ent2ix.values()) + 1
        self.n_rel = max(self.rel2ix.values()) + 1
        time_val = list(self.time2ix.values())

        if isinstance(time_val[0], torch.Tensor):
            self.n_time = int(torch.cat(time_val).max()) + 1
        else:
            self.n_time = max(time_val) + 1

#         print('self.n_time: ',self.n_time)
        if df is not None:
            # build kg from a pandas dataframe
            self.n_facts = len(df)
            self.head_idx = tensor(df['from'].map(self.ent2ix).values).long()
            self.tail_idx = tensor(df['to'].map(self.ent2ix).values).long()
            self.relations = tensor(df['rel'].map(self.rel2ix).values).long()
#             self.start_time = tensor(df['start_time'].map(self.rel2ix).values).long()
#             self.end_time = tensor(df['end_time'].map(self.rel2ix).values).long()
#             print(self.time2ix)
            self.start_time = list(df['start_time'].map(self.time2ix).values)
#             print(self.start_time)
#             print('-'*22)
#             print("type(self.start_time[0]): ",type(self.start_time[0]))
#             print('type(self.start_time): ',type(self.start_time))
#             if isinstance(self.start_time[0], torch.Tensor):
#                 print('llllll')
            if isinstance(self.start_time, list) & isinstance(self.start_time[0], torch.Tensor):
                self.start_time = torch.stack(self.start_time)
            else:
                self.start_time = torch.tensor(self.start_time)

            self.start_time = self.start_time.long()

            self.end_time = list(df['end_time'].map(self.time2ix).values)
            if isinstance(self.end_time, list) & isinstance(self.end_time[0], torch.Tensor):
                self.end_time = torch.stack(self.end_time)
            else:
                self.end_time = torch.tensor(self.end_time)
            self.end_time = self.end_time.long()

        else:
            # build kg from another kg
            self.n_facts = kg['heads'].shape[0]
            self.head_idx = kg['heads']
            self.tail_idx = kg['tails']
            self.relations = kg['relations']
            self.start_time = kg['start_time']
            self.end_time = kg['end_time']

        if dict_of_heads is None or dict_of_tails is None or dict_of_rels is None:
            self.dict_of_heads = defaultdict(set)
            self.dict_of_tails = defaultdict(set)
            self.dict_of_rels = defaultdict(set)
            self.temp_dict_of_heads = defaultdict(set)
            self.temp_dict_of_tails = defaultdict(set)
            self.temp_dict_of_rels = defaultdict(set)
#             self.dict_of_start_time = defaultdict(set)
#             self.dict_of_end_time = defaultdict(set)
            self.evaluate_dicts()

        else:
            self.dict_of_heads = dict_of_heads
            self.dict_of_tails = dict_of_tails
            self.dict_of_rels = dict_of_rels
            self.temp_dict_of_heads = temp_dict_of_heads
            self.temp_dict_of_tails = temp_dict_of_tails
            self.temp_dict_of_rels = temp_dict_of_rels
#             self.dict_of_start_time = dict_of_start_time
#             self.dict_of_end_time = dict_of_end_time
        try:
            self.sanity_check()
        except AssertionError:
            raise SanityError("Please check the sanity of arguments.")

    def __len__(self):
        return self.n_facts

    def __getitem__(self, item):
        return (self.head_idx[item].item(),
                self.tail_idx[item].item(),
                self.relations[item].item())

    def sanity_check(self):
        assert (type(self.dict_of_heads) == defaultdict) & \
               (type(self.dict_of_tails) == defaultdict) & \
               (type(self.dict_of_rels) == defaultdict) & \
                (type(self.temp_dict_of_heads) == defaultdict) & \
               (type(self.temp_dict_of_tails) == defaultdict) & \
               (type(self.temp_dict_of_rels) == defaultdict)
        assert (type(self.ent2ix) == dict) & (type(self.rel2ix) == dict)
        assert (len(self.ent2ix) == self.n_ent) & \
               (len(self.rel2ix) == self.n_rel)
        assert (type(self.head_idx) == Tensor) & \
               (type(self.tail_idx) == Tensor) & \
               (type(self.relations) == Tensor)
        assert (self.head_idx.dtype == int64) & \
               (self.tail_idx.dtype == int64) & (self.relations.dtype == int64)
        assert (len(self.head_idx) == len(self.tail_idx) == len(self.relations))

    def split_kg(self, share=0.8, sizes=None, validation=False):
        if sizes is not None:
            try:
                if len(sizes) == 3:
                    try:
                        assert (sizes[0] + sizes[1] + sizes[2] == self.n_facts)
                    except AssertionError:
                        raise WrongArgumentsError('Sizes should sum to the '
                                                  'number of facts.')
                elif len(sizes) == 2:
                    try:
                        assert (sizes[0] + sizes[1] == self.n_facts)
                    except AssertionError:
                        raise WrongArgumentsError('Sizes should sum to the '
                                                  'number of facts.')
                else:
                    raise SizeMismatchError('Tuple `sizes` should be of '
                                            'length 2 or 3.')
            except AssertionError:
                raise SizeMismatchError('Tuple `sizes` should sum up to the '
                                        'number of facts in the knowledge '
                                        'graph.')
        else:
            assert share < 1

        if ((sizes is not None) and (len(sizes) == 3)) or \
                ((sizes is None) and validation):
            # return training, validation and a testing graphs

            if (sizes is None) and validation:
                mask_tr, mask_val, mask_te = self.get_mask(share,
                                                           validation=True)
            else:
                mask_tr = cat([tensor([1 for _ in range(sizes[0])]),
                               tensor([0 for _ in range(sizes[1] + sizes[2])])]).bool()
                mask_val = cat([tensor([0 for _ in range(sizes[0])]),
                                tensor([1 for _ in range(sizes[1])]),
                                tensor([0 for _ in range(sizes[2])])]).bool()
                mask_te = ~(mask_tr | mask_val)

            return (TemporalKnowledgeGraph(
                        kg={'heads': self.head_idx[mask_tr],
                            'tails': self.tail_idx[mask_tr],
                            'relations': self.relations[mask_tr],
                           'start_time': self.start_time[mask_tr],
                           'end_time': self.end_time[mask_tr]},
                            ent2ix=self.ent2ix, rel2ix=self.rel2ix, time2ix = self.time2ix,
                            time_trans = self.time_trans,
                            dict_of_heads=self.dict_of_heads,
                            dict_of_tails=self.dict_of_tails,
                            dict_of_rels=self.dict_of_rels,
                            temp_dict_of_heads = self.temp_dict_of_heads,
                            temp_dict_of_tails = self.temp_dict_of_tails,
                            temp_dict_of_rels = self.temp_dict_of_rels
                            ),
                    TemporalKnowledgeGraph(
                        kg={'heads': self.head_idx[mask_val],
                            'tails': self.tail_idx[mask_val],
                            'relations': self.relations[mask_val],
                           'start_time':  self.start_time[mask_val],
                           'end_time': self.end_time[mask_val]},
                        ent2ix=self.ent2ix, rel2ix=self.rel2ix, time2ix = self.time2ix,
                        time_trans = self.time_trans,
                        dict_of_heads=self.dict_of_heads,
                        dict_of_tails=self.dict_of_tails,
                        dict_of_rels=self.dict_of_rels,
                        temp_dict_of_heads = self.temp_dict_of_heads,
                        temp_dict_of_tails = self.temp_dict_of_tails,
                        temp_dict_of_rels = self.temp_dict_of_rels),
                    TemporalKnowledgeGraph(
                        kg={'heads': self.head_idx[mask_te],
                            'tails': self.tail_idx[mask_te],
                            'relations': self.relations[mask_te],
                           'start_time': self.start_time[mask_te],
                           'end_time': self.end_time[mask_te]},
                        ent2ix=self.ent2ix, rel2ix=self.rel2ix, time2ix = self.time2ix,
                        time_trans = self.time_trans,
                        dict_of_heads=self.dict_of_heads,
                        dict_of_tails=self.dict_of_tails,
                        dict_of_rels=self.dict_of_rels,
                        temp_dict_of_heads = self.temp_dict_of_heads,
                        temp_dict_of_tails = self.temp_dict_of_tails,
                        temp_dict_of_rels = self.temp_dict_of_rels
                        ))
        else:
            # return training and testing graphs

            assert (((sizes is not None) and len(sizes) == 2) or
                    ((sizes is None) and not validation))
            if sizes is None:
                mask_tr, mask_te = self.get_mask(share, validation=False)
            else:
                mask_tr = cat([tensor([1 for _ in range(sizes[0])]),
                               tensor([0 for _ in range(sizes[1])])]).bool()
                mask_te = ~mask_tr
            return (TemporalKnowledgeGraph(
                        kg={'heads': self.head_idx[mask_tr],
                            'tails': self.tail_idx[mask_tr],
                            'relations': self.relations[mask_tr],
                           'start_time': self.start_time[mask_tr],
                           'end_time': self.end_time[mask_tr]},
                        ent2ix=self.ent2ix, rel2ix=self.rel2ix, time2ix = self.time2ix,
                        time_trans = self.time_trans,
                        dict_of_heads=self.dict_of_heads,
                        dict_of_tails=self.dict_of_tails,
                        dict_of_rels=self.dict_of_rels,
                        temp_dict_of_heads = self.temp_dict_of_heads,
                        temp_dict_of_tails = self.temp_dict_of_tails,
                        temp_dict_of_rels = self.temp_dict_of_rels
                        ),
                    TemporalKnowledgeGraph(
                        kg={'heads': self.head_idx[mask_te],
                            'tails': self.tail_idx[mask_te],
                            'relations': self.relations[mask_te],
                           'start_time': self.start_time[mask_te],
                           'end_time': self.end_time[mask_te]},
                        ent2ix=self.ent2ix, rel2ix=self.rel2ix, time2ix = self.time2ix,
                        time_trans = self.time_trans,
                        dict_of_heads=self.dict_of_heads,
                        dict_of_tails=self.dict_of_tails,
                        dict_of_rels=self.dict_of_rels,
                        temp_dict_of_heads = self.temp_dict_of_heads,
                        temp_dict_of_tails = self.temp_dict_of_tails,
                        temp_dict_of_rels = self.temp_dict_of_rels
                        ))

    def get_mask(self, share, validation=False):

        uniques_r, counts_r = self.relations.unique(return_counts=True)
        uniques_e, _ = cat((self.head_idx,
                            self.tail_idx)).unique(return_counts=True)

        mask = zeros_like(self.relations).bool()
        if validation:
            mask_val = zeros_like(self.relations).bool()

        # splitting relations among subsets
        for i, r in enumerate(uniques_r):
            rand = randperm(counts_r[i].item())

            # list of indices k such that relations[k] == r
            sub_mask = eq(self.relations, r).nonzero(as_tuple=False)[:, 0]

            assert len(sub_mask) == counts_r[i].item()

            if validation:
                train_size, val_size, test_size = self.get_sizes(counts_r[i].item(),
                                                                 share=share,
                                                                 validation=True)
                mask[sub_mask[rand[:train_size]]] = True
                mask_val[sub_mask[rand[train_size:train_size + val_size]]] = True

            else:
                train_size, test_size = self.get_sizes(counts_r[i].item(),
                                                       share=share,
                                                       validation=False)
                mask[sub_mask[rand[:train_size]]] = True

        # adding missing entities to the train set
        u = cat((self.head_idx[mask], self.tail_idx[mask])).unique()
        if len(u) < self.n_ent:
            missing_entities = tensor(list(set(uniques_e.tolist()) -
                                           set(u.tolist())), dtype=long)
            for e in missing_entities:
                sub_mask = ((self.head_idx == e) |
                            (self.tail_idx == e)).nonzero(as_tuple=False)[:, 0]
                rand = randperm(len(sub_mask))
                sizes = self.get_sizes(mask.shape[0],
                                       share=share,
                                       validation=validation)
                mask[sub_mask[rand[:sizes[0]]]] = True
                if validation:
                    mask_val[sub_mask[rand[:sizes[0]]]] = False

        if validation:
            assert not (mask & mask_val).any().item()
            return mask, mask_val, ~(mask | mask_val)
        else:
            return mask, ~mask

    @staticmethod
    def get_sizes(count, share, validation=False):
        if count == 1:
            if validation:
                return 1, 0, 0
            else:
                return 1, 0
        if count == 2:
            if validation:
                return 1, 1, 0
            else:
                return 1, 1

        n_train = int(count * share)
        assert n_train < count
        if n_train == 0:
            n_train += 1

        if not validation:
            return n_train, count - n_train
        else:
            if count - n_train == 1:
                n_train -= 1
                return n_train, 1, 1
            else:
                n_val = int(int(count - n_train) / 2)
                return n_train, n_val, count - n_train - n_val

    def evaluate_dicts(self):
        for i in range(self.n_facts):
            self.dict_of_heads[(self.tail_idx[i].item(),
                                self.relations[i].item())].add(self.head_idx[i].item())
            self.dict_of_tails[(self.head_idx[i].item(),
                                self.relations[i].item())].add(self.tail_idx[i].item())
            self.dict_of_rels[(self.head_idx[i].item(),
                               self.tail_idx[i].item())].add(self.relations[i].item())

            self.temp_dict_of_heads[(self.tail_idx[i].item(),
                                    self.relations[i].item(),
                                     self.start_time[i].item(),
                                     self.end_time[i].item())].add(self.head_idx[i].item())
            self.temp_dict_of_tails[(self.head_idx[i].item(),
                                self.relations[i].item(),
                                     self.start_time[i].item(),
                                     self.end_time[i].item())].add(self.tail_idx[i].item())
            self.temp_dict_of_rels[(self.head_idx[i].item(),
                                   self.tail_idx[i].item(),
                                    self.start_time[i].item(),
                                     self.end_time[i].item())].add(self.relations[i].item())

    def get_df(self):
        ix2ent = {v: k for k, v in self.ent2ix.items()}
        ix2rel = {v: k for k, v in self.rel2ix.items()}

        df = DataFrame(cat((self.head_idx.view(1, -1),
                            self.tail_idx.view(1, -1),
                            self.relations.view(1, -1))).transpose(0, 1).numpy(),
                       columns=['from', 'to', 'rel'])

        df['from'] = df['from'].apply(lambda x: ix2ent[x])
        df['to'] = df['to'].apply(lambda x: ix2ent[x])
        df['rel'] = df['rel'].apply(lambda x: ix2rel[x])

        return df


class SmallKG(Dataset):
    def __init__(self, heads, tails, relations):
        assert heads.shape == tails.shape == relations.shape
        self.head_idx = heads
        self.tail_idx = tails
        self.relations = relations
        self.length = heads.shape[0]

    def __len__(self):
        return self.length

    def __getitem__(self, item):
        return self.head_idx[item].item(), self.tail_idx[item].item(), self.relations[item].item()



def get_data_home(data_home=None):
    if data_home is None:
        data_home = environ.get('TORCHKGE_DATA',
                                join('~', 'torchkge_data'))
    data_home = expanduser(data_home)
    if not exists(data_home):
        makedirs(data_home)
    return data_home


def clear_data_home(data_home=None):
    data_home = get_data_home(data_home)
    shutil.rmtree(data_home)


def get_n_batches(n, b_size):
    n_batch = n // b_size
    if n % b_size > 0:
        n_batch += 1
    return n_batch


class TempDataLoader:
    """This class is inspired from :class:`torch.utils.dataloader.DataLoader`.
    It is however way simpler.

    """
    def __init__(self, kg, batch_size, use_cuda=None):

        self.h = kg.head_idx
        self.t = kg.tail_idx
        self.r = kg.relations
        self.start_time = kg.start_time
        self.end_time = kg.end_time

        self.use_cuda = use_cuda
        self.batch_size = batch_size

        self.h = self.h.to(device)
        self.t = self.t.to(device)
        self.r = self.r.to(device)
        self.start_time = self.start_time.to(device)
        self.end_time = self.end_time.to(device)

    def __len__(self):
        return get_n_batches(len(self.h), self.batch_size)

    def __iter__(self):
        return _TempDataLoaderIter(self)


class _TempDataLoaderIter:
    def __init__(self, loader):
        self.h = loader.h
        self.t = loader.t
        self.r = loader.r
        self.start_time = loader.start_time
        self.end_time = loader.end_time

        self.use_cuda = loader.use_cuda
        self.batch_size = loader.batch_size

        self.n_batches = get_n_batches(len(self.h), self.batch_size)
        self.current_batch = 0

    def __next__(self):
        if self.current_batch == self.n_batches:
            raise StopIteration
        else:
            i = self.current_batch
            self.current_batch += 1

            tmp_h = self.h[i * self.batch_size: (i + 1) * self.batch_size]
            tmp_t = self.t[i * self.batch_size: (i + 1) * self.batch_size]
            tmp_r = self.r[i * self.batch_size: (i + 1) * self.batch_size]
            tmp_start_time = self.start_time[i * self.batch_size: (i + 1) * self.batch_size]
            tmp_end_time = self.end_time[i * self.batch_size: (i + 1) * self.batch_size]
            return tmp_h.to(device), tmp_t.to(device), tmp_r.to(device), tmp_start_time.to(device), tmp_end_time.to(device)

    def __iter__(self):
        return self

# %% [markdown]
# ## Datasets

# %%
def load_edukg(data_home=None, time_mode=None):
    data_path = data_home + '/edukg'
    ent_df = pd.read_csv(data_path + '/entity2id.txt', sep='\t',
                         header=None, names=['ent', 'id'])
    # print('ent_df.dtypes: ',ent_df.dtypes)
    rel_df = pd.read_csv(data_path + '/relation2id.txt', sep='\t',
                         header=None, names=['rel', 'id'])
    # print('rel_df.dtypes: ',rel_df.dtypes)
    ent_df = dict(zip(ent_df['ent'], ent_df['id']))
    rel_df = dict(zip(rel_df['rel'], rel_df['id']))

    df1 = read_csv(data_path + '/train.txt',
                   sep='\t', header=None, names=['from', 'rel', 'to', 'start_time', 'end_time'])
    df1['end_time'] = df1['start_time']
    # print(df1)
    # print(df1.isna().any())
    # print('df1.dtypes: ',df1.dtypes)
    df2 = read_csv(data_path + '/val.txt',
                   sep='\t', header=None, names=['from', 'rel', 'to', 'start_time', 'end_time'])
    df2['end_time'] = df2['start_time']
    # print('df2.dtypes: ',df2.dtypes)
    df3 = read_csv(data_path + '/test.txt',
                   sep='\t', header=None, names=['from', 'rel', 'to', 'start_time', 'end_time'])
    df3['end_time'] = df3['start_time']
    # print('df3.dtypes: ',df3.dtypes)
    df = concat([df1, df2, df3])
    kg = TemporalKnowledgeGraph(df, time_mode = time_mode, ent2ix=ent_df, rel2ix=rel_df)

    return kg.split_kg(sizes=(len(df1), len(df2), len(df3)))



def get_data(data_name, time_mode):
    if data_name == 'edukg':
        return load_edukg(data_home=DATA_PATH, time_mode=time_mode)
    else:
        datas = ['edukg']

        print('Choose One of the Following Datasets: ',datas)

# %% [markdown]
# ## Eval Utils

# %%
def get_true_targets(dictionary, key1, key2, key3, key4, true_idx, i):
    try:
        if key4 is not None:
            true_targets = dictionary[key1[i].item(), key2[i].item(), key3[i].item(), key4[i].item()].copy()
        else:
            true_targets = dictionary[key1[i].item(), key2[i].item(), key3[i].item()].copy()

        if true_idx is not None:
            true_targets.remove(true_idx[i].item())
            if len(true_targets) > 0:
                return tensor(list(true_targets)).long()
            else:
                return None
        else:
            return tensor(list(true_targets)).long()
    except KeyError:
        return None

# %%
# filter_scores(scores, self.kg.dict_of_tails, h_idx, r_idx, t_idx, start_time, end_time)
def filter_scores(scores, dictionary, key1, key2, key3, key4, true_idx):
    # filter out the true negative samples by assigning - inf score.
    b_size = scores.shape[0]
    filt_scores = scores.clone()

    for i in range(b_size):
        true_targets = get_true_targets(dictionary, key1, key2, key3, key4, true_idx, i)
        if true_targets is None:
            continue
        filt_scores[i][true_targets] = - float('Inf')

    return filt_scores

# %%
def get_rank(data, true, low_values=False):
    true_data = data.gather(1, true.long().view(-1, 1))

    if low_values:
        return (data <= true_data).sum(dim=1)
    else:
        return (data >= true_data).sum(dim=1)

# %% [markdown]
# ## Evaluation

# %%
class TemporalLinkPredictionEvaluator(object):

    def __init__(self, model, knowledge_graph):
        self.model = model
        self.kg = knowledge_graph

        self.rank_true_heads = empty(size=(knowledge_graph.n_facts,)).long()
        self.rank_true_tails = empty(size=(knowledge_graph.n_facts,)).long()
        self.filt_rank_true_heads = empty(size=(knowledge_graph.n_facts,)).long()
        self.filt_rank_true_tails = empty(size=(knowledge_graph.n_facts,)).long()

        self.evaluated = False

    def evaluate(self, b_size, verbose=True):
        use_cuda = next(self.model.parameters()).is_cuda

        if use_cuda:
            dataloader = TempDataLoader(self.kg, batch_size=b_size, use_cuda='batch')
            self.rank_true_heads = self.rank_true_heads.to(device)
            self.rank_true_tails = self.rank_true_tails.to(device)
            self.filt_rank_true_heads = self.filt_rank_true_heads.to(device)
            self.filt_rank_true_tails = self.filt_rank_true_tails.to(device)
        else:
            dataloader = TempDataLoader(self.kg, batch_size=b_size)

        for i, batch in tqdm(enumerate(dataloader), total=len(dataloader),
                             unit='batch', disable=(not verbose),
                             desc='Link prediction evaluation'):
            h_idx, t_idx, r_idx, start_time, end_time = batch[0], batch[1], batch[2], batch[3], batch[4]

            h_emb, t_emb, r_emb, candidates = self.model.inference_prepare_candidates(h_idx, t_idx, r_idx, start_time, end_time, entities=True)

            scores = self.model.inference_scoring_function(h_emb, candidates, r_emb, start_time, end_time)
            filt_scores = filter_scores(scores, self.kg.temp_dict_of_tails, h_idx, r_idx, start_time, end_time, t_idx)
            self.rank_true_tails[i * b_size: (i + 1) * b_size] = get_rank(scores, t_idx).detach()
            self.filt_rank_true_tails[i * b_size: (i + 1) * b_size] = get_rank(filt_scores, t_idx).detach()

            scores = self.model.inference_scoring_function(candidates, t_emb, r_emb, start_time, end_time)
            filt_scores = filter_scores(scores, self.kg.temp_dict_of_heads, t_idx, r_idx, start_time, end_time, h_idx)
            self.rank_true_heads[i * b_size: (i + 1) * b_size] = get_rank(scores, h_idx).detach()
            self.filt_rank_true_heads[i * b_size: (i + 1) * b_size] = get_rank(filt_scores, h_idx).detach()

        self.evaluated = True

        if use_cuda:
            self.rank_true_heads = self.rank_true_heads.cpu()
            self.rank_true_tails = self.rank_true_tails.cpu()
            self.filt_rank_true_heads = self.filt_rank_true_heads.cpu()
            self.filt_rank_true_tails = self.filt_rank_true_tails.cpu()

    def mean_rank(self):
        if not self.evaluated:
            raise NotYetEvaluatedError('Evaluator not evaluated call '
                                       'LinkPredictionEvaluator.evaluate')
        sum_ = (self.rank_true_heads.float().mean() +
                self.rank_true_tails.float().mean()).item()
        filt_sum = (self.filt_rank_true_heads.float().mean() +
                    self.filt_rank_true_tails.float().mean()).item()
        # return sum_ / 2, filt_sum / 2
        return {'mr':sum_ / 2, 'filt_mr':filt_sum / 2}

    def hit_at_k_heads(self, k=10):
        if not self.evaluated:
            raise NotYetEvaluatedError('Evaluator not evaluated call '
                                       'LinkPredictionEvaluator.evaluate')
        head_hit = (self.rank_true_heads <= k).float().mean()
        filt_head_hit = (self.filt_rank_true_heads <= k).float().mean()

        # return head_hit.item(), filt_head_hit.item()
        return {'head_hit_'+str(k):head_hit.item(), 'filt_head_hit_'+str(k): filt_head_hit.item()}

    def hit_at_k_tails(self, k=10):
        if not self.evaluated:
            raise NotYetEvaluatedError('Evaluator not evaluated call '
                                       'LinkPredictionEvaluator.evaluate')
        tail_hit = (self.rank_true_tails <= k).float().mean()
        filt_tail_hit = (self.filt_rank_true_tails <= k).float().mean()

        # return tail_hit.item(), filt_tail_hit.item()
        return {'tail_hit_'+str(k):tail_hit.item(), 'filt_tail_hit_'+str(k):filt_tail_hit.item()}

    def hit_at_k(self, k=10):
        if not self.evaluated:
            raise NotYetEvaluatedError('Evaluator not evaluated call '
                                       'LinkPredictionEvaluator.evaluate')

        head_hit = self.hit_at_k_heads(k=k)
        head_hit, filt_head_hit = head_hit['head_hit_'+str(k)], head_hit['filt_head_hit_'+str(k)]

        tail_hit = self.hit_at_k_tails(k=k)
        tail_hit, filt_tail_hit = tail_hit['tail_hit_'+str(k)], tail_hit['filt_tail_hit_'+str(k)]

        # return (head_hit + tail_hit) / 2, (filt_head_hit + filt_tail_hit) / 2
        return {'hit_'+str(k): (head_hit + tail_hit) / 2, 'filt_hit_'+str(k): (filt_head_hit + filt_tail_hit) / 2}

    def mrr(self):
        if not self.evaluated:
            raise NotYetEvaluatedError('Evaluator not evaluated call '
                                       'LinkPredictionEvaluator.evaluate')
        res = {}
        head_mrr = (self.rank_true_heads.float()**(-1)).mean()
        res['head_mrr'] = head_mrr.item()
        tail_mrr = (self.rank_true_tails.float()**(-1)).mean()
        res['tail_mrr'] = tail_mrr.item()
        filt_head_mrr = (self.filt_rank_true_heads.float()**(-1)).mean()
        res['filt_head_mrr'] = filt_head_mrr.item()
        filt_tail_mrr = (self.filt_rank_true_tails.float()**(-1)).mean()
        res['filt_tail_mrr'] = filt_tail_mrr.item()
        res['mrr'] = (head_mrr + tail_mrr).item() / 2
        res['filt_mrr'] = (filt_head_mrr + filt_tail_mrr).item() / 2
        return res

    def get_results(self, k=None):
        res = {}
        if k is None:
            k = 10

        for i in range(1, k + 1):
            hits_res = self.hit_at_k(k=i)
            res.update(hits_res)

        mr_res = self.mean_rank()
        res.update(mr_res)
        mrr_res = self.mrr()
        res.update(mrr_res)
        return res

    def print_results(self, k=None, n_digits=3):
        if k is None:
            k = 10

        if k is not None and type(k) == int:
            print('Hit@{} : {} \t\t Filt. Hit@{} : {}'.format(
                k, round(self.hit_at_k(k=k)[0], n_digits),
                k, round(self.hit_at_k(k=k)[1], n_digits)))
        if k is not None and type(k) == list:
            for i in k:
                print('Hit@{} : {} \t\t Filt. Hit@{} : {}'.format(
                    i, round(self.hit_at_k(k=i)[0], n_digits),
                    i, round(self.hit_at_k(k=i)[1], n_digits)))

        print('Mean Rank : {} \t Filt. Mean Rank : {}'.format(
            int(self.mean_rank()[0]), int(self.mean_rank()[1])))
        print('MRR : {} \t\t Filt. MRR : {}'.format(
            round(self.mrr()[0], n_digits), round(self.mrr()[1], n_digits)))

# %% [markdown]
# ## Interfaces

# %%
class TempModel(Module):
    def __init__(self, n_entities, n_relations):
        super().__init__()
        self.n_ent = n_entities
        self.n_rel = n_relations

    def forward(self, heads, tails, relations, start_time, end_time, negative_heads, negative_tails, negative_relations=None):
        pos = self.scoring_function(heads, tails, relations, start_time, end_time)

        if negative_relations is None:
            negative_relations = relations

        if negative_heads.shape[0] > negative_relations.shape[0]:
            # in that case, several negative samples are sampled from each fact
            n_neg = int(negative_heads.shape[0] / negative_relations.shape[0])
            # print('pos.shape: ', pos.shape)
            pos = pos.repeat(n_neg)
#             neg = self.scoring_function(negative_heads,
#                                         negative_tails,
#                                         negative_relations.repeat(n_neg),
#                                         start_time.repeat(n_neg, 1) if start_time.dim() ==2 & start_time.shape[-1]>1 else start_time.repeat(n_neg),
#                                         end_time.repeat(n_neg, 1) if end_time.dim() ==2 & end_time.shape[-1]>1 else end_time.repeat(n_neg))
            neg = self.scoring_function(negative_heads,
                            negative_tails,
                            negative_relations.repeat(n_neg),
                            start_time.repeat(n_neg),
                            end_time.repeat(n_neg))

        else:
            neg = self.scoring_function(negative_heads,
                                        negative_tails,
                                        negative_relations, start_time, end_time)

        return pos, neg

    def scoring_function(self, h_idx, t_idx, r_idx, start_time_idx, end_time_idx):
        raise NotImplementedError

    def normalize_parameters(self):
        raise NotImplementedError

    def get_embeddings(self):
        raise NotImplementedError

    def inference_scoring_function(self, h, t, r, time):
        raise NotImplementedError

    def inference_prepare_candidates(self, h_idx, t_idx, r_idx, entities=True):
        raise NotImplementedError


class TempTranslationModel(TempModel):
    def __init__(self, n_entities, n_relations, dissimilarity_type):
        super().__init__(n_entities, n_relations)

        assert dissimilarity_type in ['L1', 'L2', 'torus_L1', 'torus_L2',
                                      'torus_eL2']

        if dissimilarity_type == 'L1':
            self.dissimilarity = l1_dissimilarity
        elif dissimilarity_type == 'L2':
            self.dissimilarity = l2_dissimilarity
        elif dissimilarity_type == 'torus_L1':
            self.dissimilarity = l1_torus_dissimilarity
        elif dissimilarity_type == 'torus_L2':
            self.dissimilarity = l2_torus_dissimilarity
        else:
            self.dissimilarity = el2_torus_dissimilarity

    def scoring_function(self, h_idx, t_idx, r_idx, start_time_idx, end_time_idx):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def normalize_parameters(self):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def get_embeddings(self):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def inference_prepare_candidates(self, h_idx, t_idx, r_idx, entities=True):
        raise NotImplementedError

    def inference_scoring_function(self, proj_h, proj_t, r, start_time, end_time):
        b_size = proj_h.shape[0]

        if len(r.shape) == 2:
            if len(proj_t.shape) == 3:
                assert (len(proj_h.shape) == 2)
                # this is the tail completion case in link prediction
                hr = (proj_h + r).view(b_size, 1, r.shape[1])
                return - self.dissimilarity(hr, proj_t)
            else:
                assert (len(proj_h.shape) == 3) & (len(proj_t.shape) == 2)
                # this is the head completion case in link prediction
                r_ = r.view(b_size, 1, r.shape[1])
                t_ = proj_t.view(b_size, 1, r.shape[1])
                return - self.dissimilarity(proj_h + r_, t_)
        elif len(r.shape) == 3:
            # this is the relation prediction case
            # Two cases possible:
            # * proj_ent.shape == (b_size, self.n_rel, self.emb_dim) -> projection depending on relations
            # * proj_ent.shape == (b_size, self.emb_dim) -> no projection
            proj_h = proj_h.view(b_size, -1, self.emb_dim)
            proj_t = proj_t.view(b_size, -1, self.emb_dim)
            return - self.dissimilarity(proj_h + r, proj_t)


class TempBilinearModel(TempModel):

    def __init__(self, emb_dim, n_entities, n_relations):
        super().__init__(n_entities, n_relations)
        self.emb_dim = emb_dim

    def scoring_function(self, h_idx, t_idx, r_idx, start_time_idx, end_time_idx):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def normalize_parameters(self):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def get_embeddings(self):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def inference_scoring_function(self, h, t, r, start_time, end_time):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

    def inference_prepare_candidates(self, h_idx, t_idx, r_idx, start_time, end_time, entities=True):
        """See torchkge.models.interfaces.Models.
        """
        raise NotImplementedError

# %% [markdown]
# ## Models

# %%
from torch import nn
import math
import torch as th
import torch


class LSTMModel(nn.Module):
    def __init__(self, in_dim, n_layer):
        super(LSTMModel, self).__init__()
        self.n_layer = n_layer
        self.hidden_dim = in_dim
        # self.lstm = nn.LSTM(in_dim, self.hidden_dim, n_layer, batch_first=True)
        self.lstm = LSTMLinear(in_dim, self.hidden_dim)

    def forward(self, x):
        out, h = self.lstm(x)
        return h[0]


class LSTMCell(nn.Module):

    def __init__(self, input_size, hidden_size, bias=True):
        super(LSTMCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.bias = bias
        self.i2h = nn.Linear(input_size, 4 * hidden_size, bias=bias)
        self.h2h = nn.Linear(hidden_size, 4 * hidden_size, bias=bias)
        self.linear_acti = nn.Linear(hidden_size, hidden_size)
        self.reset_parameters()

    def reset_parameters(self):
        std = 1.0 / math.sqrt(self.hidden_size)
        for w in self.parameters():
            w.data.uniform_(-std, std)

    def forward(self, x, hidden):
        x = x.contiguous()
        if hidden is None:
            hidden = self._init_hidden(x, self.hidden_size)

        h, c = hidden
        h = h.view(h.size(1), -1)
        c = c.view(c.size(1), -1)

        preact = self.i2h(x) + self.h2h(h)

        # activations
        gates = preact[:, :3 * self.hidden_size].sigmoid()
        # g_t = preact[:, 3 * self.hidden_size:].tanh()
        g_t = preact[:, 3 * self.hidden_size:]
        i_t = gates[:, :self.hidden_size]
        f_t = gates[:, self.hidden_size:2 * self.hidden_size]
        o_t = gates[:, -self.hidden_size:]

        c_t = th.mul(c, f_t) + th.mul(i_t, g_t)
        h_t = th.mul(o_t, c_t)

        h_t = h_t.view(1, h_t.size(0), -1)
        c_t = c_t.view(1, c_t.size(0), -1)
        return h_t, c_t

    @staticmethod
    def _init_hidden(input_, hidden_size):
        h = th.zeros_like(input_.view(1, input_.size(0), -1))
        c = th.zeros_like(input_.view(1, input_.size(0), -1))
        return h, c


class LSTMLinear(nn.Module):

    def __init__(self, input_size, hidden_size, bias=True):
        super(LSTMLinear, self).__init__()
        self.lstm_cell = LSTMCell(input_size, hidden_size, bias)
        self.batch_first = True

    def forward(self, input_, hidden=None):

        if self.batch_first:
            input_ = input_.transpose(0, 1)

        outputs = []
        steps = range(input_.size(0))
        for i in steps:
            hidden = self.lstm_cell(input_[i], hidden)
            if isinstance(hidden, tuple):
                outputs.append(hidden[0])
            else:
                outputs.append(hidden)

        outputs = torch.stack(outputs, dim=0)
        if self.batch_first:
            outputs = outputs.transpose(0, 1)

        return outputs, hidden

# %%
class TDistMultModel(TempBilinearModel):

    def __init__(self, args):
        super().__init__(args.emb_dim, args.n_entities, args.n_relations)
        self.emb_dim = args.emb_dim


        self.ent_emb = init_embedding(self.n_ent, self.emb_dim)
        self.rel_emb = init_embedding(self.n_rel, self.emb_dim)

        self.tem_total = args.tem_total
        self.tem_emb = init_embedding(self.tem_total, self.emb_dim)
        self.lstm = LSTMModel(self.emb_dim, n_layer=1)
        self.time_trans = None
        self.normalize_parameters()

    def scoring_function(self, h_idx, t_idx, r_idx, start_time_idx, end_time_idx):
        if start_time_idx.shape[-1]<2:
            start_time_idx = self.time_trans[start_time_idx]
        h = normalize(self.ent_emb(h_idx), p=2, dim=1)
        t = normalize(self.ent_emb(t_idx), p=2, dim=1)
        r = self.get_rseq(r_idx, start_time_idx)

        return (h * r * t).sum(dim=1)

    def get_rseq(self, r, tem):
        r_e = self.rel_emb(r)
        r_e = r_e.unsqueeze(0).transpose(0, 1)

        bs = tem.shape[0]  # batch size
        tem_len = tem.shape[1]
        tem = tem.contiguous()
        tem = tem.view(bs * tem_len)
        token_e = self.tem_emb(tem)
        token_e = token_e.view(bs, tem_len, self.emb_dim)
        seq_e = torch.cat((r_e, token_e), 1)

        hidden_tem = self.lstm(seq_e)
        hidden_tem = hidden_tem[0, :, :]
        rseq_e = hidden_tem

        return rseq_e

    def normalize_parameters(self):
        self.ent_emb.weight.data = normalize(self.ent_emb.weight.data, p=2,
                                             dim=1)


    def get_embeddings(self):
        self.normalize_parameters()
        return self.ent_emb.weight.data, self.rel_emb.weight.data

    def inference_scoring_function(self, h, t, r, start_time, end_time):
        b_size = h.shape[0]

        if len(t.shape) == 3:
            assert (len(h.shape) == 2) & (len(r.shape) == 2)
            # this is the tail completion case in link prediction
            hr = (h * r).view(b_size, 1, self.emb_dim)
            return (hr * t).sum(dim=2)
        elif len(h.shape) == 3:
            assert (len(t.shape) == 2) & (len(r.shape) == 2)
            # this is the head completion case in link prediction
            rt = (r * t).view(b_size, 1, self.emb_dim)
            return (h * rt).sum(dim=2)
        elif len(r.shape) == 3:
            assert (len(h.shape) == 2) & (len(t.shape) == 2)
            # this is the relation prediction case
            hr = (h.view(b_size, 1, self.emb_dim) * r)  # hr has shape (b_size, self.n_rel, self.emb_dim)
            return (hr * t.view(b_size, 1, self.emb_dim)).sum(dim=2)


    def inference_prepare_candidates(self, h_idx, t_idx, r_idx, start_time_idx, end_time_idx, entities=True):
        b_size = h_idx.shape[0]
        start_time_idx = self.time_trans[start_time_idx]
        h = self.ent_emb(h_idx)
        t = self.ent_emb(t_idx)
        r = self.get_rseq(r_idx, start_time_idx)

        if entities:
            candidates = self.ent_emb.weight.data.view(1, self.n_ent, self.emb_dim)
            candidates = candidates.expand(b_size, self.n_ent, self.emb_dim)
        else:
            candidates = self.rel_emb.weight.data.view(1, self.n_rel, self.emb_dim)
            candidates = candidates.expand(b_size, self.n_rel, self.emb_dim)

        return h, t, r, candidates

# %%
def get_model(model_name, args):
    if model_name == 'TDistMultModel':
        return TDistMultModel(args)

# %% [markdown]
# ## Inference Process

# %%
def get_trained_model(args, kg_train):
    model = get_model(model_name = args.model_name, args = args)
    model.load_state_dict(torch.load(join(args.model_path, args.model_save_name), map_location=device))
    model.time_trans = kg_train.time_trans.to(device)
    return model

# %%
def optimal_params():
    args = Params()
    args.n_epochs = 1000
    args.data_home = '/home/vortex/Desktop/Projects/TempTorchKGE_V2/datasets'
    args.model_name = 'TDistMultModel' # 'TTransEModel','TDistMultModel'
    args.model_save_name = args.model_name + '.bt'
    args.loss_name = 'MarginLoss'
    args.model_path = MODEL_PATH
    args.time_mode = 'seq'
    args.dissimilarity_type = 'L2'
    args.dataset = "edukg"
    args.b_size = 4000
    args.lr = 0.001
    args.emb_dim = 50
    args.margin = 1
    args.n_neg = 10
    return args
    # DATA_PATH MODEL_PATH

# %%
args = optimal_params()
kg_train, kg_val, kg_test = get_data(args.dataset, args.time_mode)
args.n_entities = kg_train.n_ent
args.n_relations = kg_train.n_rel
args.tem_total = kg_train.n_time

# %%
inf_model = get_trained_model(args, kg_train)
inf_model = inf_model.to(device)

# %%
def type_map(ent_name_):
    all_types = ['recruiters', 'sector', 'soft_skills', 'hard_skills', 'locations', 'function', 'coursera', 'job_titles']
    for i in all_types:
        if ent_name_.startswith(i):
            return i

def get_ent_data():
    data_path = DATA_PATH + '/edukg'
    ent_df = pd.read_csv(data_path + '/entity2id.txt', sep='\t',
                     header=None, names=['kg_id', 'model_id'])
    rel_df = pd.read_csv(data_path + '/relation2id.txt', sep='\t',
                     header=None, names=['kg_id', 'model_id'])
    train_triples = read_csv(data_path + '/train.txt',
                   sep='\t', header=None, names=['from', 'rel', 'to', 'start_time', 'end_time'])
    train_triples['head_type'] = train_triples['from'].map(type_map)
    train_triples['tail_type'] = train_triples['to'].map(type_map)
    schema_df = train_triples.groupby(['head_type', 'rel', 'tail_type']).first().reset_index()[['head_type','rel','tail_type']]
    ent_names = pd.read_csv(data_path + '/all_ent_names.csv')
    ent_names_map = dict(zip(ent_names['ent_id'], ent_names['ent_name']))
    ent_df['name'] = ent_df['kg_id'].map(ent_names_map)
    ent_df['type'] = ent_df['kg_id'].map(type_map)
    return ent_df, rel_df, schema_df

# %%
def generate_time_stamps(start_time, end_time):
#     start_time 1/1/2005 end_time 1/08/2023
    return list(pd.date_range(start=start_time, end=end_time, freq='3M').astype(str))

def temporal_triples_generation(heads, rel, tails, start_time, end_time):
    time_stamps = generate_time_stamps(start_time, end_time)
    triples = itertools.product(*[
        heads, [rel], tails, time_stamps
    ])
    return list(triples)

def get_time_seq(x):
    return torch.tensor(transform_time(x))

def infer_data(model, triple_meta, ent_df, rel_df, start_time, end_time):
    triple_meta['head_type']
    triple_meta['tail_type']
    triple_meta['rel']
    head_ents = list(ent_df[ent_df['type']== triple_meta['head_type']]['model_id'].unique())
    print('len(head_ents): ',len(head_ents))
    tail_ents = list(ent_df[ent_df['type'] == triple_meta['tail_type'] ]['model_id'].unique())
    print('len(tail_ents): ',len(tail_ents))
#     return
    rel = list(rel_df[rel_df['kg_id'] == triple_meta['rel']]['model_id'])[0]

    triples = temporal_triples_generation(head_ents, rel, tail_ents, start_time, end_time)
    triples = pd.DataFrame(triples, columns =['head', 'rel', 'tail', 'date'])
    triples = triples.sample(2000)
    for triples_chunk in np.array_split(triples, 500):
        h_idx = torch.tensor(list(triples_chunk['head']))
        r_idx = torch.tensor(list(triples_chunk['rel']))
        t_idx = torch.tensor(list(triples_chunk['tail']))
        start_time_idx = torch.cat(list(triples_chunk['tail'].map(get_time_seq)))
        model(h_idx, t_idx, r_idx, start_time_idx, None)
        return triples_chunk
    return triples

def infer_job_skills(model, job_title, rel, ent_df, rel_df, start_time, end_time):
    with torch.no_grad():
#
        ent_name_map = dict(zip(ent_df['model_id'], ent_df['name']))
        rel_name_map = dict(zip(rel_df['model_id'], rel_df['kg_id']))
        job_title_model_id = list(ent_df[ent_df['name']==job_title]['model_id'])
        tail_ents = list(ent_df[ent_df['type'] == 'hard_skills']['model_id'].unique())
        print('len(tail_ents): ',len(tail_ents))
        rel = list(rel_df[rel_df['kg_id'] == rel]['model_id'])[0]

        triples = temporal_triples_generation(job_title_model_id, rel, tail_ents, start_time, end_time)
        triples = pd.DataFrame(triples, columns =['head', 'rel', 'tail', 'date'])
        ##############

        h_idx = torch.tensor(list(triples['head'])).to(device)
        r_idx = torch.tensor(list(triples['rel'])).to(device)
        t_idx = torch.tensor(list(triples['tail'])).to(device)
        start_time_idx = torch.vstack(list(triples['date'].map(get_time_seq))).to(device)
        scores = model.scoring_function(h_idx, t_idx, r_idx, start_time_idx, None)
        triples['score'] = list(scores.cpu().numpy())
        triples['head'] = triples['head'].map(ent_name_map)
        triples['rel'] = triples['rel'].map(rel_name_map)
        triples['tail'] = triples['tail'].map(ent_name_map)
        return triples
        print(scores)

# %%
"Responsable Recherche & Développement", "Ingénieurs Consultants en Informatique de Gestion"

# %%
ent_df, rel_df, schema_df = get_ent_data()

# %%
ent_df
# Out:
#                                  kg_id  model_id  \
# 0                      job_titles_2235         0
# 1                      job_titles_7358         1
# 2                      job_titles_9593         2
# 3      coursera_H_SYjXVXEeuBTg7vUdMe9w         3
# 4      coursera_Qv4OEHIuEeuBTg7vUdMe9w         4
# ...                                ...       ...
# 13341                  job_titles_5022     13341
# 13342                hard_skills_32131     13342
# 13343  coursera_69sweSMjEeuCghIYeOsGoQ     13343
# 13344                  job_titles_5421     13344
# 13345                 hard_skills_8543     13345
#
#                                                     name         type
# 0                Business Controller   Réf. 17.R.014.A.R   job_titles
# 1                               Chef de Projet TMA AS400   job_titles
# 2                                 Stagiaires Recrutement   job_titles
# 3      Identify One Source of Truth with a Project Wa...     coursera
# 4      Visual Basic Programming: Inheritance and Poly...     coursera
# ...                                                  ...          ...
# 13341                                  Production Leader   job_titles
# 13342                            outils de développement  hard_skills
# 13343                            Digitale Transformation     coursera
# 13344                                          Analystes   job_titles
# 13345                mener des négociations commerciales  hard_skills
#
# [13346 rows x 4 columns]

# %%
names = ent_df[ent_df['type']== "soft_skills"]
soft_skills = names['name'].to_list()

names = ent_df[ent_df['type']== "hard_skills"]
hard_skills = names['name'].to_list()

names = ent_df[ent_df['type']== "coursera"]
courses = names['name'].to_list()

# %%
rel_df
# Out:
#               kg_id  model_id
# 0           _favors         0
# 1              _has         1
# 2   _co_occurs_with         2
# 3               _by         3
# 4         _requires         4
# 5            _needs         5
# 6         _provides         6
# 7       _belongs_to         7
# 8      _acquired_by         8
# 9          _locates         9
# 10      _needed_for        10
# 11      _is_located        11

# %%
courses
# Out:
# ['Identify One Source of Truth with a Project Wall in Miro',
#  'Visual Basic Programming: Inheritance and Polymorphism',
#  'Fundamentals of Sales and Marketing, with Goldman Sachs 10,000 Women',
#  'Crea un calendario de contenidos para Twitter',
#  'Getting started with Augmented Reality',
#  'Financing Infrastructure in African Cities',
#  'Uncommon Sense Teaching',
#  'Sustainable Food Teach-Out',
#  'Prepare for DP-203: Data Engineering on Microsoft Azure Exam',
#  'Cybersecurity and Its Ten Domains',
#  'User-Defined Functions in JavaScript',
#  'Create Social Media Dashboards in Tableau',
#  'Program Communications Management in ClickUp',
#  'Operational Risk Management: Frameworks & Strategies',
#  'Cultural impact of housing displacement gentrification',
#  'Create a User Journey Map in Miro',
#  'Foundations of Diversity and Inclusion at Work TeachOut',
#  'Create an App for Managing Company Expenses in Power Apps',
#  'Account Management & Sales Force Design',
#  'Introduction to Accounting Data Analytics and Visualization',
#  'International Leadership and Organizational Behavior',
#  'Digital Product Management: Modern Fundamentals',
#  'Build an App in Android Studio using Activities',
#  'Data Storage in Microsoft Azure',
#  'Basic Game Development with Levels using Scratch',
#  'Advertising with Meta',
#  'Cost Accounting: Profit and Loss Calculation',
#  'Machine Learning: Regression',
#  'Innovation for Entrepreneurs: From Idea to Marketplace',
#  'Installation et gestion des paquets logiciels sous Linux',
#  'K-Means Clustering 101: World Happiness Report',
#  "Economie du sol et de l'immobilier II",
#  'Introducing Cellular Automata',
#  'Introduction to Software, Programming, and Databases ',
#  'Construye ideas para tu contenido en Twitter',
#  'Create motion graphics for a website using Adobe Illustrator',
#  'Object-Oriented Design',
#  'إختيار الهدف المثالي للحملات الإعلانية على Facebook',
#  'Sustainable Vikings:  Sustainability & Corporate Social Responsibility in Scandinavia  ',
#  'Design and Make Infographics (Project-Centered Course)',
#  'Coexistence in Medieval Spain: Jews, Christians, and Muslims',
#  'Water Resources Management and Policy',
#  'Building a Dynamic Web App using PHP & MySQL',
#  'Learn to Teach Java:  Writing Classes and Arrays',
#  'Understanding China, 1700-2000: A Data Analytic Approach, Part 2',
#  'CAM and Design Manufacturing for Mechanical Engineers with Autodesk Fusion 360',
#  'Demand management: Breaking down today’s commercial silos',
#  'Inclusive Leadership: The Power of Workplace Diversity',
#  'ML Pipelines on Google Cloud - Português',
#  'Saving Money for the Future',
#  'Foundations of Teaching for Learning: Being a Teacher',
#  'Pricing Strategy in Practice',
#  " Création D'Identité Visuelle En Utilisant Canva",
#  'Bacterial Bioinformatics',
#  'Essential Cloud Infrastructure: Foundation dalam bahasa Indonesia',
#  'Develop a Company Website with Wix',
#  'Economic Growth and Distributive Justice Part II - Maximize Social Wellbeing',
#  'Crea tu primer juego de adivinanza con Python',
#  'Bases de la planification et de la gestion de projet',
#  'Twitter, LinkedIn, and YouTube Marketing',
#  'Linux: Introduction to Shell Scripting for DevOps',
#  'Modernizing Data Lakes and Data Warehouses with Google Cloud',
#  'Marketing Verde',
#  'Sound and Sonification Design for Interactive Learning Tools',
#  'Affectation de variable en Python',
#  'Server side JavaScript with Node.js',
#  'AI Workflow: Enterprise Model Deployment',
#  'Successful Career Development',
#  'Predict Ad Clicks Using Logistic Regression and XG-Boost',
#  'Fundamentals of Red Hat Enterprise Linux',
#  'Create Docker Container with Flask Seaborn Regression Plot App',
#  'Leading Healthcare Quality and Safety',
#  'English for Common Interactions in the Workplace: Basic Level',
#  'Créer des visuels Twitter  pour entreprises avec PicMonkey',
#  'Marketing e o Consumidor no Ambiente Digital',
#  'Containerize a full-stack NodeJS application in Docker',
#  'Build Messenger Clone Using PHP and MySQL',
#  'Data-Driven Testing (via spreadsheet) with Selenium & TestNG',
#  'Logo Design for a Fashion Website using Adobe Illustrator',
#  'React: Operaciones Básicas CRUD',
#  'Simple Parallel Coordinates Plot using d3 js',
#  'Estrategias y estilos de negociación\xa0\xa0\xa0\xa0\xa0\xa0',
#  'Front-End Web UI Frameworks and Tools: Bootstrap 4',
#  'Datastream MySQL to BigQuery',
#  'Advertise your Fundraiser using Canva',
#  'Design Thinking for Innovation',
#  'Linux: I/O Redirection for DevOps',
#  'System Validation: Automata and behavioural equivalences',
#  'What is Data Science? ',
#  'Strategy and Sustainability',
#  'Intro to International Marketing',
#  'Positioning: What you need for a successful Marketing Strategy',
#  'Digital Business Marketing with Easil',
#  'Draw a wireframe in Wireframe.cc',
#  'Prepared Statements and Stored Procedures',
#  '¿Qué son los medios sociales?',
#  'Build a Simple App in Android Studio with Java',
#  'Methods and Statistics in Social Science - Final Research Project',
#  'Experimental Design Basics',
#  'Data Processing Using Python',
#  'Administrasi Sistem dan Layanan Infrastruktur TI',
#  'Operations Analytics',
#  'Research Data Management and Sharing',
#  'Time to Reorganize! Understand Organizations, Act, and Build a Meaningful World.',
#  'Mindware: Critical Thinking for the Information Age ',
#  'Foundations of Teaching for Learning: Developing Relationships',
#  'Digitalisation in Aeronautics',
#  'Construire des wireframes (maquettes fonctionnelles) et des prototypes basse fidélité',
#  'Career Options: Exploring a New Career',
#  'Accounting: Principles of Financial Accounting',
#  'Sistemas operativos y tú: Convertirse en un usuario avanzado',
#  'Comment naviguer dans le gestionnaire de publicités de Twitter et afficher les résultats',
#  'Analytical Solutions to Common Healthcare Problems',
#  'Introduction to Engineering Mechanics',
#  'Créer une instance Amazon EC2 dans la console AWS',
#  'Automate an e-commerce web application using Selenium & Java',
#  'Resilient Teaching Through Times of Crisis and Change',
#  'Finance of Mergers and Acquisitions: Valuation and Pricing',
#  'Fase final de Marketing en redes sociales de Meta',
#  'Capstone - Launch Your Own Business!',
#  'Journalism, the future, and you!',
#  'Predict Sales Revenue with scikit-learn',
#  'Linux: Use Vim to Edit an HTML Document',
#  'Create a Project Charter with Microsoft Word',
#  'Get Started with Click Up',
#  'Build a Relative Layout App in Android Studio',
#  'Security Operations',
#  'Pesquisa de Mercado com Métodos Qualitativos',
#  'Custom Prediction Routine on Google AI Platform',
#  'Digital Transformation',
#  'Introduction to Relational Database and SQL',
#  'Building Your Artistic Brand',
#  'Feature Engineering em Português Brasileiro',
#  'Approximation Algorithms Part I',
#  'Designing the Future of Work',
#  'Expand Employee Interaction with Canvas',
#  "Innovation publique et pensée design, l'innovation sociale au service des territoires",
#  'Essential Cloud Infrastructure: Foundation em Português Brasileiro',
#  'Connectez vos outils avec Slack',
#  'Six Sigma Tools for Define and Measure',
#  'MySQL تكنولوجيا المعلومات مع ',
#  'Build a Product Management Plan Framework in Trello',
#  'Analyze Box Office Data with Plotly and Python',
#  'Créer des infographies attrayantes avec Creately',
#  'ETL and Data Pipelines with Shell, Airflow and Kafka',
#  'Scripting Bash - Découverte du Langage de Programmation',
#  '行銷典範轉移: 變動中的消費世界 (Marketing in a changing world)',
#  'Design and Conduct of Clinical Trials',
#  'Hybrid Cloud Infrastructure Foundations with Anthos en Français',
#  'Cybersecurity in Healthcare (Hospitals & Care Centres)',
#  'Introduction to Node-red',
#  'Data, Security, and Privacy',
#  'Edit your photos for Social Media with Easil',
#  'Spring Data Repositories',
#  'Creativity And Entrepreneurship ',
#  'Blockchain, Cryptoassets, and Decentralized Finance',
#  'Effective Compliance Programs',
#  'English Communication for Tech Professionals',
#  'Principles of UI/UX Design (Mobile)',
#  'Data Visualization with Tableau Project',
#  'Using Porter’s Five Forces Model for Competitive Analysis   ',
#  'Design a mobile app interface with Moqups',
#  'How to setup a followers campaign on Twitter',
#  'The Finite Element Method for Problems in Physics',
#  'Inclusive Online Teaching Teach-Out',
#  'Project Management: Beyond planning and control',
#  'Introduction to Finance: The Basics',
#  'Developing a Roadmap Timeline in PowerPoint',
#  'Strategic Sales Management Final Project',
#  'The exposome: cracking the science about what makes us sick',
#  'Webpage Design with Wireframes in Miro',
#  'Align Design Teams with SCAMPER Brainstorming in Miro',
#  'Product Management',
#  'Explore Management Concepts through Metaphor and Music',
#  'Conduct a 5 Whys Analysis in Miro',
#  'Tencent Cloud SysOps Associate',
#  'Build a Toolkit with Advanced Windows Commands',
#  'Introduction to Cloud Bigtable (Java)',
#  'Autodesk Certified Professional: Revit for Architectural Design Exam Prep',
#  'Tableau Public for Project Management and Beyond',
#  'Value Chain Analysis and Visualization in Miro',
#  'Privacy in the USA',
#  'Leading Teams: Building Effective Team Cultures',
#  'Unsupervised Machine Learning for Customer Market Segmentation',
#  'Welcome to Game Theory',
#  'Google Sheets',
#  'Reliable Cloud Infrastructure: Design and Process em Português Brasileiro',
#  'Health Care Delivery in Healthcare Organizations',
#  'Build Sports Management System using JavaFX',
#  'Facebook, Instagram, and Snapchat Marketing',
#  'Intermediate Object-Oriented Programming for Unity Games',
#  'Create environmental awareness content with Canva',
#  'Writing and Editing: Revising',
#  'Draw Insights with Crosstabs Reports in Google Sheets',
#  'Seismology to Earthquake Engineering',
#  'Digital Thread: Components',
#  'Planification et Design de Systèmes et Technologies d’Assainissement',
#  'Create an Animation for a Social Media Icon using Adobe Illustrator',
#  'Palliative Care Always Capstone Course',
#  'Building Resilient Streaming Analytics Systems on GCP en Français',
#  'Create a JavaFX GUI with radio buttons and check boxes',
#  'Feeding the World',
#  'Entrepreneurship 1: Developing the Opportunity',
#  'Fundamentals of Data Visualization',
#  'Créer une Fonction Personnalisée en JS et Google App Script',
#  'Marketing Analytics Capstone Project',
#  'Cloud Computing Primer: Software as a Service (SaaS)',
#  'International Entertainment and Sports Marketing',
#  'Research Methodologies',
#  'Advanced Financial Reporting: Accounting for Business Combinations and Preparation of Consolidated Financial Statements',
#  "Traitement d'images : introduction au filtrage",
#  'Diseña stories para Instagram y Facebook con Canva',
#  'Cooking for Busy Healthy People',
#  'Gestión Empresarial Exitosa para Pymes',
#  'Introduction to Marketing',
#  'Database Engineer Capstone',
#  'Autodesk Certified Professional: Revit for Structural Design Exam Prep',
#  'Financial Forecasting and Reporting',
#  'Math for MBA and GMAT Prep',
#  'Fundamentos do design da experiência do usuário (UX)',
#  'Contact Center AI: Operations and Implementation',
#  'Mathematical Thinking in Computer Science',
#  'Identifying, Attracting, and Growing Your Digital Audience',
#  'Stay Results-Focused with S.M.A.R.T. Goals in Miro',
#  'Criar designs e protótipos de alta fidelidade no Figma',
#  'Create Keyboard Movement Mechanics with C# in Unity',
#  'Comment créer un compte Instagram professionnel',
#  'How to Manage a Remote Team',
#  'Object-Oriented Hierarchies in Java',
#  'System Validation (2): Model process behaviour',
#  'Introduction to Cyber Attacks',
#  'Internet of Things Capstone: Build a Mobile Surveillance System',
#  'Communicating During Global Emergencies',
#  'How to create presentations using Canva',
#  'Getting Started with IPv6',
#  'Medical Applications of Particle Accelerators (NPAP MOOC)',
#  'Introduction to Databases',
#  'Healthcare Marketplace',
#  'Digitales Business Marketing mit Easil',
#  'Bases de la conception Expérience Utilisateur (UX)',
#  '3D Model Creation with Autodesk Fusion 360',
#  'Mécanique : Solide Indéformable',
#  'Imagery, Automation, and Applications',
#  'Introducing z/OS UNIX System Services',
#  'Basic Information Literacy',
#  'Define Product Vision with User Experience Maps in Miro',
#  'Create Customer Personas in Canva',
#  'Teach English Now! Lesson Design and Assessment',
#  'Communication skills for engineering scholars',
#  'Fundamentos de Vendas e Marketing com o 10,000 Women da Goldman Sachs',
#  'Sales Training: Building Your Sales Career',
#  'Estimación de la línea base de tiempos y costos',
#  'Create your first test automation script - Selenium and C#',
#  'Introduction to Corporate Finance',
#  'Building the Business Model for Corporate Entrepreneurs',
#  'Interpreting Machine Learning datasets',
#  'Information Design',
#  'Computers, Waves, Simulations: A Practical Introduction to Numerical Methods using Python',
#  'Алгоритмы, часть\xa0I',
#  'Build a Stopwatch using JavaScript',
#  'Lesson | Business English Skills: How to Write Effective Openings and Closings to Emails',
#  'Introduction to Machine Learning in Production',
#  'Container Orchestration using Kubernetes',
#  "Suivre les actions des visiteurs du site Web à l'aide de Facebook Pixel",
#  'Introduction to DevOps',
#  'Program Quality Planning with ClickUp',
#  'Business Model Canvas: A Tool for Entrepreneurs and Innovators (Project-Centered Course)',
#  'Capstone MOOC for "Android App Development"',
#  'Introduction to APIs in Google',
#  'Advanced Understanding of Stocks and Bonds',
#  'Economic Growth and Distributive Justice Part I - The Role of the State',
#  'International Business Venturing Abroad',
#  'Seeing Through Photographs',
#  'Internet of Things V2: DragonBoard™ bring up and community ecosystem',
#  'Computer Hardware and Software',
#  'Inbound Sales',
#  'Cloud Top Ten Risks',
#  'A Simple Scatter Plot using D3 js',
#  'Agile Organization',
#  'Splunk Knowledge Manager 103',
#  'Anti-Racism III',
#  'Introduction to HTML5',
#  'Introduction to Supply Chain Finance & Blockchain Technology',
#  'Optimizing a Website for Google Search',
#  'Small Business Marketing Using LinkedIn',
#  'Design an App with Mockitt',
#  'Choosing Which Method Is Best For Illustrating Data',
#  'Corporate & Commercial Law II: Business Forms, Financing & Governmental Regulation',
#  'Discrete Optimization',
#  'A Guide to Healthcare Innovation: Principles and Practice ',
#  'Surviving Disruptive Technologies (On Demand)',
#  'Analyse datasets with Java streams',
#  'Beauty, Form & Function: An Exploration of Symmetry',
#  'Computing for Cancer Informatics',
#  'The Emergence of the Modern Middle East - Part II',
#  'Marketing Channel Incentives',
#  'Introduction to Back-End Development',
#  'Management Foundations in the Hospitality Industry',
#  'How To Measure Your Campaign On Pinterest',
#  'MV Substation - An industrial approach (PART-B)',
#  'Gerenciamento de mídias sociais',
#  'Python Classes and Inheritance',
#  'First Steps in Making the Business Case for Sustainability',
#  'Simple Retrieval Queries in MySQL Workbench',
#  'Speaking with a Webpage - Streaming Speech Transcripts',
#  'Aggregate Data with LibreOffice Base Queries',
#  'Ethics, Culture, and Global Perspectives',
#  'Negotiation, Mediation, and Conflict Resolution - Capstone Project',
#  'Understanding Plants - Part II: Fundamentals of Plant Biology',
#  'Digital Signal Processing 1: Basic Concepts and Algorithms',
#  'Communicate UX Research with Empathy Maps in Miro',
#  'Making Architecture',
#  'Installer et configurer le registre Harbor sous Ubuntu',
#  'Water Supply and Sanitation Policy in Developing Countries Part 2: Developing Effective Interventions',
#  'Light Up Your World in Unity (Introduction to Lighting)',
#  'How to create an email campaign with SendinBlue',
#  'Reliable Cloud Infrastructure: Design and Process dalam bahasa Indonesia',
#  'Framework for Data Collection and Analysis',
#  'Getting Started with Cloud Data Fusion',
#  'Capstone: Build a Winning Investment Portfolio',
#  'Introduction to JavaScript Arrays',
#  'Teaching with Peer Review Using Eduflow',
#  'Generate a PDF File with JavaScript',
#  'Introduction to PicsArt for Social Media Marketing',
#  'MySQL with Information Technology',
#  'Designing Learning Innovation',
#  'Object Oriented Development using C#',
#  'Créer des visuels pour une boutique Facebook avec Canva',
#  'Create a Business Model Canvas with Mural',
#  'Design and Visualize Impact Metrics in Miro',
#  'International Business and Culture',
#  'Terraform for absolute beginners',
#  'Instala e integra Facebook Pixel con Shopify',
#  'COVID-19 Contact Tracing',
#  'Bookkeeping Basics',
#  'Cybersecurity Job Search and Interviews: Getting Started',
#  'Transforming Data in R',
#  'Medindo o Marketing Digital',
#  'Build a User Experience (UX) Map in Miro',
#  'Creating Perspective Visuals Using Adobe Illustrator ',
#  'UX / UI: Fundamentos para o design de interface',
#  'Building Scalable Java Microservices with Spring Boot and Spring Cloud',
#  ' Understanding the average Facebook User',
#  'Creating a Budget with Microsoft Excel',
#  'Applications in Engineering Mechanics',
#  'How to make invitations using Canva',
#  'Accomplishment STAR Techniques for Job Interviews',
#  'Business Strategy in Practice (Project-centered Course)',
#  'Let’s Read! Learning Japanese through Science & Technology-1',
#  'Cómo empezar con Facebook Commerce Manager',
#  'HI-FIVE: Health Informatics For Innovation, Value & Enrichment (Administrative/IT Perspective)',
#  'Fraud Detection on Financial Transactions with Machine Learning on Google Cloud',
#  'User Experience Design with Disney Creative Strategy in Miro',
#  'Blended Learning: Personalizing Education for Students',
#  'Developing Advanced Programme Delivery Framework in ClickUp',
#  'Installation et configuration de Java avec VS Code',
#  'Fandom, Social Media, and Authenticity in the Digital Age',
#  'Linux: Archiving and Compression for DevOps (tar/gzip)',
#  'Planning for Climate Change in African Cities',
#  'Improving your statistical inferences',
#  'Leading Oneself with Self-Knowledge',
#  'Inglés Empresarial: Finanzas y Economía',
#  'Juniper Cloud Concepts and Open Source Technologies',
#  'Fundamentals of Quantitative Modeling',
#  'Create 3D Text for a Musical Poster using Adobe Illustrator',
#  'Training and Learning Online',
#  'Configuring and Deploying Windows SQL Server on Google Cloud',
#  'Hypothesis-Driven Development',
#  'Cyber Attack Countermeasures',
#  'The Marketing Plan',
#  'Fundamentals of financial and management accounting',
#  'International B2B (Business to Business) Marketing',
#  ' Get started with Facebook Audience Insights',
#  'Product  and Service Development: Empathy  Mapping with Miro',
#  'Introduction to Agent-based Modeling with NetLogo',
#  'Retrieve Data using Single-Table SQL Queries',
#  'Materials Science: 10 Things Every Engineer Should Know',
#  'Evaluate Machine Learning Models with Yellowbrick',
#  "Hôtel “De l'étoile” - a hotel in crisis? ",
#  'Planification des mobilités',
#  'Use RACI charts for work management with Asana',
#  'Learn to Teach Java:  ArrayLists and 2D Arrays',
#  'Major Engineering Project Performance',
#  'Comienza con Facebook Messenger for Business',
#  'Data Processing and Feature Engineering with MATLAB',
#  'Business Model Canvas',
#  'Formal Financial Accounting',
#  'Doing Clinical Research: Biostatistics with the Wolfram Language',
#  'Conducting Exploratory Data Analysis',
#  'Design your own trading strategy – Culminating Project',
#  'Digital Signal Processing 2: Filtering',
#  'Global Marketing: Building Iconic Brands',
#  'Participatory NetLogo Simulations with HubNet',
#  'The Social and Technical Context of Health Informatics',
#  ' Storytelling in Branding and Content Marketing ',
#  'Product Design: Draw a Classic Armchair using SketchUp',
#  'Travailler Avec des Tableaux de Bord en SQL',
#  'Wonders of Ancient Egypt',
#  'Wireframes und Low-Fidelity-Prototypen Erstellen',
#  'Create a Performance Summary using SnapEval',
#  'Introduction to Clinical Data',
#  'Health Coaching Conversations',
#  'Agile Leader Training',
#  'Installing Plugins- SpotBugs, SonarLint, TestNG with Eclipse',
#  'Designing a Low Fidelity Prototype in Figma',
#  'Finance for Non-Finance Professionals',
#  'Create Social Media Posts using Adobe Illustrator',
#  'Predictive Modeling, Model Fitting, and Regression Analysis',
#  'Ebola: Essential Knowledge for Health Professionals',
#  'NIST CSF',
#  'Project Management: Life cycle and project planning',
#  'Negotiation Strategies and Styles ',
#  'Créer des diagrammes de Buyer Persona avec Creately',
#  'Fandom, Community, and Identity in Popular Music',
#  'Comment Installer Linux sur Votre Ordinateur',
#  ' Comercio, Inmigración y Tipos de Cambio en un Mundo Globalizado',
#  'Enterprise Systems',
#  'Professionalism in an era of change',
#  'NGO Startup Analysis with Nonprofit Business Model Canvas',
#  'Full Stack Cloud Development Capstone Project',
#  'Collaborate Effectively for Professional Success',
#  'Work with Dates in JavaScript',
#  'Introduction to Multinational and Cross-Cultural Teams',
#  'Fundamentals of Social Media Advertising',
#  'App Deployment, Debugging, and Performance',
#  'Check Point Jump Start: Harmony Endpoint Security',
#  'Process File Data using C Pointers',
#  'Protecting Business Innovations via Trademark',
#  'Text file Input/Output in Java',
#  'Manage Idea Generation with Brainwriting in Miro ',
#  'Effective Business Presentations with Powerpoint',
#  'Build a Website Map with Jumpchart',
#  'Enregistrer vos designs Canva sur MailChimp',
#  'Organize yourself as a remote worker or self-employed',
#  'Introducción al marketing en redes sociales',
#  'Metagenomics applied to surveillance of pathogens and antimicrobial resistance',
#  'IELTS Writing Section Skills Mastery',
#  'Introduction to Java and Object-Oriented Programming',
#  'Create a High-Fidelity Prototype with Figma',
#  'JavaScript Decision Programming with If-Else',
#  'Introduction to Advance Features in Rasa Chatbot Framework 2',
#  'Renewable Energy: Fundamentals and Job Opportunities',
#  'Initiation à la programmation (en Java)',
#  'Nettoyer vos données avec Python',
#  'Travailler en ligne de commande sous Linux',
#  'Unleashing the Impact of your Social Enterprise',
#  'Les bases de la stratégie d’entreprise',
#  'Introduction to Calculus',
#  'RESTful Web Services with JAX-RS',
#  'UX Design: From Concept to Prototype',
#  'Creating Accounting Statements Using Accounting Fundamentals',
#  'Running Windows Containers on Compute Engine',
#  'Introduction to Blockchain for Financial Services',
#  'Design Thinking for the Greater Good: Innovation in the Social Sector',
#  'Serverless Data Processing with Dataflow:Foundations Español',
#  'Vue d’ensemble sur la visualisation de données avec Canva',
#  'Geodesign: Change Your World',
#  'Evaluating Designs with Users',
#  'Business Statistics and Analysis Capstone',
#  'Legal Contracts and Agreements for Entrepreneurs',
#  'Business Models For Sustainability',
#  "Le Bien, le Juste, l'Utile. Introduction aux éthiques philosophiques",
#  'Cybersecurity for Everyone',
#  'Business Model Innovation for Sustainable Landscape Restoration',
#  'Integra Facebook Messenger para Negocios a un Sitio Web',
#  'Natural Creativity',
#  'Entrepreneurial Mindset',
#  'Marketing e vendas B2B: Fechando novos negócios',
#  'Escalamiento exitoso e Innovación en los Negocios',
#  'Communications and High-Speed Signals with Raspberry Pi',
#  'Agile with Atlassian Jira',
#  'SQL Joins ',
#  'Use the GE-McKinsey Matrix to Analyze and Set Your Strategy',
#  'The Blues: Understanding and Performing an American Art Form',
#  'Introduction to Bash Shell Scripting',
#  'Import and Configure an Animated 3D Character in Unity',
#  'Design a User Experience Survey in SurveyMonkey',
#  'Create Infographics using Piktochart',
#  'Singing Popular Music',
#  'Managing Responsibly: Practicing Sustainability, Responsibility and Ethics',
#  'JavaScript Basics',
#  'Implementing a Risk Management Framework ',
#  'Choosing a Facebook Post Type Based on Desired Engagement',
#  'Erste Schritte in Instagram for Business',
#  'What is the Metaverse?',
#  'Design and Build a Data Warehouse for Business Intelligence Implementation',
#  'Benutze Facebook für Marketing von Kleinunternehmen',
#  'Business Applications of Hypothesis Testing and Confidence Interval Estimation ',
#  'A General Approach to Risk Management',
#  'Crie designs e protótipos de alta fidelidade com Figma',
#  'Cloud Systems Software',
#  'JavaScript Arithmetic Operators',
#  'Organisational design: Know your organisation',
#  'Build a Chat UI application using CSS3 Flexbox',
#  'Cómo utilizar Adobe Illustrator',
#  'Creating a Portfolio ',
#  'Create a Google Ads Search Campaign',
#  'Distributed Programming in Java',
#  'Crear contenidos para redes sociales con Prezi',
#  'Learning to Teach Online',
#  'Create and Sell Digital Teaching Printables with Canva',
#  'Leading Diverse Teams',
#  ' Gestalte deinen Shop in Facebook Shops mit Canva',
#  'Building High Quality User Experience Using Material UI',
#  'Create IT Diagrams with Lucidchart',
#  'Agiles Arbeiten trifft auf Design Thinking',
#  'Tencent Cloud Developer Associate',
#  'Finances pour les professionnels non financiers',
#  'Access WebView in an Android Studio Project',
#  'Cost and Economics in Pricing Strategy',
#  'Machine Learning Foundations: A Case Study Approach',
#  'Physique des particules - une introduction',
#  'Building Batch Data Pipelines on GCP en Español',
#  'Use Canva to Create Social Media Visuals for Business',
#  'Introduction to Software Testing',
#  'Use Pastel in UX Design',
#  'Introduction to C# Programming and Unity',
#  'Getting started with Prezi for small businesses',
#  'Construire votre audience sur Facebook Audience Insights',
#  'Creating a Personal Site with Gatsby',
#  'Architecting with Google Kubernetes Engine: Foundations en Français',
#  'Hide and Reveal Secret Rooms in Unity',
#  'Engineering of Structures: Tension',
#  'Providing Social, Emotional, Behavioral, and Special Education Services in School',
#  'Musicianship: Tensions, Harmonic Function, and Modal Interchange',
#  'Management of Fashion and Luxury Companies',
#  'إدارة المواقع باستخدام apache2',
#  'Qualitative Research Design',
#  'Get Started with Facebook Business Manager ',
#  'Anthos on Bare Metal',
#  'Proceso de datos sucios a datos limpios',
#  'Apply advanced testing for your Django web application',
#  'Les partenariats qui changent le monde : alliances innovantes entre entreprises et associations',
#  'MailChimp pour les débutants ',
#  'Test Accessibility of your Design with A11ygator',
#  'القرارات الاستثمارية باستخدام معيار صافي القيمة الحالية',
#  'Фінанси для нефінансових спеціалістів',
#  'Data Warehousing with Microsoft Azure Synapse Analytics',
#  'Crear un panel de inspiración para su marca con Canva',
#  'Credit Risk Management: Frameworks and Strategies',
#  'Introducción a Java',
#  'Relational Databases - MySQL - قواعد البيانات العلائقية',
#  'Marketing en Redes Sociales Proyecto Final',
#  'Encouraging Student Collaboration with Padlet',
#  'Cyber Security in Manufacturing  ',
#  'Data Structures and Performance',
#  'Essentials of Corporate Finance Capstone',
#  'How to find customers by uploading contacts on Twitter',
#  'How to design Facebook and IG stories using Canva',
#  'Computational Thinking with JavaScript 2: Model & Analyse',
#  'Grundlagen der Geschäftsstrategie',
#  'Create a Basic Mini-Map in Unity',
#  'Viral Marketing and How to Craft Contagious Content',
#  'OWASP Top 10 - Risks 6-10',
#  'The Music of the Beatles',
#  'Cómo encontrar intereses de la audiencia con Meta Business',
#  'Edita tus fotos para las redes sociales con Easil',
#  'Competitive Strategy and Organization Design Project',
#  'Development Methodologies Overview',
#  'Exploring the Lineage of Data with Cloud Data Fusion',
#  'Global Sodium Reduction Strategies',
#  'Using Advanced SWOT Analysis to Determine Competitiveness',
#  'Comment commencer avec Pinterest Shopping',
#  'Platform Thinking: designing a Platform',
#  'How to Create Printable Media in Canva',
#  'Jakarta Persistence (JPA)',
#  'Essential Cloud Infrastructure: Foundation en Español',
#  'أخلاقيات وآداب السلوك في الأعمال',
#  'Hootsuite pour les débutants',
#  'Design A Newsletter with MailChimp',
#  'Ecologie Politique: défi de la durabilité pour les démocraties',
#  'The Unix Workbench',
#  'Implementación del Marketing Mix Proyecto Capstone',
#  'Entdecke verschiedene Arten von Facebook Ads',
#  'Manage Docker on Linux Servers',
#  'Deploying a Python Flask Web Application to App Engine Flexible',
#  'Fundamentos de Inteligência Artifical em Marketing',
#  'Marketing estratégico: claves para competir con éxito',
#  'Inglés Empresarial: el márketing y ventas',
#  'Real-World Cloud PM 1 of 3: Cloud Business and Technology',
#  'Use Mailchimp to Build an E-mail Marketing Campaign',
#  'Transformação digital',
#  'Get started with Piktochart ',
#  'Marketing Mix Implementation Capstone ',
#  'Knowledge Exchange: Using, Protecting and Monetizing Ideas with Third Parties',
#  'Créer un pitch deck pour votre projet avec Canva',
#  'Create Striking Real Estate Instagram Posts in Canva',
#  'Design and Interpretation of Clinical Trials',
#  'The 360º Corporation: Tools for Achieving Corporate Purpose',
#  'Make a Bill Splitter App with AngularJS',
#  'Transportation, Sustainable Buildings, Green Construction',
#  'Einführung in Marketing für soziale Medien mit Visme',
#  'VM Migration: Planning',
#  'Copyright for Multimedia',
#  'Data Visualization Best Practices',
#  'Réussir une négociation : Stratégies et compétences clés',
#  'Software Design Threats and Mitigations',
#  'Supply Chain Finance Market and Fintech Ecosystem',
#  'Digital business - Grow on digital world',
#  'Program Change Management in ClickUp',
#  'Build automated speech systems with Azure Cognitive Services',
#  'Prácticas efectivas de marketing usando Facebook Messenger',
#  'Introduction to Cost Accounting',
#  'Basic Principles of Cell Signaling',
#  'Success',
#  'System Validation (4): Modelling Software, Protocols, and other behaviour',
#  'Device-based Models with TensorFlow Lite',
#  'Inove na gestão de equipes e negócios: O crescimento da empresa',
#  'Basics of Cost Accounting: Product Costing',
#  'Teaching Impacts of Technology: Data Collection, Use, and Privacy',
#  'Hypotheses Testing in Econometrics',
#  'Effective Communication for Today’s Leader',
#  'Introduction to Digital Transformation Part 2',
#  'Channel Management and Retailing ',
#  'Innovar tu enseñanza con design thinking',
#  'Getting Started with Adobe Spark',
#  'Stories of Infection',
#  'Genetic Epidemiology Foundations',
#  'Introduction to Microsoft Azure Synapse Analytics',
#  'Create a Record of Students using Abstraction in Java',
#  'Cryptography',
#  'Knowledge and Skills for Dementia Care: the SSLD Approach ',
#  'Adaptability and Resiliency',
#  'Architecting with Google Kubernetes Engine: Workloads en Français',
#  'Making the Case for Robotic Process Automation',
#  'Designing Traps with C# in Unity',
#  'Interprofessional Healthcare Informatics ',
#  'Build a Database from a Relational Model',
#  "Troubles du spectre de l'autisme : biologie et neurosciences",
#  'Statistical Thermodynamics: Molecules to Machines',
#  'Ready, Set, Future! Introduction to Futures Thinking',
#  'Orchestrating Whole Classroom Discussion',
#  'Cybersecurity Foundations for Risk Management',
#  'Create an online brainstorming with Stormboard',
#  'ML Pipelines on Google Cloud',
#  'Einführung in die Datenanalyse mit Excel',
#  'Designing data-intensive applications',
#  'Basic Data Descriptors, Statistical Distributions, and Application to Business Decisions',
#  "Créer un compte de gestionnaire d'entreprise Facebook",
#  'Sustainable Fashion',
#  'Fundamentals of Funding, with Goldman Sachs 10,000 Women',
#  'Advanced React',
#  'Chinese for Beginners',
#  'Microwave engineering and antennas',
#  'Static Routing Configuration Using Packet Tracer',
#  'Create an FPS Weapon in Unity (Part 1 - Revolver)',
#  'Explore Variables and Data Types in VB.NET',
#  'Creating a virtual book store using java GUI',
#  'Create a Business Model Canvas in Miro',
#  'Leadership in Interprofessional Informatics ',
#  'Design and Implementation of Digital Health Interventions ',
#  'Create a Brand Awareness Survey in Qualtrics',
#  'Use Basecamp for Project Management',
#  'Introduction to Programming in Swift 5',
#  'Geographical Information Systems - Part 1',
#  'Marketing digital para E-commerce',
#  'Transmedia Storytelling: Narrative worlds, emerging technologies, and global audiences',
#  'Using Data for Healthcare Improvement',
#  'Advanced Business Strategy',
#  'Create a workspace for a team project on Slack',
#  'Investments II: Lessons and Applications for Investors',
#  'Ethical Leadership Through Giving Voice to Values',
#  'Programming Fundamentals in Swift',
#  'Aprendizajes en Ingeniería y Agricultura con Arduino: Construcción y automatización de un invernadero',
#  'U.S. Federal Taxation Capstone',
#  'JavaScript Security Part 1',
#  'Modifier et améliorer votre publicité Facebook',
#  'Securing and Integrating Components of your Application en Français',
#  'Managing ADHD, Autism, Learning Disabilities, and Concussion in School',
#  'Manipulate Object Properties with C# in Unity',
#  'Das liebe Geld - Finance im Alltag',
#  'Detecting and Mitigating Cyber Threats and Attacks',
#  'Introduction to Meteor.js Development  ',
#  'Data Warehouse Concepts, Design, and Data Integration',
#  ' Edita fotos para las redes sociales con Canva',
#  'E-Commerce Payments Using Stripe and NodeJS',
#  'Urban Nature: Connecting Cities, Sustainability and Innovation',
#  'Windows Server Management and Security',
#  'Networking and Security in iOS Applications',
#  'Programming for the Internet of Things Project',
#  "Travail d'équipe et créativité ",
#  'Material Components for Flutter Basics',
#  'Business Strategies for Social Impact',
#  'Address Business Issues with Data Science ',
#  'Advertise and grow your business on Facebook with Canva',
#  'Embedded Software and Hardware Architecture',
#  'Technologies and platforms for Artificial Intelligence',
#  'Tweet Emotion Recognition with TensorFlow',
#  'Prezi para pequeñas empresas',
#  'How to find audience interests with Meta Business Suite',
#  'Digital Fashion Industry',
#  'Launching Your Freelancing Business',
#  'Basic Recommender Systems',
#  'Business Partner e o Papel dos Agentes na Gestão de RH',
#  'Python Programming Essentials',
#  'How to use the perspective grid tool in Adobe Illustrator',
#  'Program Resource Planning with ClickUp',
#  'Sustainable Business: Big Issues, Big Changes',
#  'Mastering Statics',
#  'People, Technology and the Future of Mobility ',
#  'Speaking to Inspire: Ceremonial and Motivational Speeches',
#  'The Future of Payment Technologies',
#  'Introduction to Personal Finance',
#  'Scripting with Python and SQL for Data Engineering',
#  'Operations and Supply Chain Decisions and Metrics',
#  'Design Research para Estratégia e Inovação',
#  'Data-Driven Testing (via spreadsheet) with Selenium & Nunit',
#  'Programming in C#: A comprehensive approach to C# Fundamentals',
#  'Marketing Mix Fundamentals',
#  'Verstehe den durchschnittlichen Facebook Nutzer',
#  'Quantitative Research',
#  'Spanish for Successful Communication in Healthcare Settings',
#  'Test your Django views and forms using Selenium',
#  'Visualize Project Milestones with Gantt Charts in Miro',
#  'Introduction to CSS3',
#  'Introduction to TensorFlow for Artificial Intelligence, Machine Learning, and Deep Learning',
#  'How to Set Up a Facebook Ads Campaign',
#  'Marketing Analytics',
#  'Strategic Organization Design',
#  'Emerging Trends & Technologies in the Virtual K-12 Classroom',
#  'Response Surfaces, Mixtures, and Model Building',
#  'IoT Devices',
#  'Program Risk Planning with ClickUp',
#  'Financial Accounting: Foundations',
#  'Alternative Mobility Narratives',
#  'Analyzing Macro-Environmental Factors Using Creately',
#  'Involve Critical Players with Stakeholder Maps in Miro\t',
#  'Cloud Computing Primer: Infrastructure as a Service (IaaS)',
#  'Native Advertising',
#  'Create a Tic-Tac-Toe Game using Java ',
#  'Stepping Up: Preparing Yourself for Leadership',
#  'Reimagining Consumer Experience',
#  'Design a Client Welcome Kit using Canva',
#  'Understanding China, 1700-2000: A Data Analytic Approach, Part 1',
#  'Introduction to virtual machines in Microsoft Azure',
#  'Juniper Networks Security Concepts and Initial Configuration',
#  'Optimizing Machine Learning Performance',
#  'Code Free Data Science',
#  'MOOC and Blended Learning',
#  'Data Structures and Algorithms (III)',
#  'Getting started with PicMonkey for Small Businesses',
#  'Generative Design for Performance and Weight Reduction',
#  'Engineering of Structures: Response of Structures',
#  'Principles of Secure Coding',
#  'Getting Started with Automation 360',
#  'Getting Started with Git and GitHub',
#  'فن التفاوض | The Art of Negotiation',
#  'Technology Strategy: Creative Destruction',
#  'Design, Format, and Presentation in Microsoft PowerPoint',
#  'Sequences, Time Series and Prediction',
#  'How to Use the CPM to Analyze and Set Your Strategy',
#  'Project Management: Creating the WBS',
#  'Product Development using AutoCAD',
#  '(Business Writing) الكتابة في مجال الأعمال',
#  'الترجيح الإحصائي أو Statistical Weighting فى Microsoft Excel',
#  'Basic Data Processing and Visualization',
#  'Use a Binary Search Tree to Process Simple Data in Java',
#  'Beyond Silicon Valley: Growing Entrepreneurship in Transitioning Economies',
#  'Chinese for HSK 1',
#  'Nouveaux modèles économiques des associations',
#  'Cloud Computing Foundations',
#  'عمل presentation غنية بالمعلومات في Microsoft PowerPoint',
#  'File Editor Time Travel with Linux',
#  'Promote your Scientific Results',
#  ' المالية لغير الخبراء الماليين',
#  'Interessen des durchschnittlichen Facebook Nutzers',
#  'Global Trends for Business and Society',
#  'Restful Web Service Spring Boot Visual Studio Code Gradle',
#  'Create a no-code one page SMB website with Carrd',
#  'Design Principles: an Introduction',
#  'Financing and Profiting from Innovation for Corporate Entrepreneurs',
#  'Evaluations of AI Applications in Healthcare',
#  'Protecting Business Innovations via Copyright',
#  'API Testing with Karate Framework',
#  'Creative Design, Prototyping, and Testing',
#  'Global Challenges in Business Capstone',
#  'Deploying Redis Enterprise for GKE and Serverless App on Anthos Bare Metal',
#  'Developing Applications with SQL, Databases, and Django ',
#  'Mastering Digital Twins',
#  'Global Marketing: Cultural Frameworks',
#  'Protecting the World: Introducing Corrosion Science and Engineering',
#  'Build an Automated Landing page using AI from Wix ADI',
#  'El Abogado del Futuro: Legaltech y la Transformación Digital del Derecho',
#  'Developing Your Musicianship',
#  'Server-side Development with NodeJS, Express and MongoDB',
#  'AIDS: Fear and Hope',
#  'Java Programming: Build a Recommendation System',
#  'Crea gráficos para Facebook en Visme',
#  ' Project Management among Multiple Organizations with Trello',
#  'Game-based Learning with Scratch',
#  'ESG Investing: Industry Impacts & Transformations',
#  'Generate an Opportunity Solution Tree in Miro',
#  'Consolidando empresas: Estrutura jurídica e financeira',
#  'How to Build an Effective Service Company',
#  'New Product Development For Small Businesses and Start-Ups',
#  'Digital Marketing Analytics in Practice',
#  'Creating Horizontal and Vertical Timelines in PowerPoint',
#  'Deploy a Complete Wordpress Video Blog in Microsoft Azure',
#  'Implicaciones estratégicas de la marca',
#  'Marketing in a Digital World',
#  'Using JavaScript, JQuery, and JSON in Django',
#  'Geometría Analítica Preuniversitaria',
#  'Crea un perfil de negocios en Twitter',
#  'Programming Languages, Part B',
#  'Hacking and Patching',
#  'Create a Balanced Scorecard to Align Priorities in Miro',
#  'PEST Analysis with Service Blueprints in Miro ',
#  'Introduction au Marketing des réseaux sociaux',
#  'LCFA Practice Course',
#  'Responsive Web Design dans Adobe XD',
#  'Applying Data Analytics in Accounting',
#  'Test Driven Development in Java for Beginners ',
#  'Database Management Essentials',
#  'Create UI in Unity Part 3 - Settings Menu',
#  'Ein Crashkurs in Datenwissenschaft',
#  'Get Started with Wrike',
#  'Cómo Configurar una Campaña en Facebook Ads ',
#  'Optimize Digital Experiences with Service Blueprints in Miro',
#  'Introduction to C++ Programming: Build a Calculator',
#  "Les deux infinis et nous - Voyages de l'infiniment grand à l'infiniment petit",
#  'Study Skills for University Success',
#  'Automating Image Processing',
#  'Risk governance: Manage the risks',
#  'Getting Started with Ubuntu Linux',
#  'Business Opportunities and Risks in a Globalized Economy',
#  'Build an App in Android Studio using Resources',
#  'Serious Gaming',
#  'Introduction to Operations Management',
#  'Measurement – Turning Concepts into Data',
#  'Mechanics of Materials II: Thin-Walled Pressure Vessels and Torsion',
#  'Gestión de redes sociales',
#  'Design a Product Package on Mockup using Adobe Photoshop',
#  'Finance For Everyone: Value',
#  'Erstelle Grafiken für Facebook in Visme',
#  'Lesson | Business English Skills: Introducing Yourself in Business Settings ',
#  'Simulation Skills: This is Your Brain on the Future',
#  'Introduction to Valuation with WACC',
#  'Population Health: Health & Health Behaviour',
#  'Draw an Isometric House with Inkscape',
#  'A Simple Picture Storing App with Java and Android Studio',
#  'Real-Time Cyber Threat Detection and Mitigation',
#  'JavaScript Security Part 3',
#  'Positive Psychiatry and Mental Health ',
#  'Making Successful Decisions through the Strategy, Law & Ethics Model',
#  'iOS App Capstone',
#  'Finance for Non-Financial Professionals',
#  'أنت وأنظمة التشغيل: كيف تصبح مستخدمًا محترفًا',
#  'Introduction to Networking and Storage',
#  'Mastering Final Cut Pro',
#  'Script Writing: Write a Pilot Episode for a TV or Web Series (Project-Centered Course)',
#  'Python and Machine Learning for Asset Management ',
#  'Reliable Cloud Infrastructure: Design & Process italiano',
#  'Installer et configurer la pile LAMP sous Ubuntu',
#  'Introduction to HTML',
#  'Cybersecurity Policy for Aviation and Internet Infrastructures',
#  'Créer une carte de visite professionnelle avec Canva',
#  'Learn to Teach Java:  Sequences, Primitive Types and Using Objects',
#  'Introduction to Linear Algebra and Python',
#  'Développement et Intégration Avec Java',
#  'Arctic Economy ',
#  'Managing the Company of the Future',
#  'Digital Marketing Capstone',
#  'How to create a Newsletter on Twitter using Revue',
#  'Customer Insights: Quantitative Techniques',
#  'How to Setup Facebook Messenger for a Business',
#  'Algorithms, Data Collection, and Starting to Code',
#  'Diseña infografías con Prezi',
#  'How To Create a Website in a Weekend! (Project-Centered Course)',
#  'Spring Boot Inversion of Control and Dependency Injection',
#  'Doing Business in China Capstone',
#  'Managing Linux Systems',
#  'Data Storage in Microsoft Azure for Associate Developers',
#  'Valuing Excellence',
#  'Customer Analytics',
#  'Measure a Marketing Strategy using Facebook Insights',
#  'Creatividad, diseño e innovación: Técnicas y herramientas - Proyecto Final',
#  'Installer des Plugins SpotBugs, SonarLint, TestNG (Eclipse)',
#  'International Business Context',
#  'Lead Management with HubSpot',
#  'Finanzas y Operaciones de Marketing y Ventas',
#  'Build a Business Architecture using AWS Organization',
#  'How to create custom typography design in Adobe Illustrator',
#  'Smart Contracts',
#  'Managing Talent',
#  'Creating Reusable Pipelines in Cloud Data Fusion',
#  'Legal Tech and the Digital Transformation of Law',
#  'IT Infrastructure and Emerging Trends',
#  'Software Architecture for the Internet of Things',
#  'Grow Your Business with Goldman Sachs 10,000 Women',
#  'Quelques instructions en PHP',
#  'Support Interactive Learning with Genially',
#  'Object-Oriented Programming with Java',
#  'معالجة الملفات والمجلدات بإستخدام Linux لمهندسي الكمبيوتر',
#  'Building Realtime Pipelines in Cloud Data Fusion',
#  'Introduction to Quantum Information',
#  'Cultura e Consumo no Marketing Digital',
#  'Drug Development',
#  'Smart Working: Lavoro agile e Business English',
#  'Disability Awareness and Support',
#  'A Complete Reinforcement Learning System (Capstone)',
#  'Relational Modeling in Dia',
#  'Introduction à la programmation orientée objet (en Java)',
#  'Get Interactive: Practical Teaching with Technology',
#  'Feature Engineering',
#  'Ищем популярные ключевые слова и хэштеги в Twitter',
#  'Test Accessibility of Your Design with WAVE',
#  'Introduction to Faecal Sludge Management',
#  'Introduction to iOS Mobile Application Development',
#  'What future for education?',
#  'Preparing for Graduate Study in the U.S.: A course for international students',
#  'Validate Data in SQL using MySQL Workbench',
#  'Introduction to Software Engineering',
#  '用 Python 做商管程式設計（二）(Programming for Business Computing in Python (2))',
#  'Linux: SSH to remote server & Networking basics for DevOps',
#  'Understanding Medical Research: Your Facebook Friend is Wrong',
#  'IBM z/OS Rexx Programming',
#  'Modern JavaScript: ES6 Basics',
#  'Global Systemic Risk ',
#  'Financing and Initiating Major Engineering Projects',
#  'Leading Teams',
#  'Bearbeite Fotos für Soziale Medien in PicsArt',
#  'Corporate Finance Essentials II',
#  'Calculus: Single Variable Part 2 - Differentiation',
#  'Mechanics of Materials IV: Deflections, Buckling, Combined Loading & Failure Theories',
#  'Inequality and Democracy',
#  ' Market your new business with Canva',
#  'Utilisez les fonctionnalités cachées de Canva',
#  'Project: Creating Your First C++ Application',
#  'Artificial Intelligence and legal issues',
#  'Introduction to Financial Accounting',
#  'The Art & Science of Product Management',
#  'Virtual Agent Development in Dialogflow CX for Citizen Devs',
#  'The Factors that Influence the Effectiveness of Boards and the Governance Process',
#  'How to Create a Facebook Business Manager Account',
#  'Essentials of Management and Strategic Planning',
#  'Cloud Networking',
#  'Android App Components - Intents, Activities, and Broadcast Receivers',
#  'Inferential and Predictive Statistics for Business',
#  'Quantitative Formal Modeling and Worst-Case Performance Analysis',
#  'Driving business towards the Sustainable Development Goals',
#  'Securing and Integrating Components of your Application',
#  'Create a business profile on Twitter',
#  'Business English: Basics',
#  'Project Management: Foundations and Initiation',
#  'Lier des comptes Facebook Ads à Facebook Business Manager',
#  'An Introduction to Consumer Neuroscience & Neuromarketing ',
#  'Build Critical Path Visualizations in Tableau and Excel',
#  'Experimentation for Improvement',
#  'E-Business: Negocios Online',
#  'Agile Projects: Creating User Stories with Value in Taiga',
#  'Introduction to Medical Software',
#  'E-commerce Academy',
#  'The Roles and Responsibilities of Nonprofit Boards of Directors within the Governance Process',
#  'Effective Problem-Solving and Decision-Making',
#  'Structure: Building the Frame for Business Growth',
#  'Microsoft Azure Databricks for Data Engineering',
#  'Introduction to Graph Theory',
#  'English for Developing a Business',
#  'Sécurité informatique et dangers du numérique',
#  'Introduction to UI Design',
#  'Introduction to Big Data with Spark and Hadoop',
#  'Static Website Hosting and Cross-Region Replication ',
#  "Mieux comprendre l'ESS pour mieux en parler",
#  'CFD Simulation Through a Centrifugal Pump',
#  'Sales Strategy',
#  'Gestalte Grafiken für soziale Medien mit Canva',
#  'Introduction to TestNG and Integration with Selenium',
#  'Learn and design an attractive PowerPoint presentation ',
#  'Cloud Data Engineering',
#  'Introduction to Object-Oriented Programming with Java',
#  'Change Leadership: Developing Force Field Analysis in Miro',
#  'Wie erstellen Sie einen Facebook-Geschäftsführer',
#  'Customer Segmentation and Prospecting',
#  'How Music Can Change Your Life',
#  'Fundamentals of Finance',
#  'Digital Business - Understand the digital world',
#  'Algorithmic Thinking (Part 2)',
#  'Getting Started with Blazor Server',
#  'Organizational innovation and creativity',
#  'Market Research and Consumer Behavior',
#  'ESG and Climate Change',
#  'Managing Machine Learning Projects',
#  'DevOps monitoring with Nagios: Configure Nagios in AWS EC2',
#  'Assessing Achievement with the ELL in Mind',
#  'Visual Machine Learning with Yellowbrick',
#  'Financing for Startup Businesses',
#  'Research kitchen',
#  'European Business Law: Competing in Europe',
#  'Chicken Behaviour and Welfare',
#  'AWS Fundamentals: Addressing Security Risk',
#  'Social Media Management ',
#  'Six Sigma Advanced Improve and Control Phases',
#  'Secure Networked System with Firewall and IDS',
#  'Accountability and Employee Engagement',
#  'Veiculação de anúncios com o Meta',
#  'Planned Giving',
#  'Introduction to Customer Segmentation in Python',
#  'Deploy a Website Container Image in AWS ECS and AWS Fargate',
#  'Leadership in 21st Century Organizations',
#  'Influencer Marketing Strategy',
#  ...]

# %%
'Fundamentals of financial and management accounting', 'Travailler Avec des Tableaux de Bord en SQL', 'Predictive Modeling, Model Fitting, and Regression Analysis', 'Data Visualization Best Practices', 'Basic Data Descriptors, Statistical Distributions, and Application to Business Decisions', 'Designing data-intensive applications'

# %%
import plotly.express as px

import numpy as np

# Example data (replace this with your actual data)
entities = soft_skills
hard_skills = ["système de gestion", "gestion financière", "gérer les risques",'tableau', 'systèmes de stockage', 'database', 'gestion du personnel', 'assurer la gestion administrative', 'data analysis', 'travail d\'équipe', 'leadership', 'java', 'Fundamentals of financial and management accounting', 'Travailler Avec des Tableaux de Bord en SQL', 'Predictive Modeling, Model Fitting, and Regression Analysis', 'Data Visualization Best Practices', 'Basic Data Descriptors, Statistical Distributions, and Application to Business Decisions', 'Designing data-intensive applications']
time_periods = ['31/1/2011', '31/07/2011', '31/1/2012', '31/7/2012', '31/1/2013', '31/7/2013', '31/1/2014', '31/07/2014', '31/1/2015', '31/7/2015', '31/1/2016', '31/7/2016', '31/1/2017','31/7/2017', '31/1/2018', '31/7/2018', '31/1/2019','31/7/2019', '31/1/2020', '31/7/2020', '31/1/2021', '31/7/2021', '31/1/2022', '31/7/2022', '31/1/2023', '31/7/2023', '31/1/2024', '31/7/2024', '31/1/2025', '31/7/2025']
co_occurrence_data = np.random.randint(0, 10, size=(len(entities), len(time_periods)))

# Create a DataFrame
df = pd.DataFrame(co_occurrence_data, columns=time_periods, index=entities)

# Create the Plotly heatmap
fig = px.imshow(df, x=time_periods, y=entities, color_continuous_scale='YlGnBu')
fig.update_xaxes()
fig.update_layout(
    title='Entity Co-occurrence Heatmap',
    xaxis_title='Time Period',
    yaxis_title='Entities'
)

# Show the Plotly heatmap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df917578-2e90-4ff9-a807-4efe4b88aba7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df917578-2e90-4ff9-a807-4efe4b88aba7")) {                    Plotly.newPlot(                        "df917578-2e90-4ff9-a807-4efe4b88aba7",                        [{"coloraxis":"coloraxis","name":"0","x":["31\u002f1\u002f2011","31\u002f07\u002f2011","31\u002f1\u002f2012","31\u002f7\u002f2012","31\u002f1\u002f2013","31\u002f7\u002f2013","31\u002f1\u002f2014","31\u002f07\u002f2014","31\u002f1\u002f2015","31\u002f7\u002f2015","31\u002f1\u002f2016","31\u002f7\u002f2016","31\u002f1\u002f2017","31\u002f7\u002f2017","31\u002f1\u002f2018","31\u002f7\u002f2018","31\u002f1\u002f2019","31\u002f7\u002f2019","31\u002f1\u002f2020","31\u002f7\u002f2020","31\u002f1\u002f2021","31\u002f7\u002f2021","31\u002f1\u002f2022","31\u002f7\u002f2022","31\u002f1\u002f2023","31\u002f7\u002f2023","31\u002f1\u002f2024","31\u002f7\u002f2024","31\u002f1\u002f2025","31\u002f7\u002f2025"],"y":["Sensibilit\u00e9 \u00e9motionnelle","Besoin d'autonomie","Intuition \u002f Spontan\u00e9it\u00e9","Rationalisme","Introversion","Besoin d'objectivit\u00e9","Besoin d'action","Ambition","Recherche de nouveaut\u00e9","Improvisation","Volont\u00e9 de persuasion","Conventionnel","Respect des r\u00e8gles","Humilit\u00e9","Distance \u00e9motionnelle"],"z":[[8,8,5,0,7,9,0,0,6,7,8,9,9,0,9,7,9,1,5,0,1,3,4,2,0,5,7,1,3,5],[2,2,3,4,7,8,9,4,1,4,5,6,8,1,6,9,1,9,5,1,6,2,8,3,6,3,9,1,0,1],[1,9,9,3,7,6,1,1,4,4,8,6,5,2,4,7,8,0,7,9,7,7,7,9,7,9,1,2,3,0],[2,7,7,6,8,0,3,9,4,1,7,0,0,7,0,3,5,5,1,3,4,1,1,7,7,8,4,5,3,2],[6,8,8,8,9,5,7,7,4,8,4,4,2,5,4,1,5,2,3,0,5,3,6,7,1,1,8,9,3,6],[9,3,1,5,2,7,9,7,8,8,4,2,7,9,0,3,3,4,0,0,2,9,9,6,5,5,3,6,5,4],[8,0,8,1,0,7,2,2,1,8,4,3,0,1,9,9,2,2,3,2,3,3,2,9,5,8,8,1,7,1],[0,1,4,6,2,6,3,1,0,8,2,5,7,4,9,2,8,7,5,9,2,8,9,5,2,6,9,6,8,2],[7,9,3,7,6,2,5,0,5,0,6,7,4,3,2,2,7,4,6,4,9,4,1,4,7,3,4,7,3,9],[5,0,6,6,1,8,1,9,4,7,0,1,8,8,6,9,3,8,8,4,0,8,8,6,2,7,3,1,8,0],[0,7,7,5,5,7,7,4,7,7,0,0,5,0,9,0,5,7,5,2,0,2,8,5,8,1,8,3,1,3],[9,8,2,1,6,8,4,7,2,8,0,5,7,6,7,2,6,0,7,5,3,7,6,6,0,4,2,6,3,7],[5,0,2,4,6,9,4,8,1,8,1,8,1,8,5,0,6,3,0,2,8,6,1,2,0,1,0,4,2,0],[1,3,7,9,0,4,4,1,2,9,2,9,1,5,1,8,8,8,6,1,3,6,7,8,3,9,4,8,1,0],[9,1,4,7,0,2,9,0,9,0,4,5,4,9,6,4,2,6,7,9,7,9,5,6,1,2,1,8,2,9]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl", ...

# %% [markdown]
# # Temporal Evolution

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px


def plot_temporal_evolution(data):
    # Assuming 'data' contains the output of the 'infer_job_skills' function

    # Group the data by the date and calculate the average score (or other relevant statistics)
    grouped_data = data.groupby('date')['score'].mean().reset_index()

    # Create a line chart
    plt.figure(figsize=(12, 6))
    plt.plot(grouped_data['date'], grouped_data['score'], marker='o', linestyle='-')

    # Customize the plot
    #plt.title('Temporal Evolution of Job Skills')
    plt.xlabel('Date')
    plt.ylabel('Average Score')  # You can customize this label based on your data

    # Display the plot
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()



def plot_temporal_evolution_plotly(data):
    # Assuming 'data' contains the output of the 'infer_job_skills' function

    # Group the data by the date and calculate the average score (or other relevant statistics)
    grouped_data = data.groupby('date')['score'].mean().reset_index()

    # Create a line chart with Plotly Express
    fig = px.line(grouped_data, x='date', y='score', title='Temporal Evolution of Job Skills',
                  labels={'score': 'Average Score', 'date': 'Date'})

    # Customize the plot
    fig.update_layout(xaxis=dict(tickangle=-45), showlegend=False)

    # Display the plot
    fig.show()

# %%
xx = infer_job_skills(model = inf_model, job_title = 'Production Leader',rel = '_requires',
           ent_df = ent_df, rel_df = rel_df, start_time = '1/1/2010', end_time='1/1/2026')

plot_temporal_evolution_plotly(xx)
# Out:
# len(tail_ents):  730
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="93b4e09d-a144-4753-9ebc-5194167ef074" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93b4e09d-a144-4753-9ebc-5194167ef074")) {                    Plotly.newPlot(                        "93b4e09d-a144-4753-9ebc-5194167ef074",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eAverage Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2010-01-31","2010-04-30","2010-07-31","2010-10-31","2011-01-31","2011-04-30","2011-07-31","2011-10-31","2012-01-31","2012-04-30","2012-07-31","2012-10-31","2013-01-31","2013-04-30","2013-07-31","2013-10-31","2014-01-31","2014-04-30","2014-07-31","2014-10-31","2015-01-31","2015-04-30","2015-07-31","2015-10-31","2016-01-31","2016-04-30","2016-07-31","2016-10-31","2017-01-31","2017-04-30","2017-07-31","2017-10-31","2018-01-31","2018-04-30","2018-07-31","2018-10-31","2019-01-31","2019-04-30","2019-07-31","2019-10-31","2020-01-31","2020-04-30","2020-07-31","2020-10-31","2021-01-31","2021-04-30","2021-07-31","2021-10-31","2022-01-31","2022-04-30","2022-07-31","2022-10-31","2023-01-31","2023-04-30","2023-07-31","2023-10-31","2024-01-31","2024-04-30","2024-07-31","2024-10-31","2025-01-31","2025-04-30","2025-07-31","2025-10-31"],"xaxis":"x","y":[0.2563129663467407,0.3944145441055298,0.2563129663467407,1.062788486480713,0.8765970468521118,1.0195798873901367,0.8765970468521118,1.1412583589553833,1.0427197217941284,0.9597272276878357,1.0427197217941284,1.2447888851165771,0.9999358057975769,0.8495877385139465,0.9999358057975769,0.9053176641464233,0.7648340463638306,1.1631561517715454,0.7648340463638306,0.9434797167778015,0.06345123052597046,0.007520289625972509,0.06345123052597046,-0.004247700795531273,1.004037618637085,0.7541447281837463,1.004037618637085,1.282749891281128,0.5645362734794617,0.6236213445663452,0.5645362734794617,1.1897366046905518,0.19785639643669128,0.18147045373916626,0.19785639643669128,1.0013731718063354,0.5132147669792175,0.42290645837783813,0.5132147669792175,1.0640504360198975,0.23207761347293854,0.2734966278076172,0.23207761347293854,1.0118958950042725,0.6091020107269287,0.738227903842926,0.6091020107269287,1.0571378469467163,0.8128418922424316,0.832101047039032,0.8128418922424316,1.2219820022583008,0.7258812189102173,0.5361903309822083,0.7258812189102173,0.9468413591384888,0.5411719679832458,0.9388693571090698,0.5411719679832458,1.0975160598754883,0.16767440736293793,0.10210622847080231,0.16767440736293793,0.31892094016075134],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"# ...

# %%
plot_temporal_evolution(xx)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

def plot_temporal_evolution(data, skill_name, highlight_start, highlight_end):
    # Assuming 'data' contains the output of the 'infer_job_skills' function

    # Filter the data for the specific skill
    skill_data = data[data['tail'] == skill_name]

    # Group the filtered data by the date and calculate the average score (or other relevant statistics)
    grouped_data = skill_data.groupby('date')['score'].mean().reset_index()

    highlight_start_date = pd.to_datetime(highlight_start)
    highlight_end_date = pd.to_datetime(highlight_end)

    # Create a line chart
    plt.figure(figsize=(12, 6))
    plt.plot(grouped_data['date'], grouped_data['score'], marker='o', linestyle='-')

    #plt.axvline(x=highlight_start_num, color='lightcoral', linestyle='--', label='Highlight Start')
    #plt.axvline(x=highlight_end_num, color='lightcoral', linestyle='--', label='Highlight End')
    #plt.axhline(y=0, xmin=highlight_start_num, xmax=highlight_end_num, color='red', linestyle='--', label='Highlighted Range')
    #plt.axvspan(highlight_start, highlight_end, facecolor='red', alpha=0.5, label='Highlighted Range')
    #plt.fill_between(grouped_data['date'], grouped_data['score'], where=((grouped_data['date'] >= highlight_start) & (grouped_data['date'] <= highlight_end)),
                      #color='red', alpha=0.5, label='Highlighted Range')

    highlight_mask = (grouped_data['date'] >= highlight_start) & (grouped_data['date'] <= highlight_end)
    plt.fill_between(grouped_data['date'][highlight_mask], grouped_data['score'][highlight_mask], color='red', alpha=0.5, label='Highlighted Range')
    # Customize the plot
    #plt.title(f'Temporal Evolution of {skill_name} Skill')
    plt.xlabel('Date')
    plt.ylabel('Average Score')  # You can customize this label based on your data


    #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

    # Display the plot
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Example usage:
# temporal_data = infer_job_skills(model, 'Job_Title', 'has_skill', ent_df, rel_df, '01/01/2010', '01/01/2025')
# plot_temporal_evolution(temporal_data, 'Python')  # Replace 'Python' with the skill you want to visualize

# %%
xx = infer_job_skills(model = inf_model, job_title = 'Ingénieurs Consultants en Informatique de Gestion',rel = '_requires',
           ent_df = ent_df, rel_df = rel_df, start_time = '1/1/2010', end_time='1/1/2025')
plot_temporal_evolution(xx, 'data analysis', '1/1/2023', '1/1/2025')
# Out:
# len(tail_ents):  730

# %%
#xx = infer_job_skills(model = inf_model, job_title = 'Ingénieurs Consultants en Informatique de Gestion',rel = '_requires',
           #ent_df = ent_df, rel_df = rel_df, start_time = '1/1/2010', end_time='1/1/2025')
#plot_temporal_evolution(xx, 'java')
# Out:
# len(tail_ents):  730
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-32730d7deb30> in <cell line: 3>()
#       1 xx = infer_job_skills(model = inf_model, job_title = 'Ingénieurs Consultants en Informatique de Gestion',rel = '_requires',
#       2            ent_df = ent_df, rel_df = rel_df, start_time = '1/1/2010', end_time='1/1/2025')
# ----> 3 plot_temporal_evolution(xx, 'java')
#
# TypeError: plot_temporal_evolution() missing 2 required positional arguments: 'highlight_start' and 'highlight_end'

# %% [markdown]
# ## inference from 1 job title

# %%
xx = infer_job_skills(model = inf_model, job_title = 'Production Leader',rel = '_requires',
           ent_df = ent_df, rel_df = rel_df, start_time = '1/1/2010', end_time='1/1/2025')
# Out:
# len(tail_ents):  730

# %%
# Group the data by Store and Product Category
grouped = xx.groupby(['head', 'rel', 'tail'])
# Calculate the rolling window statistics
rolling_avg = grouped['score'].rolling(window=5).mean()

# Add the rolling average column to the original dataframe
xx['Rolling Average'] = rolling_avg.reset_index(drop=True)

# %%
xx_pivot = pd.pivot_table(xx, values='Rolling Average', index='tail', columns='date')
xx_pivot = xx_pivot.rename_axis(index='Skills').rename_axis(columns='Date', axis=1)

# %%
example_piv = xx_pivot[xx_pivot.index.isin(["système de gestion", "gestion financière", "gérer les risques",'tableau', 'systèmes de stockage', 'database', 'gestion du personnel', 'assurer la gestion administrative', 'data analysis', 'travail d\'équipe', 'leadership', 'java'])]

# %%
sns.heatmap(example_piv, cmap=sns.cubehelix_palette(as_cmap=True), annot=False)
# Out:
# <Axes: xlabel='Date', ylabel='Skills'>

# %%
custom_x_labels = ['Management system', 'Finacial management', 'Risk management', 'Tableau', 'Storage system', 'database', 'staff management', 'ensure administrative management', 'data analysis', 'Team work', 'leadership', 'java']
plt.yticks(ticks=range(len(custom_x_labels)), labels=custom_x_labels)
# Out:
# ([<matplotlib.axis.YTick at 0x7fd9eb03c970>,
#   <matplotlib.axis.YTick at 0x7fd9eb03c310>,
#   <matplotlib.axis.YTick at 0x7fd9eb01b310>,
#   <matplotlib.axis.YTick at 0x7fd9eaf72c20>,
#   <matplotlib.axis.YTick at 0x7fd9eae70940>,
#   <matplotlib.axis.YTick at 0x7fd9eae71120>,
#   <matplotlib.axis.YTick at 0x7fd9eb03f8b0>,
#   <matplotlib.axis.YTick at 0x7fd9eae71870>,
#   <matplotlib.axis.YTick at 0x7fd9eae72050>,
#   <matplotlib.axis.YTick at 0x7fd9eae72830>,
#   <matplotlib.axis.YTick at 0x7fd9eae73010>,
#   <matplotlib.axis.YTick at 0x7fd9eb03fcd0>],
#  [Text(0, 0, 'Management system'),
#   Text(0, 1, 'Finacial management'),
#   Text(0, 2, 'Risk management'),
#   Text(0, 3, 'Tableau'),
#   Text(0, 4, 'Storage system'),
#   Text(0, 5, 'database'),
#   Text(0, 6, 'staff management'),
#   Text(0, 7, 'ensure administrative management'),
#   Text(0, 8, 'data analysis'),
#   Text(0, 9, 'Team work'),
#   Text(0, 10, 'leadership'),
#   Text(0, 11, 'java')])

# %% [markdown]
# # Second job

# %%
xx = infer_job_skills(model = inf_model, job_title = 'Ingénieurs Consultants en Informatique de Gestion', rel = '_requires',
           ent_df = ent_df, rel_df = rel_df, start_time = '1/1/2010', end_time='1/1/2025')
# Out:
# len(tail_ents):  730

# %%
# Group the data by Store and Product Category
grouped = xx.groupby(['head', 'rel', 'tail'])
# Calculate the rolling window statistics
rolling_avg = grouped['score'].rolling(window=5).mean()

# Add the rolling average column to the original dataframe
xx['Rolling Average'] = rolling_avg.reset_index(drop=True)

# %%
xx_pivot = pd.pivot_table(xx, values='Rolling Average', index='tail', columns='date')
xx_pivot = xx_pivot.rename_axis(index='Skills').rename_axis(columns='Date', axis=1)

# %%
example_piv = xx_pivot[xx_pivot.index.isin(["système de gestion", "gestion financière", "gérer les risques", 'tableau', 'systèmes de stockage', 'database', 'gestion du personnel', 'assurer la gestion administrative', 'data analysis', 'travail d\'équipe', 'leadership', 'java'])]

# %%
sns.heatmap(example_piv, cmap=sns.cubehelix_palette(as_cmap=True), annot=False)
# Out:
# <Axes: xlabel='Date', ylabel='Skills'>

# %% [markdown]
# ## Ideas
# - get the scores of job x with all hard skills during a time period
# - see the correlation between time series in order to establish skills that are demended in similar times

# %% [markdown]
# ## Line Chart

# %%
analyse des données

système de gestion',
       'selenium', 'veiller au respect des normes', 'prise en main',
       'mener des études', 'aménagement du territoire',
       'organisation du travail', 'contribuer au développement',
       'software', 'gérer les risques', 'autres services',
       'gammes de produits', 'gestion financière

"système de gestion", "gestion financière", "gérer les risques"

# %%
xx['tail'].unique()
# Out:
# array(['assurer la formation du personnel', 'conseils juridiques',
#        'database', 'gestion de la sécurité', 'utiliser',
#        'intégrer une structure', 'projets de développement',
#        "participer à l'élaboration des modules de formation juridique",
#        'nouveau produit', 'assurer un suivi régulier',
#        'projets de construction',
#        'déployer les processus en matière de ressources humaines',
#        'différentes étapes', 'superviser les audits internes et externes',
#        'animation commerciale', 'traitement des dossiers',
#        'assurer la gestion administrative', 'gestion de stock',
#        'contribuer au développement du chiffre', 'contrôle de la qualité',
#        'veiller au contrôle', 'accompagner le directeur',
#        'participer à la conception', 'relations avec les partenaires',
#        'évolution professionnelle', 'l’espace', 'expression orale',
#        'opérations comptables', 'gestion de compte',
#        'traduire les textes de lois relatifs', 'traitement des demandes',
#        'réaliser des articles', 'centos', 'prise de décision',
#        'techniques de modélisation', 'logiciels comptables',
#        'effectuer les tests unitaires', 'gestion de la trésorerie',
#        'golf', 'interaction', 'suivi commercial', 'assurer le classement',
#        'acquérir des compétences', 'tableau',
#        'réaliser des analyses techniques', 'gestion du personnel',
#        'gestion du changement', 'documents administratifs',
#        'l’utilisation', 'segmentation',
#        'assurer la pré-vente des produits', 'identifier les risques',
#        'assurer un reporting régulier', 'contrôle technique',
#        'activités quotidiennes',
#        'assurer la tenue de la comptabilité générale',
#        'mettre en place une approche de service entièrement',
#        'assurer la maintenance du parc', "règles d'hygiène",
#        'organiser les déplacements', 'tenir les livres comptables',
#        "assurer l'accueil physique", 'développer votre carrière',
#        'haute qualité', 'suivre les réalisations', 'monitoring',
#        "assurer l'accueil de la clientèle", 'anglais opérationnel',
#        'support', "démarche d'amélioration", 'procédures judiciaires',
#        'scanner', 'éléments nécessaires', 'analyse des données',
#        'audit interne', 'code source', 'interface utilisateur',
#        'plan de marketing', 'génie mécanique', 'marchés financiers',
#        'mettre en œuvre les moyens', 'twitter', 'veiller à la sécurité',
#        'ressources humaines', 'modes opératoires',
#        'proposer des solutions techniques', 'temps réel', 'segment',
#        "assurer l'accueil physique des visiteurs", 'questions relatives',
#        'qualité de l’', 'surveiller la collection', 'nouveaux produits',
#        'environnement de travail', 'bonne utilisation',
#        'normes de sécurité', 'assurer le suivi des fournisseurs',
#        'commercialiser des produits',
#        'développer vos compétences techniques', 'régler les litiges',
#        'techniques de vente par téléphone',
#        'gestion des ressources humaines',
#        'négocier avec des interlocuteurs', 'conditions de sécurité',
#        'assurer le suivi relationnel', 'réaliser des maquettes',
#        'rendre compte', 'flux', 'nouveau projet',
#        'gestion administrative', 'premier niveau', 'bonne pratique',
#        'gérer un portefeuille clients', 'material', 'stations de pompage',
#        'organiser les événements', 'différents services',
#        'prendre des responsabilités',
#        'assurer le suivi des tableaux de bords',
#        'définition de la politique', 'documentation',
#        'assurer la formation des patients', 'certificate',
#        'analyse fonctionnelle', 'normes internationales',
#        'optimiser les moyens de planification', 'maintenance préventive',
#        'sites internet', 'besoins spécifiques', 'site industriel',
#        'gérer l’', "gérer l'escalade des problèmes",
#        'national et international', 'langages de programmation',
#        'gamme de produit', "gouvernance d'entreprise",
#        'organiser des réunions', 'informer les clients', 'workflow',
#        'réaliser les prestations topographiques', 'logiciel de gestion',
#        'effectuer le remplacement des éléments défectueux',
#        'suivre la fabrication en fonction de ces objectifs',
#        'actions marketing',
#        'définir les objectifs de la dsi en cohérence',
#        'optimiser le rapport qualité', 'outils bureautiques',
#        'data analysis', 'shell', 'jouer un rôle', 'anglais technique',
#        'mise en place', 'documents comptables', 'préparer les dossiers',
#        'protection des données', 'indicateurs clés de performance',
#        'accompagner leur montée en compétences', 'gérer les projets',
#        'advertising', 'bases de données', 'grand public',
#        'identifier les besoins de formation', 'gestion commerciale',
#        'organisation personnelle', 'équipe technique', 'linux',
#        'génie logiciel', 'eclipse',
#        'intervenir dans le recrutement des participants,',
#        'gestion comptable', 'compiler', 'ressources financières',
#        'gestion des flux', 'stratégie financière', 'mettre à jour',
#        'actes juridiques', 'planning de production',
#        'analyser le potentiel de clients',
#        'effectuer les déclarations fiscales',
#        'appliquer les protocoles de vente',
#        'veiller au respect des normes de sécurité',
#        'gérer les déclarations fiscales', 'service client',
#        'différentes instances', 'assurer une veille réglementaire',
#        'exploiter des systèmes', 'garantir la satisfaction du client',
#        'commercialisation de produits', 'travailler sous pression',
#        'système de management', 'situation de travail',
#        'gestion administrative du personnel', 'faire preuve',
#        'optimiser le dispositif de contrôle', 'bonne exécution',
#        'l’accès', 'développement durable', 'mysql',
#        'opérations commerciales',
#        'réaliser les reportings comptables et financiers',
#        'fonctionnement des machines', 'mettre au point',
#        'lieu de travail', 'application de la législation',
#        'bonnes pratiques', 'robot', 'entrées et sorties',
#        'objectifs de vente', 'logiciels de gestion',
#        'stratégie de marketing', 'génie civil', 'marchés publics',
#        'gérer les produits pharmaceutiques', 'marché potentiel',
#        'clients, fournisseurs', 'programme de formation', 'journalisme',
#        'ressources nécessaires', 'analyser les risques',
#        'archiver les documents de manière', 'réseau de distribution',
#        'assistance technique', 'variables', 'l’élaboration',
#        'matériaux de construction', 'appel d’offres',
#        'assurer une veille technique', 'workload',
#        'développement personnel', 'l’environnement', 'outil de gestion',
#        "services de l'entreprise", 'aspects financiers',
#        'tests psychotechniques', 'outils de production',
#        'préparer les devis', 'développer le chiffre d’affaires',
#        'normes juridiques', 'assurer la coordination',
#        'vente de produits',
#        'assurer le suivi dans le respect des procédures',
#        'expertise technique',
#        "réaliser l'acquisition et la valorisation de documents",
#        'rédiger les produits nouveaux', "gestion d'entreprise",
#        'élaboration de programmes', 'étude de marché',
#        'installations techniques', 'gestion des dossiers',
#        'identité visuelle', 'recherche documentaire',
#        'technique et économique', 'faire le suivi',
#        'politique commerciale', 'effectuer une analyse',
#        'respecter les règles', 'commerce', 'développer des systèmes',
#        'portefeuille client', 'création de contenu',
#        'développer vos compétences', 'impacts environnementaux',
#        'utiliser des outils', 'collaboration', 'formation technique',
#        'détecter les litiges', 'javascript',
#        'développer vos connaissances', 'communications',
#        'politique de communication',
#        'avoir les connaissances nécessaires',
#        'présenter les offres commerciales', 'java',
#        'assurer la communication avec les contacts internes',
#        'identifier les sources de progrès', 'équipes de développement',
#        'assurer la qualité', 'assurer le suivi des traitements',
#        'centre d’appel',
#        'organiser les déplacements du directeur et des collaborateurs',
#        'release', 'electrical engineering', 'forums',
#        'techniques de négociation', 'pose', 'mise en oeuvre',
#        "analyser les demandes d'achat", 'éléments graphiques',
#        'impression numérique', 'gestion de projets',
#        'fidéliser la clientèle', "assister l'assistante de direction",
#        'systèmes de stockage', 'travaux neufs', 'outils de gestion',
#        'assurance qualité', 'l’usage',
#        'mettre à jour les fichiers stocks',
#        'suivre des indicateurs de performances des processus clés',
#        'activité commerciale', 'génie climatique',
#        'réseaux de distribution', 'analyser la législation',
#        'former le personnel', 'entretenir une relation commerciale',
#        'propositions techniques', 'réalisation des plans',
#        'contrôler les produits peinture à réception',
#        'sources d’information', 'support administratif',
#        'équipes techniques', 'assurer un reporting',
#        'consignes de sécurité', 'assister des utilisateurs',
#        'application du règlement', 'business intelligence',
#        'points de vente', 'construction métallique',
#        'analyser les besoins du marché', 'fonctionnement du service',
#        'administratif et financier', 'business process', 'simulation',
#        'suivi des dossiers', 'gestion de projet',
#        'conformité avec les normes', 'mettre en place un système',
#        'stratégies de communication', 'imagerie médicale',
#        'mettre en œuvre', 'business', 'analyser les données',
#        'fiches techniques', "chiffre d'affaires", 'animer des réunions',
#        'devise', 'règles de gestion', 'mettre à profit votre savoir',
#        'leadership', 'différents éléments', 'étude de faisabilité',
#        'communiquer avec les membres de votre équipe',
#        'service financier', 'outils de communication', 'base de données',
#        'médias sociaux', 'assurer la gestion commerciale',
#        'participer à l’élaboration des appels', 'prise en charge',
#        'assurer le reporting financier', "contrôler la main d'œuvre",
#        'gérer et développer un portefeuille', 'techniques de réalisation',
#        'clients dans le cadre', 'demandes des clients',
#        'normes de qualité', 'design',
#        "participer à l'élaboration des offres", 'gérer un projet btp',
#        'campagne publicitaire', 'science politique',
#        'activités de service', 'respect des procédures',
#        'preuve d’esprit', 'nettoyer la salle',
#        'mettre en place des processus proactifs',
#        'maintenance corrective et préventive',
#        'sélectionner les fournisseurs', 'server', 'compose',
#        'maintenance, méthodes', 'mener les projets à terme',
#        'analyser le contenu des documents', 'techniques de management',
#        'commerce international', 'effectuer des visites techniques',
#        'construire le cadre technique',
#        "réaliser les différents types d'audits", 'prendre en charge',
#        'conseiller le client sur les formalités de circulation internationale',
#        'c#', 'vendre notre gamme innovante', 'droit social',
#        'clients potentiels', 'contribuer à la mise', 'mises à jour',
#        'différentes opérations', 'matière de sécurité',
#        'gérer les priorités de votre activité',
#        'participer au développement', 'gestion des déchets',
#        'électriques, électroniques', 'portefeuille clients et prospects',
#        'assurer une assistance technique', 'ligne de production',
#        'veiller au respect des engagements', 'anglais véritable',
#        'conseiller la clientèle', 'composer', 'traitement de données',
#        'participer à l’', 'envoyer votre dossier', 'suivre le processus',
#        'conduite de projet', 'appui technique',
#        'contribuer à la réalisation des études préalables',
#        'informer le client', 'systèmes d’exploitation',
#        'procédures de travail', 'stratégie de fidélisation',
#        'accueillir le client', 'états financiers',
#        'participer à la réalisation des objectifs',
#        'représenter la société', 'droit international',
#        'suivi des dossiers contentieux', 'indicateurs de gestion',
#        'assurer un haut niveau de qualité', 'outils de suivi',
#        'assurer la vente des packs', 'comptes rendus',
#        'organiser le travail des équipes sur le projet',
#        'équipe de vente', 'problèmes techniques', 'faire face',
#        'superviser les activités du service', 'assurer la mise en œuvre',
#        "travail d'équipe", 'monde entier', 'projets d’aménagement',
#        'identifier les causes des problèmes', 'système de gestion',
#        'selenium', 'veiller au respect des normes', 'prise en main',
#        'mener des études', 'aménagement du territoire',
#        'organisation du travail', 'contribuer au développement',
#        'software', 'gérer les risques', 'autres services',
#        'gammes de produits', 'gestion financière',
#        'analyser les problèmes des arrêts des convoyeurs',
#        'projet immobilier', 'procédés de fabrication',
#        'contrôler la conformité de procédés', 'matière de gestion',
#        'relations internationales', 'action commercial', 'languages',
#        'l’installation', 'développer un portefeuille clients',
#        'secteur bancaire', 'projet de développement',
#        'réaliser les audits qualité', 'techniques de nettoyage',
#        'déclarations fiscales et sociales', 'hygiène et sécurité',
#        'tableau de bord', 'fidéliser le portefeuille',
#        'promouvoir un projet', 'atteindre des objectifs',
#        'différents types', 'réseaux sociaux',
#        'environnement de développement',
#        'mettre en place une approche de service', 'normes qualité',
#        'prendre en compte', 'base de donnée',
#        'suivre le déroulement de la mission', 'appels d’offres',
#        'évaluation des risques', 'identifier les opportunités',
#        'assurer le filtrage', 'analyser les résultats de son activité',
#        'intégrer une structure ambitieuse', 'dispositifs médicaux',
#        'gestion des risques', 'marketing direct',
#        'service à la clientèle', 'mettre à profit votre expérience',
#        'compétences professionnelles',
#        'préparer les documents nécessaires', 'évolution du marché',
#        'réseau télécom', 'coordonner la maintenance préventive',
#        'mise à jour', 'stratégie commerciale',
#        'développer le portefeuille', 'accompagner les projets',
#        'qualité de service', 'procédures et techniques',
#        'techniques de massage', 'assurer la correction des articles',
#        'engineering', 'participer à la gestion des moyens logistiques',
#        'réduire les risques', 'marketing',
#        'contrôler la qualité des prestations des fournisseurs',
#        'physico-chimiques', 'prendre des initiatives',
#        'conseiller vos clients', 'actions de communication',
#        'session de recrutement', 'mode', 'compétences techniques',
#        'entretenir le vivier des candidatures',
#        'organiser la réception des employés •',
#        'mettre en pratique votre background théorique',
#        'anglais professionnel', 'assister à la production',
#        'former une équipe', 'offre commerciale', 'entretien du matériel',
#        'établir les plans', 'propriété intellectuelle',
#        'gérer la relation', 'effectuer des plans d’exécution de détail',
#        'action commerciale', 'normes comptables', 'gestion du stress',
#        'l’industrie', 'rédiger des spécifications organiques', 'library',
#        'satisfaction des clients', 'veille réglementaire',
#        'langage de programmation', 'besoins du client',
#        'rapprochement bancaire', 'nouvelles technologies',
#        'travail d’équipe', 'référencement naturel',
#        'elaborer le concept visuel', 'accueillir les visiteurs',
#        'environnement international', 'import/export', 'l’innovation',
#        'nouveaux clients', 'promouvoir les produits',
#        'comprendre leurs besoins',
#        "proposer des initiatives/projets d'amélioration pour l'agence",
#        'méthodes de traitement', 'windows', 'milieu industriel',
#        'sites industriels', 'spécifications fonctionnelles',
#        'assurer la réalisation des objectifs', 'réseau social',
#        'sciences politiques', 'zone géographique',
#        'gérer les contrats avec les patients', 'équipement médical',
#        'debugging', 'outils d’analyse', 'organiser les voyages',
#        'contrat de travail', 'conditions de travail',
#        'techniques de vente', 'maintenance du matériel',
#        'analyse financière', 'apporter un support administratif',
#        'relation avec le client', "technologies de l'information",
#        'déposer vos cv', 'relations commerciales', 'travaux pratiques',
#        'accounting', 'actions correctives',
#        'déterminer les besoins du chantier', 'sécurité sociale',
#        'bonne gestion', 'systèmes d’information',
#        'effectuer les taches requises',
#        "mettre à jour les systèmes d'informations",
#        's’adapter aux changements', 'oracle', 'directeur artistique',
#        'gérer la résolution des incidents complexe', 'nouveaux contrats',
#        'assumer la responsabilité', 'assurer une veille concurrentielle',
#        'réseau commercial', 'objectifs commerciaux',
#        'évolution technique', 'gérer les missions suivantes',
#        'site internet', 'préparer les projets', 'modes de fonctionnement',
#        'communiquer aux professionnels', 'cadre de projets',
#        'marché national', 'gérer les achats', 'visual studio',
#        'conseil juridique', 'l’entretien', 'négocier les prix',
#        'travail en équipe', 'box', 'mobile', 'tâches administratives',
#        'assurer une qualité optimale', 'aménagement urbain',
#        'prestation de services', 'projet de construction',
#        'développer les compétences',
#        'maintenance assistée par ordinateur', 'créer un environnement',
#        'assurer le suivi des relations', 'plate-forme',
#        'relever des défis', 'gérer les comptes de nos abonnés',
#        'cahier des charges', 'mettre en place des actions correctives',
#        'l’exploitation', 'mettre en place un réseau de distribution',
#        'moyens nécessaires', 'wimax', 'diagram', 'cycle de vie',
#        "proposer des axes d'amélioration", 'qualité de prestation',
#        'bon état', 'contrôler les résultats', 'contrôle qualité',
#        'développer votre sens du contact',
#        "effectuer le suivi de l'inventaire", 'mettre en oeuvre',
#        'project management', 'définition des besoins',
#        'superviser le contrôle de gestion', 'eau potable',
#        'assister les départements internes', "billets d'avion",
#        'security', 'traitement des données', "travailler dans l'urgence",
#        'planification de la production', 'travail quotidien',
#        'collecter les informations', 'droit des assurances',
#        'techniques en matière', 'questions juridiques',
#        'animer les réunions de production et de résolution',
#        'grande consommation', 'procédures de contrôle', 'l’éthique',
#        'assurer la qualité de notre production ainsi',
#        'organiser les réunions', 'améliorer le pilotage des activités',
#        'processus métier', "systèmes d'information", 'tableaux de bord',
#        'améliorer le modèle de chaîne', 'nouveaux marchés',
#        'services sociaux', 'matières premières', 'planifier',
#        'chambres froides', 'faire partie d’une entreprise',
#        'cahiers des charges', 'l’organisation',
#        'gérer les relations avec les partenaires',
#        'résolution de problèmes', 'analyser le marché',
#        'améliorer la capitalisation', "méthodes d'analyse",
#        'technique et financier', 'ai', 'gérer votre processus',
#        'logiciels de bureautique', 'déploiement de solutions',
#        'assurer une bonne disponibilité du parc', 'génie industriel',
#        'mécanique', 'finance', 'mise en œuvre', 'ios',
#        'participer à la définition', 'gérer les priorités',
#        'biens immobiliers', 'travailler en équipe', 'framework',
#        'fidéliser nos clients', 'aspects techniques',
#        'apporter une solution professionnelle', 'procédures comptables',
#        'l’administration', 'définir des objectifs', 'chef',
#        'projets immobiliers', 'fidéliser votre portefeuille',
#        'suivre la réalisation des travaux', 'informations techniques',
#        'gestion des déplacements', 'réaliser les études nécessaires',
#        'veiller à la satisfaction', 'contenu marketing',
#        'systèmes informatiques', 'espaces publicitaires',
#        'fidéliser vos clients', 'passation de tests',
#        'atteinte des objectifs', 'agence de publicité',
#        'application des procédures', 'suivre les indicateurs',
#        'effectuer divers travaux electriques dans les chantiers',
#        'réaliser des campagnes de télévente en assurance portant',
#        'gamme de produits', 'indicateurs de performance',
#        'outils spécifiques', 'fusion', 'assurer le suivi des ventes',
#        'espace de travail', 'fonctions administratives',
#        'techniques de communication', 'data processing',
#        'droit du travail', 'suivre le dossier du client',
#        'système d’information', 'gérer des projets', 'formation de base',
#        'documentation technique', 'font', 'publics ou privés',
#        'assurer les tâches administratives',
#        'mettre à jour la fiche de stock', 'outils de développement',
#        'mener des négociations commerciales'], dtype=object)
